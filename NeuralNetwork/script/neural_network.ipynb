# %%
# %% [markdown]
# Import necessary libraries
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Subset
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error
import json
from tqdm import tqdm
import torch.nn.functional as F
import joblib
import os
import sys
import numpy as np
from torch.utils.data import DataLoader, random_split
import time  # For timing

# Set matplotlib to use a non-interactive backend
plt.switch_backend('Agg')

# Get the notebook's directory
notebook_dir = os.getcwd()
# Add parent directory to path
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)

# %% [markdown]
# Checking if the MPS (Metal Performance Shaders) backend is available

# %%
# Check if MPS is available
if not torch.backends.mps.is_available():
    raise RuntimeError("MPS device not available. Check if PyTorch and macOS set up correctly.")

# Set the device to MPS
device = torch.device("mps")  # Use GPU on M2 Pro

# %%
# %%
# Import the objective function
from QKD_Functions.QKD_Functions import (
    calculate_factorial, calculate_tau_n, calculate_eta_ch, calculate_eta_sys,
    calculate_D_mu_k, calculate_n_X_total, calculate_N, calculate_n_Z_total,
    calculate_e_mu_k, calculate_e_obs, calculate_h, calculate_lambda_EC,
    calculate_sqrt_term, calculate_n_pm, calculate_S_0, calculate_S_1,
    calculate_m_mu_k, calculate_m_pm, calculate_v_1, calculate_gamma,
    calculate_Phi, calculate_LastTwoTerm, calculate_l, calculate_R,
    experimental_parameters, other_parameters, calculate_key_rates_and_metrics,
    penalty, objective,
)
# Out:
# /Users/daai6ga1hou2/anaconda3/envs/qkd-training_set/lib/python3.9/site-packages/tqdm_joblib/__init__.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Define a safe wrapper for the objective function
def safe_objective(params, L, nx, **kwargs):
    try:
        key_rate = objective(params, L, nx, **kwargs)[0]
        if np.isnan(key_rate) or np.isinf(key_rate):
            print(f"objective returned NaN/Inf for params {params}, L={L}, nx={nx}: {key_rate}")
            return 0
        if key_rate < 0:
            print(f"objective returned negative key rate {key_rate} for params {params}, L={L}, nx={nx}")
            return 0
        return key_rate
    except Exception as e:
        print(f"Error in objective for params {params}, L={L}, nx={nx}: {e}")
        return 0 # Replace with 1e-8 on error

# Define a wrapper for the objective function to get raw key rates
# Define a wrapper for the objective function to get raw key rates
# def safe_objective(params, L, nx, **kwargs):
#     try:
#         key_rate = objective(params, L, nx, **kwargs)[0]
#         if np.isnan(key_rate) or np.isinf(key_rate):
#             print(f"objective returned NaN/Inf for params {params}, L={L}, nx={nx}: {key_rate}")
#         elif key_rate < 0:
#             print(f"objective returned negative key rate for params {params}, L={L}, nx={nx}: {key_rate}")
#         return key_rate  # Return the raw key rate
#     except Exception as e:
#         print(f"Error in objective for params {params}, L={L}, nx={nx}: {e}")
#         return float('nan')  # Return NaN on error to propagate the issue
    
# %%
# Load dataset
with open('../Training_Data/n_X/good/cleaned_combined_datasets.json', 'r') as f:
    data_by_nx = json.load(f)

print(f"The overall dataset contains {len(data_by_nx)} entries (number of unique n_X values).")

first_key = list(data_by_nx.keys())[0]
print(f"The number of entries associated with the first key ({first_key}) is: {len(data_by_nx[first_key])}")


# Flatten the data structure and filter
cleaned_data = []
for n_x, entries in data_by_nx.items():
    cleaned_data.extend([
        item for item in entries
    if item["key_rate"] > 0 and item["e_1"] * 100 <= 200
])

# Optional: Verify the cleaned dataset
if not cleaned_data:
    print("No valid data after filtering.")
else:
    print(f"Filtered dataset contains {len(cleaned_data)} entries.")
    print("\nSample entry from the cleaned dataset:")
    print(json.dumps(cleaned_data[0], indent=2))
    print("\nNumber of unique n_X values:", len(data_by_nx))


# # Print the number of entries for each n_X before filtering
# for n_x in data_by_nx.keys():
#     print(f"Number of entries for n_X = {n_x}: {len(data_by_nx[n_x])}")


# # Define a safe wrapper for the objective function
# def safe_objective(params, L, nx, **kwargs):
#     try:
#         # Assuming objective returns (key_rate, other_metrics...) or just key_rate
#         result = objective(params, L, nx, **kwargs)
#         # Extract key_rate, handle tuple or single value returns
#         key_rate = result[0] if isinstance(result, (tuple, list)) and len(result) > 0 else result

#         # Check for NaN or negative rates (non-physical)
#         if not isinstance(key_rate, (int, float, np.number)) or np.isnan(key_rate) or key_rate < 0:
#             # Optional: Print only if you want to see these specific cases during debug
#             # print(f"objective returned invalid rate {key_rate} for params {params}, L={L}, nx={nx}")
#             return 0.0  # Return 0 for invalid rates
#         return float(key_rate) # Ensure it's a standard float

#     except (ValueError, TypeError, ZeroDivisionError, FloatingPointError) as e: # Catch common calculation errors
#         # Optional: Print calculation errors if needed during debug
#         # print(f"Calculation Error in objective for params {params}, L={L}, nx={nx}: {type(e).__name__} - {e}")
#         return 0.0 # Return 0 on calculation error

#     except Exception as e: # Catch any unexpected errors
#         print(f"Unexpected Error in objective for params {params}, L={L}, nx={nx}: {type(e).__name__} - {e}")
#         # You might want to print the traceback here for unexpected errors during debugging
#         # import traceback
#         # traceback.print_exc()
#         return 0.0 # Return 0 on unexpected error

# # Define a worker function suitable for starmap
# # (Ensure this matches the arguments used in your starmap calls)
# def safe_objective_starmap_worker(params, L, nx,
#                                 alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7,
#                                 epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16,
#                                 e_mis=5e-3, P_ap=0, n_event=1):
#     """Calls safe_objective with arguments suitable for starmap."""
#     return safe_objective(params, L, nx,
#                           alpha=alpha, eta_Bob=eta_Bob, P_dc_value=P_dc_value,
#                           epsilon_sec=epsilon_sec, epsilon_cor=epsilon_cor, f_EC=f_EC,
#                           e_mis=e_mis, P_ap=P_ap, n_event=n_event)
# Out:
# The overall dataset contains 6 entries (number of unique n_X values).
# The number of entries associated with the first key (10000.0) is: 736
# Filtered dataset contains 5310 entries.
#
# Sample entry from the cleaned dataset:
# {
#   "fiber_length": 0.0,
#   "e_1": 0.0,
#   "e_2": 6.221848749616356,
#   "e_3": 0.5,
#   "e_4": 4.0,
#   "key_rate": 0.00037995895580899045,
#   "optimized_params": {
#     "mu_1": 0.6126301275287198,
#     "mu_2": 0.13818683663411718,
#     "P_mu_1": 0.04604299826386499,
#     "P_mu_2": 0.6110117432731096,
#     "P_X_value": 0.414731486913827
#   }
# }
#
# Number of unique n_X values: 6

# %%
# def objective(params, L, nx, alpha, eta_Bob, P_dc_value, epsilon_sec, epsilon_cor, f_EC, e_mis, P_ap, n_event):
#     mu_1, mu_2, P_mu_1, P_mu_2, P_X = params
#     # Existing computations
#     eta_ch = calculate_eta_ch(L, alpha)
#     eta_sys = calculate_eta_sys(eta_ch, eta_Bob)
#     n_X_total = calculate_n_X_total(nx, P_X, eta_sys, P_dc_value)
#     e_obs = calculate_e_obs(...)  # Replace with actual computation
#     print(f"Debug for params={params}, L={L}, nx={nx}:")
#     print(f"eta_ch: {eta_ch}, eta_sys: {eta_sys}, n_X_total: {n_X_total}, e_obs: {e_obs}")
#     key_rate = calculate_R(...)  # Replace with actual computation
#     print(f"Raw key rate: {key_rate}")
#     return key_rate, None

# %%
# # Flatten the data structure and filter
# all_data = []
# for n_x, entries in data_by_nx.items():
#     for item in entries:
#         item['n_X'] = float(n_x)
#         all_data.append(item)

# # Filter the data
# filtered_data = [item for item in all_data if item["key_rate"] > 0 and item["e_1"] * 100 <= 200]
# print(f"Filtered dataset contains {len(filtered_data)} entries.")

# # Split into train+val (85%) and test (15%)
# train_val_data, test_data = train_test_split(filtered_data, test_size=0.15, random_state=42)
# print(f"Train+Val dataset: {len(train_val_data)} entries, Test dataset: {len(test_data)} entries.")

# # Further split train+val into train (70/85 ≈ 82.35%) and val (15/85 ≈ 17.65%)
# train_data, val_data = train_test_split(train_val_data, test_size=0.1765, random_state=42)
# print(f"Train dataset: {len(train_data)} entries, Val dataset: {len(val_data)} entries.")

# # Prepare training and validation datasets
# X_train = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in train_data])
# Y_train = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'],
#                      item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'],
#                      item['optimized_params']['P_X_value']] for item in train_data])

# X_val = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in val_data])
# Y_val = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'],
#                    item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'],
#                    item['optimized_params']['P_X_value']] for item in val_data])

# # Scale the data
# scaler = StandardScaler()
# X_train = scaler.fit_transform(X_train)
# X_val = scaler.transform(X_val)

# y_scaler = MinMaxScaler()
# Y_train = y_scaler.fit_transform(Y_train)
# Y_val = y_scaler.transform(Y_val)

# # Save the scalers
# joblib.dump(scaler, 'scaler.pkl')
# joblib.dump(y_scaler, 'y_scaler.pkl')

# # Create datasets and data loaders
# train_dataset = TensorDataset(torch.tensor(X_train, dtype=torch.float32), torch.tensor(Y_train, dtype=torch.float32))
# val_dataset = TensorDataset(torch.tensor(X_val, dtype=torch.float32), torch.tensor(Y_val, dtype=torch.float32))

# train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
# val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)

# %%
# # Flatten the data structure and filter
# cleaned_data = []
# for n_x, entries in data_by_nx.items():
#     filtered_entries = [item for item in entries if item["key_rate"] > 0 and item["e_1"] * 100 <= 200]
#     print(f"After filtering, n_X = {n_x} has {len(filtered_entries)} entries.")
#     cleaned_data.extend(filtered_entries)

# # Verify the cleaned dataset
# if not cleaned_data:
#     print("No valid data after filtering.")
# else:
#     print(f"Filtered dataset contains {len(cleaned_data)} entries.")
#     print("\nSample entry from the cleaned dataset:")
#     print(json.dumps(cleaned_data[0], indent=2))
#     print("\nNumber of unique n_X values:", len(data_by_nx))

X = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in cleaned_data])
Y = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'], item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'], item['optimized_params']['P_X_value']] for item in cleaned_data])

# # %%
# X = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in cleaned_data])
# Y = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'], item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'], item['optimized_params']['P_X_value']] for item in cleaned_data])

# %%
from sklearn.utils import shuffle

X, Y = shuffle(X, Y, random_state=42)

scaler = StandardScaler()
X = scaler.fit_transform(X)  # Fit and transform on training data

y_scaler = MinMaxScaler()  # Scale targets to [0, 1]
Y = y_scaler.fit_transform(Y)

# Save the scalers
joblib.dump(scaler, 'scaler.pkl')  # Save StandardScaler
joblib.dump(y_scaler, 'y_scaler.pkl')  # Save MinMaxScaler

print(f"X shape: {X.shape}, Y shape: {Y.shape}")
dataset = TensorDataset(torch.tensor(X, dtype=torch.float32), torch.tensor(Y, dtype=torch.float32))

# %%
# Split dataset into train and validation sets
train_size = int(0.8 * len(dataset))  # 80% for training
val_size = len(dataset) - train_size  # 20% for validation

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Data loaders with increased batch size
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
# Out:
# X shape: (5310, 4), Y shape: (5310, 5)

# %%
# %%
# Load evaluation data for n_X = 5e8
with open("../n_X/good/5e8_100_reordered_qkd_grouped_dataset_20250226_191349.json", 'r') as f:
    evaluation_dataset = json.load(f)

# Select target n_X for evaluation
target_nx = 5 * 100000000  # 5e8
nx_key = str(float(target_nx))
if nx_key not in evaluation_dataset:
    raise ValueError(f"No data found for n_X = {target_nx}")
evaluation_data = evaluation_dataset[nx_key]

# Verify the size of the evaluation dataset
print(f"Number of data points for n_X = {target_nx}: {len(evaluation_data)}")
# Out:
# Number of data points for n_X = 500000000: 100

# %%
# Extract evaluation fiber lengths and optimized parameters
fiber_lengths_un_seen = np.array([entry["fiber_length"] for entry in evaluation_data])
optimized_params_array_un_seen = np.array([list(entry["optimized_params"].values()) for entry in evaluation_data])

# Compute optimized key rates for evaluation
optimized_key_rates_un_seen = []
valid_indices_un_seen = []
for idx, (params, L) in enumerate(zip(optimized_params_array_un_seen, fiber_lengths_un_seen)):
    key_rate = safe_objective(params, L, target_nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
    if np.isnan(key_rate):
        print(f"NaN detected in optimized_key_rates_un_seen at index {idx} with params {params}, fiber_length={L}")
    else:
        optimized_key_rates_un_seen.append(key_rate)
        valid_indices_un_seen.append(idx)
optimized_key_rates_un_seen = np.array(optimized_key_rates_un_seen)

# Filter the evaluation data to exclude NaN key rates
fiber_lengths_un_seen = fiber_lengths_un_seen[valid_indices_un_seen]
optimized_params_array_un_seen = optimized_params_array_un_seen[valid_indices_un_seen]
# Out:
# objective returned negative key rate -2.5459075744215506e-31 for params [5.21125578e-01 3.37384994e-01 1.92634353e-01 6.63224253e-01
#  1.00000000e-12], L=189.89898989898992, nx=500000000
# objective returned negative key rate -1.0847670075212521e-30 for params [9.00000000e-01 4.09777073e-01 1.21908112e-01 6.52515070e-01
#  1.00000000e-12], L=191.91919191919195, nx=500000000
# objective returned negative key rate -1.0756742243147874e-30 for params [8.13544868e-01 2.57789157e-01 3.75126595e-01 1.07065241e-01
#  1.00000000e-12], L=193.93939393939394, nx=500000000
# objective returned negative key rate -5.9934352286340745e-31 for params [5.53278979e-01 2.55719551e-01 4.01755354e-01 4.61925236e-01
#  1.00000000e-12], L=195.95959595959596, nx=500000000
# objective returned negative key rate -8.89190788063512e-31 for params [7.59296721e-01 3.16646804e-02 3.70889007e-01 2.18637344e-01
#  1.00000000e-12], L=197.97979797979798, nx=500000000
# objective returned negative key rate -1.1490135538073274e-30 for params [6.73503745e-01 3.99482743e-01 3.28961560e-01 3.94124936e-01
#  1.00000000e-12], L=200.0, nx=500000000

# %%
# Prepare test inputs for evaluation (n_X = 5e8)
X_test_un_seen = []
for L in fiber_lengths_un_seen:
    e_1 = L / 100
    e_2 = -np.log10(6e-7)
    e_3 = 5e-3 * 100
    e_4 = np.log10(target_nx)
    X_test_un_seen.append([e_1, e_2, e_3, e_4])

X_test_un_seen = np.array(X_test_un_seen)
X_test_scaled_un_seen = scaler.transform(X_test_un_seen)
X_test_tensor_un_seen = torch.tensor(X_test_scaled_un_seen, dtype=torch.float32).to(device)
print(f"After filtering NaN in optimized_key_rates_un_seen, {len(optimized_key_rates_un_seen)} data points remain for n_X = 5e8.")
# Out:
# After filtering NaN in optimized_key_rates_un_seen, 100 data points remain for n_X = 5e8.

# %%
# %% [markdown]
# ### Prepare Evaluation Data for All n_X Values (10^4 to 10^9) Before Training

# Load the combined dataset
combined_file_path = '../Training_Data/n_X/good/cleaned_combined_datasets.json'
try:
    with open(combined_file_path, 'r') as f:
        combined_data = json.load(f)
    print(f"Loaded combined dataset with {len(combined_data)} n_X entries.")
except FileNotFoundError:
    raise FileNotFoundError(f"Combined dataset not found at {combined_file_path}.")
# Out:
# Loaded combined dataset with 6 n_X entries.

# %%
# Define the range of n_X values to evaluate
nx_values = [10**s for s in range(4, 10)]  # 10^4 to 10^9

# Dictionary to store evaluation data for each n_X
all_evaluation_data = {}

# %%
# # Prepare evaluation data from the test set
# nx_values = [10**s for s in range(4, 10)]
# all_evaluation_data = {}

# for nx in nx_values:
#     # Filter test data for this n_X
#     eval_data = [item for item in test_data if item['n_X'] == nx]
#     if not eval_data:
#         print(f"No test data found for n_X = {nx}. Skipping...")
#         continue
#     print(f"Extracted {len(eval_data)} test entries for n_X = {nx}.")

#     # Extract fiber lengths and optimized parameters
#     fiber_lengths = np.array([entry["fiber_length"] for entry in eval_data])
#     optimized_params_array = np.array([list(entry["optimized_params"].values()) for entry in eval_data])

#     # Compute optimized key rates
#     optimized_key_rates = []
#     valid_indices = []
#     for idx, (params, L) in enumerate(zip(optimized_params_array, fiber_lengths)):
#         key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7,
#                                   epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16,
#                                   e_mis=5e-3, P_ap=0, n_event=1)
#         if np.isnan(key_rate):
#             print(f"NaN detected in optimized_key_rates for n_X = {nx} at index {idx} with params {params}, fiber_length={L}")
#         else:
#             optimized_key_rates.append(key_rate)
#             valid_indices.append(idx)
#     optimized_key_rates = np.array(optimized_key_rates)

#     # Filter the evaluation data to exclude NaN key rates
#     fiber_lengths = fiber_lengths[valid_indices]
#     optimized_params_array = optimized_params_array[valid_indices]

#     # Prepare test inputs for evaluation
#     X_test = []
#     for L in fiber_lengths:
#         e_1 = L / 100
#         e_2 = -np.log10(6e-7)
#         e_3 = 5e-3 * 100
#         e_4 = np.log10(nx)
#         X_test.append([e_1, e_2, e_3, e_4])
#     X_test = np.array(X_test)
#     X_test_scaled = scaler.transform(X_test)
#     X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)

#     # Store evaluation data
#     all_evaluation_data[nx] = {
#         'fiber_lengths': fiber_lengths,
#         'optimized_params_array': optimized_params_array,
#         'optimized_key_rates': optimized_key_rates,
#         'X_test_tensor': X_test_tensor
#     }
#     print(f"After filtering NaN, {len(optimized_key_rates)} data points remain for n_X = {nx}.")

# %%
# Extract and prepare evaluation data for each n_X
for nx in nx_values:
    nx_key = str(float(nx))
    if nx_key not in combined_data:
        print(f"No data found for n_X = {nx} in the combined dataset. Skipping...")
        continue
    evaluation_data = combined_data[nx_key]
    print(f"Extracted {len(evaluation_data)} entries for n_X = {nx}.")

    # Extract fiber lengths and optimized parameters
    fiber_lengths = np.array([entry["fiber_length"] for entry in evaluation_data])
    optimized_params_array = np.array([list(entry["optimized_params"].values()) for entry in evaluation_data])

    # Compute optimized key rates
    optimized_key_rates = []
    valid_indices = []
    for idx, (params, L) in enumerate(zip(optimized_params_array, fiber_lengths)):
        key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
        if np.isnan(key_rate):
            print(f"NaN detected in optimized_key_rates for n_X = {nx} at index {idx} with params {params}, fiber_length={L}")
        else:
            optimized_key_rates.append(key_rate)
            valid_indices.append(idx)
    optimized_key_rates = np.array(optimized_key_rates)

    # Filter the evaluation data to exclude NaN key rates
    fiber_lengths = fiber_lengths[valid_indices]
    optimized_params_array = optimized_params_array[valid_indices]

    # Prepare test inputs for evaluation
    X_test = []
    for L in fiber_lengths:
        e_1 = L / 100
        e_2 = -np.log10(6e-7)
        e_3 = 5e-3 * 100
        e_4 = np.log10(nx)
        X_test.append([e_1, e_2, e_3, e_4])
    X_test = np.array(X_test)
    X_test_scaled = scaler.transform(X_test)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)

    # Store all evaluation data in a dictionary
    all_evaluation_data[nx] = {
        'fiber_lengths': fiber_lengths,
        'optimized_params_array': optimized_params_array,
        'optimized_key_rates': optimized_key_rates,
        'X_test_tensor': X_test_tensor
    }
    print(f"After filtering NaN, {len(optimized_key_rates)} data points remain for n_X = {nx}.")
# Out:
# Extracted 736 entries for n_X = 10000.
# After filtering NaN, 736 data points remain for n_X = 10000.
# Extracted 855 entries for n_X = 100000.
# After filtering NaN, 855 data points remain for n_X = 100000.
# Extracted 902 entries for n_X = 1000000.
# After filtering NaN, 902 data points remain for n_X = 1000000.
# Extracted 927 entries for n_X = 10000000.
# After filtering NaN, 927 data points remain for n_X = 10000000.
# Extracted 942 entries for n_X = 100000000.
# After filtering NaN, 942 data points remain for n_X = 100000000.
# Extracted 948 entries for n_X = 1000000000.
# After filtering NaN, 948 data points remain for n_X = 1000000000.

# %%
# %%
# Define the neural network model
class BB84NN(nn.Module):
    def __init__(self):
        super(BB84NN, self).__init__()
        self.fc1 = nn.Linear(4, 16)
        self.fc2 = nn.Linear(16, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 5)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Initialize model, loss, optimizer, and scheduler
model = BB84NN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, min_lr=1e-6)

# Lists to store metrics
train_losses = []
val_losses = []
learning_rates = []

# %%
def plot_keyrate_subplots(all_data, epoch, filename):
    """
    Plots key rates vs fiber length for multiple n_X values on separate subplots. all_data: dict with keys as n_X values and values containing fiber_lengths, optimized_key_rates, predicted_key_rates.
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True, sharey=True)
    fig.suptitle(f"Key Rates vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())  # Ensure n_X values are sorted

    for i, nx in enumerate(nx_values):
        if i >= 6:  # Limit to 6 subplots
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        predicted_key_rates = all_data[nx].get('predicted_key_rates', None)

        # Filter out NaN values
        valid_mask = ~(np.isnan(optimized_key_rates))
        if predicted_key_rates is not None:
            valid_mask &= ~np.isnan(predicted_key_rates)
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_key_rates = optimized_key_rates[valid_mask]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[valid_mask]

        # Find cutoff where optimized key rate becomes very small
        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_key_rates = optimized_key_rates[:cutoff_idx]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[:cutoff_idx]

        # Plot key rates with adjusted linestyles and transparency
        ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linestyle='-', linewidth=2.0, alpha=1.0)  # Thicker line, semi-transparent
        if predicted_key_rates is not None and len(predicted_key_rates) > 0:
            ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r', label='Predicted Key Rate', 
                    linestyle=':',
                    # linestyle=(0, (1, 10)),  # Short dash (1 point) to look like a dot, 10-point gap
                    linewidth=6.0, alpha=1.0) # Thicker line, fully opaque
        
                
        # Compute the exponent for nx (e.g., nx = 10000 -> exponent = 4)
        exponent = int(np.log10(nx))
        # Set the title with LaTeX formatting for 10^exponent
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Secret Key Rate per Pulse")

        ax.legend(loc='upper right')

    # Remove empty subplots
    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)

    print(f"Key rate subplots saved to {filename}")

# %%
def plot_parameters_subplots(all_data, epoch, filename):
    """
    Plots optimized and predicted parameters vs fiber length for multiple n_X values on separate subplots.
    all_data: dict with keys as n_X values and values containing fiber_lengths, optimized_params_array, predicted_params_array.
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True, sharey=True)
    fig.suptitle(f"Optimized and Predicted Parameters vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())

    param_labels = ['$P_X$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$\mu_1$', '$\mu_2$']
    colors = ['blue', 'orange', 'green', 'red', 'purple']

    # Store handles and labels for the shared legend
    handles, labels = [], []

    for i, nx in enumerate(nx_values):
        if i >= 6:
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_params_array = all_data[nx]['optimized_params_array']
        predicted_params_array = all_data[nx].get('predicted_params_array', None)

        # Filter out NaN values in key rates to align with key rate plots
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        valid_mask = ~(np.isnan(optimized_key_rates))
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_params_array = optimized_params_array[valid_mask]
        if predicted_params_array is not None:
            predicted_params_array = predicted_params_array[valid_mask]

        # Truncate based on key rate cutoff
        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates[valid_mask] <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_params_array = optimized_params_array[:cutoff_idx]
        if predicted_params_array is not None:
            predicted_params_array = predicted_params_array[:cutoff_idx]

        # Plot parameters with slight transparency for predicted lines
        for param_idx, (label, color) in enumerate(zip(param_labels, colors)):
            # Plot optimized line
            line_opt = ax.plot(fiber_lengths, optimized_params_array[:, param_idx], 
                               label=f'Optimized {label}', color=color, linestyle='-', linewidth=2.0, alpha=1.0)
            # Plot predicted line
            if predicted_params_array is not None:
                line_pred = ax.plot(fiber_lengths, predicted_params_array[:, param_idx], 
                                    label=f'Predicted {label}', color=color, linestyle=':', 
                                    linewidth=4.0, alpha=0.7)
            
            # Collect handles and labels only from the first subplot (i=0)
            if i == 0:
                handles.append(line_opt[0])
                labels.append(f'Optimized {label}')
                if predicted_params_array is not None:
                    handles.append(line_pred[0])
                    labels.append(f'Predicted {label}')

        # Compute the exponent for nx (e.g., nx = 10000 -> exponent = 4)
        exponent = int(np.log10(nx))
        # Set the title with LaTeX formatting for 10^exponent
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        
        ax.set_ylim(0.0, 1.0)
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Parameter Value")

    # Remove empty subplots
    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    # Add a single shared legend outside the entire grid
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.92, 0.5))

    # Adjust layout to make space for the legend on the right
    plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # Leave 10% space on the right for the shared legend
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"Parameter subplots saved to {filename}")

# %%
# def plot_absolute_differences_keyrate_and_parameters(fiber_lengths, optimized_key_rates, optimized_params_array,
#                                                     predicted_key_rates, predicted_params_array, epoch, filename,
#                                                     nx=None, threshold=1e-8):
#     """
#     Plots absolute differences of key rates and parameters for a specific n_X value.

#     Parameters:
#     - fiber_lengths: Array of fiber lengths (km).
#     - optimized_key_rates: Array of optimized key rates.
#     - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
#     - predicted_key_rates: Array of predicted key rates.
#     - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
#     - epoch: Epoch number or string (e.g., 'final_test').
#     - filename: Output filename for the plot.
#     - nx: The n_X value for the plot title (optional).
#     - threshold: Key rate threshold for physical cutoff (default: 1e-8).
#     """
#     # Start timing
#     plot_start_time = time.time()

#     # Filter out NaN values
#     valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
#     fiber_lengths = fiber_lengths[valid_mask]
#     optimized_key_rates = optimized_key_rates[valid_mask]
#     predicted_key_rates = predicted_key_rates[valid_mask]
#     optimized_params_array = optimized_params_array[valid_mask]
#     predicted_params_array = predicted_params_array[valid_mask]

#     # Find cutoff where optimized key rate becomes very small
#     cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
#     if len(cutoff_idx) > 0:
#         cutoff_idx = cutoff_idx[0]
#     else:
#         cutoff_idx = len(fiber_lengths)

#     fiber_lengths = fiber_lengths[:cutoff_idx]
#     optimized_key_rates = optimized_key_rates[:cutoff_idx]
#     predicted_key_rates = predicted_key_rates[:cutoff_idx]
#     optimized_params_array = optimized_params_array[:cutoff_idx]
#     predicted_params_array = predicted_params_array[:cutoff_idx]

#     # Compute absolute differences
#     key_rate_abs_diff = predicted_key_rates - optimized_key_rates
#     param_abs_diffs = predicted_params_array - optimized_params_array
#     param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']

#     # Create figure with 6 subplots (2 rows, 3 columns)
#     fig = plt.figure(figsize=(18, 10))
#     gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    

#     # Plot absolute differences for parameters
#     for i in range(5):
#         row = (i + 1) // 3
#         col = (i + 1) % 3
#         ax = fig.add_subplot(gs[row, col])
#         ax.plot(fiber_lengths, param_abs_diffs[:, i], 'b-', label=f'Abs. Diff. {param_labels[i]}', linewidth=2.0)
#         ax.set_xlabel('Fiber Length (km)')
#         ax.set_ylabel('Absolute Difference')
#         ax.set_title(f'Abs. Diff. for {param_labels[i]}')
#         ax.grid(True)
#         ax.legend(loc='best')

#     # Plot absolute difference for key rate
#     ax_key = fig.add_subplot(gs[0, 0])
#     ax_key.plot(fiber_lengths, key_rate_abs_diff, 'g-', label='Predicted - Optimized Key Rate', linewidth=2.0)
#     ax_key.set_xlabel('Fiber Length (km)')
#     ax_key.set_ylabel('Absolute Difference')
#     ax_key.set_title('Absolute Difference in Key Rate')
#     ax_key.grid(True)
#     ax_key.legend(loc='best')
    
#     # Overall title
#     exponent = int(np.log10(nx)) if nx is not None else ''
#     fig.suptitle(f'Absolute Differences for Key Rate and Parameters ($n_X = 10^{{{exponent}}}$)', fontsize=16)

#     # Save and close
#     plt.tight_layout(rect=[0, 0, 1, 0.95])
#     plt.savefig(filename, dpi=300, bbox_inches='tight')
#     plt.show()
#     plt.close(fig)
#     print(f"Absolute differences plot saved to {filename}")

#     # Print plotting time
#     plot_time = time.time() - plot_start_time
#     print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
import matplotlib.pyplot as plt
import numpy as np
import time

def plot_absolute_differences_keyrate_and_parameters(fiber_lengths, optimized_key_rates, optimized_params_array,
                                                    predicted_key_rates, predicted_params_array, epoch, filename,
                                                    nx=None, threshold=1e-8):
    """
    Plots absolute differences of key rates and parameters for a specific n_X value.

    Parameters:
    - fiber_lengths: Array of fiber lengths (km).
    - optimized_key_rates: Array of optimized key rates.
    - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - nx: The n_X value for the plot title (optional).
    - threshold: Key rate threshold for physical cutoff (default: 1e-8).
    """
    # Start timing
    plot_start_time = time.time()

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Compute absolute differences
    key_rate_abs_diff = predicted_key_rates - optimized_key_rates
    param_abs_diffs = predicted_params_array - optimized_params_array
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Define subplot positions for parameters to avoid bottom-right
    param_positions = [
        (0, 0),  # Top-left
        (0, 1),  # Top-middle
        (0, 2),  # Top-right
        (1, 0),  # Bottom-left
        (1, 1),  # Bottom-middle
    ]

    # Plot absolute differences for parameters
    for i in range(5):
        row, col = param_positions[i]
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, param_abs_diffs[:, i], 'b-', label=f'Abs. Diff. {param_labels[i]}', linewidth=2.0)
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Absolute Difference')
        ax.set_title(f'Abs. Diff. for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Plot absolute difference for key rate in bottom-right (gs[1, 2])
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_abs_diff, 'g-', label='Predicted - Optimized Key Rate', linewidth=2.0)
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Absolute Difference')
    ax_key.set_title('Absolute Difference in Key Rate')
    ax_key.grid(True)
    ax_key.legend(loc='best')
    
    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
    fig.suptitle(f'Absolute Differences for Key Rate and Parameters ($n_X = 10^{{{exponent}}}$)', fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close(fig)
    print(f"Absolute differences plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
                        predicted_key_rates, predicted_params_array, epoch, filename, 
                        nx=None, threshold=1e-8):
    """
    Plots relative errors of predicted vs. optimized parameters and key rate for a specific n_X.
    """
    plot_start_time = time.time()

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Check for negative optimized key rates (shouldn't happen based on data filtering)
    if np.any(optimized_key_rates < 0):
        print(f"Warning: {np.sum(optimized_key_rates < 0)} optimized key rates are negative for n_X={nx}. Min value: {np.min(optimized_key_rates)}")
    
    # Check for negative predicted key rates (indicates insecure protocol)
    negative_pred_mask = predicted_key_rates < 0
    if np.any(negative_pred_mask):
        print(f"Found {np.sum(negative_pred_mask)} negative predicted key rates for n_X={nx}. Min value: {np.min(predicted_key_rates)}")
        # Optionally print fiber lengths where this occurs
        negative_fiber_lengths = fiber_lengths[negative_pred_mask]
        print(f"Fiber lengths with negative predicted key rates: {negative_fiber_lengths[:5]} (first 5 shown)")

    # Compute relative errors for parameters
    relative_errors = []
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    for i in range(5):
        optimized = optimized_params_array[:, i]
        predicted = predicted_params_array[:, i]
        denominator = np.maximum(optimized, 1e-10)
        rel_error = (predicted - optimized) / denominator
        relative_errors.append(rel_error)
    
    # Key rate relative error
    denominator = np.maximum(optimized_key_rates, threshold)
    key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Plot relative errors for parameters
    for i in range(5):
        row = i // 3
        col = i % 3
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Relative Error')
        ax.set_title(f'Relative Error for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Key rate subplot with linear scale
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Relative Error')
    ax_key.set_title('Relative Error for Key Rate')
    ax_key.set_ylim(-2, 2)  # Set a reasonable linear range
    ax_key.grid(True)
    ax_key.legend(loc='best')

    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
    fig.suptitle(f'Relative Errors of Parameters for $n_X = 10^{{{exponent}}}$', fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Relative error plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
# def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
#                         predicted_key_rates, predicted_params_array, epoch, filename, 
#                         nx=None, threshold=1e-8):
#     """
#     Plots relative errors of predicted vs. optimized parameters and key rate for a specific n_X.
#     """
#     plot_start_time = time.time()

#     # Filter out NaN values
#     valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
#     fiber_lengths = fiber_lengths[valid_mask]
#     optimized_key_rates = optimized_key_rates[valid_mask]
#     predicted_key_rates = predicted_key_rates[valid_mask]
#     optimized_params_array = optimized_params_array[valid_mask]
#     predicted_params_array = predicted_params_array[valid_mask]

#     # Find cutoff where optimized key rate becomes very small
#     cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
#     if len(cutoff_idx) > 0:
#         cutoff_idx = cutoff_idx[0]
#     else:
#         cutoff_idx = len(fiber_lengths)

#     fiber_lengths = fiber_lengths[:cutoff_idx]
#     optimized_key_rates = optimized_key_rates[:cutoff_idx]
#     predicted_key_rates = predicted_key_rates[:cutoff_idx]
#     optimized_params_array = optimized_params_array[:cutoff_idx]
#     predicted_params_array = predicted_params_array[:cutoff_idx]

#     # Compute relative errors for parameters
#     relative_errors = []
#     param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
#     for i in range(5):
#         optimized = optimized_params_array[:, i]
#         predicted = predicted_params_array[:, i]
#         denominator = np.maximum(optimized, 1e-10)
#         rel_error = (predicted - optimized) / denominator
#         relative_errors.append(rel_error)
    
#     # Key rate relative error
#     denominator = np.maximum(optimized_key_rates, threshold)
#     key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator
#     # Remove capping to see the true relative err
# or
#     # key_rate_rel_error = np.clip(key_rate_rel_error, -10, 10)

#     # Create figure with 6 subplots (2 rows, 3 columns)
#     fig = plt.figure(figsize=(18, 10))
#     gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

#     # Plot relative errors for parameters
#     for i in range(5):
#         row = i // 3
#         col = i % 3
#         ax = fig.add_subplot(gs[row, col])
#         ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
#         ax.set_xlabel('Fiber Length (km)')
#         ax.set_ylabel('Relative Error')
#         ax.set_title(f'Relative Error for {param_labels[i]}')
#         ax.grid(True)
#         ax.legend(loc='best')

#     # Key rate subplot with linear scale
#     ax_key = fig.add_subplot(gs[1, 2])
#     ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
#     ax_key.set_xlabel('Fiber Length (km)')
#     ax_key.set_ylabel('Relative Error')
#     ax_key.set_title('Relative Error for Key Rate')
#     ax_key.set_ylim(-2, 2)  # Set a reasonable linear range
#     ax_key.grid(True)
#     ax_key.legend(loc='best')

#     # Overall title
#     exponent = int(np.log10(nx)) if nx is not None else ''
#     fig.suptitle(f'Relative Errors of Parameters for $n_X = 10^{{{exponent}}}$', fontsize=16)

#     # Save and close
#     plt.tight_layout(rect=[0, 0, 1, 0.95])
#     plt.savefig(filename, dpi=300, bbox_inches='tight')
#     plt.close(fig)
#     print(f"Relative error plot saved to {filename}")

#     # Print plotting time
#     plot_time = time.time() - plot_start_time
#     print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
# def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
#                         predicted_key_rates, predicted_params_array, epoch, filename, 
#                         nx=None, threshold=1e-8):
#     """
#     Plots relative errors of predicted vs. optimized parameters and key rate for a specific n_X.
    
#     Parameters:
#     - fiber_lengths: Array of fiber lengths (km).
#     - optimized_key_rates: Array of optimized key rates.
#     - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
#     - predicted_key_rates: Array of predicted key rates.
#     - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
#     - epoch: Epoch number or string (e.g., 'final_test').
#     - filename: Output filename for the plot.
#     - nx: The n_X value for the plot title (optional).
#     - threshold: Key rate threshold for physical cutoff (default: 1e-8).
#     """
#     # Start timing
#     plot_start_time = time.time()

#     # Filter out NaN values
#     valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
#     fiber_lengths = fiber_lengths[valid_mask]
#     optimized_key_rates = optimized_key_rates[valid_mask]
#     predicted_key_rates = predicted_key_rates[valid_mask]
#     optimized_params_array = optimized_params_array[valid_mask]
#     predicted_params_array = predicted_params_array[valid_mask]

#     # Find cutoff where optimized key rate becomes very small
#     cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
#     if len(cutoff_idx) > 0:
#         cutoff_idx = cutoff_idx[0]
#     else:
#         cutoff_idx = len(fiber_lengths)

#     fiber_lengths = fiber_lengths[:cutoff_idx]
#     optimized_key_rates = optimized_key_rates[:cutoff_idx]
#     predicted_key_rates = predicted_key_rates[:cutoff_idx]
#     optimized_params_array = optimized_params_array[:cutoff_idx]
#     predicted_params_array = predicted_params_array[:cutoff_idx]

#     # Compute relative errors for parameters
#     relative_errors = []
#     param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
#     for i in range(5):
#         optimized = optimized_params_array[:, i]
#         predicted = predicted_params_array[:, i]
#         # Avoid division by zero with a small threshold
#         denominator = np.maximum(optimized, 1e-10)
#         rel_error = (predicted - optimized) / denominator
#         relative_errors.append(rel_error)
    
#     # Key rate relative error
#     # Key rate relative error
#     denominator = np.maximum(optimized_key_rates, threshold)
#     key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator
# # Remove the capping to see the true relative error
# # key_rate_rel_error = np.clip(key_rate_rel_error, -10, 10)
#     # Cap the relative error for key rate to prevent extreme spikes
#     key_rate_rel_error = np.clip(key_rate_rel_error, -10, 10)

#     # Create figure with 6 subplots (2 rows, 3 columns)
#     fig = plt.figure(figsize=(18, 10))
#     gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

#     # Plot relative errors for parameters
#     for i in range(5):
#         row = i // 3
#         col = i % 3
#         ax = fig.add_subplot(gs[row, col])
#         ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
#         ax.set_xlabel('Fiber Length (km)')
#         ax.set_ylabel('Relative Error')
#         ax.set_title(f'Relative Error for {param_labels[i]}')
#         ax.grid(True)
#         ax.legend(loc='best')

#     # Key rate subplot with logarithmic scale
#     ax_key = fig.add_subplot(gs[1, 2])
#     ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
#     ax_key.set_xlabel('Fiber Length (km)')
#     ax_key.set_ylabel('Relative Error')
#     ax_key.set_title('Relative Error for Key Rate')
#     ax_key.set_yscale('symlog', linthresh=0.1)  # Symmetric logarithmic scale
#     ax_key.grid(True)
#     ax_key.legend(loc='best')

#     # Overall title
#     exponent = int(np.log10(nx)) if nx is not None else ''
#     fig.suptitle(f'Relative Errors of Parameters for $n_X = 10^{{{exponent}}}$', fontsize=16)

#     # Save and close
#     plt.tight_layout(rect=[0, 0, 1, 0.95])
#     plt.savefig(filename, dpi=300, bbox_inches='tight')
#     plt.close(fig)
#     print(f"Relative error plot saved to {filename}")

#     # Print plotting time
#     plot_time = time.time() - plot_start_time
#     print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
import matplotlib.pyplot as plt
import numpy as np

def plot_keyrate_subplots_with_relative_error(all_data, epoch, filename):
    """
    Plots key rates and relative errors vs fiber length for multiple n_X values on separate subplots.
    
    Parameters:
    - all_data: Dictionary with keys as n_X values and values containing fiber_lengths, optimized_key_rates, predicted_key_rates.
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True)
    fig.suptitle(f"Key Rates and Relative Error vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())

    for i, nx in enumerate(nx_values):
        if i >= 6:
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        predicted_key_rates = all_data[nx].get('predicted_key_rates', None)

        # Filter out NaN values
        valid_mask = ~(np.isnan(optimized_key_rates))
        if predicted_key_rates is not None:
            valid_mask &= ~np.isnan(predicted_key_rates)
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_key_rates = optimized_key_rates[valid_mask]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[valid_mask]

        # Apply key rate cutoff
        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_key_rates = optimized_key_rates[:cutoff_idx]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[:cutoff_idx]

        # Plot key rates
        ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linewidth=2.0)
        if predicted_key_rates is not None:
            ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r:', label='Predicted Key Rate', linewidth=4.0)

        # Plot relative error on a secondary axis
        ax2 = ax.twinx()
# denominator = np.maximum(optimized_key_rates, 1e-8)
        denominator = np.maximum(optimized_key_rates, threshold)
        rel_error = (predicted_key_rates - optimized_key_rates) / denominator
        rel_error = np.clip(rel_error, -10, 10)
        ax2.plot(fiber_lengths, rel_error, 'g--', label='Relative Error', alpha=0.5)
        ax2.set_ylabel('Relative Error', color='g')
        ax2.tick_params(axis='y', labelcolor='g')
        ax2.set_ylim(-10, 10)

        # Set title and labels
        exponent = int(np.log10(nx))
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Log10(Secret Key Rate per Pulse)")
        ax.legend(loc='upper left')
        ax2.legend(loc='upper right')

    # Remove empty subplots
    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.show()
    plt.close(fig)
    print(f"Key rate subplots with relative error saved to {filename}")

# %%
# Function to save predicted data as JSON
def save_dataset_to_json(plot_data, epoch, output_dir='datasets_json'):
    """
    Saves the predicted key rates and parameters for each n_X to JSON files.
    
    Parameters:
    - plot_data: Dictionary with n_X as keys and data (fiber_lengths, e_values, predicted key rates, predicted params) as values.
    - epoch: The epoch number.
    - output_dir: Directory to save the JSON files.
    """
    # Create output directory if it doesn't exist
    if not os.path.exists(output_dir):
        os.makedirs(output_dir)

    for nx, data in plot_data.items():
        fiber_lengths = data['fiber_lengths']
        e_values = data['e_values']  # List of [e_1, e_2, e_3, e_4] for each fiber length
        predicted_key_rates = data['predicted_key_rates']
        predicted_params_array = data['predicted_params_array']

        # Create a dictionary in the desired JSON structure
        dataset = {}
        nx_key = str(float(nx))  # e.g., "10000.0"
        dataset[nx_key] = []

        for i in range(len(fiber_lengths)):
            entry = {
                "fiber_length": float(fiber_lengths[i]),
                "e_1": float(e_values[i][0]),
                "e_2": float(e_values[i][1]),
                "e_3": float(e_values[i][2]),
                "e_4": float(e_values[i][3]),
                "predicted_key_rate": float(predicted_key_rates[i]),  # Predicted key rate only
                "predicted_params": {
                    "mu_1": float(predicted_params_array[i, 0]),
                    "mu_2": float(predicted_params_array[i, 1]),
                    "P_mu_1": float(predicted_params_array[i, 2]),
                    "P_mu_2": float(predicted_params_array[i, 3]),
                    "P_X_value": float(predicted_params_array[i, 4])
                }
            }
            dataset[nx_key].append(entry)

        # Save to JSON
        filename = os.path.join(output_dir, f'predicted_keyrate_params_nx_{nx:.0e}_epoch_{epoch}.json')
        try:
            with open(filename, 'w') as f:
                json.dump(dataset, f, indent=4)
            print(f"Saved predicted dataset to {filename}")
        except Exception as e:
            print(f"Error saving predicted dataset to {filename}: {e}")

# %%
# import time

# # Start total training time measurement
# total_start_time = time.time()
# # Training loop
# num_epochs = 5000
# for epoch in range(num_epochs):
#     start_time = time.time()

#     # Training phase
#     model.train()
#     running_loss = 0.0
#     for inputs, targets in train_loader:
#         inputs, targets = inputs.to(device), targets.to(device)
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, targets)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item() * inputs.size(0)
#     epoch_loss = running_loss / len(train_loader.dataset)
#     train_losses.append(epoch_loss)

#     # Validation phase
#     model.eval()
#     val_running_loss = 0.0
#     with torch.no_grad():
#         for inputs, targets in val_loader:
#             inputs, targets = inputs.to(device), targets.to(device)
#             outputs = model(inputs)
#             loss = criterion(outputs, targets)
#             val_running_loss += loss.item() * inputs.size(0)
#     val_loss = val_running_loss / len(val_loader.dataset)
#     val_losses.append(val_loss)

#     # Update learning rate
#     scheduler.step(val_loss)
#     current_lr = optimizer.param_groups[0]['lr']
#     learning_rates.append(current_lr)

#     # Evaluate and plot at the first and last epochs
#     eval_time = 0
#     plot_time = 0
#     if epoch == 0 or epoch == num_epochs - 1:
#         model.eval()
#         with torch.no_grad():
#             # Prepare data for all n_X values
#             plot_data = {}
#             eval_start = time.time()
#             for nx, eval_data in all_evaluation_data.items():
#                 fiber_lengths = eval_data['fiber_lengths']
#                 optimized_params_array = eval_data['optimized_params_array']
#                 optimized_key_rates = eval_data['optimized_key_rates']
#                 X_test_tensor = eval_data['X_test_tensor']

#                 # Compute predicted parameters and key rates
#                 predicted_params_scaled = model(X_test_tensor).cpu().numpy()
#                 predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
#                 predicted_params = y_scaler.inverse_transform(predicted_params_scaled)
#                 predicted_params[:, 0] = np.maximum(predicted_params[:, 0], 1e-6)
#                 predicted_params[:, 1] = np.maximum(predicted_params[:, 1], 1e-6)
#                 predicted_params[:, 2] = np.clip(predicted_params[:, 2], 0, 1)
#                 predicted_params[:, 3] = np.clip(predicted_params[:, 3], 0, 1)
#                 predicted_params[:, 4] = np.clip(predicted_params[:, 4], 0, 1)
#                 predicted_key_rates = []
#                 for params, L in zip(predicted_params, fiber_lengths):
#                     key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
#                     predicted_key_rates.append(key_rate)
#                 predicted_key_rates = np.array(predicted_key_rates)

#                 # Store data for plotting
#                 plot_data[nx] = {
#                     'fiber_lengths': fiber_lengths,
#                     'optimized_key_rates': optimized_key_rates,
#                     'predicted_key_rates': predicted_key_rates,
#                     'optimized_params_array': optimized_params_array,
#                     'predicted_params_array': predicted_params
#                 }

#                 # Plot relative errors for this n_X
#                 plot_relative_errors(
#                     fiber_lengths, optimized_key_rates, optimized_params_array,
#                     predicted_key_rates, predicted_params, epoch,
#                     f'relative_error_nx_{nx:.0e}_epoch_{epoch}.png', nx=nx
#                 )
#                 # Plot absolute differences for this n_X
#                 plot_absolute_differences_keyrate_and_parameters(
#                     fiber_lengths, optimized_key_rates, optimized_params_array,
#                     predicted_key_rates, predicted_params, epoch,
#                     filename=f'absolute_differences_nx_{nx:.0e}.png', nx=nx
#                 )

#             eval_time += time.time() - eval_start

#             # Plot subplots at the first and last epochs
#             plot_start = time.time()
#             if epoch == 0:
#                 plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_first_epoch.png')
#                 plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_first_epoch.png')
#             if epoch == num_epochs - 1:
#                 plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_last_epoch.png')
#                 plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
#                 # Optionally, plot key rate subplots with relative error
#                 plot_keyrate_subplots_with_relative_error(plot_data, epoch, f'keyrate_subplots_with_rel_error_last_epoch.png')
#             plot_time += time.time() - plot_start

#             torch.save(model.state_dict(), 'bb84_nn_model.pth')
#             print("Model saved to bb84_nn_model.pth")

#     # Print epoch results with timing and learning rate
#     epoch_time = time.time() - start_time
#     print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
#           f"Learning Rate: {current_lr:.6f}, Time: {epoch_time:.2f}s (Eval: {eval_time:.2f}s, Plot: {plot_time:.2f}s)")

# # Print total training time
# total_training_time = time.time() - total_start_time
# print(f"--- Total Training Time: {total_training_time:.2f} seconds ---")

# %%
# Start total training time measurement
total_start_time = time.time()
# Training loop
num_epochs = 5000
for epoch in range(num_epochs):
    start_time = time.time()

    # Training phase
    model.train()
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_running_loss += loss.item() * inputs.size(0)
    val_loss = val_running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)

    # Update learning rate
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    learning_rates.append(current_lr)

    # Evaluate and plot at the first and last epochs
    eval_time = 0
    plot_time = 0
    if epoch == 0 or epoch == num_epochs - 1:
        model.eval()
        with torch.no_grad():
            # Prepare data for all n_X values
            plot_data = {}
            eval_start = time.time()
            for nx, eval_data in all_evaluation_data.items():
                fiber_lengths = eval_data['fiber_lengths']
                optimized_params_array = eval_data['optimized_params_array']
                optimized_key_rates = eval_data['optimized_key_rates']
                X_test_tensor = eval_data['X_test_tensor']

                # Compute e_1, e_2, e_3, e_4 for each fiber length
                e_values = []
                for L in fiber_lengths:
                    e_1 = L / 100
                    e_2 = -np.log10(6e-7)
                    e_3 = 5e-3 * 100
                    e_4 = np.log10(nx)
                    e_values.append([e_1, e_2, e_3, e_4])

                # Compute predicted parameters and key rates
                predicted_params_scaled = model(X_test_tensor).cpu().numpy()
                predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
                predicted_params = y_scaler.inverse_transform(predicted_params_scaled)
                predicted_params[:, 0] = np.maximum(predicted_params[:, 0], 1e-6)
                predicted_params[:, 1] = np.maximum(predicted_params[:, 1], 1e-6)
                predicted_params[:, 2] = np.clip(predicted_params[:, 2], 0, 1)
                predicted_params[:, 3] = np.clip(predicted_params[:, 3], 0, 1)
                predicted_params[:, 4] = np.clip(predicted_params[:, 4], 0, 1)
                predicted_key_rates = []
                for params, L in zip(predicted_params, fiber_lengths):
                    key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
                    predicted_key_rates.append(key_rate)
                predicted_key_rates = np.array(predicted_key_rates)

                # Store data for plotting and saving
                plot_data[nx] = {
                    'fiber_lengths': fiber_lengths,
                    'e_values': e_values,  # Store e_1, e_2, e_3, e_4
                    'optimized_key_rates': optimized_key_rates,
                    'predicted_key_rates': predicted_key_rates,
                    'optimized_params_array': optimized_params_array,
                    'predicted_params_array': predicted_params
                }

                # Plot relative errors for this n_X
                plot_relative_errors(
                    fiber_lengths, optimized_key_rates, optimized_params_array,
                    predicted_key_rates, predicted_params, epoch,
                    f'relative_error_nx_{nx:.0e}_epoch_{epoch}.png', nx=nx
                )
                # Plot absolute differences for this n_X
                plot_absolute_differences_keyrate_and_parameters(
                    fiber_lengths, optimized_key_rates, optimized_params_array,
                    predicted_key_rates, predicted_params, epoch,
                    filename=f'absolute_differences_nx_{nx:.0e}.png', nx=nx
                )

            eval_time += time.time() - eval_start

            # Save the predicted datasets in JSON format
            save_dataset_to_json(plot_data, epoch)

            # Plot subplots at the first and last epochs
            plot_start = time.time()
            if epoch == 0:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_first_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_first_epoch.png')
            if epoch == num_epochs - 1:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_last_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
                # Optionally, plot key rate subplots with relative error
                plot_keyrate_subplots_with_relative_error(plot_data, epoch, f'keyrate_subplots_with_rel_error_last_epoch.png')
            plot_time += time.time() - plot_start

            torch.save(model.state_dict(), 'bb84_nn_model.pth')
            print("Model saved to bb84_nn_model.pth")

    # Print epoch results with timing and learning rate
    epoch_time = time.time() - start_time
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Learning Rate: {current_lr:.6f}, Time: {epoch_time:.2f}s (Eval: {eval_time:.2f}s, Plot: {plot_time:.2f}s)")

# Print total training time
total_training_time = time.time() - total_start_time
print(f"--- Total Training Time: {total_training_time:.2f} seconds ---")
# Out:
# objective returned NaN/Inf for params [0.44669247 0.2409524  0.156103   0.41808417 0.71528256], L=0.0, nx=10000: nan
# objective returned NaN/Inf for params [0.44669127 0.24089167 0.15610468 0.4178427  0.71488273], L=0.2002002002002002, nx=10000: nan
# objective returned NaN/Inf for params [0.44669005 0.24083094 0.15610638 0.4176012  0.714483  ], L=0.4004004004004004, nx=10000: nan
# objective returned NaN/Inf for params [0.4466888  0.24077024 0.15610807 0.41735974 0.71408325], L=0.6006006006006006, nx=10000: nan
# objective returned NaN/Inf for params [0.44668794 0.24070756 0.1561078  0.41711578 0.71367866], L=0.8008008008008008, nx=10000: nan
# objective returned NaN/Inf for params [0.4466871  0.24064463 0.15610725 0.41687143 0.71327364], L=1.001001001001001, nx=10000: nan
# objective returned NaN/Inf for params [0.44668627 0.24058169 0.15610671 0.4166271  0.7128684 ], L=1.2012012012012012, nx=10000: nan
# objective returned NaN/Inf for params [0.4466854  0.24051875 0.15610614 0.4163828  0.71246326], L=1.4014014014014016, nx=10000: nan
# objective returned NaN/Inf for params [0.4466846  0.24045582 0.15610561 0.41613847 0.7120581 ], L=1.6016016016016017, nx=10000: nan
# objective returned NaN/Inf for params [0.44668376 0.24039288 0.15610506 0.4158941  0.71165293], L=1.8018018018018018, nx=10000: nan
# objective returned NaN/Inf for params [0.44668293 0.24032992 0.1561045  0.4156498  0.7112478 ], L=2.002002002002002, nx=10000: nan
# objective returned NaN/Inf for params [0.44668207 0.240267   0.15610395 0.41540548 0.7108427 ], L=2.2022022022022023, nx=10000: nan
# objective returned NaN/Inf for params [0.4466813  0.24020407 0.15610342 0.41516113 0.71043754], L=2.4024024024024024, nx=10000: nan
# objective returned NaN/Inf for params [0.44668043 0.24014112 0.15610287 0.4149168  0.71003234], L=2.6026026026026026, nx=10000: nan
# objective returned NaN/Inf for params [0.4466796  0.24007817 0.15610231 0.4146725  0.7096273 ], L=2.802802802802803, nx=10000: nan
# objective returned NaN/Inf for params [0.44667873 0.24001522 0.15610175 0.41442814 0.7092221 ], L=3.0030030030030033, nx=10000: nan
# objective returned NaN/Inf for params [0.44667795 0.2399523  0.1561012  0.41418386 0.70881695], L=3.2032032032032034, nx=10000: nan
# objective returned NaN/Inf for params [0.4466771  0.23988934 0.15610066 0.41393948 0.70841175], L=3.4034034034034035, nx=10000: nan
# objective returned NaN/Inf for params [0.44667625 0.23982641 0.15610011 0.41369513 0.70800656], L=3.6036036036036037, nx=10000: nan
# objective returned NaN/Inf for params [0.44667542 0.23976347 0.15609956 0.41345084 0.7076015 ], L=3.8038038038038042, nx=10000: nan
# objective returned NaN/Inf for params [0.44667462 0.23970053 0.15609902 0.4132065  0.7071963 ], L=4.004004004004004, nx=10000: nan
# objective returned NaN/Inf for params [0.44667375 0.23963758 0.15609847 0.41296217 0.70679116], L=4.2042042042042045, nx=10000: nan
# objective returned NaN/Inf for params [0.44667292 0.23957466 0.15609792 0.41271785 0.7063861 ], L=4.404404404404405, nx=10000: nan
# objective returned NaN/Inf for params [0.44667208 0.23951171 0.15609737 0.41247353 0.7059809 ], L=4.604604604604605, nx=10000: nan
# objective returned NaN/Inf for params [0.44667128 0.23944877 0.1560968  0.41222915 0.7055757 ], L=4.804804804804805, nx=10000: nan
# objective returned NaN/Inf for params [0.44667044 0.23938583 0.15609626 0.41198483 0.7051706 ], L=5.005005005005005, nx=10000: nan
# objective returned NaN/Inf for params [0.44666958 0.2393229  0.15609571 0.41174054 0.70476544], L=5.205205205205205, nx=10000: nan
# objective returned NaN/Inf for params [0.44666874 0.23925994 0.15609515 0.4114962  0.7043603 ], L=5.405405405405406, nx=10000: nan
# objective returned NaN/Inf for params [0.44666794 0.23919702 0.1560946  0.4112519  0.7039551 ], L=5.605605605605606, nx=10000: nan
# objective returned NaN/Inf for params [0.4466671  0.23913406 0.15609407 0.41100755 0.70355   ], L=5.805805805805806, nx=10000: nan
# objective returned NaN/Inf for params [0.44666624 0.23907115 0.15609352 0.4107632  0.70314485], L=6.0060060060060065, nx=10000: nan
# objective returned NaN/Inf for params [0.4466654  0.23900817 0.15609297 0.4105189  0.70273966], L=6.206206206206207, nx=10000: nan
# objective returned NaN/Inf for params [0.44666454 0.23894525 0.15609242 0.41027457 0.7023345 ], L=6.406406406406407, nx=10000: nan
# objective returned NaN/Inf for params [0.44666377 0.2388823  0.15609185 0.41003022 0.7019294 ], L=6.606606606606607, nx=10000: nan
# objective returned NaN/Inf for params [0.4466629  0.23881936 0.15609132 0.40978587 0.70152414], L=6.806806806806807, nx=10000: nan
# objective returned NaN/Inf for params [0.44666207 0.23875642 0.15609075 0.40954158 0.70111907], L=7.007007007007007, nx=10000: nan
# objective returned NaN/Inf for params [0.44666126 0.23869349 0.15609021 0.40929723 0.7007139 ], L=7.207207207207207, nx=10000: nan
# objective returned NaN/Inf for params [0.44666043 0.23863055 0.15608966 0.40905294 0.7003088 ], L=7.407407407407407, nx=10000: nan
# objective returned NaN/Inf for params [0.44665956 0.2385676  0.1560891  0.4088086  0.69990355], L=7.6076076076076085, nx=10000: nan
# objective returned NaN/Inf for params [0.44665873 0.23850466 0.15608856 0.40856424 0.6994984 ], L=7.807807807807809, nx=10000: nan
# objective returned NaN/Inf for params [0.44665793 0.23844172 0.15608802 0.4083199  0.6990932 ], L=8.008008008008009, nx=10000: nan
# objective returned NaN/Inf for params [0.4466571  0.2383788  0.15608746 0.40807563 0.6986882 ], L=8.208208208208209, nx=10000: nan
# objective returned NaN/Inf for params [0.44665626 0.23831585 0.1560869  0.4078313  0.698283  ], L=8.408408408408409, nx=10000: nan
# objective returned NaN/Inf for params [0.4466554  0.23825291 0.15608637 0.4075869  0.6978778 ], L=8.608608608608609, nx=10000: nan
# objective returned NaN/Inf for params [0.44665456 0.23818998 0.15608582 0.40734264 0.69747275], L=8.80880880880881, nx=10000: nan
# objective returned NaN/Inf for params [0.44665375 0.23812701 0.15608527 0.40709826 0.6970675 ], L=9.00900900900901, nx=10000: nan
# objective returned NaN/Inf for params [0.44665292 0.23806408 0.15608472 0.40685397 0.6966624 ], L=9.20920920920921, nx=10000: nan
# objective returned NaN/Inf for params [0.44665205 0.23800114 0.15608416 0.40660962 0.69625723], L=9.40940940940941, nx=10000: nan
# objective returned NaN/Inf for params [0.44665128 0.23793821 0.15608361 0.40636533 0.6958521 ], L=9.60960960960961, nx=10000: nan
# objective returned NaN/Inf for params [0.44665042 0.23787527 0.15608308 0.406121   0.69544697], L=9.80980980980981, nx=10000: nan
# objective returned NaN/Inf for params [0.44664958 0.23781233 0.15608251 0.40587667 0.6950417 ], L=10.01001001001001, nx=10000: nan
# objective returned NaN/Inf for params [0.44664872 0.23774938 0.15608197 0.40563232 0.69463664], L=10.21021021021021, nx=10000: nan
# objective returned NaN/Inf for params [0.44664794 0.23768644 0.15608142 0.405388   0.69423145], L=10.41041041041041, nx=10000: nan
# objective returned NaN/Inf for params [0.44664708 0.23762351 0.15608087 0.40514368 0.6938263 ], L=10.61061061061061, nx=10000: nan
# objective returned NaN/Inf for params [0.44664624 0.23756056 0.1560803  0.4048993  0.6934212 ], L=10.810810810810812, nx=10000: nan
# objective returned NaN/Inf for params [0.4466454  0.23749763 0.15607978 0.404655   0.69301605], L=11.011011011011012, nx=10000: nan
# objective returned NaN/Inf for params [0.4466446  0.23743469 0.15607922 0.40441066 0.69261086], L=11.211211211211213, nx=10000: nan
# objective returned NaN/Inf for params [0.44664374 0.23737174 0.15607868 0.40416634 0.6922057 ], L=11.411411411411413, nx=10000: nan
# objective returned NaN/Inf for params [0.4466429  0.23730882 0.15607813 0.40392205 0.6918006 ], L=11.611611611611613, nx=10000: nan
# objective returned NaN/Inf for params [0.44664207 0.23724587 0.15607758 0.40367767 0.6913954 ], L=11.811811811811813, nx=10000: nan
# objective returned NaN/Inf for params [0.4466412  0.23718292 0.15607706 0.40343332 0.69099027], L=12.012012012012013, nx=10000: nan
# objective returned NaN/Inf for params [0.44664043 0.23711997 0.15607648 0.40318903 0.6905851 ], L=12.212212212212213, nx=10000: nan
# objective returned NaN/Inf for params [0.44663957 0.23705705 0.15607592 0.4029447  0.69017994], L=12.412412412412413, nx=10000: nan
# objective returned NaN/Inf for params [0.44663873 0.2369941  0.15607537 0.40270036 0.6897748 ], L=12.612612612612613, nx=10000: nan
# objective returned NaN/Inf for params [0.44663793 0.23693116 0.15607482 0.40245605 0.6893696 ], L=12.812812812812814, nx=10000: nan
# objective returned NaN/Inf for params [0.4466371  0.23686822 0.15607427 0.40221173 0.6889645 ], L=13.013013013013014, nx=10000: nan
# objective returned NaN/Inf for params [0.44663623 0.23680528 0.15607373 0.40196738 0.6885593 ], L=13.213213213213214, nx=10000: nan
# objective returned NaN/Inf for params [0.4466354  0.23674235 0.15607317 0.40172306 0.68815416], L=13.413413413413414, nx=10000: nan
# objective returned NaN/Inf for params [0.4466346  0.2366794  0.15607263 0.4014787  0.687749  ], L=13.613613613613614, nx=10000: nan
# objective returned NaN/Inf for params [0.44663376 0.23661648 0.15607208 0.40123445 0.6873439 ], L=13.813813813813814, nx=10000: nan
# objective returned NaN/Inf for params [0.4466329  0.23655352 0.15607153 0.40099007 0.6869387 ], L=14.014014014014014, nx=10000: nan
# objective returned NaN/Inf for params [0.44663206 0.23649058 0.15607099 0.40074572 0.6865336 ], L=14.214214214214214, nx=10000: nan
# objective returned NaN/Inf for params [0.44663584 0.23644406 0.15605737 0.40055332 0.6862137 ], L=14.414414414414415, nx=10000: nan
# objective returned NaN/Inf for params [0.44664207 0.23640633 0.1560368  0.40038866 0.6859395 ], L=14.614614614614615, nx=10000: nan
# objective returned NaN/Inf for params [0.44664824 0.23636858 0.1560162  0.400224   0.68566525], L=14.814814814814815, nx=10000: nan
# objective returned NaN/Inf for params [0.44665444 0.23633085 0.15599562 0.4000593  0.685391  ], L=15.015015015015017, nx=10000: nan
# objective returned NaN/Inf for params [0.44666067 0.2362931  0.15597501 0.39989465 0.68511677], L=15.215215215215217, nx=10000: nan
# objective returned NaN/Inf for params [0.44666684 0.23625538 0.15595445 0.39973003 0.6848425 ], L=15.415415415415417, nx=10000: nan
# objective returned NaN/Inf for params [0.44667307 0.23621763 0.15593384 0.39956537 0.68456835], L=15.615615615615617, nx=10000: nan
# objective returned NaN/Inf for params [0.4466793  0.2361799  0.15591328 0.3994007  0.6842941 ], L=15.815815815815817, nx=10000: nan
# objective returned NaN/Inf for params [0.44668546 0.23614216 0.15589269 0.39923602 0.68401986], L=16.016016016016017, nx=10000: nan
# objective returned NaN/Inf for params [0.4466917  0.23610443 0.15587209 0.39907137 0.6837457 ], L=16.216216216216218, nx=10000: nan
# objective returned NaN/Inf for params [0.4466979  0.2360667  0.1558515  0.39890674 0.68347144], L=16.416416416416418, nx=10000: nan
# objective returned NaN/Inf for params [0.44670412 0.23602894 0.15583092 0.39874205 0.68319714], L=16.616616616616618, nx=10000: nan
# objective returned NaN/Inf for params [0.4467103  0.23599121 0.15581034 0.39857742 0.68292296], L=16.816816816816818, nx=10000: nan
# objective returned NaN/Inf for params [0.44671652 0.23595348 0.15578975 0.3984127  0.6826487 ], L=17.017017017017018, nx=10000: nan
# objective returned NaN/Inf for params [0.44672275 0.23591574 0.15576917 0.39824808 0.6823745 ], L=17.217217217217218, nx=10000: nan
# objective returned NaN/Inf for params [0.44672894 0.235878   0.15574856 0.39808342 0.68210024], L=17.41741741741742, nx=10000: nan
# objective returned NaN/Inf for params [0.44673514 0.23584028 0.155728   0.3979188  0.68182606], L=17.61761761761762, nx=10000: nan
# objective returned NaN/Inf for params [0.44674134 0.2358025  0.15570739 0.3977541  0.68155175], L=17.81781781781782, nx=10000: nan
# objective returned NaN/Inf for params [0.44674757 0.23576477 0.15568681 0.39758947 0.6812776 ], L=18.01801801801802, nx=10000: nan
# objective returned NaN/Inf for params [0.44675374 0.23572706 0.15566623 0.39742482 0.68100333], L=18.21821821821822, nx=10000: nan
# objective returned NaN/Inf for params [0.44675997 0.23568928 0.15564564 0.3972601  0.68072903], L=18.41841841841842, nx=10000: nan
# objective returned NaN/Inf for params [0.4467662  0.23565157 0.15562506 0.39709547 0.68045485], L=18.61861861861862, nx=10000: nan
# objective returned NaN/Inf for params [0.44677237 0.23561381 0.15560447 0.3969308  0.6801806 ], L=18.81881881881882, nx=10000: nan
# objective returned NaN/Inf for params [0.44677857 0.23557608 0.15558387 0.39676613 0.67990637], L=19.01901901901902, nx=10000: nan
# objective returned NaN/Inf for params [0.4467848  0.23553833 0.1555633  0.39660147 0.6796322 ], L=19.21921921921922, nx=10000: nan
# objective returned NaN/Inf for params [0.44679102 0.2355006  0.15554272 0.39643684 0.67935795], L=19.41941941941942, nx=10000: nan
# objective returned NaN/Inf for params [0.4467972  0.23546286 0.15552214 0.39627218 0.6790837 ], L=19.61961961961962, nx=10000: nan
# objective returned NaN/Inf for params [0.44680342 0.23542513 0.15550154 0.39610747 0.67880946], L=19.81981981981982, nx=10000: nan
# objective returned NaN/Inf for params [0.44680962 0.23538738 0.15548097 0.3959428  0.6785352 ], L=20.02002002002002, nx=10000: nan
# objective returned NaN/Inf for params [0.44681582 0.23534966 0.15546037 0.39577818 0.678261  ], L=20.22022022022022, nx=10000: nan
# objective returned NaN/Inf for params [0.44682202 0.23531191 0.1554398  0.39561352 0.67798674], L=20.42042042042042, nx=10000: nan
# objective returned NaN/Inf for params [0.44682825 0.23527418 0.15541919 0.39544886 0.6777125 ], L=20.62062062062062, nx=10000: nan
# objective returned NaN/Inf for params [0.44683447 0.23523645 0.1553986  0.39528424 0.6774384 ], L=20.82082082082082, nx=10000: nan
# objective returned NaN/Inf for params [0.44684064 0.2351987  0.15537803 0.39511952 0.6771641 ], L=21.02102102102102, nx=10000: nan
# objective returned NaN/Inf for params [0.44684687 0.23516096 0.15535742 0.3949549  0.6768899 ], L=21.22122122122122, nx=10000: nan
# objective returned NaN/Inf for params [0.44685307 0.23512323 0.15533686 0.39479023 0.67661566], L=21.421421421421424, nx=10000: nan
# objective returned NaN/Inf for params [0.44685924 0.2350855  0.15531626 0.39462557 0.6763414 ], L=21.621621621621625, nx=10000: nan
# objective returned NaN/Inf for params [0.44686547 0.23504774 0.15529567 0.39446092 0.6760671 ], L=21.821821821821825, nx=10000: nan
# objective returned NaN/Inf for params [0.4468717  0.23501001 0.1552751  0.39429623 0.67579293], L=22.022022022022025, nx=10000: nan
# objective returned NaN/Inf for params [0.44687793 0.23497227 0.1552545  0.39413154 0.67551863], L=22.222222222222225, nx=10000: nan
# objective returned NaN/Inf for params [0.4468841  0.23493455 0.15523393 0.39396694 0.6752445 ], L=22.422422422422425, nx=10000: nan
# objective returned NaN/Inf for params [0.4468903  0.23489681 0.15521334 0.3938023  0.67497027], L=22.622622622622625, nx=10000: nan
# objective returned NaN/Inf for params [0.44689652 0.23485906 0.15519276 0.39363763 0.67469597], L=22.822822822822825, nx=10000: nan
# objective returned NaN/Inf for params [0.44690275 0.23482132 0.15517215 0.3934729  0.6744218 ], L=23.023023023023026, nx=10000: nan
# objective returned NaN/Inf for params [0.44690892 0.23478359 0.15515158 0.39330828 0.67414755], L=23.223223223223226, nx=10000: nan
# objective returned NaN/Inf for params [0.44691515 0.23474585 0.15513101 0.39314362 0.6738733 ], L=23.423423423423426, nx=10000: nan
# objective returned NaN/Inf for params [0.44692138 0.23470812 0.15511039 0.39297897 0.67359906], L=23.623623623623626, nx=10000: nan
# objective returned NaN/Inf for params [0.44692755 0.23467037 0.15508981 0.3928143  0.6733248 ], L=23.823823823823826, nx=10000: nan
# objective returned NaN/Inf for params [0.44693375 0.23463263 0.15506923 0.39264962 0.6730506 ], L=24.024024024024026, nx=10000: nan
# objective returned NaN/Inf for params [0.44693998 0.23459491 0.15504865 0.392485   0.6727764 ], L=24.224224224224226, nx=10000: nan
# objective returned NaN/Inf for params [0.4469462  0.23455715 0.15502805 0.39232033 0.67250216], L=24.424424424424426, nx=10000: nan
# objective returned NaN/Inf for params [0.44695237 0.23451944 0.15500747 0.39215568 0.6722279 ], L=24.624624624624627, nx=10000: nan
# objective returned NaN/Inf for params [0.4469586  0.23448168 0.15498689 0.39199096 0.6719536 ], L=24.824824824824827, nx=10000: nan
# objective returned NaN/Inf for params [0.4469648  0.23444395 0.1549663  0.39182633 0.6716794 ], L=25.025025025025027, nx=10000: nan
# objective returned NaN/Inf for params [0.446971   0.23440622 0.15494572 0.39166167 0.6714052 ], L=25.225225225225227, nx=10000: nan
# objective returned NaN/Inf for params [0.4469772  0.23436847 0.15492514 0.39149702 0.67113096], L=25.425425425425427, nx=10000: nan
# objective returned NaN/Inf for params [0.44698343 0.23433073 0.15490453 0.39133236 0.6708567 ], L=25.625625625625627, nx=10000: nan
# objective returned NaN/Inf for params [0.4469896  0.234293   0.15488395 0.39116767 0.6705825 ], L=25.825825825825827, nx=10000: nan
# objective returned NaN/Inf for params [0.44699582 0.23425524 0.15486336 0.39100307 0.6703083 ], L=26.026026026026027, nx=10000: nan
# objective returned NaN/Inf for params [0.44700205 0.23421752 0.15484278 0.39083835 0.67003405], L=26.226226226226228, nx=10000: nan
# objective returned NaN/Inf for params [0.44700825 0.23417976 0.1548222  0.39067373 0.6697598 ], L=26.426426426426428, nx=10000: nan
# objective returned NaN/Inf for params [0.44701442 0.23414204 0.15480159 0.39050907 0.6694856 ], L=26.626626626626628, nx=10000: nan
# objective returned NaN/Inf for params [0.44702065 0.23410429 0.15478101 0.3903444  0.6692114 ], L=26.826826826826828, nx=10000: nan
# objective returned NaN/Inf for params [0.44702688 0.23406656 0.15476044 0.39017972 0.66893715], L=27.027027027027028, nx=10000: nan
# objective returned NaN/Inf for params [0.4470331  0.23402882 0.15473983 0.3900151  0.66866297], L=27.227227227227228, nx=10000: nan
# objective returned NaN/Inf for params [0.44703928 0.23399109 0.15471926 0.38985044 0.6683887 ], L=27.42742742742743, nx=10000: nan
# objective returned NaN/Inf for params [0.44704548 0.23395334 0.15469866 0.38968575 0.6681144 ], L=27.62762762762763, nx=10000: nan
# objective returned NaN/Inf for params [0.4470517  0.23391561 0.15467808 0.38952112 0.66784024], L=27.82782782782783, nx=10000: nan
# objective returned NaN/Inf for params [0.44705787 0.23387787 0.15465751 0.38935643 0.667566  ], L=28.02802802802803, nx=10000: nan
# objective returned NaN/Inf for params [0.4470641  0.23384014 0.15463692 0.38919178 0.6672917 ], L=28.22822822822823, nx=10000: nan
# objective returned NaN/Inf for params [0.44707033 0.2338024  0.15461633 0.38902712 0.6670175 ], L=28.42842842842843, nx=10000: nan
# objective returned NaN/Inf for params [0.44707656 0.23376466 0.15459573 0.38886246 0.6667433 ], L=28.62862862862863, nx=10000: nan
# objective returned NaN/Inf for params [0.44708273 0.23372692 0.15457515 0.38869777 0.66646904], L=28.82882882882883, nx=10000: nan
# objective returned NaN/Inf for params [0.44708893 0.23368919 0.15455458 0.38853312 0.6661948 ], L=29.02902902902903, nx=10000: nan
# objective returned NaN/Inf for params [0.44709516 0.23365144 0.15453398 0.3883685  0.66592056], L=29.22922922922923, nx=10000: nan
# objective returned NaN/Inf for params [0.44710132 0.2336137  0.1545134  0.38820383 0.6656463 ], L=29.42942942942943, nx=10000: nan
# objective returned NaN/Inf for params [0.44710755 0.23357597 0.15449281 0.3880391  0.6653721 ], L=29.62962962962963, nx=10000: nan
# objective returned NaN/Inf for params [0.44711378 0.23353824 0.15447223 0.3878745  0.6650979 ], L=29.82982982982983, nx=10000: nan
# objective returned NaN/Inf for params [0.44711995 0.2335005  0.15445165 0.38770983 0.66482365], L=30.030030030030034, nx=10000: nan
# objective returned NaN/Inf for params [0.44712618 0.23346275 0.15443106 0.38754517 0.6645494 ], L=30.230230230230234, nx=10000: nan
# objective returned NaN/Inf for params [0.44713238 0.233425   0.15441048 0.3873805  0.6642751 ], L=30.430430430430434, nx=10000: nan
# objective returned NaN/Inf for params [0.4471386  0.23338728 0.15438987 0.3872158  0.6640009 ], L=30.630630630630634, nx=10000: nan
# objective returned NaN/Inf for params [0.44714484 0.23334955 0.1543693  0.38705117 0.66372675], L=30.830830830830834, nx=10000: nan
# objective returned NaN/Inf for params [0.447151   0.2333118  0.1543487  0.38688654 0.66345257], L=31.031031031031034, nx=10000: nan
# objective returned NaN/Inf for params [0.44715723 0.23327406 0.15432812 0.38672188 0.66317827], L=31.231231231231234, nx=10000: nan
# objective returned NaN/Inf for params [0.4471634  0.23323633 0.15430754 0.38655722 0.662904  ], L=31.431431431431434, nx=10000: nan
# objective returned NaN/Inf for params [0.4471696  0.2331986  0.15428694 0.38639256 0.6626298 ], L=31.631631631631635, nx=10000: nan
# objective returned NaN/Inf for params [0.44717583 0.23316085 0.15426637 0.38622788 0.66235554], L=31.831831831831835, nx=10000: nan
# objective returned NaN/Inf for params [0.44718206 0.23312311 0.15424578 0.38606322 0.6620813 ], L=32.032032032032035, nx=10000: nan
# objective returned NaN/Inf for params [0.44718823 0.23308538 0.1542252  0.38589856 0.66180706], L=32.232232232232235, nx=10000: nan
# objective returned NaN/Inf for params [0.44719446 0.23304765 0.15420462 0.38573393 0.6615329 ], L=32.432432432432435, nx=10000: nan
# objective returned NaN/Inf for params [0.44720066 0.2330099  0.15418401 0.38556927 0.66125864], L=32.632632632632635, nx=10000: nan
# objective returned NaN/Inf for params [0.44720688 0.23297216 0.15416344 0.38540456 0.66098434], L=32.832832832832835, nx=10000: nan
# objective returned NaN/Inf for params [0.44721305 0.23293443 0.15414286 0.38523993 0.66071016], L=33.033033033033036, nx=10000: nan
# objective returned NaN/Inf for params [0.44721928 0.23289669 0.15412226 0.38507527 0.660436  ], L=33.233233233233236, nx=10000: nan
# objective returned NaN/Inf for params [0.4472255  0.23285896 0.15410167 0.38491064 0.6601618 ], L=33.433433433433436, nx=10000: nan
# objective returned NaN/Inf for params [0.44723168 0.23282121 0.1540811  0.38474593 0.6598875 ], L=33.633633633633636, nx=10000: nan
# objective returned NaN/Inf for params [0.44723815 0.23277833 0.15405853 0.38457537 0.6595875 ], L=33.833833833833836, nx=10000: nan
# objective returned NaN/Inf for params [0.4472447  0.23273411 0.15403546 0.38440326 0.6592809 ], L=34.034034034034036, nx=10000: nan
# objective returned NaN/Inf for params [0.44725123 0.23268992 0.1540124  0.38423112 0.6589743 ], L=34.234234234234236, nx=10000: nan
# objective returned NaN/Inf for params [0.44725776 0.2326457  0.15398933 0.38405904 0.65866774], L=34.434434434434436, nx=10000: nan
# objective returned NaN/Inf for params [0.44726428 0.23260151 0.15396628 0.38388693 0.65836114], L=34.63463463463464, nx=10000: nan
# objective returned NaN/Inf for params [0.44727084 0.23255731 0.15394321 0.3837148  0.65805453], L=34.83483483483484, nx=10000: nan
# objective returned NaN/Inf for params [0.44727737 0.2325131  0.15392016 0.3835427  0.65774786], L=35.03503503503504, nx=10000: nan
# objective returned NaN/Inf for params [0.4472839  0.23246889 0.1538971  0.3833706  0.6574413 ], L=35.23523523523524, nx=10000: nan
# objective returned NaN/Inf for params [0.44729045 0.23242469 0.15387402 0.38319847 0.6571348 ], L=35.43543543543544, nx=10000: nan
# objective returned NaN/Inf for params [0.44729698 0.23238048 0.15385097 0.3830264  0.6568282 ], L=35.63563563563564, nx=10000: nan
# objective returned NaN/Inf for params [0.4473035  0.23233627 0.1538279  0.3828543  0.65652156], L=35.83583583583584, nx=10000: nan
# objective returned NaN/Inf for params [0.44731006 0.23229207 0.15380485 0.38268217 0.656215  ], L=36.03603603603604, nx=10000: nan
# objective returned NaN/Inf for params [0.4473166  0.23224787 0.15378179 0.38251007 0.6559084 ], L=36.23623623623624, nx=10000: nan
# objective returned NaN/Inf for params [0.4473231  0.23220365 0.15375873 0.38233793 0.6556018 ], L=36.43643643643644, nx=10000: nan
# objective returned NaN/Inf for params [0.4473296  0.23215945 0.15373567 0.38216582 0.6552952 ], L=36.63663663663664, nx=10000: nan
# objective returned NaN/Inf for params [0.4473362  0.23211524 0.15371262 0.38199374 0.6549886 ], L=36.83683683683684, nx=10000: nan
# objective returned NaN/Inf for params [0.44734272 0.23207104 0.15368955 0.3818216  0.654682  ], L=37.03703703703704, nx=10000: nan
# objective returned NaN/Inf for params [0.44734922 0.23202683 0.15366647 0.3816495  0.6543754 ], L=37.23723723723724, nx=10000: nan
# objective returned NaN/Inf for params [0.4473558  0.23198263 0.15364341 0.38147742 0.6540688 ], L=37.43743743743744, nx=10000: nan
# objective returned NaN/Inf for params [0.44736233 0.23193842 0.15362035 0.38130528 0.6537622 ], L=37.63763763763764, nx=10000: nan
# objective returned NaN/Inf for params [0.44736883 0.23189422 0.1535973  0.3811332  0.6534557 ], L=37.83783783783784, nx=10000: nan
# objective returned NaN/Inf for params [0.44737536 0.23185001 0.15357424 0.38096103 0.653149  ], L=38.03803803803804, nx=10000: nan
# objective returned NaN/Inf for params [0.44738194 0.2318058  0.15355116 0.38078898 0.65284246], L=38.23823823823824, nx=10000: nan
# objective returned NaN/Inf for params [0.44738844 0.2317616  0.15352811 0.38061684 0.6525358 ], L=38.43843843843844, nx=10000: nan
# objective returned NaN/Inf for params [0.44739497 0.2317174  0.15350504 0.38044474 0.65222925], L=38.63863863863864, nx=10000: nan
# objective returned NaN/Inf for params [0.44740152 0.23167318 0.15348199 0.38027263 0.65192264], L=38.83883883883884, nx=10000: nan
# objective returned NaN/Inf for params [0.44740805 0.23162898 0.15345891 0.3801005  0.65161604], L=39.03903903903904, nx=10000: nan
# objective returned NaN/Inf for params [0.44741458 0.23158477 0.15343584 0.3799284  0.65130943], L=39.23923923923924, nx=10000: nan
# objective returned NaN/Inf for params [0.44742113 0.23154056 0.15341277 0.3797563  0.6510028 ], L=39.43943943943944, nx=10000: nan
# objective returned NaN/Inf for params [0.44742766 0.23149635 0.15338974 0.37958416 0.6506962 ], L=39.63963963963964, nx=10000: nan
# objective returned NaN/Inf for params [0.4474342  0.23145215 0.15336666 0.37941206 0.6503896 ], L=39.83983983983984, nx=10000: nan
# objective returned NaN/Inf for params [0.4474407  0.23140796 0.1533436  0.37923998 0.650083  ], L=40.04004004004004, nx=10000: nan
# objective returned NaN/Inf for params [0.44744727 0.23136376 0.15332054 0.3790679  0.6497765 ], L=40.24024024024024, nx=10000: nan
# objective returned NaN/Inf for params [0.4474538  0.23131955 0.15329748 0.37889576 0.64946985], L=40.44044044044044, nx=10000: nan
# objective returned NaN/Inf for params [0.44746032 0.23127533 0.15327443 0.37872365 0.64916337], L=40.64064064064064, nx=10000: nan
# objective returned NaN/Inf for params [0.44746688 0.23123114 0.15325135 0.37855157 0.6488567 ], L=40.84084084084084, nx=10000: nan
# objective returned NaN/Inf for params [0.4474734  0.23118693 0.1532283  0.37837943 0.64855015], L=41.04104104104104, nx=10000: nan
# objective returned NaN/Inf for params [0.44748017 0.23114301 0.15320534 0.37820765 0.64824474], L=41.24124124124124, nx=10000: nan
# objective returned NaN/Inf for params [0.44748932 0.2311025  0.15318367 0.3780402  0.6479535 ], L=41.44144144144144, nx=10000: nan
# objective returned NaN/Inf for params [0.44749853 0.23106195 0.153162   0.37787268 0.6476624 ], L=41.64164164164164, nx=10000: nan
# objective returned NaN/Inf for params [0.44750774 0.2310214  0.15314034 0.37770516 0.6473711 ], L=41.84184184184184, nx=10000: nan
# objective returned NaN/Inf for params [0.44751695 0.23098087 0.15311866 0.37753758 0.6470798 ], L=42.04204204204204, nx=10000: nan
# objective returned NaN/Inf for params [0.44752616 0.23094034 0.15309697 0.3773701  0.6467887 ], L=42.24224224224224, nx=10000: nan
# objective returned NaN/Inf for params [0.44753537 0.2308998  0.1530753  0.3772025  0.6464974 ], L=42.44244244244244, nx=10000: nan
# objective returned NaN/Inf for params [0.44754452 0.23085926 0.15305363 0.37703502 0.64620626], L=42.64264264264264, nx=10000: nan
# objective returned NaN/Inf for params [0.44755378 0.23081872 0.15303195 0.3768675  0.64591503], L=42.84284284284285, nx=10000: nan
# objective returned NaN/Inf for params [0.44756293 0.23077817 0.1530103  0.37669995 0.6456238 ], L=43.04304304304305, nx=10000: nan
# objective returned NaN/Inf for params [0.44757214 0.23073764 0.1529886  0.37653244 0.6453326 ], L=43.24324324324325, nx=10000: nan
# objective returned NaN/Inf for params [0.44758135 0.23069711 0.15296696 0.3763649  0.6450414 ], L=43.44344344344345, nx=10000: nan
# objective returned NaN/Inf for params [0.44759056 0.23065656 0.15294528 0.37619737 0.6447501 ], L=43.64364364364365, nx=10000: nan
# objective returned NaN/Inf for params [0.44759977 0.23061605 0.1529236  0.37602988 0.644459  ], L=43.84384384384385, nx=10000: nan
# objective returned NaN/Inf for params [0.44760898 0.23057547 0.15290192 0.3758623  0.6441677 ], L=44.04404404404405, nx=10000: nan
# objective returned NaN/Inf for params [0.4476182  0.23053496 0.15288024 0.37569478 0.64387643], L=44.24424424424425, nx=10000: nan
# objective returned NaN/Inf for params [0.44762734 0.23049442 0.15285857 0.3755273  0.64358526], L=44.44444444444445, nx=10000: nan
# objective returned NaN/Inf for params [0.44763654 0.23045386 0.15283689 0.37535974 0.6432941 ], L=44.64464464464465, nx=10000: nan
# objective returned NaN/Inf for params [0.44764575 0.23041333 0.15281522 0.3751922  0.6430028 ], L=44.84484484484485, nx=10000: nan
# objective returned NaN/Inf for params [0.44765496 0.2303728  0.15279356 0.3750247  0.64271164], L=45.04504504504505, nx=10000: nan
# objective returned NaN/Inf for params [0.44766417 0.23033227 0.15277188 0.37485716 0.6424204 ], L=45.24524524524525, nx=10000: nan
# objective returned NaN/Inf for params [0.44767338 0.23029171 0.15275022 0.37468964 0.6421292 ], L=45.44544544544545, nx=10000: nan
# objective returned NaN/Inf for params [0.4476826  0.23025118 0.15272853 0.3745221  0.64183795], L=45.64564564564565, nx=10000: nan
# objective returned NaN/Inf for params [0.44769174 0.23021065 0.15270686 0.37435457 0.6415467 ], L=45.84584584584585, nx=10000: nan
# objective returned NaN/Inf for params [0.44770095 0.2301701  0.1526852  0.37418705 0.6412555 ], L=46.04604604604605, nx=10000: nan
# objective returned NaN/Inf for params [0.44771016 0.23012958 0.15266351 0.37401956 0.6409643 ], L=46.24624624624625, nx=10000: nan
# objective returned NaN/Inf for params [0.44771937 0.23008902 0.15264183 0.37385198 0.64067304], L=46.44644644644645, nx=10000: nan
# objective returned NaN/Inf for params [0.44772857 0.2300485  0.15262017 0.37368444 0.6403819 ], L=46.64664664664665, nx=10000: nan
# objective returned NaN/Inf for params [0.44773778 0.23000796 0.1525985  0.37351692 0.6400907 ], L=46.84684684684685, nx=10000: nan
# objective returned NaN/Inf for params [0.447747   0.22996743 0.15257682 0.37334943 0.6397994 ], L=47.04704704704705, nx=10000: nan
# objective returned NaN/Inf for params [0.44775614 0.22992688 0.15255515 0.37318185 0.6395082 ], L=47.24724724724725, nx=10000: nan
# objective returned NaN/Inf for params [0.44776535 0.22988634 0.15253349 0.37301436 0.639217  ], L=47.44744744744745, nx=10000: nan
# objective returned NaN/Inf for params [0.44777456 0.2298458  0.15251179 0.37284678 0.6389258 ], L=47.64764764764765, nx=10000: nan
# objective returned NaN/Inf for params [0.44778377 0.22980528 0.15249012 0.37267926 0.63863456], L=47.84784784784785, nx=10000: nan
# objective returned NaN/Inf for params [0.44779298 0.22976471 0.15246846 0.37251177 0.63834333], L=48.04804804804805, nx=10000: nan
# objective returned NaN/Inf for params [0.4478022  0.22972418 0.15244678 0.37234426 0.6380521 ], L=48.24824824824825, nx=10000: nan
# objective returned NaN/Inf for params [0.4478114  0.22968365 0.15242511 0.3721767  0.6377609 ], L=48.44844844844845, nx=10000: nan
# objective returned NaN/Inf for params [0.4478206  0.22964309 0.15240343 0.3720092  0.63746965], L=48.64864864864865, nx=10000: nan
# objective returned NaN/Inf for params [0.4478298  0.22960258 0.15238176 0.37184164 0.6371785 ], L=48.84884884884885, nx=10000: nan
# objective returned NaN/Inf for params [0.44783896 0.22956204 0.1523601  0.37167412 0.63688725], L=49.04904904904905, nx=10000: nan
# objective returned NaN/Inf for params [0.44784817 0.2295215  0.15233842 0.3715066  0.636596  ], L=49.24924924924925, nx=10000: nan
# objective returned NaN/Inf for params [0.44785738 0.22948097 0.15231675 0.37133905 0.6363048 ], L=49.44944944944945, nx=10000: nan
# objective returned NaN/Inf for params [0.4478666  0.2294404  0.15229507 0.37117153 0.6360136 ], L=49.64964964964965, nx=10000: nan
# objective returned NaN/Inf for params [0.4478758  0.22939987 0.15227342 0.371004   0.63572234], L=49.84984984984985, nx=10000: nan
# objective returned NaN/Inf for params [0.447885   0.22935934 0.15225172 0.37083647 0.6354312 ], L=50.050050050050054, nx=10000: nan
# objective returned NaN/Inf for params [0.44789422 0.22931881 0.15223005 0.37066898 0.63513994], L=50.250250250250254, nx=10000: nan
# objective returned NaN/Inf for params [0.44790336 0.22927825 0.15220837 0.3705014  0.6348487 ], L=50.450450450450454, nx=10000: nan
# objective returned NaN/Inf for params [0.44791257 0.22923772 0.1521867  0.3703339  0.63455755], L=50.650650650650654, nx=10000: nan
# objective returned NaN/Inf for params [0.44792178 0.22919719 0.15216503 0.3701664  0.63426626], L=50.850850850850854, nx=10000: nan
# objective returned NaN/Inf for params [0.447931   0.22915666 0.15214334 0.36999884 0.6339751 ], L=51.051051051051054, nx=10000: nan
# objective returned NaN/Inf for params [0.4479402  0.22911611 0.15212166 0.36983132 0.6336839 ], L=51.251251251251254, nx=10000: nan
# objective returned NaN/Inf for params [0.4479494  0.22907558 0.15210001 0.3696638  0.6333926 ], L=51.451451451451454, nx=10000: nan
# objective returned NaN/Inf for params [0.44795862 0.22903503 0.15207833 0.36949626 0.6331014 ], L=51.651651651651655, nx=10000: nan
# objective returned NaN/Inf for params [0.4479678  0.22899449 0.15205666 0.36932874 0.63281024], L=51.851851851851855, nx=10000: nan
# objective returned NaN/Inf for params [0.44797698 0.22895396 0.15203498 0.36916122 0.63251895], L=52.052052052052055, nx=10000: nan
# objective returned NaN/Inf for params [0.4479862  0.22891343 0.1520133  0.36899367 0.6322278 ], L=52.252252252252255, nx=10000: nan
# objective returned NaN/Inf for params [0.4479954  0.2288729  0.15199165 0.36882615 0.63193655], L=52.452452452452455, nx=10000: nan
# objective returned NaN/Inf for params [0.4480046  0.22883233 0.15196997 0.3686586  0.6316453 ], L=52.652652652652655, nx=10000: nan
# objective returned NaN/Inf for params [0.4480138  0.22879182 0.1519483  0.3684911  0.63135415], L=52.852852852852855, nx=10000: nan
# objective returned NaN/Inf for params [0.448023   0.22875127 0.15192664 0.3683236  0.63106287], L=53.053053053053056, nx=10000: nan
# objective returned negative key rate -4.3975452983483987e-05 for params [0.4480322  0.22871074 0.15190494 0.36815602 0.6307717 ], L=53.253253253253256, nx=10000
# objective returned negative key rate -4.3534686280800255e-05 for params [0.44804138 0.22867018 0.1518833  0.36798853 0.63048047], L=53.453453453453456, nx=10000
# objective returned negative key rate -1e+250 for params [0.4480506  0.22862965 0.15186161 0.367821   0.6301892 ], L=53.653653653653656, nx=10000
# objective returned negative key rate -4.266680969218019e-05 for params [0.4480598  0.22858912 0.15183994 0.36765346 0.629898  ], L=53.853853853853856, nx=10000
# objective returned negative key rate -4.223961561490266e-05 for params [0.448069   0.22854859 0.15181828 0.36748594 0.6296068 ], L=54.054054054054056, nx=10000
# objective returned negative key rate -1e+250 for params [0.4480782  0.22850806 0.1517966  0.36731842 0.62931556], L=54.254254254254256, nx=10000
# objective returned negative key rate -4.1398456291163686e-05 for params [0.4480874  0.2284675  0.15177491 0.36715087 0.6290243 ], L=54.454454454454456, nx=10000
# objective returned negative key rate -1e+250 for params [0.4480966  0.22842696 0.15175323 0.36698335 0.62873316], L=54.65465465465466, nx=10000
# objective returned negative key rate -4.057465645625985e-05 for params [0.4481058  0.22838642 0.15173155 0.3668158  0.6284419 ], L=54.85485485485486, nx=10000
# objective returned negative key rate -4.016916502246598e-05 for params [0.44811502 0.2283459  0.15170988 0.3666483  0.6281507 ], L=55.05505505505506, nx=10000
# objective returned negative key rate -1e+250 for params [0.4481242  0.22830534 0.1516882  0.36648077 0.6278595 ], L=55.25525525525526, nx=10000
# objective returned negative key rate -1e+250 for params [0.44813338 0.22826481 0.15166655 0.36631322 0.62756824], L=55.45545545545546, nx=10000
# objective returned negative key rate -1e+250 for params [0.4481426  0.22822426 0.15164487 0.3661457  0.627277  ], L=55.65565565565566, nx=10000
# objective returned negative key rate -1e+250 for params [0.4481518  0.22818375 0.15162319 0.3659782  0.6269858 ], L=55.85585585585586, nx=10000
# objective returned negative key rate -1e+250 for params [0.448161   0.22814319 0.15160151 0.36581063 0.6266946 ], L=56.05605605605606, nx=10000
# objective returned negative key rate -3.7822968810925064e-05 for params [0.4481702  0.22810265 0.15157986 0.36564314 0.62640345], L=56.25625625625626, nx=10000
# objective returned negative key rate -3.7445999407108196e-05 for params [0.44817942 0.22806212 0.15155819 0.36547562 0.62611216], L=56.45645645645646, nx=10000
# objective returned negative key rate -1e+250 for params [0.44818857 0.22802159 0.15153651 0.36530808 0.625821  ], L=56.65665665665666, nx=10000
# objective returned negative key rate -3.670375881990638e-05 for params [0.44819778 0.22798103 0.15151483 0.36514056 0.62552977], L=56.85685685685686, nx=10000
# objective returned negative key rate -3.633839345635299e-05 for params [0.448207   0.2279405  0.15149316 0.36497298 0.6252385 ], L=57.05705705705706, nx=10000
# objective returned negative key rate -1e+250 for params [0.4482162  0.22789997 0.1514715  0.3648055  0.6249473 ], L=57.25725725725726, nx=10000
# objective returned negative key rate -1e+250 for params [0.44823217 0.22785944 0.15144111 0.36463964 0.62469584], L=57.45745745745746, nx=10000
# objective returned negative key rate -1e+250 for params [0.44824857 0.22781889 0.15141027 0.36447385 0.6244464 ], L=57.65765765765766, nx=10000
# objective returned negative key rate -3.492659407093472e-05 for params [0.4482649  0.22777836 0.15137944 0.36430803 0.624197  ], L=57.85785785785786, nx=10000
# objective returned negative key rate -3.458374856078985e-05 for params [0.4482812  0.22773784 0.15134859 0.36414224 0.6239476 ], L=58.05805805805806, nx=10000
# objective returned negative key rate -3.424442962853096e-05 for params [0.4482976  0.22769731 0.15131778 0.36397642 0.62369823], L=58.25825825825826, nx=10000
# objective returned negative key rate -1e+250 for params [0.4483139  0.22765678 0.15128694 0.36381063 0.6234487 ], L=58.45845845845846, nx=10000
# objective returned negative key rate -1e+250 for params [0.44833022 0.22761624 0.15125611 0.36364484 0.62319934], L=58.65865865865866, nx=10000
# objective returned negative key rate -1e+250 for params [0.44834656 0.2275757  0.15122528 0.36347902 0.62294996], L=58.85885885885886, nx=10000
# objective returned negative key rate -3.292161733181155e-05 for params [0.44836292 0.22753517 0.15119445 0.36331326 0.6227005 ], L=59.05905905905906, nx=10000
# objective returned negative key rate -3.2599363951973096e-05 for params [0.44837925 0.22749464 0.15116361 0.36314747 0.6224511 ], L=59.25925925925926, nx=10000
# objective returned negative key rate -1e+250 for params [0.44839558 0.22745413 0.1511328  0.36298165 0.62220174], L=59.45945945945946, nx=10000
# objective returned negative key rate -1e+250 for params [0.44841194 0.22741356 0.15110196 0.36281586 0.62195224], L=59.65965965965966, nx=10000
# objective returned negative key rate -3.165232413442677e-05 for params [0.44842827 0.22737305 0.15107113 0.3626501  0.62170285], L=59.85985985985987, nx=10000
# objective returned negative key rate -1e+250 for params [0.4484446  0.22733252 0.15104029 0.36248428 0.62145346], L=60.06006006006007, nx=10000
# objective returned negative key rate -3.1037064798349616e-05 for params [0.44846097 0.22729199 0.15100947 0.3623185  0.621204  ], L=60.26026026026027, nx=10000
# objective returned negative key rate -1e+250 for params [0.4484773  0.22725146 0.15097864 0.3621527  0.6209546 ], L=60.46046046046047, nx=10000
# objective returned negative key rate -1e+250 for params [0.44849363 0.22721092 0.1509478  0.36198694 0.62070525], L=60.66066066066067, nx=10000
# objective returned negative key rate -1e+250 for params [0.44851    0.22717038 0.15091698 0.3618211  0.62045574], L=60.86086086086087, nx=10000
# objective returned negative key rate -2.9844000423392618e-05 for params [0.44852632 0.22712986 0.15088615 0.36165532 0.62020636], L=61.06106106106107, nx=10000
# objective returned negative key rate -1e+250 for params [0.44854265 0.22708933 0.1508553  0.3614895  0.619957  ], L=61.26126126126127, nx=10000
# objective returned negative key rate -1e+250 for params [0.44855896 0.2270488  0.1508245  0.3613237  0.6197076 ], L=61.46146146146147, nx=10000
# objective returned negative key rate -1e+250 for params [0.44857535 0.22700825 0.15079366 0.3611579  0.6194581 ], L=61.66166166166167, nx=10000
# objective returned negative key rate -2.8699194039102566e-05 for params [0.44859168 0.22696772 0.15076283 0.3609921  0.61920875], L=61.86186186186187, nx=10000
# objective returned negative key rate -2.8420297750626027e-05 for params [0.44860798 0.22692719 0.15073201 0.36082634 0.6189593 ], L=62.06206206206207, nx=10000
# objective returned negative key rate -2.8144265753427372e-05 for params [0.44862437 0.22688666 0.15070117 0.36066055 0.61870986], L=62.26226226226227, nx=10000
# objective returned negative key rate -1e+250 for params [0.4486407  0.22684613 0.15067033 0.3604947  0.6184604 ], L=62.46246246246247, nx=10000
# objective returned negative key rate -1e+250 for params [0.448657   0.2268056  0.15063949 0.36032894 0.6182111 ], L=62.66266266266267, nx=10000
# objective returned negative key rate -1e+250 for params [0.4486734  0.22676507 0.15060867 0.36016318 0.61796165], L=62.86286286286287, nx=10000
# objective returned negative key rate -2.7068192108570143e-05 for params [0.4486897  0.22672454 0.15057784 0.35999733 0.6177122 ], L=63.06306306306307, nx=10000
# objective returned negative key rate -1e+250 for params [0.44870603 0.226684   0.150547   0.35983157 0.6174628 ], L=63.26326326326327, nx=10000
# objective returned negative key rate -1e+250 for params [0.44872242 0.22664347 0.15051618 0.35966575 0.6172134 ], L=63.46346346346347, nx=10000
# objective returned negative key rate -1e+250 for params [0.44873872 0.22660293 0.15048535 0.35949996 0.616964  ], L=63.66366366366367, nx=10000
# objective returned negative key rate -1e+250 for params [0.44875506 0.2265624  0.1504545  0.35933414 0.6167146 ], L=63.86386386386387, nx=10000
# objective returned negative key rate -1e+250 for params [0.44877145 0.22652186 0.15042369 0.35916835 0.61646515], L=64.06406406406407, nx=10000
# objective returned negative key rate -1e+250 for params [0.44878775 0.22648135 0.15039286 0.3590026  0.6162157 ], L=64.26426426426427, nx=10000
# objective returned negative key rate -1e+250 for params [0.44880408 0.22644082 0.15036203 0.3588368  0.6159663 ], L=64.46446446446447, nx=10000
# objective returned negative key rate -1e+250 for params [0.44882044 0.22640027 0.15033118 0.35867098 0.6157169 ], L=64.66466466466467, nx=10000
# objective returned negative key rate -1e+250 for params [0.44883677 0.22635974 0.15030035 0.35850513 0.6154675 ], L=64.86486486486487, nx=10000
# objective returned negative key rate -1e+250 for params [0.4488531  0.22631921 0.15026954 0.35833937 0.61521804], L=65.06506506506507, nx=10000
# objective returned negative key rate -1e+250 for params [0.44886947 0.22627868 0.15023868 0.35817358 0.61496866], L=65.26526526526527, nx=10000
# objective returned negative key rate -1e+250 for params [0.4488858  0.22623815 0.15020786 0.35800782 0.6147193 ], L=65.46546546546547, nx=10000
# objective returned negative key rate -1e+250 for params [0.44890213 0.2261976  0.15017703 0.35784197 0.6144698 ], L=65.66566566566567, nx=10000
# objective returned negative key rate -1e+250 for params [0.44891846 0.22615708 0.1501462  0.3576762  0.61422044], L=65.86586586586587, nx=10000
# objective returned negative key rate -1e+250 for params [0.44893482 0.22611655 0.15011537 0.35751042 0.613971  ], L=66.06606606606607, nx=10000
# objective returned negative key rate -2.318169608541385e-05 for params [0.44895115 0.226076   0.15008453 0.3573446  0.61372155], L=66.26626626626627, nx=10000
# objective returned negative key rate -2.2959434713323073e-05 for params [0.4489675  0.22603549 0.15005371 0.35717884 0.61347216], L=66.46646646646647, nx=10000
# objective returned negative key rate -1e+250 for params [0.44898385 0.22599494 0.15002288 0.35701305 0.6132228 ], L=66.66666666666667, nx=10000
# objective returned negative key rate -2.252171566570489e-05 for params [0.44900018 0.22595441 0.14999205 0.35684723 0.61297333], L=66.86686686686687, nx=10000
# objective returned negative key rate -1e+250 for params [0.4490165  0.22591388 0.14996123 0.35668144 0.6127239 ], L=67.06706706706707, nx=10000
# objective returned negative key rate -2.2092933204200748e-05 for params [0.44903287 0.22587337 0.14993039 0.35651562 0.6124745 ], L=67.26726726726727, nx=10000
# objective returned negative key rate -1e+250 for params [0.4490492  0.2258328  0.14989956 0.35634983 0.6122251 ], L=67.46746746746747, nx=10000
# objective returned negative key rate -1e+250 for params [0.4490655  0.22579229 0.14986871 0.35618407 0.6119757 ], L=67.66766766766767, nx=10000
# objective returned negative key rate -1e+250 for params [0.4490819  0.22575176 0.1498379  0.35601822 0.6117263 ], L=67.86786786786787, nx=10000
# objective returned negative key rate -2.1261437166453345e-05 for params [0.44909823 0.22571123 0.14980707 0.35585245 0.6114769 ], L=68.06806806806807, nx=10000
# objective returned negative key rate -2.1058859964490973e-05 for params [0.44911453 0.2256707  0.14977622 0.35568666 0.61122745], L=68.26826826826827, nx=10000
# objective returned negative key rate -2.085836747216705e-05 for params [0.44913092 0.22563018 0.1497454  0.35552084 0.61097807], L=68.46846846846847, nx=10000
# objective returned negative key rate -1e+250 for params [0.44914725 0.22558963 0.14971456 0.35535508 0.6107287 ], L=68.66866866866867, nx=10000
# objective returned negative key rate -1e+250 for params [0.44916356 0.2255491  0.14968373 0.3551893  0.6104792 ], L=68.86886886886887, nx=10000
# objective returned negative key rate -1e+250 for params [0.4491799  0.22550857 0.1496529  0.35502347 0.6102298 ], L=69.06906906906907, nx=10000
# objective returned negative key rate -2.007672030679442e-05 for params [0.44919625 0.22546804 0.14962208 0.35485768 0.6099804 ], L=69.26926926926927, nx=10000
# objective returned negative key rate -1e+250 for params [0.44921258 0.22542751 0.14959125 0.3546919  0.60973096], L=69.46946946946947, nx=10000
# objective returned negative key rate -1e+250 for params [0.4492289  0.22538696 0.1495604  0.35452607 0.6094816 ], L=69.66966966966967, nx=10000
# objective returned negative key rate -1e+250 for params [0.44924527 0.22534645 0.14952958 0.3543603  0.6092322 ], L=69.86986986986987, nx=10000
# objective returned negative key rate -1.932662324875097e-05 for params [0.4492616  0.2253059  0.14949876 0.35419452 0.6089827 ], L=70.07007007007007, nx=10000
# objective returned negative key rate -1e+250 for params [0.44927794 0.22526537 0.14946793 0.35402867 0.60873336], L=70.27027027027027, nx=10000
# objective returned negative key rate -1.8963008816510193e-05 for params [0.4492943  0.22522485 0.1494371  0.3538629  0.6084839 ], L=70.47047047047047, nx=10000
# ...
# objective returned negative key rate -1e+250 for params [0.4376012  0.29566294 0.507353   0.37784263 0.7656214 ], L=163.76376376376376, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43734732 0.29486096 0.5097481  0.37553647 0.76459706], L=163.96396396396398, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43683973 0.29325706 0.514538   0.37092432 0.7625481 ], L=164.36436436436438, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4365859  0.2924551  0.516933   0.36861828 0.7615235 ], L=164.56456456456456, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43633214 0.29165313 0.519328   0.36631212 0.760499  ], L=164.76476476476478, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43582448 0.29004928 0.524118   0.36170003 0.75845015], L=165.16516516516518, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43557066 0.28924733 0.52651286 0.35939398 0.75742567], L=165.36536536536536, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4353169  0.28844538 0.5289078  0.35708794 0.75640124], L=165.56556556556558, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43480924 0.28684148 0.5336978  0.35247573 0.7543523 ], L=165.96596596596598, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4345554  0.2860395  0.5360929  0.35016963 0.7533278 ], L=166.16616616616616, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43430158 0.28523755 0.53848785 0.34786347 0.7523033 ], L=166.36636636636638, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43303257 0.28122783 0.55046254 0.33633313 0.74718094], L=167.36736736736736, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43277878 0.28042588 0.5528575  0.33402714 0.74615645], L=167.56756756756758, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43125588 0.2756142  0.5672273  0.3201907  0.7400096 ], L=168.76876876876878, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43074828 0.2740103  0.57201725 0.3155785  0.7379607 ], L=169.16916916916918, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4294792  0.27000055 0.5839922  0.3040482  0.7328383 ], L=170.17017017017017, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42846397 0.26679277 0.5935721  0.29482386 0.7287405 ], L=170.970970970971, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42821014 0.26599085 0.5959669  0.29251787 0.727716  ], L=171.17117117117118, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42744872 0.26358497 0.6031519  0.28559962 0.7246426 ], L=171.7717717717718, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4264335  0.2603772  0.61273175 0.27637538 0.7205447 ], L=172.5725725725726, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42465684 0.25476354 0.6294966  0.26023284 0.71337336], L=173.97397397397398, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.424403   0.2539616  0.63189137 0.25792673 0.7123489 ], L=174.1741741741742, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4241492  0.25315967 0.63428646 0.25562075 0.71132445], L=174.37437437437438, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42338777 0.25075382 0.64147127 0.24870245 0.70825106], L=174.974974974975, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42313394 0.24995187 0.6438663  0.24639641 0.70722663], L=175.17517517517518, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42262635 0.24834794 0.6486563  0.24178419 0.70517766], L=175.57557557557558, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42237252 0.24754603 0.6510511  0.23947819 0.7041532 ], L=175.7757757757758, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4218649  0.2459421  0.6558412  0.23486595 0.7021042 ], L=176.1761761761762, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4216111  0.24514018 0.658236   0.23255996 0.7010797 ], L=176.37637637637638, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42135727 0.24433823 0.6606311  0.23025386 0.70005536], L=176.5765765765766, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42110348 0.24353626 0.6630261  0.22794779 0.6990308 ], L=176.77677677677679, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4210985  0.24147515 0.66673404 0.22505407 0.69391614], L=176.976976976977, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42119724 0.23680305 0.6747229  0.21900997 0.6819007 ], L=177.3773773773774, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4212466  0.23446697 0.6787175  0.21598782 0.6758929 ], L=177.57757757757759, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42129597 0.23213105 0.68271184 0.21296594 0.6698856 ], L=177.7777777777778, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4213453  0.22979496 0.6867064  0.2099438  0.6638778 ], L=177.977977977978, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42139468 0.22745897 0.69070095 0.20692183 0.6578702 ], L=178.1781781781782, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42144403 0.22512288 0.6946954  0.20389973 0.6518623 ], L=178.3783783783784, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4214934  0.22278683 0.6986899  0.20087759 0.6458547 ], L=178.5785785785786, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42154273 0.22045082 0.70268434 0.19785567 0.639847  ], L=178.7787787787788, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4215921  0.2181148  0.70667875 0.19483362 0.63383937], L=178.978978978979, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4216908  0.21344276 0.7146678  0.18878952 0.62182415], L=179.3793793793794, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4218389  0.20643456 0.7266515  0.1797233  0.603801  ], L=179.97997997998, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42188826 0.2040986  0.7306458  0.17670144 0.5977934 ], L=180.1801801801802, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42193764 0.20176253 0.7346403  0.17367928 0.59178567], L=180.3803803803804, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42198697 0.19942649 0.7386348  0.17065723 0.58577794], L=180.5805805805806, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42203635 0.1970905  0.7426293  0.16763523 0.57977045], L=180.7807807807808, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4220857 0.1947544 0.7466239 0.1646131 0.5737626], L=180.980980980981, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42213508 0.19241838 0.75061834 0.16159113 0.5677549 ], L=181.1811811811812, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4221844  0.19008234 0.7546129  0.15856908 0.56174725], L=181.3813813813814, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42223376 0.18774638 0.7586073  0.15554707 0.5557398 ], L=181.5815815815816, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42228314 0.18541029 0.7626018  0.15252496 0.549732  ], L=181.7817817817818, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42238185 0.18073827 0.7705908  0.146481   0.53771675], L=182.1821821821822, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42248058 0.17606612 0.77857983 0.14043668 0.5257012 ], L=182.5825825825826, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4225299  0.17373012 0.7825743  0.13741477 0.5196937 ], L=182.7827827827828, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42257926 0.17139408 0.7865687  0.13439266 0.513686  ], L=182.982982982983, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42267802 0.16672207 0.7945577  0.1283487  0.50167084], L=183.3833833833834, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42277676 0.16204995 0.80254674 0.12230445 0.48965544], L=183.7837837837838, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42287543 0.15737785 0.8105358  0.11626038 0.47763997], L=184.1841841841842, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42292482 0.15504187 0.8145301  0.11323848 0.4716323 ], L=184.3843843843844, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42297414 0.15270579 0.81852466 0.1102164  0.4656246 ], L=184.5845845845846, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42302352 0.1503698  0.82251924 0.10719425 0.45961702], L=184.7847847847848, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42307287 0.14803374 0.82651365 0.10417227 0.45360932], L=184.984984984985, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42312226 0.14569765 0.8305083  0.10115014 0.44760156], L=185.1851851851852, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42317158 0.1433617  0.8345026  0.09812818 0.44159418], L=185.3853853853854, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42322093 0.14102562 0.83849704 0.0951061  0.43558627], L=185.5855855855856, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42327031 0.13868953 0.84249187 0.09208398 0.42957848], L=185.7857857857858, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42336905 0.13401745 0.85048074 0.08603995 0.4175631 ], L=186.1861861861862, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42341837 0.13168152 0.854475   0.083018   0.41155565], L=186.3863863863864, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42346776 0.12934549 0.8584696  0.07999592 0.40554807], L=186.5865865865866, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4235171  0.12700939 0.86246425 0.07697381 0.39954022], L=186.7867867867868, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42356643 0.12467334 0.86645865 0.07395175 0.39353248], L=186.986986986987, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4236158  0.12233734 0.87045324 0.07092973 0.38752493], L=187.1871871871872, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4236652  0.12000127 0.8744475  0.06790767 0.38151717], L=187.3873873873874, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42371455 0.11766528 0.8784421  0.06583714 0.37550965], L=187.5875875875876, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42376387 0.11532933 0.8794155  0.06583714 0.3695021 ], L=187.7877877877878, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42381325 0.11299324 0.8794155  0.06583714 0.36349434], L=187.987987987988, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4238626  0.11065716 0.8794155  0.06583714 0.3574866 ], L=188.1881881881882, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.423912   0.10832108 0.8794155  0.06583714 0.35147882], L=188.3883883883884, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42396137 0.10598508 0.8794155  0.06583714 0.34547117], L=188.5885885885886, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4240107  0.10364907 0.8794155  0.06583714 0.33946356], L=188.7887887887888, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42406005 0.10131298 0.8794155  0.06583714 0.3334558 ], L=188.988988988989, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42410943 0.09897704 0.8794155  0.06583714 0.3274484 ], L=189.1891891891892, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42415878 0.09664103 0.8794155  0.06583714 0.3214407 ], L=189.3893893893894, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4242081  0.09430491 0.8794155  0.06583714 0.31543282], L=189.5895895895896, nx=1000000000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/222585919.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to relative_error_nx_1e+09_epoch_4999.png
# --- Plotting Time: 1.26 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3821646061.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3821646061.py:91: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/2821489376.py:43: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linestyle='-', linewidth=2.0, alpha=1.0)  # Thicker line, semi-transparent
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/2821489376.py:45: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r', label='Predicted Key Rate',
# Absolute differences plot saved to absolute_differences_nx_1e+09.png
# --- Plotting Time: 1.26 seconds ---
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+04_epoch_4999.json
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+05_epoch_4999.json
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+06_epoch_4999.json
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+07_epoch_4999.json
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+08_epoch_4999.json
# Saved predicted dataset to datasets_json/predicted_keyrate_params_nx_1e+09_epoch_4999.json
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/2821489376.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Key rate subplots saved to keyrate_subplots_last_epoch.png
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/4242544360.py:90: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/1809396058.py:53: RuntimeWarning: divide by zero encountered in log10
#   ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r:', label='Predicted Key Rate', linewidth=4.0)
# Parameter subplots saved to parameters_subplots_last_epoch.png
# Key rate subplots with relative error saved to keyrate_subplots_with_rel_error_last_epoch.png
# Model saved to bb84_nn_model.pth
# Epoch 5000/5000, Train Loss: 0.0002, Val Loss: 0.0002, Learning Rate: 0.000001, Time: 19.91s (Eval: 15.26s, Plot: 4.34s)
# --- Total Training Time: 1216.89 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/1809396058.py:84: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# import time 

# # Start total training time measurement
# total_start_time = time.time()
# # Training loop
# num_epochs = 5000
# for epoch in range(num_epochs):
#     start_time = time.time()

#     # Training phase
#     model.train()
#     running_loss = 0.0
#     for inputs, targets in train_loader:
#         inputs, targets = inputs.to(device), targets.to(device)
#         optimizer.zero_grad()
#         outputs = model(inputs)
#         loss = criterion(outputs, targets)
#         loss.backward()
#         optimizer.step()
#         running_loss += loss.item() * inputs.size(0)
#     epoch_loss = running_loss / len(train_loader.dataset)
#     train_losses.append(epoch_loss)

#     # Validation phase
#     model.eval()
#     val_running_loss = 0.0
#     with torch.no_grad():
#         for inputs, targets in val_loader:
#             inputs, targets = inputs.to(device), targets.to(device)
#             outputs = model(inputs)
#             loss = criterion(outputs, targets)
#             val_running_loss += loss.item() * inputs.size(0)
#     val_loss = val_running_loss / len(val_loader.dataset)
#     val_losses.append(val_loss)

#     # Update learning rate
#     scheduler.step(val_loss)
#     current_lr = optimizer.param_groups[0]['lr']
#     learning_rates.append(current_lr)

#     # Evaluate and plot at the first and last epochs
#     eval_time = 0
#     plot_time = 0
#     if epoch == 0 or epoch == num_epochs - 1:
#         model.eval()
#         with torch.no_grad():
#             # Prepare data for all n_X values
#             plot_data = {}
#             eval_start = time.time()
#             for nx, eval_data in all_evaluation_data.items():
#                 fiber_lengths = eval_data['fiber_lengths']
#                 optimized_params_array = eval_data['optimized_params_array']
#                 optimized_key_rates = eval_data['optimized_key_rates']
#                 X_test_tensor = eval_data['X_test_tensor']

#                 # Compute predicted parameters and key rates
#                 predicted_params_scaled = model(X_test_tensor).cpu().numpy()
#                 predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
#                 predicted_params = y_scaler.inverse_transform(predicted_params_scaled)
#                 predicted_params[:, 0] = np.maximum(predicted_params[:, 0], 1e-6)
#                 predicted_params[:, 1] = np.maximum(predicted_params[:, 1], 1e-6)
#                 predicted_params[:, 2] = np.clip(predicted_params[:, 2], 0, 1)
#                 predicted_params[:, 3] = np.clip(predicted_params[:, 3], 0, 1)
#                 predicted_params[:, 4] = np.clip(predicted_params[:, 4], 0, 1)
#                 predicted_key_rates = []
#                 for params, L in zip(predicted_params, fiber_lengths):
#                     key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
#                     predicted_key_rates.append(key_rate)
#                 predicted_key_rates = np.array(predicted_key_rates)

#                 # Store data for plotting
#                 plot_data[nx] = {
#                     'fiber_lengths': fiber_lengths,
#                     'optimized_key_rates': optimized_key_rates,
#                     'predicted_key_rates': predicted_key_rates,
#                     'optimized_params_array': optimized_params_array,
#                     'predicted_params_array': predicted_params
#                 }
#             eval_time += time.time() - eval_start

#             # Plot subplots at the first and last epochs
#             plot_start = time.time()
#             if epoch == 0:
#                 plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_first_epoch.png')
#                 plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_first_epoch.png')
#             if epoch == num_epochs - 1:
#                 plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_last_epoch.png')
#                 plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
#             plot_time += time.time() - plot_start

#             torch.save(model.state_dict(), 'bb84_nn_model.pth')
#             print("Model saved to bb84_nn_model.pth")

#             # Plot relative errors
#             plot_relative_errors(
#                 fiber_lengths, optimized_key_rates, optimized_params_array,
#                 predicted_key_rates, predicted_params, epoch,
#                 f'relative_error_nx_{nx:.0e}_epoch_{epoch}.png', nx=nx
#             )
#             # Add absolute differences plot for this n_X
#             plot_absolute_differences_keyrate_and_parameters(
#                 fiber_lengths, optimized_key_rates, optimized_params_array,
#                 predicted_key_rates, predicted_params, epoch,
#                 filename=f'absolute_differences_nx_{nx:.0e}.png', nx=nx
#             )
#     # Print epoch results with timing and learning rate
#     epoch_time = time.time() - start_time
#     print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
#           f"Learning Rate: {current_lr:.6f}, Time: {epoch_time:.2f}s (Eval: {eval_time:.2f}s, Plot: {plot_time:.2f}s)")

# # Print total training time
# total_training_time = time.time() - total_start_time
# print(f"--- Total Training Time: {total_training_time:.2f} seconds ---")

# %%
# %%
# Plotting the losses with smoothing
def moving_average(data, window_size=5):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

epochs = range(1, len(train_losses) + 1)
window_size = 5
smoothed_train_losses = moving_average(train_losses, window_size)
smoothed_val_losses = moving_average(val_losses, window_size)
smoothed_epochs = range(window_size, len(train_losses) + 1)

# %%
plt.figure(figsize=(12, 6))
# plt.plot(smoothed_epochs, smoothed_train_losses, label='Smoothed Training Loss', linestyle='-')
# plt.plot(smoothed_epochs, smoothed_val_losses, label='Smoothed Validation Loss', linestyle='--')
plt.plot(epochs, train_losses, label='Training Loss', linestyle='-', alpha=0.3)
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--', alpha=0.5)
plt.xlabel('Epochs')
plt.ylim(0, 0.002)
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_plot.png', dpi=150)
plt.show()
# plt.close()

print("Training Complete")

# Plotting the learning rates
plt.figure(figsize=(12, 6))
plt.plot(epochs, learning_rates, label='Learning Rate', linestyle='-', color='tab:blue')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')
plt.grid(True)
plt.tight_layout()
plt.savefig('learning_rate_plot.png', dpi=150)
plt.show()
# plt.close()
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/2391135169.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Training Complete
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/2391135169.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

# Assuming you have your training and validation losses, epochs, and learning rates
# For example, let's create some dummy data:
epochs = np.arange(1, 101)  # Example: 100 epochs
train_losses = np.random.rand(100) * 0.001 + np.linspace(0.0005, 0.0001, 100)  # Example decreasing trend with noise
val_losses = np.random.rand(100) * 0.0005 + np.linspace(0.0007, 0.0002, 100) # Example decreasing trend with noise
learning_rates = np.linspace(0.01, 0.0001, 100)  # Example learning rate decay



# 1. Plotting Loss
plt.figure(figsize=(12, 6))
plt.plot(epochs, train_losses, label='Training Loss', linestyle='-', alpha=0.3)
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--', alpha=0.5)
plt.xlabel('Epochs')
plt.ylim(0, 0.002)
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_plot.png', dpi=150)
plt.show()


# 2. Finding Epochs Where Loss No Longer Decreases (or increases, more generally)
#    Focus on the validation loss, as that indicates generalization
val_loss_diff = np.diff(val_losses) # calculate the differences between consecutive validation loss values
# Find the indices where the difference is greater than a small tolerance (e.g., indicating no more significant decrease)

tolerance = 1e-6  # A small value to define when the loss stops decreasing significantly.  Adjust this.

increasing_epochs = np.where(val_loss_diff > tolerance)[0] + 1 # Add 1 to shift to epoch indices, not diff indices.

# Print the epochs where the validation loss starts to increase/stops decreasing
if len(increasing_epochs) > 0:
    print("Epochs where validation loss is no longer decreasing (or starts increasing):")
    for epoch in increasing_epochs:
        print(f"Epoch {epoch}: Loss = {val_losses[epoch-1]:.6f}") # Display the losses at these epochs.
else:
    print("Validation loss consistently decreases (or does not increase significantly) throughout the training.")

# 3. Plotting Learning Rate
plt.figure(figsize=(12, 6))
plt.plot(epochs, learning_rates, label='Learning Rate', linestyle='-', color='tab:blue')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')
plt.grid(True)
plt.tight_layout()
plt.savefig('learning_rate_plot.png', dpi=150)
plt.show()

print("Training Complete")
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/4145880424.py:25: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Epochs where validation loss is no longer decreasing (or starts increasing):
# Epoch 1: Loss = 0.001059
# Epoch 3: Loss = 0.000698
# Epoch 6: Loss = 0.000811
# Epoch 8: Loss = 0.000665
# Epoch 10: Loss = 0.000668
# Epoch 12: Loss = 0.000767
# Epoch 14: Loss = 0.000874
# Epoch 16: Loss = 0.000742
# Epoch 18: Loss = 0.000677
# Epoch 21: Loss = 0.000615
# Epoch 22: Loss = 0.000736
# Epoch 24: Loss = 0.000611
# Epoch 27: Loss = 0.000635
# Epoch 28: Loss = 0.000864
# Epoch 31: Loss = 0.000555
# Epoch 33: Loss = 0.000805
# Epoch 36: Loss = 0.000527
# Epoch 38: Loss = 0.000892
# Epoch 41: Loss = 0.000842
# Epoch 43: Loss = 0.000911
# Epoch 47: Loss = 0.000508
# Epoch 48: Loss = 0.000868
# Epoch 50: Loss = 0.000686
# Epoch 52: Loss = 0.000643
# Epoch 55: Loss = 0.000501
# Epoch 57: Loss = 0.000461
# Epoch 58: Loss = 0.000731
# Epoch 60: Loss = 0.000526
# Epoch 62: Loss = 0.000649
# Epoch 64: Loss = 0.000458
# Epoch 65: Loss = 0.000489
# Epoch 66: Loss = 0.000688
# Epoch 68: Loss = 0.000735
# Epoch 71: Loss = 0.000490
# Epoch 74: Loss = 0.000356
# Epoch 75: Loss = 0.000372
# Epoch 77: Loss = 0.000354
# Epoch 78: Loss = 0.000400
# Epoch 79: Loss = 0.000598
# Epoch 81: Loss = 0.000537
# Epoch 83: Loss = 0.000484
# Epoch 85: Loss = 0.000366
# Epoch 88: Loss = 0.000470
# Epoch 89: Loss = 0.000541
# Epoch 91: Loss = 0.000499
# Epoch 93: Loss = 0.000405
# Epoch 94: Loss = 0.000558
# Epoch 96: Loss = 0.000448
# Epoch 97: Loss = 0.000606
# Epoch 99: Loss = 0.000362
# Training Complete
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/4145880424.py:55: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np # Often needed for numerical operations like min/max

# Assuming epochs, train_losses, val_losses, learning_rates are defined from your training process
# Example dummy data - REPLACE WITH YOUR ACTUAL DATA
epochs = list(range(1, 5001))
# Simulate training loss decreasing
train_losses = [1.0 / (e + 50) + np.random.normal(0, 0.00005) for e in epochs]
# Simulate validation loss decreasing then plateauing/increasing slightly
val_losses = [1.0 / (e + 30) + np.random.normal(0, 0.00008) for e in epochs[:3500]] + \
             [1.0 / (3500 + 30) + np.random.normal(0, 0.0001) + (e - 3500)*1e-7 for e in epochs[3500:]] # Simulate slight increase after 3500

# Ensure losses are positive (common requirement) and scale example data
train_losses = np.maximum(0.0001, np.array(train_losses)).tolist()
val_losses = np.maximum(0.0002, np.array(val_losses)).tolist()

# Simulate learning rate (example: decay)
learning_rates = [0.001 * 0.95**(e/100) for e in epochs]
# --- End of dummy data ---


plt.figure(figsize=(12, 6))
plt.plot(epochs, train_losses, label='Training Loss', linestyle='-', alpha=0.3)
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--', alpha=0.5)
plt.xlabel('Epochs')
# Use max of data or user's limit for ylim
plt.ylim(0, max(max(train_losses), max(val_losses)) * 1.1 or 0.002)
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_plot.png', dpi=150)
plt.show()
# plt.close() # Keep commented if you want the plot to display immediately

print("Training Complete")

# --- New Code to Detect Plateau ---

# Define patience: how many epochs to wait for an improvement before declaring a plateau
patience = 50 # Adjust this value based on how much fluctuation you expect

# --- For Validation Loss ---
print("\nAnalyzing Validation Loss:")
best_val_loss = float('inf')
epochs_no_improve_val = 0
plateau_start_epoch_val = None

# Iterate through validation losses starting from 'patience' epochs in
# to allow for initial fluctuations
for i in range(patience, len(val_losses)):
    current_val_loss = val_losses[i]
    previous_val_loss = val_losses[i-1] # Compare to previous for general trend

    # Check if current loss is NOT significantly better than the best seen so far
    # Use a small epsilon to handle floating point noise
    # We are looking for when it stops decreasing or starts increasing
    # A simple check: is the loss NOT decreasing compared to the best seen?
    if current_val_loss >= best_val_loss - 1e-6: # Use >= to catch plateaus and increases
         epochs_no_improve_val += 1
    else: # Significant improvement
         best_val_loss = current_val_loss
         epochs_no_improve_val = 0
         plateau_start_epoch_val = None # Reset if we see improvement

    # If no significant improvement for 'patience' epochs and we haven't marked a plateau yet
    if epochs_no_improve_val >= patience and plateau_start_epoch_val is None:
         # The plateau started *after* the best loss was seen and improvement stopped
         # The epoch where the 'patience' period of no improvement *started* is the detection point.
         # This is the epoch 'patience' steps BEFORE the current epoch 'i'.
         plateau_start_epoch_val = epochs[i - patience]
         print(f"Validation loss showed no significant improvement for {patience} consecutive epochs starting around Epoch {plateau_start_epoch_val}.")
         # You can break here if you only want the first instance of a plateau
         # break


if plateau_start_epoch_val is None and epochs_no_improve_val > 0:
    # This handles the case where training finishes during a period of no improvement,
    # but the patience limit wasn't fully reached *before* the end.
     print(f"Validation loss showed no significant improvement over the last {epochs_no_improve_val} epochs.")
elif plateau_start_epoch_val is None:
     print("Validation loss was consistently improving or stable throughout training (no plateau of size >= patience detected).")


# --- For Training Loss ---
# Training loss should ideally always decrease slowly. Detecting a plateau
# often means the learning rate is too low or it's stuck in a shallow minimum.
# A simple way is to check the relative change over a window.
print("\nAnalyzing Training Loss:")
window_size = 100 # Look back over this many epochs

plateau_start_epoch_train = None
relative_loss_change_threshold = 1e-4 # Percentage change threshold (0.01%)

for i in range(window_size, len(train_losses)):
    loss_window = train_losses[i - window_size : i + 1]
    loss_at_start = loss_window[0]
    loss_at_end = loss_window[-1]
    avg_loss_in_window = np.mean(loss_window)

    # Check if the decrease over the window is smaller than a threshold
    # We also require the average loss to be above zero to avoid division by zero or noise issues at very low losses
    if avg_loss_in_window > 1e-9 and (loss_at_start - loss_at_end) / avg_loss_in_window < relative_loss_change_threshold:
        plateau_start_epoch_train = epochs[i - window_size]
        print(f"Training loss decrease over {window_size} epochs fell below a relative threshold of {relative_loss_change_threshold:.4f} starting around Epoch {plateau_start_epoch_train}.")
        # break # Uncomment to stop at the first training plateau detection

if plateau_start_epoch_train is None:
     print("Training loss was still decreasing significantly throughout training (no plateau of size >= window_size detected).")


# --- Plotting the learning rates (as provided by user) ---
plt.figure(figsize=(12, 6))
plt.plot(epochs, learning_rates, label='Learning Rate', linestyle='-', color='tab:blue')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')
plt.grid(True)
plt.tight_layout()
plt.savefig('learning_rate_plot.png', dpi=150)
plt.show()
# plt.close() # Keep commented if you want the plot to display immediately
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3035943954.py:34: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Training Complete
#
# Analyzing Validation Loss:
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 612.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 728.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 898.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1010.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1159.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1244.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1355.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1442.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1625.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1711.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1803.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 1885.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 2220.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 2303.
# Validation loss showed no significant improvement for 50 consecutive epochs starting around Epoch 2387.
#
# Analyzing Training Loss:
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 735.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 789.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 822.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 828.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 837.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 840.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 864.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 891.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 894.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 945.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 953.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 960.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 984.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1001.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1009.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1010.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1014.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1033.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1036.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1049.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1059.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1061.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1066.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1068.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1077.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1079.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1081.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1086.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1088.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1116.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1120.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1129.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1130.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1143.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1153.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1157.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1160.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1162.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1169.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1184.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1191.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1193.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1196.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1198.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1200.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1201.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1202.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1205.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1207.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1210.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1217.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1227.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1238.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1241.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1244.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1251.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1252.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1261.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1263.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1264.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1265.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1266.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1270.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1271.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1276.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1279.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1285.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1291.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1292.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1294.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1299.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1308.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1312.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1314.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1319.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1320.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1323.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1325.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1326.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1331.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1338.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1339.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1340.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1343.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1346.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1349.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1354.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1357.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1358.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1367.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1369.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1374.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1377.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1381.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1382.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1383.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1385.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1393.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1394.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1395.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1398.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1403.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1406.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1413.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1417.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1421.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1428.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1434.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1435.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1441.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1442.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1446.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1448.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1450.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1451.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1456.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1463.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1468.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1471.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1472.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1474.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1476.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1484.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1489.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1496.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1497.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1498.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1500.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1502.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1504.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1510.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1512.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1515.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1516.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1523.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1524.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1532.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1536.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1539.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1541.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1547.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1549.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1553.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1554.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1556.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1564.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1567.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1579.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1582.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1588.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1591.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1595.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1598.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1607.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1611.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1612.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1614.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1620.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1622.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1628.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1630.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1633.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1642.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1644.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1645.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1648.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1652.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1659.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1662.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1665.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1667.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1668.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1671.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1676.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1680.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1685.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1689.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1690.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1692.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1694.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1697.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1702.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1703.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1704.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1706.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1708.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1709.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1713.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1714.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1716.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1717.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1718.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1719.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1721.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1724.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1726.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1727.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1729.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1732.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1734.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1737.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1739.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1740.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1741.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1742.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1743.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1747.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1752.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1753.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1755.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1758.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1760.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1769.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1772.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1775.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1784.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1789.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1790.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1791.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1793.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1795.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1799.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1801.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1807.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1810.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1811.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1812.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1822.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1825.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1831.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1838.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1840.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1848.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1849.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1850.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1854.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1857.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1859.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1862.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1863.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1865.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1867.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1870.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1877.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1879.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1880.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1881.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1886.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1887.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1888.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1892.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1900.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1902.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1905.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1914.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1918.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1920.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1928.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1930.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1934.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1936.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1937.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1939.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1944.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1946.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1949.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1951.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1953.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1954.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1955.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1959.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1961.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1965.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1966.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1968.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1969.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1971.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1972.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1973.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1974.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1976.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1977.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1978.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1985.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1986.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1990.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1991.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1994.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1995.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1996.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1997.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1998.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 1999.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2003.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2004.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2006.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2007.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2008.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2009.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2010.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2011.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2012.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2016.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2020.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2022.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2026.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2027.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2028.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2029.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2030.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2032.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2033.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2042.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2043.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2047.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2048.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2050.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2052.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2058.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2060.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2067.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2069.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2070.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2079.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2080.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2083.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2087.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2092.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2093.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2099.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2102.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2103.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2105.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2106.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2111.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2115.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2117.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2118.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2119.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2121.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2123.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2124.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2131.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2132.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2133.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2136.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2137.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2141.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2144.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2149.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2153.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2155.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2156.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2157.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2158.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2164.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2172.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2174.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2175.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2176.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2180.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2181.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2182.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2184.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2185.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2188.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2189.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2190.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2191.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2195.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2197.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2198.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2201.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2202.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2206.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2207.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2208.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2213.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2214.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2216.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2219.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2220.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2221.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2224.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2229.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2231.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2234.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2235.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2240.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2243.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2245.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2246.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2250.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2259.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2263.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2267.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2268.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2270.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2272.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2273.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2275.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2276.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2279.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2282.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2286.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2294.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2297.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2298.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2300.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2304.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2311.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2315.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2317.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2318.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2325.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2332.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2335.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2336.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2338.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2339.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2346.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2347.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 2348.
# ...
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4599.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4601.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4604.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4608.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4609.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4610.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4613.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4614.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4615.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4616.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4618.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4622.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4623.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4626.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4629.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4631.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4633.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4634.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4635.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4636.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4638.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4639.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4640.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4642.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4643.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4647.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4651.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4652.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4653.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4655.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4656.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4657.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4661.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4664.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4668.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4669.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4671.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4680.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4683.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4688.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4689.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4690.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4692.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4693.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4696.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4697.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4699.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4700.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4701.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4703.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4705.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4706.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4707.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4714.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4718.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4719.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4720.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4721.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4724.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4725.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4727.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4728.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4730.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4732.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4733.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4735.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4736.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4737.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4741.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4744.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4745.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4746.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4749.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4750.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4751.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4753.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4757.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4758.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4759.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4760.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4762.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4765.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4766.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4768.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4770.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4772.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4773.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4776.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4777.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4782.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4784.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4785.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4791.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4792.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4795.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4798.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4802.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4808.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4809.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4811.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4812.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4813.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4815.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4816.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4823.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4826.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4828.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4830.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4831.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4832.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4833.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4834.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4835.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4837.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4838.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4839.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4840.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4841.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4848.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4849.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4850.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4857.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4858.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4863.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4865.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4867.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4871.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4873.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4874.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4875.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4876.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4877.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4878.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4879.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4881.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4883.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4885.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4886.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4889.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4890.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4892.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4894.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4895.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4896.
# Training loss decrease over 100 epochs fell below a relative threshold of 0.0001 starting around Epoch 4898.
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3035943954.py:123: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# %% [markdown]
# ### Test the Trained Model on n_X = 5e8 Dataset

# Load the saved model
model = BB84NN().to(device)
model.load_state_dict(torch.load('bb84_nn_model.pth'))
model.eval()
print("Loaded saved model for testing.")

# Evaluate the model on the n_X = 5e8 dataset
with torch.no_grad():
    predicted_params_scaled_un_seen = model(X_test_tensor_un_seen).cpu().numpy()
    predicted_params_scaled_un_seen = np.clip(predicted_params_scaled_un_seen, 0, 1)
    predicted_params_un_seen = y_scaler.inverse_transform(predicted_params_scaled_un_seen)
    print("Predicted parameters (mu_1, mu_2, P_mu_1, P_mu_2, P_X):")
    print(predicted_params_un_seen[:5])
    predicted_params_un_seen[:, 0] = np.maximum(predicted_params_un_seen[:, 0], 1e-6)
    predicted_params_un_seen[:, 1] = np.maximum(predicted_params_un_seen[:, 1], 1e-6)
    predicted_params_un_seen[:, 2] = np.clip(predicted_params_un_seen[:, 2], 0, 1)
    predicted_params_un_seen[:, 3] = np.clip(predicted_params_un_seen[:, 3], 0, 1)
    predicted_params_un_seen[:, 4] = np.clip(predicted_params_un_seen[:, 4], 0, 1)
    predicted_key_rates_un_seen = []
    valid_indices_pred = []
    for idx, (params, L) in enumerate(zip(predicted_params_un_seen, fiber_lengths_un_seen)):
        key_rate = safe_objective(params, L, target_nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
        if np.isnan(key_rate):
            print(f"NaN detected in predicted_key_rates_un_seen at index {idx} with params {params}, fiber_length={L}")
        else:
            predicted_key_rates_un_seen.append(key_rate)
            valid_indices_pred.append(idx)
    predicted_key_rates_un_seen = np.array(predicted_key_rates_un_seen)

    fiber_lengths_un_seen = fiber_lengths_un_seen[valid_indices_pred]
    optimized_key_rates_un_seen = optimized_key_rates_un_seen[valid_indices_pred]
    optimized_params_array_un_seen = optimized_params_array_un_seen[valid_indices_pred]
    predicted_params_un_seen = predicted_params_un_seen[valid_indices_pred]
    print(f"After filtering NaN in predicted_key_rates_un_seen, {len(predicted_key_rates_un_seen)} data points remain for n_X = 5e8.")

# Debug: Check for NaN in optimized_key_rates_un_seen and predicted_key_rates_un_seen
print("Checking for NaN in optimized_key_rates_un_seen:")
print(f"Number of NaN values: {np.isnan(optimized_key_rates_un_seen).sum()}")
print("Checking for NaN in predicted_key_rates_un_seen:")
print(f"Number of NaN values: {np.isnan(predicted_key_rates_un_seen).sum()}")
# Out:
# Loaded saved model for testing.
# Predicted parameters (mu_1, mu_2, P_mu_1, P_mu_2, P_X):
# [[0.49174497 0.35559565 0.18052845 0.7699288  0.8551783 ]
#  [0.4907131  0.35526213 0.18107088 0.76955384 0.8555565 ]
#  [0.48968118 0.35492855 0.18161334 0.7691789  0.8559347 ]
#  [0.4886493  0.35459507 0.18215576 0.7688039  0.85631305]
#  [0.4876174  0.35426152 0.18269818 0.76842886 0.85669124]]
# objective returned negative key rate -1e+250 for params [0.49174497 0.35559565 0.18052845 0.7699288  0.8551783 ], L=0.0, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4907131  0.35526213 0.18107088 0.76955384 0.8555565 ], L=2.0202020202020203, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48968118 0.35492855 0.18161334 0.7691789  0.8559347 ], L=4.040404040404041, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4886493  0.35459507 0.18215576 0.7688039  0.85631305], L=6.0606060606060606, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4876174  0.35426152 0.18269818 0.76842886 0.85669124], L=8.080808080808081, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48658556 0.35392803 0.18324064 0.76805407 0.8570697 ], L=10.101010101010102, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48555362 0.35359448 0.18378304 0.767679   0.85744774], L=12.121212121212121, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48452172 0.35326096 0.18432549 0.7673041  0.8578262 ], L=14.141414141414142, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48348984 0.35292745 0.18486787 0.76692903 0.8582045 ], L=16.161616161616163, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48245794 0.35259393 0.18541035 0.7665542  0.8585827 ], L=18.181818181818183, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48142606 0.3522604  0.18595277 0.7661792  0.8589609 ], L=20.202020202020204, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48039415 0.35192683 0.18649516 0.7658042  0.8593392 ], L=22.222222222222225, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4793623  0.35159335 0.18703762 0.7654292  0.85971755], L=24.242424242424242, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47833037 0.35125983 0.18758008 0.7650542  0.86009574], L=26.262626262626263, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47729853 0.3509263  0.1881225  0.7646793  0.86047405], L=28.282828282828284, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4762666  0.3505928  0.1886649  0.76430434 0.86085236], L=30.303030303030305, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4756501  0.34992334 0.18849191 0.7634516  0.8602182 ], L=32.323232323232325, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47514805 0.34923032 0.18817972 0.76286757 0.8595796 ], L=34.343434343434346, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47464597 0.34853733 0.18786757 0.76228374 0.8589411 ], L=36.36363636363637, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47445327 0.34825587 0.18787976 0.7622698  0.85910475], L=38.38383838383839, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47442088 0.34815377 0.1880102  0.76261526 0.8596827 ], L=40.40404040404041, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47438848 0.34805164 0.18814066 0.76296055 0.86026055], L=42.42424242424243, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47435606 0.34794953 0.18827114 0.76330596 0.8608385 ], L=44.44444444444445, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47461158 0.34765548 0.18837135 0.76357883 0.86149764], L=48.484848484848484, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47498852 0.34743857 0.18829648 0.7633906  0.86144114], L=50.505050505050505, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47536543 0.34722164 0.1882216  0.7632021  0.8613845 ], L=52.525252525252526, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47611928 0.34678784 0.18807192 0.7628253  0.86127126], L=56.56565656565657, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4764962  0.34657097 0.18799707 0.762637   0.8612147 ], L=58.58585858585859, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47687313 0.34635407 0.18792221 0.7624485  0.8611582 ], L=60.60606060606061, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47725004 0.34613717 0.18784733 0.7622601  0.86110145], L=62.62626262626263, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47762695 0.34592026 0.18777253 0.76207185 0.86104494], L=64.64646464646465, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47838074 0.34548646 0.1876228  0.76169497 0.86093175], L=68.68686868686869, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4787577  0.3452696  0.18754795 0.76150656 0.8608751 ], L=70.70707070707071, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47951156 0.34483576 0.18739823 0.76112974 0.8607621 ], L=74.74747474747475, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47988847 0.3446189  0.18732338 0.7609414  0.8607054 ], L=76.76767676767678, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48026535 0.34440196 0.18724848 0.760753   0.8606489 ], L=78.7878787878788, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4810192  0.34396815 0.18709882 0.7603761  0.8605357 ], L=82.82828282828284, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4813961  0.34375128 0.18702398 0.76018775 0.86047894], L=84.84848484848486, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4818364  0.34358555 0.18712811 0.76000017 0.8604422 ], L=86.86868686868688, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48247567 0.34358042 0.18779346 0.7598152  0.8604672 ], L=88.8888888888889, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48439312 0.343565   0.18978958 0.75925994 0.86054206], L=94.94949494949496, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48548073 0.3433436  0.19418015 0.7545702  0.8592077 ], L=103.03030303030303, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48587164 0.34321195 0.19655529 0.75181425 0.85839134], L=107.07070707070707, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4860753  0.34311604 0.19769548 0.7504447  0.8578523 ], L=109.0909090909091, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48628032 0.34301502 0.19882752 0.74907655 0.85729104], L=111.11111111111111, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4864853  0.34291396 0.1999596  0.7477086  0.8567297 ], L=113.13131313131314, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4866903  0.34281293 0.20109169 0.7463405  0.85616827], L=115.15151515151516, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4868953 0.3427119 0.2022237 0.7449724 0.8556071], L=117.17171717171718, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4873053  0.3425098  0.20448785 0.7422362  0.8544843 ], L=121.21212121212122, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4875103  0.34240878 0.20561992 0.74086815 0.853923  ], L=123.23232323232324, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4879203  0.3422067  0.20788404 0.73813194 0.8528003 ], L=127.27272727272728, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48812535 0.34210563 0.2090161  0.7367637  0.852239  ], L=129.2929292929293, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4882984  0.34245354 0.21089967 0.73410803 0.85116345], L=131.31313131313132, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48845682 0.34300637 0.21312632 0.7308643  0.8498528 ], L=133.33333333333334, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4889321  0.34466502 0.21980628 0.7211329  0.8459213 ], L=139.3939393939394, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48940745 0.34632364 0.22648628 0.71140164 0.8419898 ], L=145.45454545454547, nx=500000000
# objective returned negative key rate -1e+250 for params [0.48838663 0.3468102  0.22857335 0.70581496 0.83871245], L=147.4747474747475, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4861661  0.3472293  0.23051849 0.6978451  0.8334343 ], L=149.4949494949495, nx=500000000
# objective returned negative key rate -1e+250 for params [0.47967216 0.347129   0.2324619  0.6815313  0.82479215], L=151.51515151515153, nx=500000000
# objective returned negative key rate -1e+250 for params [0.46029797 0.33205542 0.30393293 0.5877925  0.7961828 ], L=155.55555555555557, nx=500000000
# objective returned negative key rate -1e+250 for params [0.44464377 0.31114134 0.40951166 0.46576625 0.77222174], L=159.5959595959596, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42967102 0.27980664 0.5276178  0.34994164 0.7198207 ], L=167.6767676767677, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4219875  0.2555295  0.60012    0.28013048 0.6888072 ], L=173.73737373737376, nx=500000000
# objective returned negative key rate -1e+250 for params [0.41942635 0.24743707 0.6242875  0.25686005 0.67846936], L=175.75757575757578, nx=500000000
# objective returned negative key rate -1e+250 for params [0.41827378 0.23221685 0.65588677 0.2302631  0.6449779 ], L=177.7777777777778, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4187719  0.20864405 0.6961949  0.19976786 0.5843549 ], L=179.79797979797982, nx=500000000
# objective returned negative key rate -1e+250 for params [0.41926998 0.18507133 0.73650295 0.16927269 0.523732  ], L=181.81818181818184, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4202661  0.13792601 0.8171189  0.10828248 0.40248662], L=185.85858585858588, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42076415 0.11435325 0.857427   0.07778724 0.3418637 ], L=187.8787878787879, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42126226 0.09078047 0.8794155  0.06583714 0.2812407 ], L=189.89898989898992, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42176032 0.08250339 0.8794155  0.06583714 0.22061789], L=191.91919191919195, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42193252 0.08250339 0.8794155  0.06583714 0.16343796], L=193.93939393939394, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42168686 0.08250339 0.8794155  0.06583714 0.1106731 ], L=195.95959595959596, nx=500000000
# objective returned negative key rate -1e+250 for params [0.4214412  0.08250339 0.8794155  0.06583714 0.05790803], L=197.97979797979798, nx=500000000
# objective returned negative key rate -1e+250 for params [0.42321432 0.08250339 0.8794155  0.06583714 0.05188993], L=200.0, nx=500000000
# After filtering NaN in predicted_key_rates_un_seen, 100 data points remain for n_X = 5e8.
# Checking for NaN in optimized_key_rates_un_seen:
# Number of NaN values: 0
# Checking for NaN in predicted_key_rates_un_seen:
# Number of NaN values: 0

# %%
def plot_keyrate_and_parameters(fiber_lengths, optimized_key_rates, optimized_params_array, 
                                predicted_key_rates, predicted_params_array, epoch, filename, 
                                learning_rates=None, nx=None):
    """
    Plots key rates and parameters for a specific n_X value.
    
    Parameters:
    - fiber_lengths: Array of fiber lengths.
    - optimized_key_rates: Array of optimized key rates.
- optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - learning_rates: List of learning rates over epochs (optional, not used).
    - nx: The n_X value for the plot title (optional).
    """

    # Start timing
    plot_start_time = time.time()

    # Create a figure with 2 subplots: key rate (left), all parameters (right)
    fig = plt.figure(figsize=(15, 6))  # Adjusted height for horizontal layout

    # Define the grid layout: 1 row, 2 columns
    gs = fig.add_gridspec(1, 2, width_ratios=[1, 1])

    # Key Rate Plot (Left)
    ax_keyrate = fig.add_subplot(gs[0, 0])

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    threshold = 1e-8
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Plot key rates with distinct linestyles and increased thickness for predicted
    
    ax_keyrate.plot(fiber_lengths, np.log10(predicted_key_rates), 'r--', label='Predicted Key Rate', linewidth=4.0, alpha=0.7)
    ax_keyrate.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linewidth=2.0, alpha=1.0)
    exponent = int(np.log10(nx))

    ax_keyrate.set_title(f"Key Rates for $n_X = 10^{{{exponent}}}$") # (Epoch {epoch})
    ax_keyrate.set_xlabel("Fiber Length (km)")
    ax_keyrate.set_ylabel("Secret Key Rate per Pulse")
    ax_keyrate.grid(True)
    ax_keyrate.legend(loc='upper right')

    # Parameter Plot (Right) - Combine probabilities and intensities
    ax_params = fig.add_subplot(gs[0, 1])

    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    colors = ['red', 'purple', 'orange', 'green', 'blue']
    param_indices = [0, 1, 2, 3, 4]  # Indices for mu_1, mu_2, P_mu_1, P_mu_2, P_X  

    # Plot all parameters
    for param_idx, (label, color) in zip(param_indices, zip(param_labels, colors)):
        ax_params.plot(fiber_lengths, predicted_params_array[:, param_idx], label=f'Predicted {label}', color=color, linestyle='--', linewidth=4.0, alpha=0.7)
        ax_params.plot(fiber_lengths, optimized_params_array[:, param_idx], label=f'Optimized {label}', color=color, linestyle='-', linewidth=2.0,alpha=1.0)
        
     # Compute the exponent for nx (e.g., nx = 10000 -> exponent = 4)
    exponent = int(np.log10(nx))
    ax_params.set_title(f"Parameters for $n_X = 5 * 10^{{{exponent}}}$") # (Epoch {epoch})
    ax_params.set_xlabel("Fiber Length (km)")
    ax_params.set_ylabel("Parameter Value")
    ax_params.set_ylim(0.0, 1.0)
    ax_params.grid(True)

    # Move legend outside the plot to avoid overlap
    ax_params.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Comparison plot saved to {filename}")


# Plot the comparison for n_X = 5e8
plot_start_time = time.time()
plot_keyrate_and_parameters(
    fiber_lengths_un_seen, optimized_key_rates_un_seen, optimized_params_array_un_seen,
    predicted_key_rates_un_seen, predicted_params_un_seen, epoch='final_test',
    filename='keyrate_parameters_5e8.png', learning_rates=learning_rates, nx=target_nx
)

print(f"--- Final Test Plotting Time (keyrate_and_parameters): {time.time() - plot_start_time:.2f} seconds ---")

# Plot relative errors for n_X = 5e8
plot_relative_errors(
    fiber_lengths_un_seen, optimized_key_rates_un_seen, optimized_params_array_un_seen,
    predicted_key_rates_un_seen, predicted_params_un_seen, epoch='final_test',
    filename=f'relative_error_nx_{target_nx:.0e}.png', nx=target_nx
)

# Add the new plot here
plot_absolute_differences_keyrate_and_parameters(
    fiber_lengths_un_seen, optimized_key_rates_un_seen, optimized_params_array_un_seen,
    predicted_key_rates_un_seen, predicted_params_un_seen, epoch='final_test',
    filename='absolute_differences_5e8.png', nx=target_nx
)
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3996903420.py:55: RuntimeWarning: divide by zero encountered in log10
#   ax_keyrate.plot(fiber_lengths, np.log10(predicted_key_rates), 'r--', label='Predicted Key Rate', linewidth=4.0, alpha=0.7)
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3996903420.py:91: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/222585919.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Comparison plot saved to keyrate_parameters_5e8.png
# --- Final Test Plotting Time (keyrate_and_parameters): 0.69 seconds ---
# Relative error plot saved to relative_error_nx_5e+08.png
# --- Plotting Time: 1.10 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/3821646061.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Absolute differences plot saved to absolute_differences_5e8.png
# --- Plotting Time: 1.26 seconds ---

# %%
# Evaluate and plot for all n_X values (10^4 to 10^9)
for nx in all_evaluation_data.keys():
    eval_data = all_evaluation_data[nx]
    fiber_lengths = eval_data['fiber_lengths']
    optimized_params_array = eval_data['optimized_params_array']
    optimized_key_rates = eval_data['optimized_key_rates']
    X_test_tensor = eval_data['X_test_tensor']

    with torch.no_grad():
        predicted_params_scaled = model(X_test_tensor).cpu().numpy()
        predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
        predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
        predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6)
        predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6)
        predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)
        predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)
        predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)
        predicted_key_rates = []
        for params, L in zip(predicted_params_array, fiber_lengths):
            key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                     epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                     e_mis=5e-3, P_ap=0, n_event=1)
            predicted_key_rates.append(key_rate)
        predicted_key_rates = np.array(predicted_key_rates)

    # Plot relative errors for this n_X
    plot_start_time = time.time()
    plot_relative_errors(
        fiber_lengths, optimized_key_rates, optimized_params_array,
        predicted_key_rates, predicted_params_array, epoch='final_test',
        filename=f'relative_error_nx_{nx:.0e}.png', nx=nx
    )
    print(f"--- Final Test Plotting Time (relative_error_nx_{nx:.0e}): {time.time() - plot_start_time:.2f} seconds ---")
# Out:
# objective returned negative key rate -1e+250 for params [0.6072972  0.14025092 0.04766058 0.6189414  0.40844586], L=0.0, nx=10000
# objective returned negative key rate -1e+250 for params [0.6069195  0.14003786 0.0475364  0.61850834 0.40851188], L=0.6006006006006006, nx=10000
# objective returned negative key rate -1e+250 for params [0.6067934  0.1399715  0.04749403 0.6183753  0.40855283], L=0.8008008008008008, nx=10000
# objective returned negative key rate -1e+250 for params [0.60666716 0.13990508 0.04745167 0.61824214 0.4085935 ], L=1.001001001001001, nx=10000
# objective returned negative key rate -1e+250 for params [0.606541   0.13983876 0.04740933 0.61810905 0.40863457], L=1.2012012012012012, nx=10000
# objective returned negative key rate -1e+250 for params [0.60641474 0.13977239 0.04736705 0.61797595 0.4086754 ], L=1.4014014014014016, nx=10000
# objective returned negative key rate -1e+250 for params [0.60628855 0.13970603 0.04732463 0.6178429  0.4087164 ], L=1.6016016016016017, nx=10000
# objective returned negative key rate -1e+250 for params [0.6061623  0.13963969 0.04728226 0.61770993 0.40875736], L=1.8018018018018018, nx=10000
# objective returned negative key rate -1e+250 for params [0.60603607 0.1395733  0.04723994 0.6175767  0.40879825], L=2.002002002002002, nx=10000
# objective returned negative key rate -1e+250 for params [0.6059098  0.13950695 0.04719758 0.61744374 0.4088392 ], L=2.2022022022022023, nx=10000
# objective returned negative key rate -1e+250 for params [0.60578364 0.13944061 0.04715525 0.6173106  0.40888014], L=2.4024024024024024, nx=10000
# objective returned negative key rate -1e+250 for params [0.6056574  0.13937426 0.04711289 0.6171776  0.408921  ], L=2.6026026026026026, nx=10000
# objective returned negative key rate -1e+250 for params [0.6055312  0.13930787 0.04707052 0.6170445  0.40896192], L=2.802802802802803, nx=10000
# objective returned negative key rate -1e+250 for params [0.60540503 0.13924152 0.04702813 0.6169115  0.4090029 ], L=3.0030030030030033, nx=10000
# objective returned negative key rate -1e+250 for params [0.6052788  0.13917516 0.04698582 0.6167784  0.40904388], L=3.2032032032032034, nx=10000
# objective returned negative key rate -1e+250 for params [0.60515255 0.13910876 0.04694352 0.6166453  0.4090847 ], L=3.4034034034034035, nx=10000
# objective returned negative key rate -1e+250 for params [0.6050263  0.13904245 0.04690111 0.61651224 0.40912572], L=3.6036036036036037, nx=10000
# objective returned negative key rate -1e+250 for params [0.60490006 0.13897605 0.04685879 0.6163791  0.40916663], L=3.8038038038038042, nx=10000
# objective returned negative key rate -1e+250 for params [0.6047739  0.13890973 0.0468164  0.6162461  0.4092076 ], L=4.004004004004004, nx=10000
# objective returned negative key rate -1e+250 for params [0.60464764 0.13884334 0.04677412 0.61611295 0.4092484 ], L=4.2042042042042045, nx=10000
# objective returned negative key rate -1e+250 for params [0.60452145 0.13877697 0.04673176 0.61597985 0.40928942], L=4.404404404404405, nx=10000
# objective returned negative key rate -1e+250 for params [0.6043952  0.13871063 0.04668938 0.6158469  0.40933037], L=4.604604604604605, nx=10000
# objective returned negative key rate -1e+250 for params [0.60426897 0.13864428 0.04664706 0.6157138  0.40937132], L=4.804804804804805, nx=10000
# objective returned negative key rate -1e+250 for params [0.6041427  0.13857791 0.04660472 0.6155807  0.40941224], L=5.005005005005005, nx=10000
# objective returned negative key rate -1e+250 for params [0.60401654 0.13851154 0.0465624  0.6154476  0.4094531 ], L=5.205205205205205, nx=10000
# objective returned negative key rate -1e+250 for params [0.6037641  0.13837881 0.04647764 0.61518145 0.4095349 ], L=5.605605605605606, nx=10000
# objective returned negative key rate -1e+250 for params [0.6036379  0.13831244 0.04643533 0.61504835 0.40957585], L=5.805805805805806, nx=10000
# objective returned negative key rate -1e+250 for params [0.60351163 0.1382461  0.04639293 0.6149153  0.40961686], L=6.0060060060060065, nx=10000
# objective returned negative key rate -1e+250 for params [0.60338545 0.13817976 0.04635059 0.6147822  0.40965787], L=6.206206206206207, nx=10000
# objective returned negative key rate -1e+250 for params [0.6032592  0.1381134  0.04630829 0.6146492  0.40969878], L=6.406406406406407, nx=10000
# objective returned negative key rate -1e+250 for params [0.603133   0.138047   0.04626591 0.614516   0.40973958], L=6.606606606606607, nx=10000
# objective returned negative key rate -1e+250 for params [0.6030068  0.13798064 0.04622357 0.61438304 0.40978053], L=6.806806806806807, nx=10000
# objective returned negative key rate -1e+250 for params [0.60288054 0.13791431 0.04618121 0.6142499  0.40982145], L=7.007007007007007, nx=10000
# objective returned negative key rate -1e+250 for params [0.6027543  0.13784792 0.04613887 0.6141168  0.4098623 ], L=7.207207207207207, nx=10000
# objective returned negative key rate -1e+250 for params [0.6026281  0.13778162 0.04609651 0.6139838  0.40990344], L=7.407407407407407, nx=10000
# objective returned negative key rate -1e+250 for params [0.60250187 0.13771522 0.04605412 0.6138507  0.40994436], L=7.6076076076076085, nx=10000
# objective returned negative key rate -1e+250 for params [0.6023757  0.13764885 0.04601182 0.61371756 0.40998527], L=7.807807807807809, nx=10000
# objective returned negative key rate -1e+250 for params [0.60224944 0.13758253 0.04596947 0.6135846  0.4100262 ], L=8.008008008008009, nx=10000
# objective returned negative key rate -1e+250 for params [0.60212326 0.13751614 0.04592713 0.6134515  0.41006708], L=8.208208208208209, nx=10000
# objective returned negative key rate -1e+250 for params [0.601997   0.13744979 0.04588476 0.6133184  0.4101081 ], L=8.408408408408409, nx=10000
# objective returned negative key rate -1e+250 for params [0.60187083 0.13738343 0.04584242 0.6131853  0.41014895], L=8.608608608608609, nx=10000
# objective returned negative key rate -1e+250 for params [0.60174453 0.13731708 0.04580006 0.61305225 0.41019   ], L=8.80880880880881, nx=10000
# objective returned negative key rate -1e+250 for params [0.60161835 0.1372507  0.04575769 0.6129192  0.41023085], L=9.00900900900901, nx=10000
# objective returned negative key rate -1e+250 for params [0.6014921  0.13718432 0.04571537 0.61278605 0.41027173], L=9.20920920920921, nx=10000
# objective returned negative key rate -1e+250 for params [0.6013659  0.137118   0.04567299 0.61265296 0.41031268], L=9.40940940940941, nx=10000
# objective returned negative key rate -1e+250 for params [0.6012397  0.13705163 0.04563065 0.61252    0.4103536 ], L=9.60960960960961, nx=10000
# objective returned negative key rate -1e+250 for params [0.60111344 0.13698529 0.04560989 0.6123869  0.41039458], L=9.80980980980981, nx=10000
# objective returned negative key rate -1e+250 for params [0.60098726 0.13691892 0.04560989 0.61225384 0.4104355 ], L=10.01001001001001, nx=10000
# objective returned negative key rate -1e+250 for params [0.600861   0.13685253 0.04560989 0.6121207  0.41047645], L=10.21021021021021, nx=10000
# objective returned negative key rate -1e+250 for params [0.60073483 0.1367862  0.04560989 0.6119877  0.41051736], L=10.41041041041041, nx=10000
# objective returned negative key rate -1e+250 for params [0.60060865 0.13671982 0.04560989 0.6118546  0.4105583 ], L=10.61061061061061, nx=10000
# objective returned negative key rate -1e+250 for params [0.6004823  0.13665347 0.04560989 0.6117215  0.41059926], L=10.810810810810812, nx=10000
# objective returned negative key rate -1e+250 for params [0.60035616 0.1365871  0.04560989 0.6115884  0.41064015], L=11.011011011011012, nx=10000
# objective returned negative key rate -1e+250 for params [0.6002299  0.13652076 0.04560989 0.61145544 0.4106811 ], L=11.211211211211213, nx=10000
# objective returned negative key rate -1e+250 for params [0.60010374 0.1364544  0.04560989 0.6113223  0.41072208], L=11.411411411411413, nx=10000
# objective returned negative key rate -1e+250 for params [0.59997743 0.13638803 0.04560989 0.6111892  0.41076303], L=11.611611611611613, nx=10000
# objective returned negative key rate -1e+250 for params [0.59985125 0.1363217  0.04560989 0.6110561  0.41080394], L=11.811811811811813, nx=10000
# objective returned negative key rate -1e+250 for params [0.59972507 0.13625531 0.04560989 0.61092305 0.4108447 ], L=12.012012012012013, nx=10000
# objective returned negative key rate -1e+250 for params [0.5995988  0.13618894 0.04560989 0.61078995 0.4108857 ], L=12.212212212212213, nx=10000
# objective returned negative key rate -1e+250 for params [0.5994726  0.13612258 0.04560989 0.6106569  0.41092673], L=12.412412412412413, nx=10000
# objective returned negative key rate -1e+250 for params [0.5993464  0.13605621 0.04560989 0.61052376 0.41096756], L=12.612612612612613, nx=10000
# objective returned negative key rate -1e+250 for params [0.59922016 0.13598984 0.04560989 0.61039066 0.41100848], L=12.812812812812814, nx=10000
# objective returned negative key rate -1e+250 for params [0.599094   0.1359235  0.04560989 0.6102576  0.4110495 ], L=13.013013013013014, nx=10000
# objective returned negative key rate -1e+250 for params [0.59896773 0.13585715 0.04560989 0.61012465 0.4110904 ], L=13.213213213213214, nx=10000
# objective returned negative key rate -1e+250 for params [0.5988415  0.13579082 0.04560989 0.6099916  0.41113144], L=13.413413413413414, nx=10000
# objective returned negative key rate -1e+250 for params [0.59871525 0.13572443 0.04560989 0.60985845 0.4111722 ], L=13.613613613613614, nx=10000
# objective returned negative key rate -1e+250 for params [0.59858906 0.13565807 0.04560989 0.60972536 0.4112132 ], L=13.813813813813814, nx=10000
# objective returned negative key rate -1e+250 for params [0.5984628  0.13559169 0.04560989 0.6095922  0.411254  ], L=14.014014014014014, nx=10000
# objective returned negative key rate -1e+250 for params [0.59833664 0.13552535 0.04560989 0.6094592  0.41129503], L=14.214214214214214, nx=10000
# objective returned negative key rate -1e+250 for params [0.5982104  0.13545898 0.04560989 0.6093261  0.41133595], L=14.414414414414415, nx=10000
# objective returned negative key rate -1e+250 for params [0.5980842  0.13539265 0.04560989 0.60919315 0.41137704], L=14.614614614614615, nx=10000
# objective returned negative key rate -1e+250 for params [0.5979579  0.13532625 0.04560989 0.60906    0.41141784], L=14.814814814814815, nx=10000
# objective returned negative key rate -1e+250 for params [0.59785056 0.1352909  0.04560989 0.6090114  0.4114458 ], L=15.015015015015017, nx=10000
# objective returned negative key rate -1e+250 for params [0.59774673 0.13526137 0.04560989 0.60897857 0.4114715 ], L=15.215215215215217, nx=10000
# objective returned negative key rate -1e+250 for params [0.59764284 0.1352318  0.04560989 0.60894567 0.41149712], L=15.415415415415417, nx=10000
# objective returned negative key rate -1e+250 for params [0.597539   0.13520223 0.04560989 0.6089128  0.41152278], L=15.615615615615617, nx=10000
# objective returned negative key rate -1e+250 for params [0.5974351  0.1351727  0.04560989 0.60888    0.4115483 ], L=15.815815815815817, nx=10000
# objective returned negative key rate -1e+250 for params [0.5973313  0.13514309 0.04560989 0.6088471  0.41157386], L=16.016016016016017, nx=10000
# objective returned negative key rate -1e+250 for params [0.59722733 0.13511358 0.04560989 0.60881424 0.4115996 ], L=16.216216216216218, nx=10000
# objective returned negative key rate -1e+250 for params [0.59712356 0.135084   0.04560989 0.6087814  0.4116252 ], L=16.416416416416418, nx=10000
# objective returned negative key rate -1e+250 for params [0.5970197  0.13505448 0.04560989 0.60874856 0.41165084], L=16.616616616616618, nx=10000
# objective returned negative key rate -1e+250 for params [0.5969158  0.13502492 0.04560989 0.6087157  0.41167644], L=16.816816816816818, nx=10000
# objective returned negative key rate -1e+250 for params [0.59681195 0.13499536 0.04560989 0.6086829  0.41170207], L=17.017017017017018, nx=10000
# objective returned negative key rate -1e+250 for params [0.5967081  0.13496579 0.04560989 0.60865    0.41172767], L=17.217217217217218, nx=10000
# objective returned negative key rate -1e+250 for params [0.5966042  0.13493623 0.04560989 0.6086171  0.4117532 ], L=17.41741741741742, nx=10000
# objective returned negative key rate -1e+250 for params [0.59650034 0.13490668 0.04560989 0.6085843  0.41177893], L=17.61761761761762, nx=10000
# objective returned negative key rate -1e+250 for params [0.59639645 0.13487713 0.04560989 0.60855144 0.4118045 ], L=17.81781781781782, nx=10000
# objective returned negative key rate -1e+250 for params [0.5962926  0.1348476  0.04560989 0.6085186  0.41183022], L=18.01801801801802, nx=10000
# objective returned negative key rate -1e+250 for params [0.5961888  0.134818   0.04560989 0.60848576 0.4118558 ], L=18.21821821821822, nx=10000
# objective returned negative key rate -1e+250 for params [0.5960849  0.13478847 0.04560989 0.6084529  0.41188142], L=18.41841841841842, nx=10000
# objective returned negative key rate -1e+250 for params [0.59598106 0.13475886 0.04560989 0.60842    0.41190702], L=18.61861861861862, nx=10000
# objective returned negative key rate -1e+250 for params [0.5958772  0.13472934 0.04560989 0.6083872  0.4119326 ], L=18.81881881881882, nx=10000
# objective returned negative key rate -1e+250 for params [0.5957733  0.13469976 0.04560989 0.6083544  0.41195825], L=19.01901901901902, nx=10000
# objective returned negative key rate -1e+250 for params [0.59566945 0.13467026 0.04560989 0.6083216  0.41198397], L=19.21921921921922, nx=10000
# objective returned negative key rate -1e+250 for params [0.59556556 0.13464066 0.04560989 0.60828865 0.41200954], L=19.41941941941942, nx=10000
# objective returned negative key rate -1e+250 for params [0.5954617  0.13461111 0.04560989 0.60825574 0.4120351 ], L=19.61961961961962, nx=10000
# objective returned negative key rate -1e+250 for params [0.59535784 0.13458152 0.04560989 0.60822284 0.41206062], L=19.81981981981982, nx=10000
# objective returned negative key rate -1e+250 for params [0.595254   0.134552   0.04560989 0.6081901  0.4120863 ], L=20.02002002002002, nx=10000
# objective returned negative key rate -1e+250 for params [0.5951501  0.13452245 0.04560989 0.6081573  0.41211206], L=20.22022022022022, nx=10000
# objective returned negative key rate -1e+250 for params [0.5950463  0.13449289 0.04560989 0.6081244  0.4121376 ], L=20.42042042042042, nx=10000
# objective returned negative key rate -1e+250 for params [0.5949424  0.13446331 0.04560989 0.60809153 0.41216326], L=20.62062062062062, nx=10000
# objective returned negative key rate -1e+250 for params [0.59483856 0.13443376 0.04560989 0.60805863 0.41218883], L=20.82082082082082, nx=10000
# objective returned negative key rate -1e+250 for params [0.59473467 0.13440421 0.04560989 0.6080257  0.41221434], L=21.02102102102102, nx=10000
# objective returned negative key rate -1e+250 for params [0.5946308  0.13437465 0.04560989 0.60799295 0.41224003], L=21.22122122122122, nx=10000
# objective returned negative key rate -1e+250 for params [0.5945269  0.1343451  0.04560989 0.60796005 0.41226572], L=21.421421421421424, nx=10000
# objective returned negative key rate -1e+250 for params [0.59442306 0.13431557 0.04560989 0.60792726 0.41229138], L=21.621621621621625, nx=10000
# objective returned negative key rate -1e+250 for params [0.5943192  0.134286   0.04560989 0.6078943  0.4123169 ], L=21.821821821821825, nx=10000
# objective returned negative key rate -1e+250 for params [0.5942154  0.13425647 0.04560989 0.6078616  0.41234258], L=22.022022022022025, nx=10000
# objective returned negative key rate -1e+250 for params [0.5941115  0.13422686 0.04560989 0.6078288  0.41236815], L=22.222222222222225, nx=10000
# objective returned negative key rate -1e+250 for params [0.5940076  0.13419728 0.04560989 0.60779583 0.41239375], L=22.422422422422425, nx=10000
# objective returned negative key rate -1e+250 for params [0.5939038  0.1341678  0.04560989 0.60776305 0.41241956], L=22.622622622622625, nx=10000
# objective returned negative key rate -1e+250 for params [0.5937998  0.13413817 0.04560989 0.60773015 0.412445  ], L=22.822822822822825, nx=10000
# objective returned negative key rate -1e+250 for params [0.59369606 0.13410863 0.04560989 0.60769725 0.41247067], L=23.023023023023026, nx=10000
# objective returned negative key rate -1e+250 for params [0.59359217 0.13407907 0.04560989 0.60766447 0.4124963 ], L=23.223223223223226, nx=10000
# objective returned negative key rate -1e+250 for params [0.5934883  0.13404953 0.04560989 0.6076317  0.4125219 ], L=23.423423423423426, nx=10000
# objective returned negative key rate -1e+250 for params [0.59338444 0.13401997 0.04560989 0.6075988  0.41254756], L=23.623623623623626, nx=10000
# objective returned negative key rate -1e+250 for params [0.5932806  0.13399042 0.04560989 0.6075659  0.41257313], L=23.823823823823826, nx=10000
# objective returned negative key rate -1e+250 for params [0.5931767  0.13396083 0.04560989 0.60753304 0.41259873], L=24.024024024024026, nx=10000
# objective returned negative key rate -1e+250 for params [0.5930729  0.1339313  0.04560989 0.6075002  0.41262433], L=24.224224224224226, nx=10000
# objective returned negative key rate -1e+250 for params [0.59296894 0.13390173 0.04560989 0.6074673  0.41264996], L=24.424424424424426, nx=10000
# objective returned negative key rate -1e+250 for params [0.5928651  0.13387218 0.04560989 0.60743445 0.41267562], L=24.624624624624627, nx=10000
# objective returned negative key rate -1e+250 for params [0.5927613  0.13384262 0.04560989 0.6074016  0.41270122], L=24.824824824824827, nx=10000
# objective returned negative key rate -1e+250 for params [0.5926574  0.1338131  0.04560989 0.6073688  0.41272694], L=25.025025025025027, nx=10000
# objective returned negative key rate -1e+250 for params [0.59255356 0.13378352 0.04560989 0.6073359  0.4127524 ], L=25.225225225225227, nx=10000
# objective returned negative key rate -1e+250 for params [0.59244967 0.13375399 0.04560989 0.6073031  0.4127782 ], L=25.425425425425427, nx=10000
# objective returned negative key rate -1e+250 for params [0.5923458  0.13372439 0.04560989 0.60727024 0.4128037 ], L=25.625625625625627, nx=10000
# objective returned negative key rate -1e+250 for params [0.59224194 0.13369487 0.04560989 0.6072374  0.41282943], L=25.825825825825827, nx=10000
# objective returned negative key rate -1e+250 for params [0.59213805 0.13366531 0.04560989 0.60720456 0.41285497], L=26.026026026026027, nx=10000
# objective returned negative key rate -1e+250 for params [0.5920342  0.13363574 0.04560989 0.6071717  0.4128807 ], L=26.226226226226228, nx=10000
# objective returned negative key rate -1e+250 for params [0.5919303  0.13360618 0.04560989 0.6071388  0.41290614], L=26.426426426426428, nx=10000
# objective returned negative key rate -1e+250 for params [0.5918265  0.13357663 0.04560989 0.607106   0.4129318 ], L=26.626626626626628, nx=10000
# objective returned negative key rate -1e+250 for params [0.59172267 0.13354708 0.04560989 0.6070731  0.41295743], L=26.826826826826828, nx=10000
# objective returned negative key rate -1e+250 for params [0.5916188  0.13351752 0.04560989 0.60704035 0.4129831 ], L=27.027027027027028, nx=10000
# objective returned negative key rate -1e+250 for params [0.59151495 0.13348797 0.04560989 0.60700744 0.41300872], L=27.227227227227228, nx=10000
# objective returned negative key rate -1e+250 for params [0.59141105 0.13345842 0.04560989 0.6069746  0.41303435], L=27.42742742742743, nx=10000
# objective returned negative key rate -1e+250 for params [0.59130716 0.13342884 0.04560989 0.60694164 0.4130599 ], L=27.62762762762763, nx=10000
# objective returned negative key rate -1e+250 for params [0.5912033  0.13339931 0.04560989 0.60690886 0.4130856 ], L=27.82782782782783, nx=10000
# objective returned negative key rate -1e+250 for params [0.59109944 0.13336971 0.04560989 0.606876   0.41311112], L=28.02802802802803, nx=10000
# objective returned negative key rate -1e+250 for params [0.59099555 0.13334017 0.04560989 0.6068431  0.41313678], L=28.22822822822823, nx=10000
# objective returned negative key rate -1e+250 for params [0.5908917  0.13331065 0.04560989 0.60681033 0.41316244], L=28.42842842842843, nx=10000
# objective returned negative key rate -1e+250 for params [0.5907878  0.13328104 0.04560989 0.60677737 0.413188  ], L=28.62862862862863, nx=10000
# objective returned negative key rate -1e+250 for params [0.59068394 0.1332515  0.04560989 0.6067445  0.4132136 ], L=28.82882882882883, nx=10000
# objective returned negative key rate -1e+250 for params [0.59058017 0.13322194 0.04560989 0.60671175 0.41323927], L=29.02902902902903, nx=10000
# objective returned negative key rate -1e+250 for params [0.5904763  0.13319242 0.04560989 0.6066789  0.41326493], L=29.22922922922923, nx=10000
# objective returned negative key rate -1e+250 for params [0.5903723  0.13316287 0.04560989 0.606646   0.41329065], L=29.42942942942943, nx=10000
# objective returned negative key rate -1e+250 for params [0.59026855 0.13313328 0.04560989 0.60661316 0.4133161 ], L=29.62962962962963, nx=10000
# objective returned negative key rate -1e+250 for params [0.59016466 0.13310373 0.04560989 0.6065803  0.4133417 ], L=29.82982982982983, nx=10000
# objective returned negative key rate -1e+250 for params [0.5900608  0.13307416 0.04560989 0.6065474  0.41336727], L=30.030030030030034, nx=10000
# objective returned negative key rate -1e+250 for params [0.589957   0.13304462 0.04560989 0.60651475 0.41339302], L=30.230230230230234, nx=10000
# objective returned negative key rate -1e+250 for params [0.58985305 0.13301507 0.04560989 0.60648173 0.41341865], L=30.430430430430434, nx=10000
# objective returned negative key rate -1e+250 for params [0.5897492  0.1329855  0.04560989 0.6064489  0.41344425], L=30.630630630630634, nx=10000
# objective returned negative key rate -1e+250 for params [0.5896453  0.13295598 0.04560989 0.6064161  0.4134699 ], L=30.830830830830834, nx=10000
# objective returned negative key rate -1e+250 for params [0.5895415  0.13292639 0.04560989 0.60638326 0.41349542], L=31.031031031031034, nx=10000
# objective returned negative key rate -1e+250 for params [0.58943766 0.13289681 0.04560989 0.6063504  0.41352108], L=31.231231231231234, nx=10000
# objective returned negative key rate -1e+250 for params [0.5893337  0.13286729 0.04560989 0.6063175  0.41354683], L=31.431431431431434, nx=10000
# objective returned negative key rate -1e+250 for params [0.5892299  0.13283771 0.04560989 0.6062847  0.41357225], L=31.631631631631635, nx=10000
# objective returned negative key rate -1e+250 for params [0.589126   0.13280818 0.04560989 0.6062518  0.41359806], L=31.831831831831835, nx=10000
# objective returned negative key rate -1e+250 for params [0.58902216 0.1327786  0.04560989 0.60621893 0.41362357], L=32.032032032032035, nx=10000
# objective returned negative key rate -1e+250 for params [0.5889183  0.13274907 0.04560989 0.60618615 0.41364923], L=32.232232232232235, nx=10000
# objective returned negative key rate -1e+250 for params [0.5888145  0.13271952 0.04560989 0.6061533  0.4136749 ], L=32.432432432432435, nx=10000
# objective returned negative key rate -1e+250 for params [0.58871055 0.13268992 0.04560989 0.60612035 0.41370043], L=32.632632632632635, nx=10000
# objective returned negative key rate -1e+250 for params [0.5886067  0.1326604  0.04560989 0.60608757 0.41372606], L=32.832832832832835, nx=10000
# objective returned negative key rate -1e+250 for params [0.5885029  0.1326308  0.04560989 0.60605466 0.4137516 ], L=33.033033033033036, nx=10000
# objective returned negative key rate -1e+250 for params [0.588399   0.13260126 0.04560989 0.6060218  0.41377726], L=33.233233233233236, nx=10000
# objective returned negative key rate -1e+250 for params [0.58829516 0.13257173 0.04560989 0.60598904 0.4138029 ], L=33.433433433433436, nx=10000
# objective returned negative key rate -1e+250 for params [0.5881913  0.13254213 0.04560989 0.6059562  0.41382843], L=33.633633633633636, nx=10000
# objective returned negative key rate -1e+250 for params [0.58816487 0.13255018 0.04560989 0.6059794  0.41382775], L=33.833833833833836, nx=10000
# objective returned negative key rate -1e+250 for params [0.5881463  0.13256195 0.04560989 0.6060081  0.41382417], L=34.034034034034036, nx=10000
# objective returned negative key rate -1e+250 for params [0.5881278  0.13257381 0.04560989 0.606037   0.41382077], L=34.234234234234236, nx=10000
# objective returned negative key rate -1e+250 for params [0.5881093  0.13258563 0.04560989 0.60606587 0.41381723], L=34.434434434434436, nx=10000
# objective returned negative key rate -1e+250 for params [0.5880908  0.13259745 0.04560989 0.6060947  0.4138138 ], L=34.63463463463464, nx=10000
# objective returned negative key rate -1e+250 for params [0.5880723  0.13260928 0.04560989 0.60612357 0.41381025], L=34.83483483483484, nx=10000
# objective returned negative key rate -1e+250 for params [0.58805376 0.13262108 0.04560989 0.60615236 0.41380677], L=35.03503503503504, nx=10000
# objective returned negative key rate -1e+250 for params [0.5880352  0.1326329  0.04560989 0.60618126 0.41380328], L=35.23523523523524, nx=10000
# objective returned negative key rate -1e+250 for params [0.5880168  0.13264471 0.04560989 0.6062102  0.4137998 ], L=35.43543543543544, nx=10000
# objective returned negative key rate -1e+250 for params [0.5879982  0.13265654 0.04560989 0.606239   0.4137963 ], L=35.63563563563564, nx=10000
# objective returned negative key rate -1e+250 for params [0.58797973 0.13266836 0.04560989 0.6062679  0.41379276], L=35.83583583583584, nx=10000
# objective returned negative key rate -1e+250 for params [0.58796126 0.13268018 0.04560989 0.60629666 0.4137892 ], L=36.03603603603604, nx=10000
# objective returned negative key rate -1e+250 for params [0.58794266 0.13269202 0.04560989 0.60632545 0.41378567], L=36.23623623623624, nx=10000
# objective returned negative key rate -1e+250 for params [0.5879242  0.13270384 0.04560989 0.6063544  0.41378224], L=36.43643643643644, nx=10000
# objective returned negative key rate -1e+250 for params [0.5879057  0.13271566 0.04560989 0.6063832  0.41377875], L=36.63663663663664, nx=10000
# objective returned negative key rate -1e+250 for params [0.58788717 0.1327275  0.04560989 0.6064122  0.4137753 ], L=36.83683683683684, nx=10000
# objective returned negative key rate -1e+250 for params [0.5878687  0.1327393  0.04560989 0.606441   0.41377178], L=37.03703703703704, nx=10000
# objective returned negative key rate -1e+250 for params [0.58785015 0.13275112 0.04560989 0.6064698  0.4137683 ], L=37.23723723723724, nx=10000
# objective returned negative key rate -1e+250 for params [0.5878316  0.13276294 0.04560989 0.60649866 0.41376477], L=37.43743743743744, nx=10000
# objective returned negative key rate -1e+250 for params [0.58781314 0.13277477 0.04560989 0.60652757 0.4137613 ], L=37.63763763763764, nx=10000
# objective returned negative key rate -1e+250 for params [0.5877946  0.13278662 0.04560989 0.60655636 0.4137578 ], L=37.83783783783784, nx=10000
# objective returned negative key rate -1e+250 for params [0.5877761  0.1327984  0.04560989 0.60658526 0.41375428], L=38.03803803803804, nx=10000
# objective returned negative key rate -1e+250 for params [0.5877576  0.13281024 0.04560989 0.6066141  0.41375083], L=38.23823823823824, nx=10000
# objective returned negative key rate -1e+250 for params [0.58773905 0.13282205 0.04560989 0.6066429  0.41374725], L=38.43843843843844, nx=10000
# objective returned negative key rate -1e+250 for params [0.5877206  0.13283387 0.04560989 0.60667175 0.4137438 ], L=38.63863863863864, nx=10000
# objective returned negative key rate -1e+250 for params [0.58770204 0.13284574 0.04560989 0.60670066 0.4137404 ], L=38.83883883883884, nx=10000
# objective returned negative key rate -1e+250 for params [0.5876835  0.13285755 0.04560989 0.60672957 0.41373682], L=39.03903903903904, nx=10000
# objective returned negative key rate -1e+250 for params [0.587665   0.13286935 0.04560989 0.60675836 0.41373327], L=39.23923923923924, nx=10000
# objective returned negative key rate -1e+250 for params [0.5876465  0.13288113 0.04560989 0.6067872  0.41372973], L=39.43943943943944, nx=10000
# objective returned negative key rate -1e+250 for params [0.587628   0.132893   0.04560989 0.6068161  0.41372636], L=39.63963963963964, nx=10000
# objective returned negative key rate -1e+250 for params [0.58760947 0.13290484 0.04560989 0.60684496 0.4137229 ], L=39.83983983983984, nx=10000
# objective returned negative key rate -1e+250 for params [0.58759093 0.13291663 0.04560989 0.6068738  0.41371924], L=40.04004004004004, nx=10000
# objective returned negative key rate -1e+250 for params [0.58757246 0.13292849 0.04560989 0.60690266 0.41371584], L=40.24024024024024, nx=10000
# objective returned negative key rate -1e+250 for params [0.5875539  0.13294028 0.04560989 0.6069315  0.41371235], L=40.44044044044044, nx=10000
# objective returned negative key rate -1e+250 for params [0.58753544 0.13295208 0.04560989 0.6069603  0.41370887], L=40.64064064064064, nx=10000
# objective returned negative key rate -1e+250 for params [0.58751696 0.1329639  0.04560989 0.60698915 0.41370517], L=40.84084084084084, nx=10000
# objective returned negative key rate -1e+250 for params [0.58749837 0.13297573 0.04560989 0.607018   0.41370183], L=41.04104104104104, nx=10000
# objective returned negative key rate -1e+250 for params [0.5874799  0.13298757 0.04560989 0.6070469  0.41369835], L=41.24124124124124, nx=10000
# objective returned negative key rate -1e+250 for params [0.58746135 0.13299938 0.04560989 0.60707575 0.41369483], L=41.44144144144144, nx=10000
# objective returned negative key rate -1e+250 for params [0.5874428  0.13301118 0.04560989 0.6071046  0.41369134], L=41.64164164164164, nx=10000
# objective returned negative key rate -1e+250 for params [0.58742434 0.13302304 0.04560989 0.60713345 0.41368783], L=41.84184184184184, nx=10000
# objective returned negative key rate -1e+250 for params [0.5874058  0.13303484 0.04560989 0.6071623  0.4136843 ], L=42.04204204204204, nx=10000
# objective returned negative key rate -1e+250 for params [0.5873873  0.13304667 0.04560989 0.60719115 0.41368088], L=42.24224224224224, nx=10000
# objective returned negative key rate -1e+250 for params [0.5873688  0.13305847 0.04560989 0.60722    0.4136773 ], L=42.44244244244244, nx=10000
# objective returned negative key rate -1e+250 for params [0.58735025 0.13307029 0.04560989 0.60724884 0.4136739 ], L=42.64264264264264, nx=10000
# objective returned negative key rate -1e+250 for params [0.5873318  0.13308212 0.04560989 0.6072777  0.41367036], L=42.84284284284285, nx=10000
# objective returned negative key rate -1e+250 for params [0.5873132  0.13309397 0.04560989 0.60730654 0.41366687], L=43.04304304304305, nx=10000
# objective returned negative key rate -1e+250 for params [0.58729476 0.1331058  0.04560989 0.6073354  0.4136634 ], L=43.24324324324325, nx=10000
# objective returned negative key rate -1e+250 for params [0.5872762  0.13311762 0.04560989 0.60736424 0.4136599 ], L=43.44344344344345, nx=10000
# objective returned negative key rate -1e+250 for params [0.5872577  0.13312942 0.04560989 0.6073931  0.41365635], L=43.64364364364365, nx=10000
# objective returned negative key rate -1e+250 for params [0.5872392  0.13314122 0.04560989 0.607422   0.41365287], L=43.84384384384385, nx=10000
# objective returned negative key rate -1e+250 for params [0.58722067 0.13315308 0.04560989 0.60745084 0.41364947], L=44.04404404404405, nx=10000
# objective returned negative key rate -1e+250 for params [0.58720213 0.13316488 0.04560989 0.60747963 0.4136459 ], L=44.24424424424425, nx=10000
# objective returned negative key rate -1e+250 for params [0.58718365 0.13317676 0.04560989 0.6075086  0.41364244], L=44.44444444444445, nx=10000
# objective returned negative key rate -1e+250 for params [0.5871651  0.13318855 0.04560989 0.60753745 0.41363895], L=44.64464464464465, nx=10000
# objective returned negative key rate -1e+250 for params [0.58714664 0.13320038 0.04560989 0.6075663  0.41363546], L=44.84484484484485, nx=10000
# objective returned negative key rate -1e+250 for params [0.5871281  0.13321218 0.04560989 0.60759515 0.4136319 ], L=45.04504504504505, nx=10000
# objective returned negative key rate -1e+250 for params [0.58710957 0.13322401 0.04560989 0.607624   0.41362843], L=45.24524524524525, nx=10000
# objective returned negative key rate -1e+250 for params [0.5870911  0.13323583 0.04560989 0.6076527  0.41362485], L=45.44544544544545, nx=10000
# objective returned negative key rate -1e+250 for params [0.58707255 0.13324766 0.04560989 0.60768163 0.41362146], L=45.64564564564565, nx=10000
# objective returned negative key rate -1e+250 for params [0.5870541  0.13325948 0.04560989 0.60771054 0.4136179 ], L=45.84584584584585, nx=10000
# objective returned negative key rate -1e+250 for params [0.58703554 0.1332713  0.04560989 0.60773945 0.4136145 ], L=46.04604604604605, nx=10000
# objective returned negative key rate -1e+250 for params [0.587017   0.13328312 0.04560989 0.60776824 0.41361094], L=46.24624624624625, nx=10000
# objective returned negative key rate -1e+250 for params [0.5869985  0.13329495 0.04560989 0.6077971  0.41360745], L=46.44644644644645, nx=10000
# objective returned negative key rate -1e+250 for params [0.58698    0.13330674 0.04560989 0.6078259  0.41360384], L=46.64664664664665, nx=10000
# objective returned negative key rate -1e+250 for params [0.58696145 0.13331857 0.04560989 0.6078548  0.41360047], L=46.84684684684685, nx=10000
# objective returned negative key rate -1e+250 for params [0.586943   0.1333304  0.04560989 0.6078837  0.41359702], L=47.04704704704705, nx=10000
# objective returned negative key rate -1e+250 for params [0.58692443 0.13334222 0.04560989 0.6079125  0.41359347], L=47.24724724724725, nx=10000
# objective returned negative key rate -1e+250 for params [0.58690596 0.13335404 0.04560989 0.6079413  0.41358998], L=47.44744744744745, nx=10000
# objective returned negative key rate -1e+250 for params [0.5868874  0.13336588 0.04560989 0.60797024 0.41358647], L=47.64764764764765, nx=10000
# objective returned negative key rate -1e+250 for params [0.5868689  0.13337767 0.04560989 0.60799897 0.41358292], L=47.84784784784785, nx=10000
# objective returned negative key rate -1e+250 for params [0.5868504  0.13338952 0.04560989 0.6080279  0.41357952], L=48.04804804804805, nx=10000
# objective returned negative key rate -1e+250 for params [0.58683187 0.1334013  0.04560989 0.60805666 0.41357595], L=48.24824824824825, nx=10000
# objective returned negative key rate -1e+250 for params [0.5868134  0.13341315 0.04560989 0.60808563 0.41357255], L=48.44844844844845, nx=10000
# objective returned negative key rate -1e+250 for params [0.58679485 0.13342497 0.04560989 0.6081144  0.4135689 ], L=48.64864864864865, nx=10000
# objective returned negative key rate -1e+250 for params [0.5867763  0.1334368  0.04560989 0.6081433  0.41356552], L=48.84884884884885, nx=10000
# objective returned negative key rate -1e+250 for params [0.58675784 0.13344862 0.04560989 0.6081722  0.41356197], L=49.04904904904905, nx=10000
# objective returned negative key rate -1e+250 for params [0.58673936 0.13346043 0.04560989 0.6082011  0.41355848], L=49.24924924924925, nx=10000
# objective returned negative key rate -1e+250 for params [0.5867208  0.1334723  0.04560989 0.60822994 0.4135551 ], L=49.44944944944945, nx=10000
# objective returned negative key rate -1e+250 for params [0.58670235 0.1334841  0.04560989 0.6082587  0.4135515 ], L=49.64964964964965, nx=10000
# objective returned negative key rate -1e+250 for params [0.5866838  0.1334959  0.04560989 0.6082876  0.41354796], L=49.84984984984985, nx=10000
# objective returned negative key rate -1e+250 for params [0.5866653  0.13350773 0.04560989 0.6083164  0.41354442], L=50.050050050050054, nx=10000
# objective returned negative key rate -1e+250 for params [0.58664674 0.13351952 0.04560989 0.60834527 0.41354093], L=50.250250250250254, nx=10000
# objective returned negative key rate -1e+250 for params [0.5866282  0.13353138 0.04560989 0.6083741  0.41353753], L=50.450450450450454, nx=10000
# objective returned negative key rate -1e+250 for params [0.5866098  0.13354318 0.04560989 0.60840297 0.41353402], L=50.650650650650654, nx=10000
# objective returned negative key rate -1e+250 for params [0.58657324 0.13352828 0.04560989 0.6083789  0.41341358], L=50.850850850850854, nx=10000
# objective returned negative key rate -1e+250 for params [0.58654314 0.1335219  0.04560989 0.60835797 0.41329974], L=51.051051051051054, nx=10000
# objective returned negative key rate -1e+250 for params [0.58652955 0.13353828 0.04560989 0.60835385 0.41322246], L=51.251251251251254, nx=10000
# objective returned negative key rate -1e+250 for params [0.586516   0.13355468 0.04560989 0.6083496  0.41314518], L=51.451451451451454, nx=10000
# objective returned negative key rate -1e+250 for params [0.5865025  0.13357104 0.04560989 0.6083455  0.41306782], L=51.651651651651655, nx=10000
# objective returned negative key rate -1e+250 for params [0.58648896 0.13358736 0.04560989 0.6083413  0.41299036], L=51.851851851851855, nx=10000
# objective returned negative key rate -1e+250 for params [0.58647543 0.13360377 0.04560989 0.60833716 0.41291308], L=52.052052052052055, nx=10000
# objective returned negative key rate -1e+250 for params [0.58646196 0.13362013 0.04560989 0.60833305 0.41283572], L=52.252252252252255, nx=10000
# objective returned negative key rate -1e+250 for params [0.58644843 0.13363647 0.04560989 0.6083288  0.4127583 ], L=52.452452452452455, nx=10000
# objective returned negative key rate -1e+250 for params [0.58643484 0.13365284 0.04560989 0.6083247  0.41268095], L=52.652652652652655, nx=10000
# objective returned negative key rate -1e+250 for params [0.5864213  0.1336692  0.04560989 0.60832053 0.41260365], L=52.852852852852855, nx=10000
# objective returned negative key rate -1e+250 for params [0.5864078  0.1336856  0.04560989 0.6083164  0.41252637], L=53.053053053053056, nx=10000
# objective returned negative key rate -1e+250 for params [0.58639425 0.13370197 0.04560989 0.6083123  0.412449  ], L=53.253253253253256, nx=10000
# objective returned negative key rate -1e+250 for params [0.5863807  0.13371831 0.04560989 0.6083081  0.41237172], L=53.453453453453456, nx=10000
# objective returned negative key rate -1e+250 for params [0.58636725 0.13373469 0.04560989 0.608304   0.41229427], L=53.653653653653656, nx=10000
# objective returned negative key rate -1e+250 for params [0.5863537  0.13375105 0.04560989 0.6082998  0.41221684], L=53.853853853853856, nx=10000
# objective returned negative key rate -1e+250 for params [0.5863401  0.13376743 0.04560989 0.60829574 0.41213965], L=54.054054054054056, nx=10000
# objective returned negative key rate -1e+250 for params [0.5863266  0.13378379 0.04560989 0.6082915  0.4120622 ], L=54.254254254254256, nx=10000
# objective returned negative key rate -1e+250 for params [0.586313   0.13380013 0.04560989 0.6082874  0.41198495], L=54.454454454454456, nx=10000
# objective returned negative key rate -1e+250 for params [0.58629954 0.1338165  0.04560989 0.60828316 0.41190755], L=54.65465465465466, nx=10000
# objective returned negative key rate -1e+250 for params [0.586286   0.13383287 0.04560989 0.60827905 0.41183025], L=54.85485485485486, nx=10000
# objective returned negative key rate -1e+250 for params [0.5862724  0.13384925 0.04560989 0.6082749  0.4117529 ], L=55.05505505505506, nx=10000
# objective returned negative key rate -1e+250 for params [0.586259   0.13386561 0.04560989 0.60827076 0.41167554], L=55.25525525525526, nx=10000
# objective returned negative key rate -1e+250 for params [0.5862454  0.13388197 0.04560989 0.60826653 0.41159812], L=55.45545545545546, nx=10000
# objective returned negative key rate -1e+250 for params [0.5862319  0.13389836 0.04560989 0.60826254 0.41152087], L=55.65565565565566, nx=10000
# objective returned negative key rate -1e+250 for params [0.58621836 0.1339147  0.04560989 0.6082583  0.41144347], L=55.85585585585586, nx=10000
# objective returned negative key rate -1e+250 for params [0.5862048  0.13393107 0.04560989 0.6082542  0.41136613], L=56.05605605605606, nx=10000
# objective returned negative key rate -1e+250 for params [0.5861913  0.13394743 0.04560989 0.60824996 0.4112887 ], L=56.25625625625626, nx=10000
# objective returned negative key rate -1e+250 for params [0.58617777 0.13396381 0.04560989 0.60824585 0.4112114 ], L=56.45645645645646, nx=10000
# objective returned negative key rate -1e+250 for params [0.5861643  0.13398017 0.04560989 0.6082417  0.4111341 ], L=56.65665665665666, nx=10000
# objective returned negative key rate -1e+250 for params [0.5861507  0.13399652 0.04560989 0.6082375  0.41105673], L=56.85685685685686, nx=10000
# objective returned negative key rate -1e+250 for params [0.5861372  0.13401292 0.04560989 0.60823333 0.41097945], L=57.05705705705706, nx=10000
# objective returned negative key rate -1e+250 for params [0.58612365 0.13402924 0.04560989 0.6082292  0.41090193], L=57.25725725725726, nx=10000
# objective returned negative key rate -1e+250 for params [0.5861101  0.13404563 0.04560989 0.6082251  0.41082472], L=57.45745745745746, nx=10000
# objective returned negative key rate -1e+250 for params [0.5860966  0.134062   0.04560989 0.6082209  0.4107473 ], L=57.65765765765766, nx=10000
# objective returned negative key rate -1e+250 for params [0.58608305 0.13407838 0.04560989 0.60821676 0.41067013], L=57.85785785785786, nx=10000
# objective returned negative key rate -1e+250 for params [0.5860695  0.13409474 0.04560989 0.60821265 0.41059276], L=58.05805805805806, nx=10000
# objective returned negative key rate -1e+250 for params [0.586056   0.13411112 0.04560989 0.6082085  0.41051534], L=58.25825825825826, nx=10000
# objective returned negative key rate -1e+250 for params [0.58604246 0.13412744 0.04560989 0.6082043  0.4104379 ], L=58.45845845845846, nx=10000
# objective returned negative key rate -1e+250 for params [0.5860289  0.13414383 0.04562336 0.60820013 0.41036066], L=58.65865865865866, nx=10000
# objective returned negative key rate -1e+250 for params [0.5860154  0.13416019 0.04566392 0.6081961  0.41028333], L=58.85885885885886, nx=10000
# objective returned negative key rate -1e+250 for params [0.5860019  0.13417657 0.04570449 0.6081919  0.41020593], L=59.05905905905906, nx=10000
# objective returned negative key rate -1e+250 for params [0.58598834 0.13419293 0.04574509 0.60818774 0.4101286 ], L=59.25925925925926, nx=10000
# objective returned negative key rate -1e+250 for params [0.5859748  0.13420933 0.04578567 0.60818356 0.41005132], L=59.45945945945946, nx=10000
# objective returned negative key rate -1e+250 for params [0.5859613  0.13422565 0.04582626 0.6081794  0.40997392], L=59.65965965965966, nx=10000
# objective returned negative key rate -1e+250 for params [0.58594775 0.13424204 0.04586687 0.6081753  0.4098966 ], L=59.85985985985987, nx=10000
# objective returned negative key rate -1e+250 for params [0.5859342  0.13425842 0.04590741 0.60817116 0.40981922], L=60.06006006006007, nx=10000
# objective returned negative key rate -1e+250 for params [0.58592075 0.1342748  0.04594798 0.60816705 0.40974197], L=60.26026026026027, nx=10000
# objective returned negative key rate -1e+250 for params [0.58590716 0.13429119 0.04598859 0.6081629  0.40966466], L=60.46046046046047, nx=10000
# objective returned negative key rate -1e+250 for params [0.58589363 0.13430752 0.04602917 0.6081587  0.4095872 ], L=60.66066066066067, nx=10000
# objective returned negative key rate -1e+250 for params [0.5858801  0.13432387 0.04606977 0.6081545  0.40950987], L=60.86086086086087, nx=10000
# objective returned negative key rate -1e+250 for params [0.5858666  0.13434023 0.04611034 0.6081504  0.40943256], L=61.06106106106107, nx=10000
# objective returned negative key rate -1e+250 for params [0.58585304 0.1343566  0.04615097 0.6081462  0.4093551 ], L=61.26126126126127, nx=10000
# objective returned negative key rate -1e+250 for params [0.5858395  0.134373   0.04619148 0.6081421  0.40927792], L=61.46146146146147, nx=10000
# objective returned negative key rate -1e+250 for params [0.5858259  0.13438931 0.04623212 0.60813785 0.4092004 ], L=61.66166166166167, nx=10000
# objective returned negative key rate -1e+250 for params [0.58581245 0.1344057  0.04627271 0.60813373 0.40912315], L=61.86186186186187, nx=10000
# objective returned negative key rate -1e+250 for params [0.5857989  0.13442206 0.04631332 0.6081296  0.4090457 ], L=62.06206206206207, nx=10000
# objective returned negative key rate -1e+250 for params [0.58578545 0.13443843 0.04635385 0.6081255  0.40896842], L=62.26226226226227, nx=10000
# objective returned negative key rate -1e+250 for params [0.58577186 0.13445479 0.04639449 0.6081213  0.40889102], L=62.46246246246247, nx=10000
# objective returned negative key rate -1e+250 for params [0.5857583  0.13447116 0.04643502 0.60811716 0.40881377], L=62.66266266266267, nx=10000
# objective returned negative key rate -1e+250 for params [0.58574474 0.13448754 0.04647564 0.608113   0.4087364 ], L=62.86286286286287, nx=10000
# objective returned negative key rate -1e+250 for params [0.58573127 0.13450389 0.04651624 0.6081088  0.40865895], L=63.06306306306307, nx=10000
# objective returned negative key rate -1e+250 for params [0.58571774 0.13452026 0.0465568  0.60810477 0.4085817 ], L=63.26326326326327, nx=10000
# objective returned negative key rate -1e+250 for params [0.5857042  0.13453664 0.04659738 0.60810053 0.40850437], L=63.46346346346347, nx=10000
# objective returned negative key rate -1e+250 for params [0.58569074 0.13455299 0.04663796 0.6080965  0.40842697], L=63.66366366366367, nx=10000
# objective returned negative key rate -1e+250 for params [0.58567715 0.13456938 0.04667855 0.6080923  0.40834975], L=63.86386386386387, nx=10000
# objective returned negative key rate -1e+250 for params [0.5856636  0.13458572 0.04671913 0.60808814 0.4082723 ], L=64.06406406406407, nx=10000
# objective returned negative key rate -1e+250 for params [0.5856501  0.13460211 0.04675969 0.60808396 0.408195  ], L=64.26426426426427, nx=10000
# objective returned negative key rate -1e+250 for params [0.5856365  0.13461845 0.04680031 0.6080798  0.40811762], L=64.46446446446447, nx=10000
# objective returned negative key rate -1e+250 for params [0.585623   0.13463484 0.04684088 0.6080757  0.40804023], L=64.66466466466467, nx=10000
# objective returned negative key rate -1e+250 for params [0.5856095  0.1346512  0.04688147 0.60807145 0.40796295], L=64.86486486486487, nx=10000
# objective returned negative key rate -1e+250 for params [0.58559597 0.13466753 0.04692206 0.60806733 0.40788555], L=65.06506506506507, nx=10000
# objective returned negative key rate -1e+250 for params [0.58558244 0.13468394 0.0469626  0.6080633  0.4078083 ], L=65.26526526526527, nx=10000
# objective returned negative key rate -1e+250 for params [0.5855689  0.13470027 0.04700324 0.608059   0.40773082], L=65.46546546546547, nx=10000
# objective returned negative key rate -1e+250 for params [0.5855554  0.13471666 0.04704381 0.6080549  0.40765354], L=65.66566566566567, nx=10000
# objective returned negative key rate -1e+250 for params [0.58554184 0.13473304 0.04708438 0.60805076 0.40757614], L=65.86586586586587, nx=10000
# objective returned negative key rate -1e+250 for params [0.5855283  0.1347494  0.04712497 0.6080466  0.4074989 ], L=66.06606606606607, nx=10000
# objective returned negative key rate -1e+250 for params [0.5855148  0.13476576 0.04716558 0.6080425  0.40742153], L=66.26626626626627, nx=10000
# objective returned negative key rate -1e+250 for params [0.58550125 0.13478212 0.04720611 0.60803837 0.40734416], L=66.46646646646647, nx=10000
# objective returned negative key rate -1e+250 for params [0.5854878  0.1347985  0.0472467  0.6080342  0.40726683], L=66.66666666666667, nx=10000
# objective returned negative key rate -1e+250 for params [0.5854742  0.13481487 0.04728731 0.60803    0.40718955], L=66.86686686686687, nx=10000
# ...
# objective returned negative key rate -1e+250 for params [0.45812735 0.33276254 0.3452969  0.556909   0.81046927], L=155.95595595595597, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.45739898 0.33168063 0.35075697 0.5506181  0.8092768 ], L=156.15615615615616, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.45667055 0.33059874 0.356217   0.54432714 0.80808455], L=156.35635635635637, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.45521381 0.32843497 0.36713704 0.53174525 0.8056997 ], L=156.75675675675677, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.45230022 0.32410738 0.38897744 0.506581   0.8009303 ], L=157.55755755755757, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.45157188 0.32302555 0.39443693 0.5002907  0.7997379 ], L=157.75775775775776, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44939643 0.31978956 0.41072604 0.48152977 0.7961599 ], L=158.35835835835837, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44794616 0.31763226 0.4215855  0.46902242 0.79377466], L=158.75875875875877, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4457707  0.31439626 0.43787456 0.45026156 0.7901968 ], L=159.35935935935936, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44363317 0.31118512 0.45401132 0.4316664  0.78662056], L=159.95995995995997, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4423069  0.30910906 0.4643724  0.41970107 0.784241  ], L=160.36036036036037, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44143432 0.30765346 0.471303   0.41255566 0.7811352 ], L=160.76076076076077, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4411545  0.3068902  0.4738236  0.41012767 0.779964  ], L=160.96096096096096, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44090068 0.30608824 0.4762185  0.40782154 0.77893955], L=161.16116116116117, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4403931  0.3044843  0.48100844 0.40320933 0.7768906 ], L=161.56156156156158, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.44013926 0.3036824  0.48340353 0.40090328 0.77586615], L=161.76176176176176, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43937784 0.30127656 0.49058837 0.39398506 0.77279276], L=162.36236236236238, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43912402 0.3004746  0.49298334 0.39167896 0.77176833], L=162.56256256256256, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4383626  0.29806876 0.5001682  0.38476083 0.7686949 ], L=163.16316316316318, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4376012  0.29566294 0.507353   0.37784263 0.7656214 ], L=163.76376376376376, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43734732 0.29486096 0.5097481  0.37553647 0.76459706], L=163.96396396396398, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43683973 0.29325706 0.514538   0.37092432 0.7625481 ], L=164.36436436436438, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4365859  0.2924551  0.516933   0.36861828 0.7615235 ], L=164.56456456456456, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43633214 0.29165313 0.519328   0.36631212 0.760499  ], L=164.76476476476478, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43582448 0.29004928 0.524118   0.36170003 0.75845015], L=165.16516516516518, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43557066 0.28924733 0.52651286 0.35939398 0.75742567], L=165.36536536536536, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4353169  0.28844538 0.5289078  0.35708794 0.75640124], L=165.56556556556558, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43480924 0.28684148 0.5336978  0.35247573 0.7543523 ], L=165.96596596596598, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4345554  0.2860395  0.5360929  0.35016963 0.7533278 ], L=166.16616616616616, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43430158 0.28523755 0.53848785 0.34786347 0.7523033 ], L=166.36636636636638, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43303257 0.28122783 0.55046254 0.33633313 0.74718094], L=167.36736736736736, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43277878 0.28042588 0.5528575  0.33402714 0.74615645], L=167.56756756756758, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43125588 0.2756142  0.5672273  0.3201907  0.7400096 ], L=168.76876876876878, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.43074828 0.2740103  0.57201725 0.3155785  0.7379607 ], L=169.16916916916918, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4294792  0.27000055 0.5839922  0.3040482  0.7328383 ], L=170.17017017017017, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42846397 0.26679277 0.5935721  0.29482386 0.7287405 ], L=170.970970970971, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42821014 0.26599085 0.5959669  0.29251787 0.727716  ], L=171.17117117117118, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42744872 0.26358497 0.6031519  0.28559962 0.7246426 ], L=171.7717717717718, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4264335  0.2603772  0.61273175 0.27637538 0.7205447 ], L=172.5725725725726, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42465684 0.25476354 0.6294966  0.26023284 0.71337336], L=173.97397397397398, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.424403   0.2539616  0.63189137 0.25792673 0.7123489 ], L=174.1741741741742, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4241492  0.25315967 0.63428646 0.25562075 0.71132445], L=174.37437437437438, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42338777 0.25075382 0.64147127 0.24870245 0.70825106], L=174.974974974975, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42313394 0.24995187 0.6438663  0.24639641 0.70722663], L=175.17517517517518, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42262635 0.24834794 0.6486563  0.24178419 0.70517766], L=175.57557557557558, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42237252 0.24754603 0.6510511  0.23947819 0.7041532 ], L=175.7757757757758, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4218649  0.2459421  0.6558412  0.23486595 0.7021042 ], L=176.1761761761762, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4216111  0.24514018 0.658236   0.23255996 0.7010797 ], L=176.37637637637638, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42135727 0.24433823 0.6606311  0.23025386 0.70005536], L=176.5765765765766, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42110348 0.24353626 0.6630261  0.22794779 0.6990308 ], L=176.77677677677679, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4210985  0.24147515 0.66673404 0.22505407 0.69391614], L=176.976976976977, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42119724 0.23680305 0.6747229  0.21900997 0.6819007 ], L=177.3773773773774, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4212466  0.23446697 0.6787175  0.21598782 0.6758929 ], L=177.57757757757759, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42129597 0.23213105 0.68271184 0.21296594 0.6698856 ], L=177.7777777777778, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4213453  0.22979496 0.6867064  0.2099438  0.6638778 ], L=177.977977977978, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42139468 0.22745897 0.69070095 0.20692183 0.6578702 ], L=178.1781781781782, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42144403 0.22512288 0.6946954  0.20389973 0.6518623 ], L=178.3783783783784, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4214934  0.22278683 0.6986899  0.20087759 0.6458547 ], L=178.5785785785786, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42154273 0.22045082 0.70268434 0.19785567 0.639847  ], L=178.7787787787788, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4215921  0.2181148  0.70667875 0.19483362 0.63383937], L=178.978978978979, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4216908  0.21344276 0.7146678  0.18878952 0.62182415], L=179.3793793793794, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4218389  0.20643456 0.7266515  0.1797233  0.603801  ], L=179.97997997998, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42188826 0.2040986  0.7306458  0.17670144 0.5977934 ], L=180.1801801801802, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42193764 0.20176253 0.7346403  0.17367928 0.59178567], L=180.3803803803804, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42198697 0.19942649 0.7386348  0.17065723 0.58577794], L=180.5805805805806, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42203635 0.1970905  0.7426293  0.16763523 0.57977045], L=180.7807807807808, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4220857 0.1947544 0.7466239 0.1646131 0.5737626], L=180.980980980981, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42213508 0.19241838 0.75061834 0.16159113 0.5677549 ], L=181.1811811811812, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4221844  0.19008234 0.7546129  0.15856908 0.56174725], L=181.3813813813814, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42223376 0.18774638 0.7586073  0.15554707 0.5557398 ], L=181.5815815815816, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42228314 0.18541029 0.7626018  0.15252496 0.549732  ], L=181.7817817817818, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42238185 0.18073827 0.7705908  0.146481   0.53771675], L=182.1821821821822, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42248058 0.17606612 0.77857983 0.14043668 0.5257012 ], L=182.5825825825826, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4225299  0.17373012 0.7825743  0.13741477 0.5196937 ], L=182.7827827827828, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42257926 0.17139408 0.7865687  0.13439266 0.513686  ], L=182.982982982983, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42267802 0.16672207 0.7945577  0.1283487  0.50167084], L=183.3833833833834, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42277676 0.16204995 0.80254674 0.12230445 0.48965544], L=183.7837837837838, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42287543 0.15737785 0.8105358  0.11626038 0.47763997], L=184.1841841841842, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42292482 0.15504187 0.8145301  0.11323848 0.4716323 ], L=184.3843843843844, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42297414 0.15270579 0.81852466 0.1102164  0.4656246 ], L=184.5845845845846, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42302352 0.1503698  0.82251924 0.10719425 0.45961702], L=184.7847847847848, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42307287 0.14803374 0.82651365 0.10417227 0.45360932], L=184.984984984985, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42312226 0.14569765 0.8305083  0.10115014 0.44760156], L=185.1851851851852, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42317158 0.1433617  0.8345026  0.09812818 0.44159418], L=185.3853853853854, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42322093 0.14102562 0.83849704 0.0951061  0.43558627], L=185.5855855855856, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42327031 0.13868953 0.84249187 0.09208398 0.42957848], L=185.7857857857858, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42336905 0.13401745 0.85048074 0.08603995 0.4175631 ], L=186.1861861861862, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42341837 0.13168152 0.854475   0.083018   0.41155565], L=186.3863863863864, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42346776 0.12934549 0.8584696  0.07999592 0.40554807], L=186.5865865865866, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4235171  0.12700939 0.86246425 0.07697381 0.39954022], L=186.7867867867868, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42356643 0.12467334 0.86645865 0.07395175 0.39353248], L=186.986986986987, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4236158  0.12233734 0.87045324 0.07092973 0.38752493], L=187.1871871871872, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4236652  0.12000127 0.8744475  0.06790767 0.38151717], L=187.3873873873874, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42371455 0.11766528 0.8784421  0.06583714 0.37550965], L=187.5875875875876, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42376387 0.11532933 0.8794155  0.06583714 0.3695021 ], L=187.7877877877878, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42381325 0.11299324 0.8794155  0.06583714 0.36349434], L=187.987987987988, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4238626  0.11065716 0.8794155  0.06583714 0.3574866 ], L=188.1881881881882, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.423912   0.10832108 0.8794155  0.06583714 0.35147882], L=188.3883883883884, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42396137 0.10598508 0.8794155  0.06583714 0.34547117], L=188.5885885885886, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4240107  0.10364907 0.8794155  0.06583714 0.33946356], L=188.7887887887888, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42406005 0.10131298 0.8794155  0.06583714 0.3334558 ], L=188.988988988989, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42410943 0.09897704 0.8794155  0.06583714 0.3274484 ], L=189.1891891891892, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.42415878 0.09664103 0.8794155  0.06583714 0.3214407 ], L=189.3893893893894, nx=1000000000
# objective returned negative key rate -1e+250 for params [0.4242081  0.09430491 0.8794155  0.06583714 0.31543282], L=189.5895895895896, nx=1000000000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_28392/222585919.py:87: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to relative_error_nx_1e+09.png
# --- Plotting Time: 1.13 seconds ---
# --- Final Test Plotting Time (relative_error_nx_1e+09): 1.13 seconds ---

# %%
# Compute Mean Absolute Error (MAE) for parameters and key rates
mae_params = mean_absolute_error(optimized_params_array_un_seen, predicted_params_un_seen, multioutput='raw_values')
param_labels = ['$mu_1$', '$mu_2$', '$P_{mu_1}$', '$P_{mu_2}$', '$P_X$']
for label, mae in zip(param_labels, mae_params):
    print(f"MAE for {label}: {mae:.6f}")

# Compute MAE for key rates, handling NaN values
valid_mask = ~(np.isnan(optimized_key_rates_un_seen) | np.isnan(predicted_key_rates_un_seen))
if not np.any(valid_mask):
    print("Warning: All key rates are NaN. Cannot compute MAE for key rates.")
    mae_key_rates = float('nan')
else:
    mae_key_rates = mean_absolute_error(
        optimized_key_rates_un_seen[valid_mask],
        predicted_key_rates_un_seen[valid_mask]
    )
    print(f"Computed MAE for Key Rates using {np.sum(valid_mask)} valid data points.")
print(f"MAE for Key Rates: {mae_key_rates:.6f}")
# Out:
# MAE for $mu_1$: 0.018956
# MAE for $mu_2$: 0.014681
# MAE for $P_{mu_1}$: 0.040708
# MAE for $P_{mu_2}$: 0.028440
# MAE for $P_X$: 0.013721
# Computed MAE for Key Rates using 100 valid data points.
# MAE for Key Rates: 0.001294

# %%
def plot_keyrate_subplots_with_relative_error(all_data, epoch, filename):
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True)
    fig.suptitle(f"Key Rates and Relative Error vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())

    for i, nx in enumerate(nx_values):
        if i >= 6:
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        predicted_key_rates = all_data[nx].get('predicted_key_rates', None)

        valid_mask = ~(np.isnan(optimized_key_rates))
        if predicted_key_rates is not None:
            valid_mask &= ~np.isnan(predicted_key_rates)
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_key_rates = optimized_key_rates[valid_mask]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[valid_mask]

        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_key_rates = optimized_key_rates[:cutoff_idx]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[:cutoff_idx]

        # Plot key rates
        ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linewidth=2.0)
        if predicted_key_rates is not None:
            ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r:', label='Predicted Key Rate', linewidth=4.0)

        # Plot relative error on a secondary axis
        ax2 = ax.twinx()
        denominator = np.maximum(optimized_key_rates, threshold)
        rel_error = (predicted_key_rates - optimized_key_rates) / denominator
        rel_error = np.clip(rel_error, -10, 10)
        ax2.plot(fiber_lengths, rel_error, 'g--', label='Relative Error', alpha=0.5)
        ax2.set_ylabel('Relative Error', color='g')
        ax2.tick_params(axis='y', labelcolor='g')
        ax2.set_ylim(-10, 10)

        exponent = int(np.log10(nx))
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Secret Key Rate per Pulse")
        ax.legend(loc='upper left')
        ax2.legend(loc='upper right')

    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Key rate subplots with relative error saved to {filename}")

# %%
if epoch == num_epochs - 1:
    plot_keyrate_subplots_with_relative_error(plot_data, epoch, f'keyrate_subplots_with_rel_error_last_epoch.png')
    plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
