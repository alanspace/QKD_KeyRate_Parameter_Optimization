# %%
# %% [markdown]
# Import necessary libraries
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Subset
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error
import json
from tqdm import tqdm
import torch.nn.functional as F
import joblib
import os
os.environ['JAX_PLATFORMS'] = 'cpu'
import sys
from torch.utils.data import DataLoader, random_split
import time  # For timing

# Set matplotlib to use a non-interactive backend
plt.switch_backend('Agg')

# Get the notebook's directory
notebook_dir = os.getcwd()
# Add parent directory to path
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)

# %% [markdown]
# Checking if the MPS (Metal Performance Shaders) backend is available

# %%
# Check if MPS is available
if not torch.backends.mps.is_available():
    raise RuntimeError("MPS device not available. Check if PyTorch and macOS set up correctly.")

# Set the device to MPS
device = torch.device("mps")  # Use GPU on M2 Pro

# %%
# %%
# Import the objective function
# Import the physics engine from the src folder
from src.qkd.physics import (
    calculate_eta_ch, calculate_eta_sys, calculate_D_mu_k, 
    calculate_n_X_total, calculate_N, calculate_n_Z_total,
    calculate_e_mu_k, calculate_e_obs, calculate_h, calculate_lambda_EC,
    calculate_sqrt_term, calculate_n_pm, calculate_S_0, calculate_S_1,
    calculate_m_mu_k, calculate_m_pm, calculate_v_1, calculate_gamma,
    calculate_Phi, calculate_l, calculate_R
)
from src.qkd.model import calculate_key_rates_and_metrics, objective, penalty

# %%
# Load dataset
import json
import glob
import os

# Find the latest reordered grouped dataset
# Try absolute path from project root first
search_path = os.path.join(project_root, 'Training_Data/n_X/good/reordered_qkd_grouped_dataset_*.json')
files = sorted(glob.glob(search_path), reverse=True)

if not files:
    # Fallback to local relative path (if running from NeuralNetwork dir)
    files = sorted(glob.glob('../Training_Data/n_X/good/reordered_qkd_grouped_dataset_*.json'), reverse=True)

if not files:
    raise FileNotFoundError("No dataset found! Make sure you ran the optimization and reordering steps.")

latest_file = files[0]
print(f"📂 Loading latest dataset: {latest_file}")

with open(latest_file, 'r') as f:
    data_by_nx = json.load(f)

print(f"The overall dataset contains {len(data_by_nx)} entries (number of unique n_X values).")

# Print the number of entries for each n_X before filtering
for n_x in data_by_nx.keys():
    print(f"Number of entries for n_X = {n_x}: {len(data_by_nx[n_x])}")
# Out:
# 📂 Loading latest dataset: /Users/daai6ga1hou2/Documents/GitHub/Physics/QKD_KeyRate_Parameter_Optimization/Training_Data/n_X/good/reordered_qkd_grouped_dataset_20260120_060537.json
# The overall dataset contains 6 entries (number of unique n_X values).
# Number of entries for n_X = 10000.0: 1000
# Number of entries for n_X = 100000.0: 1000
# Number of entries for n_X = 1000000.0: 1000
# Number of entries for n_X = 10000000.0: 1000
# Number of entries for n_X = 100000000.0: 1000
# Number of entries for n_X = 1000000000.0: 1000

# %%
# Flatten the data structure and filter
cleaned_data = []
for n_x, entries in data_by_nx.items():
    filtered_entries = [item for item in entries if item["key_rate"] > 0 and item["e_1"] * 100 <= 200]
    print(f"After filtering, n_X = {n_x} has {len(filtered_entries)} entries.")
    cleaned_data.extend(filtered_entries)

# Verify the cleaned dataset
if not cleaned_data:
    print("No valid data after filtering.")
else:
    print(f"Filtered dataset contains {len(cleaned_data)} entries.")
    print("\nSample entry from the cleaned dataset:")
    print(json.dumps(cleaned_data[0], indent=2))
    print("\nNumber of unique n_X values:", len(data_by_nx))

# %%
X = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in cleaned_data])
Y = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'], item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'], item['optimized_params']['P_X_value']] for item in cleaned_data])
# Out:
# After filtering, n_X = 10000.0 has 740 entries.
# After filtering, n_X = 100000.0 has 855 entries.
# After filtering, n_X = 1000000.0 has 903 entries.
# After filtering, n_X = 10000000.0 has 927 entries.
# After filtering, n_X = 100000000.0 has 943 entries.
# After filtering, n_X = 1000000000.0 has 952 entries.
# Filtered dataset contains 5320 entries.
#
# Sample entry from the cleaned dataset:
# {
#   "fiber_length": 0.0,
#   "e_1": 0.0,
#   "e_2": 6.221848749616356,
#   "e_3": 0.5,
#   "e_4": 4.0,
#   "key_rate": 0.00037995895580887184,
#   "optimized_params": {
#     "mu_1": 0.6126301799469163,
#     "mu_2": 0.1381868651578539,
#     "P_mu_1": 0.04604305100679761,
#     "P_mu_2": 0.6110115806559344,
#     "P_X_value": 0.41473148234591684
#   }
# }
#
# Number of unique n_X values: 6

# %%
from sklearn.utils import shuffle

X, Y = shuffle(X, Y, random_state=42)

scaler = StandardScaler()
X = scaler.fit_transform(X)  # Fit and transform on training data

y_scaler = MinMaxScaler()  # Scale targets to [0, 1]
Y = y_scaler.fit_transform(Y)

# Save the scalers
joblib.dump(scaler, 'models/scaler.pkl')  # Save StandardScaler
joblib.dump(y_scaler, 'models/y_scaler.pkl')  # Save MinMaxScaler

print(f"X shape: {X.shape}, Y shape: {Y.shape}")
dataset = TensorDataset(torch.tensor(X, dtype=torch.float32), torch.tensor(Y, dtype=torch.float32))

# %%
# Split dataset into train and validation sets
train_size = int(0.8 * len(dataset))  # 80% for training
val_size = len(dataset) - train_size  # 20% for validation

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Data loaders with increased batch size
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
# Out:
# X shape: (5320, 4), Y shape: (5320, 5)

# %%
# %% [markdown]
# ### Prepare Evaluation Data for All n_X Values (10^4 to 10^9) Before Training

# Load the combined dataset
# combined_file_path = '../Training_Data/n_X/good/cleaned_combined_datasets.json'
# try:
#     with open(combined_file_path, 'r') as f:
#         combined_data = json.load(f)
#     print(f"Loaded combined dataset with {len(combined_data)} n_X entries.")
# except FileNotFoundError:
#     raise FileNotFoundError(f"Combined dataset not found at {combined_file_path}.")

# %% [markdown]
# ### Prepare Evaluation Data for All n_X Values (10^4 to 10^9) Before Training

# Load the combined dataset
# Note: Path corrected to be relative to the current notebook location
combined_file_path = 'Training_Data/n_X/good/cleaned_combined_datasets.json'
try:
    with open(combined_file_path, 'r') as f:
        combined_data = json.load(f)
    print(f"Loaded combined dataset with {len(combined_data)} n_X entries.")
except FileNotFoundError:
    raise FileNotFoundError(f"Combined dataset not found at {combined_file_path}.")
# Out:
# Loaded combined dataset with 6 n_X entries.

# %%
# Define the range of n_X values to evaluate
nx_values = [10**s for s in range(4, 10)]  # 10^4 to 10^9

# Dictionary to store evaluation data for each n_X
all_evaluation_data = {}

# %%
# Define a safe wrapper for the objective function
def safe_objective(params, L, nx, **kwargs):
    try:
        # Ensure params are in a numpy array for checking
        params_np = np.array(params)
        # Check for NaN/Inf in input params themselves
        if np.any(np.isnan(params_np)) or np.any(np.isinf(params_np)):
             # print(f"Invalid input params (NaN/Inf): {params_np}, L={L}, nx={nx}")
             return None

        # Call the JAX objective function (returns a tuple, key_rate is at index 0)
        key_rate = objective(params, L, nx, **kwargs)[0]

        if np.isnan(key_rate):
            # print(f"Objective returned NaN for params {params}, L={L}, nx={nx}")
            return None
        if np.isinf(key_rate):
            # print(f"Objective returned Inf for params {params}, L={L}, nx={nx}")
            return None
        if key_rate <= 0:
            # Filter non-positive key rates (expected behavior near physical limits)
            return None 

        return key_rate

    except Exception as e:
        # print(f"Exception in objective for params {params}, L={L}, nx={nx}: {e}")
        return None

# %%
# Extract and prepare evaluation data for each n_X
for nx in nx_values:
    nx_key = str(float(nx))
    if nx_key not in combined_data:
        print(f"No data found for n_X = {nx} in the combined dataset. Skipping...")
        continue
    evaluation_data = combined_data[nx_key]
    print(f"Extracted {len(evaluation_data)} entries for n_X = {nx}.")

    # Extract fiber lengths and optimized parameters
    fiber_lengths = np.array([entry["fiber_length"] for entry in evaluation_data])
    optimized_params_array = np.array([list(entry["optimized_params"].values()) for entry in evaluation_data])

    # Compute optimized key rates
    optimized_key_rates = []
    valid_indices = []
    for idx, (params, L) in enumerate(zip(optimized_params_array, fiber_lengths)):
        key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                  epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                  e_mis=5e-3, P_ap=0, n_event=1)
        if key_rate is None:
            print(f"Skipping invalid optimized key rate at index {idx} for n_X = {nx}")
            continue
        optimized_key_rates.append(key_rate)
        valid_indices.append(idx)
    optimized_key_rates = np.array(optimized_key_rates)

     #Filter the evaluation data to exclude invalid key rates
    if len(valid_indices) == 0:
        print(f"Warning: No valid key rates computed for n_X = {nx}. Skipping.")
        continue

    # Filter the evaluation data to exclude invalid key rates
    fiber_lengths = fiber_lengths[valid_indices]
    optimized_params_array = optimized_params_array[valid_indices]

    # Prepare test inputs for evaluation
    X_test = []
    for L in fiber_lengths:
        e_1 = L / 100
        e_2 = -np.log10(6e-7)
        e_3 = 5e-3 * 100
        e_4 = np.log10(nx)
        X_test.append([e_1, e_2, e_3, e_4])
    X_test = np.array(X_test)

    if X_test.size == 0:
         print(f"Warning: X_test is empty for n_X = {nx}. Skipping.")
         continue
        
    X_test_scaled = scaler.transform(X_test)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)

    # Store all evaluation data in a dictionary
    all_evaluation_data[nx] = {
        'fiber_lengths': fiber_lengths,
        'optimized_params_array': optimized_params_array,
        'optimized_key_rates': optimized_key_rates,
        'X_test_tensor': X_test_tensor
    }
    print(f"After filtering invalid key rates, {len(optimized_key_rates)} data points remain for n_X = {nx}.")
# Out:
# Extracted 736 entries for n_X = 10000.
# After filtering invalid key rates, 736 data points remain for n_X = 10000.
# Extracted 855 entries for n_X = 100000.
# After filtering invalid key rates, 855 data points remain for n_X = 100000.
# Extracted 902 entries for n_X = 1000000.
# After filtering invalid key rates, 902 data points remain for n_X = 1000000.
# Extracted 927 entries for n_X = 10000000.
# After filtering invalid key rates, 927 data points remain for n_X = 10000000.
# Extracted 942 entries for n_X = 100000000.
# After filtering invalid key rates, 942 data points remain for n_X = 100000000.
# Extracted 948 entries for n_X = 1000000000.
# After filtering invalid key rates, 948 data points remain for n_X = 1000000000.

# %%
# %%
# Define the neural network model
class BB84NN(nn.Module):
    def __init__(self):
        super(BB84NN, self).__init__()
        self.fc1 = nn.Linear(4, 16)
        self.fc2 = nn.Linear(16, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 5)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Initialize model, loss, optimizer, and scheduler
model = BB84NN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, min_lr=1e-6)

# Lists to store metrics
train_losses = []
val_losses = []
learning_rates = []

# %%
def plot_keyrate_subplots(all_data, epoch, filename):
    """
    Plots key rates vs fiber length for multiple n_X values.
    Handles cases where predicted data may be sparse or empty (e.g., at early epochs).
    """
    nx_values = sorted(all_data.keys(), key=lambda x: float(x))
    num_plots = len(nx_values)
    cols = 3
    rows = (num_plots + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=(15, 5 * rows), sharex=True, sharey=True)
    fig.suptitle(f"Key Rates vs Fiber Length at Epoch {epoch} ($n_X = 10^s$)", fontsize=16)
    
    # Handle single vs multiple plots
    if num_plots > 1:
        axes = axes.flatten()
    else:
        axes = np.array([axes])

    for i, nx in enumerate(nx_values):
        ax = axes[i]
        
        # Get data (use consistent naming)
        fiber_lengths_opt = all_data[nx]['fiber_lengths']
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        predicted_key_rates = all_data[nx].get('predicted_key_rates', np.array([]))
        fiber_lengths_pred = all_data[nx].get('fiber_lengths_pred', np.array([]))
        
        # ALWAYS plot optimized (ground truth)
        if len(optimized_key_rates) > 0:
            mask_opt = ~np.isnan(optimized_key_rates) & (optimized_key_rates > 0)
            if np.any(mask_opt):
                ax.plot(fiber_lengths_opt[mask_opt], 
                       np.log10(optimized_key_rates[mask_opt]), 
                       'b-', label='Optimized', linewidth=2, alpha=0.9)
    # for i, nx in enumerate(nx_values):
    #     ax = axes[i]
    #     data = all_data[nx]
        
    #     # # Optimized data (always available)
    #     fiber_lengths_opt = data['fiber_lengths']
    #     optimized_key_rates = data['optimized_key_rates']
        
    #     #Predicted data (may be sparse or empty, especially at epoch 0)
    #     predicted_key_rates = data.get('predicted_key_rates', np.array([]))
    #     fiber_lengths_pred = data.get('fiber_lengths_pred', fiber_lengths_opt)
        
    #     # Get data
    #     fiber_lengths_opt = all_data[nx]['fiber_lengths']  # ← For optimized
    #     optimized_key_rates = all_data[nx]['optimized_key_rates']
        
    #     predicted_key_rates = all_data[nx].get('predicted_key_rates', np.array([]))
    #     fiber_lengths_pred = all_data[nx].get('fiber_lengths_pred', np.array([]))  # ← NEW!

        # # Plot optimized (ALWAYS)
        # ax.plot(fiber_lengths_opt, np.log10(optimized_key_rates), 'b-', label='Optimized', linewidth=2.0)
        
        # ALWAYS plot optimized data (the ground truth)
        if len(predicted_key_rates) > 0 and len(fiber_lengths_pred) > 0:
            mask_pred = ~np.isnan(predicted_key_rates) & (predicted_key_rates > 0)
            if np.any(mask_pred):
                ax.plot(fiber_lengths_pred[mask_pred], np.log10(predicted_key_rates[mask_pred]), 'r--', label='Predicted (NN)', linewidth=2.5, alpha=0.7)

        # if len(optimized_key_rates) > 0:
        #     mask_opt = ~np.isnan(optimized_key_rates) & (optimized_key_rates > 0)
        #     if np.any(mask_opt):
        #         ax.plot(fiber_lengths_opt[mask_opt], 
        #                np.log10(optimized_key_rates[mask_opt]), 
        #                'b-', label='Optimized', linewidth=2, alpha=0.9)
        
        # Plot predicted data ONLY if available
        if len(predicted_key_rates) > 0:
            mask_pred = ~np.isnan(predicted_key_rates) & (predicted_key_rates > 0)
            if np.any(mask_pred):
                ax.plot(fiber_lengths_pred[mask_pred], np.log10(predicted_key_rates[mask_pred]), 'r--', label='Predicted (NN)', linewidth=2.5, alpha=0.7)
        
        # Formatting
        exponent = int(np.log10(float(nx)))
        ax.set_title(f"$n_X = 10^{{{exponent}}}$", fontsize=12)
        ax.set_xlabel("Fiber Length (km)")
        ax.set_ylabel("log₁₀(Key Rate)")
        ax.grid(True, which='both', linestyle=':', alpha=0.5)
        
        if i == 0:
            ax.legend(loc='lower left', fontsize=10)

    # Remove empty subplots
    for i in range(num_plots, len(axes)):
        fig.delaxes(axes[i])
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"✓ Key rate subplots saved to {filename}")

# %%
def plot_parameters_subplots(all_data, epoch, filename):
    """
    Plots parameters vs fiber length for multiple n_X values.
    Handles cases where predicted data may be sparse or empty.
    """
    nx_values = sorted(all_data.keys(), key=lambda x: float(x))
    num_plots = len(nx_values)
    cols = 3
    rows = (num_plots + cols - 1) // cols
    
    fig, axes = plt.subplots(rows, cols, figsize=(18, 5 * rows), sharex=True, sharey=False)
    fig.suptitle(f"Optimized Parameters vs Fiber Length at Epoch {epoch} ($n_X = 10^s$)", fontsize=16)
    
    if num_plots > 1:
        axes = axes.flatten()
    else:
        axes = np.array([axes])
    
    param_labels = ['$\\mu_1$', '$\\mu_2$', '$P_{\\mu_1}$', '$P_{\\mu_2}$', '$P_X$']
    colors = ['red', 'purple', 'orange', 'green', 'blue']

    for i, nx in enumerate(nx_values):
        ax = axes[i]
        data = all_data[nx]
        
        fiber_lengths_opt = data['fiber_lengths']
        # opt_params = data['optimized_params_array']
        # pred_params = data.get('predicted_params_array', None)
        # fiber_lengths_pred = data.get('fiber_lengths_pred', fiber_lengths_opt)
        
        fiber_lengths_opt = all_data[nx]['fiber_lengths']
        optimized_params_array = all_data[nx]['optimized_params_array']
        
        predicted_params_array = all_data[nx].get('predicted_params_array', None)
        fiber_lengths_pred = all_data[nx].get('fiber_lengths_pred', fiber_lengths_opt)  # ← NEW!

        # # Plot each parameter
        # for p_idx, (label, color) in enumerate(zip(param_labels, colors)):
        #     # Optimized (always available)
        #     if len(opt_params) > 0 and opt_params.shape[1] > p_idx:
        #         mask_opt = ~np.isnan(opt_params[:, p_idx])
        #         if np.any(mask_opt):
        #             ax.plot(fiber_lengths_opt[mask_opt], opt_params[mask_opt, p_idx], 
        #                    color=color, linestyle='-', alpha=0.4, linewidth=1.5,
        #                    label=f'Opt {label}' if i == 0 else "")
        # Plot parameters
        for param_idx, (label, color) in enumerate(zip(param_labels, colors)):
            # Optimized
            # ax.plot(fiber_lengths_opt, optimized_params_array[:, param_idx], color=color, linestyle='-', linewidth=2.0)
            ax.plot(fiber_lengths_opt, optimized_params_array[:, param_idx], 
            color=color, linestyle='-', linewidth=2.0, alpha=0.7,
            label=f'Opt {label}' if i == 0 else "")  #
            # # Predicted (may be empty)
            # if pred_params is not None and len(pred_params) > 0 and pred_params.shape[1] > p_idx:
            #     mask_pred = ~np.isnan(pred_params[:, p_idx])
            #     if np.any(mask_pred):
            #         ax.plot(fiber_lengths_pred[mask_pred], pred_params[mask_pred, p_idx], 
            #                color=color, linestyle='--', linewidth=2.5, alpha=0.8,
            #                label=f'Pred {label}' if i == 0 else "")
            # Predicted
            # if predicted_params_array is not None and len(predicted_params_array) > 0:
            #     ax.plot(fiber_lengths_pred, predicted_params_array[:, param_idx], color=color, linestyle=':', linewidth=4.0, alpha=0.7)  # ← Use fiber_lengths_pred!
            if predicted_params_array is not None and len(predicted_params_array) > 0:
                ax.plot(fiber_lengths_pred, predicted_params_array[:, param_idx], 
                color=color, linestyle=':', linewidth=4.0, alpha=0.7,
                label=f'Pred {label}' if i == 0 else "") 
        exponent = int(np.log10(float(nx)))
        ax.set_title(f"$n_X = 10^{{{exponent}}}$", fontsize=12)
        ax.set_xlabel("Fiber Length (km)")
        ax.set_ylabel("Parameter Value")
        ax.set_ylim(-0.05, 1.05)
        ax.grid(True, linestyle=':', alpha=0.4)
        
        if i == 0:
            ax.legend(loc='upper right', ncol=2, fontsize=8)

    for i in range(num_plots, len(axes)):
        fig.delaxes(axes[i])
    
    plt.tight_layout(rect=[0, 0.03, 1, 0.96])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close()
    print(f"✓ Parameter subplots saved to {filename}")

# %%
def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
                         predicted_key_rates, predicted_params_array, epoch, filename, 
                         nx=None, threshold=1e-7):  # Increase threshold to 1e-7
    # Start timing
    plot_start_time = time.time()

    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Compute relative errors
    # Parameters: mu_1, mu_2, P_mu_1, P_mu_2, P_X
    relative_errors = []
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    for i in range(5):
        optimized = optimized_params_array[:, i]
        predicted = predicted_params_array[:, i]
        denominator = np.maximum(optimized, 1e-10)
        rel_error = (predicted - optimized) / denominator
        relative_errors.append(rel_error)
    
    # Key rate relative error with a higher threshold
    denominator = np.maximum(optimized_key_rates, 1e-7)  # Increase threshold to 1e-7
    key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Plot relative errors
    for i in range(5):
        row = i // 3
        col = i % 3
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Relative Error')
        ax.set_title(f'Relative Error for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Key rate subplot
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Relative Error')
    ax_key.set_title('Relative Error for Key Rate')
    ax_key.grid(True)
    ax_key.legend(loc='best')

    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
    fig.suptitle(f'Relative Errors of Parameters for $n_X = 10^{{{exponent}}}$', fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Relative error plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
# Training loop
import time

# Training loop
total_start_time = time.time()
num_epochs = 5000
for epoch in range(num_epochs):
    start_time = time.time()

    # Training phase
    model.train()
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_running_loss += loss.item() * inputs.size(0)
    val_loss = val_running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)

    # Update learning rate
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    learning_rates.append(current_lr)

    # Evaluate and plot at the first and last epochs
    eval_time = 0
    plot_time = 0
    if epoch == 0 or epoch == num_epochs - 1:
        model.eval()
        with torch.no_grad():
            # Prepare data for all n_X values
            plot_data = {}
            eval_start = time.time()
            for nx, eval_data in all_evaluation_data.items():
                fiber_lengths = eval_data['fiber_lengths']
                optimized_params_array = eval_data['optimized_params_array']
                optimized_key_rates = eval_data['optimized_key_rates']
                X_test_tensor = eval_data['X_test_tensor']

                # Compute predicted parameters and key rates
                # predicted_params_scaled = model(X_test_tensor).cpu().numpy()
                predicted_params_scaled = model(X_test_tensor).detach().cpu().numpy()
                predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
                predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
                predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6) # mu_1
                predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6) # mu_2
                predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)    # P_mu_1
                predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)    # P_mu_2
                predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)    # P_X
                
                # --- NEW: Enforce Sum Constraint ---
                prob_sum = predicted_params_array[:, 2] + predicted_params_array[:, 3]
                # Option A: Normalize if sum > 1
                mask_sum_gt_1 = prob_sum > 1.0
                if np.any(mask_sum_gt_1):
                    predicted_params_array[mask_sum_gt_1, 2] /= prob_sum[mask_sum_gt_1] # Scale P_mu_1
                    predicted_params_array[mask_sum_gt_1, 3] /= prob_sum[mask_sum_gt_1] # Scale P_mu_2
                # Option B: Clip individual probabilities again (less physically motivated, but simpler)
                # predicted_params_array[:, 2] = np.minimum(predicted_params_array[:, 2], 1.0 - predicted_params_array[:, 3]) # Ensure P_mu_1 <= 1 - P_mu_2
                
                # Compute and filter predicted key rates
                predicted_key_rates = []
                valid_indices = []
                for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
                    key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                              epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                              e_mis=5e-3, P_ap=0, n_event=1)
                    if key_rate is None:
                        print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
                        continue
                    predicted_key_rates.append(key_rate)
                    valid_indices.append(idx)
                predicted_key_rates = np.array(predicted_key_rates)

                # Store data WITHOUT coupling optimized and predicted filtering
                # This ensures optimized data is always available even when predictions fail
                
                # Keep predicted data only for valid indices
                valid_predicted_params = predicted_params_array[valid_indices] if len(valid_indices) > 0 else np.array([])
                
                # Match fiber_lengths for predicted data
                valid_fiber_lengths_pred = fiber_lengths[valid_indices] if len(valid_indices) > 0 else np.array([])
                
                # Store data for plotting - DECOUPLED
                # plot_data[nx] = {
                #     'fiber_lengths': fiber_lengths,  # KEEP ALL for optimized data
                #     'optimized_key_rates': optimized_key_rates,  # KEEP ALL
                #     'optimized_params_array': optimized_params_array,  # KEEP ALL
                #     'predicted_key_rates': predicted_key_rates,  # Only valid predictions
                #     'predicted_params_array': valid_predicted_params,  # Only valid predictions
                #     'fiber_lengths_pred': valid_fiber_lengths_pred  # Match predicted data points
                # }

                plot_data[nx] = {
                    'fiber_lengths': fiber_lengths,  # ← KEEP ALL (for optimized)
                    'optimized_key_rates': optimized_key_rates,  # ← KEEP ALL
                    'optimized_params_array': optimized_params_array,  # ← KEEP ALL
                    'predicted_key_rates': predicted_key_rates,  # ← Only valid predictions
                    'predicted_params_array': predicted_params_array[valid_indices] if len(valid_indices) > 0 else np.array([]),  # ← Only valid predictions
                    'fiber_lengths_pred': fiber_lengths[valid_indices] if len(valid_indices) > 0 else np.array([])  # ← Matching fiber lengths for predictions
                }
                # Store data for plotting

                # Plot relative errors for this n_X
                # plot_relative_errors(
                #     fiber_lengths, optimized_key_rates, optimized_params_array,
                #     predicted_key_rates, predicted_params_array, epoch,
                #     f'parameter_relative_error_nx_{nx:.0e}.png', nx=nx
                # )
                plot_relative_errors(
                    valid_fiber_lengths_pred, 
                    optimized_key_rates[valid_indices], 
                    optimized_params_array[valid_indices],  # ← Use filtered versions
                    predicted_key_rates, 
                    predicted_params_array[valid_indices],  # Use this instead # ← Use filtered versions
                    epoch,
                    f'parameter_relative_error_nx_{nx:.0e}.png', 
                    nx=nx
                )

            eval_time += time.time() - eval_start

            # Plot subplots at the first and last epochs
            plot_start = time.time()
            if epoch == 0:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_first_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_first_epoch.png')
            if epoch == num_epochs - 1:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_last_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
            plot_time += time.time() - plot_start

            torch.save(model.state_dict(), 'models/bb84_nn_model.pth')
            print("Model saved to bb84_nn_model.pth")

    # Print epoch results with timing and learning rate
    epoch_time = time.time() - start_time
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss:a {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Learning Rate: {current_lr:.6f}, Time: {epoch_time:.2f}s (Eval: {eval_time:.2f}s, Plot: {plot_time:.2f}s)")

# Print total training time
total_training_time = time.time() - total_start_time
print(f"--- Total Training Time: {total_training_time:.2f} seconds ---")
# Out:
# Skipping invalid predicted key rate at index 0 for n_X = 10000
# Skipping invalid predicted key rate at index 1 for n_X = 10000
# Skipping invalid predicted key rate at index 2 for n_X = 10000
# Skipping invalid predicted key rate at index 3 for n_X = 10000
# Skipping invalid predicted key rate at index 4 for n_X = 10000
# Skipping invalid predicted key rate at index 5 for n_X = 10000
# Skipping invalid predicted key rate at index 6 for n_X = 10000
# Skipping invalid predicted key rate at index 7 for n_X = 10000
# Skipping invalid predicted key rate at index 8 for n_X = 10000
# Skipping invalid predicted key rate at index 9 for n_X = 10000
# Skipping invalid predicted key rate at index 10 for n_X = 10000
# Skipping invalid predicted key rate at index 11 for n_X = 10000
# Skipping invalid predicted key rate at index 12 for n_X = 10000
# Skipping invalid predicted key rate at index 13 for n_X = 10000
# Skipping invalid predicted key rate at index 14 for n_X = 10000
# Skipping invalid predicted key rate at index 15 for n_X = 10000
# Skipping invalid predicted key rate at index 16 for n_X = 10000
# Skipping invalid predicted key rate at index 17 for n_X = 10000
# Skipping invalid predicted key rate at index 18 for n_X = 10000
# Skipping invalid predicted key rate at index 19 for n_X = 10000
# Skipping invalid predicted key rate at index 20 for n_X = 10000
# Skipping invalid predicted key rate at index 21 for n_X = 10000
# Skipping invalid predicted key rate at index 22 for n_X = 10000
# Skipping invalid predicted key rate at index 23 for n_X = 10000
# Skipping invalid predicted key rate at index 24 for n_X = 10000
# Skipping invalid predicted key rate at index 25 for n_X = 10000
# Skipping invalid predicted key rate at index 26 for n_X = 10000
# Skipping invalid predicted key rate at index 27 for n_X = 10000
# Skipping invalid predicted key rate at index 28 for n_X = 10000
# Skipping invalid predicted key rate at index 29 for n_X = 10000
# Skipping invalid predicted key rate at index 30 for n_X = 10000
# Skipping invalid predicted key rate at index 31 for n_X = 10000
# Skipping invalid predicted key rate at index 32 for n_X = 10000
# Skipping invalid predicted key rate at index 33 for n_X = 10000
# Skipping invalid predicted key rate at index 34 for n_X = 10000
# Skipping invalid predicted key rate at index 35 for n_X = 10000
# Skipping invalid predicted key rate at index 36 for n_X = 10000
# Skipping invalid predicted key rate at index 37 for n_X = 10000
# Skipping invalid predicted key rate at index 38 for n_X = 10000
# Skipping invalid predicted key rate at index 39 for n_X = 10000
# Skipping invalid predicted key rate at index 40 for n_X = 10000
# Skipping invalid predicted key rate at index 41 for n_X = 10000
# Skipping invalid predicted key rate at index 42 for n_X = 10000
# Skipping invalid predicted key rate at index 43 for n_X = 10000
# Skipping invalid predicted key rate at index 44 for n_X = 10000
# Skipping invalid predicted key rate at index 45 for n_X = 10000
# Skipping invalid predicted key rate at index 46 for n_X = 10000
# Skipping invalid predicted key rate at index 47 for n_X = 10000
# Skipping invalid predicted key rate at index 48 for n_X = 10000
# Skipping invalid predicted key rate at index 49 for n_X = 10000
# Skipping invalid predicted key rate at index 50 for n_X = 10000
# Skipping invalid predicted key rate at index 51 for n_X = 10000
# Skipping invalid predicted key rate at index 52 for n_X = 10000
# Skipping invalid predicted key rate at index 53 for n_X = 10000
# Skipping invalid predicted key rate at index 54 for n_X = 10000
# Skipping invalid predicted key rate at index 55 for n_X = 10000
# Skipping invalid predicted key rate at index 56 for n_X = 10000
# Skipping invalid predicted key rate at index 57 for n_X = 10000
# Skipping invalid predicted key rate at index 58 for n_X = 10000
# Skipping invalid predicted key rate at index 59 for n_X = 10000
# Skipping invalid predicted key rate at index 60 for n_X = 10000
# Skipping invalid predicted key rate at index 61 for n_X = 10000
# Skipping invalid predicted key rate at index 62 for n_X = 10000
# Skipping invalid predicted key rate at index 63 for n_X = 10000
# Skipping invalid predicted key rate at index 64 for n_X = 10000
# Skipping invalid predicted key rate at index 65 for n_X = 10000
# Skipping invalid predicted key rate at index 66 for n_X = 10000
# Skipping invalid predicted key rate at index 67 for n_X = 10000
# Skipping invalid predicted key rate at index 68 for n_X = 10000
# Skipping invalid predicted key rate at index 69 for n_X = 10000
# Skipping invalid predicted key rate at index 70 for n_X = 10000
# Skipping invalid predicted key rate at index 71 for n_X = 10000
# Skipping invalid predicted key rate at index 72 for n_X = 10000
# Skipping invalid predicted key rate at index 73 for n_X = 10000
# Skipping invalid predicted key rate at index 74 for n_X = 10000
# Skipping invalid predicted key rate at index 75 for n_X = 10000
# Skipping invalid predicted key rate at index 76 for n_X = 10000
# Skipping invalid predicted key rate at index 77 for n_X = 10000
# Skipping invalid predicted key rate at index 78 for n_X = 10000
# Skipping invalid predicted key rate at index 79 for n_X = 10000
# Skipping invalid predicted key rate at index 80 for n_X = 10000
# Skipping invalid predicted key rate at index 81 for n_X = 10000
# Skipping invalid predicted key rate at index 82 for n_X = 10000
# Skipping invalid predicted key rate at index 83 for n_X = 10000
# Skipping invalid predicted key rate at index 84 for n_X = 10000
# Skipping invalid predicted key rate at index 85 for n_X = 10000
# Skipping invalid predicted key rate at index 86 for n_X = 10000
# Skipping invalid predicted key rate at index 87 for n_X = 10000
# Skipping invalid predicted key rate at index 88 for n_X = 10000
# Skipping invalid predicted key rate at index 89 for n_X = 10000
# Skipping invalid predicted key rate at index 90 for n_X = 10000
# Skipping invalid predicted key rate at index 91 for n_X = 10000
# Skipping invalid predicted key rate at index 92 for n_X = 10000
# Skipping invalid predicted key rate at index 93 for n_X = 10000
# Skipping invalid predicted key rate at index 94 for n_X = 10000
# Skipping invalid predicted key rate at index 95 for n_X = 10000
# Skipping invalid predicted key rate at index 96 for n_X = 10000
# Skipping invalid predicted key rate at index 97 for n_X = 10000
# Skipping invalid predicted key rate at index 98 for n_X = 10000
# Skipping invalid predicted key rate at index 99 for n_X = 10000
# Skipping invalid predicted key rate at index 100 for n_X = 10000
# Skipping invalid predicted key rate at index 101 for n_X = 10000
# Skipping invalid predicted key rate at index 102 for n_X = 10000
# Skipping invalid predicted key rate at index 103 for n_X = 10000
# Skipping invalid predicted key rate at index 104 for n_X = 10000
# Skipping invalid predicted key rate at index 105 for n_X = 10000
# Skipping invalid predicted key rate at index 106 for n_X = 10000
# Skipping invalid predicted key rate at index 107 for n_X = 10000
# Skipping invalid predicted key rate at index 108 for n_X = 10000
# Skipping invalid predicted key rate at index 109 for n_X = 10000
# Skipping invalid predicted key rate at index 110 for n_X = 10000
# Skipping invalid predicted key rate at index 111 for n_X = 10000
# Skipping invalid predicted key rate at index 112 for n_X = 10000
# Skipping invalid predicted key rate at index 113 for n_X = 10000
# Skipping invalid predicted key rate at index 114 for n_X = 10000
# Skipping invalid predicted key rate at index 115 for n_X = 10000
# Skipping invalid predicted key rate at index 116 for n_X = 10000
# Skipping invalid predicted key rate at index 117 for n_X = 10000
# Skipping invalid predicted key rate at index 118 for n_X = 10000
# Skipping invalid predicted key rate at index 119 for n_X = 10000
# Skipping invalid predicted key rate at index 120 for n_X = 10000
# Skipping invalid predicted key rate at index 121 for n_X = 10000
# Skipping invalid predicted key rate at index 122 for n_X = 10000
# Skipping invalid predicted key rate at index 123 for n_X = 10000
# Skipping invalid predicted key rate at index 124 for n_X = 10000
# Skipping invalid predicted key rate at index 125 for n_X = 10000
# Skipping invalid predicted key rate at index 126 for n_X = 10000
# Skipping invalid predicted key rate at index 127 for n_X = 10000
# Skipping invalid predicted key rate at index 128 for n_X = 10000
# Skipping invalid predicted key rate at index 129 for n_X = 10000
# Skipping invalid predicted key rate at index 130 for n_X = 10000
# Skipping invalid predicted key rate at index 131 for n_X = 10000
# Skipping invalid predicted key rate at index 132 for n_X = 10000
# Skipping invalid predicted key rate at index 133 for n_X = 10000
# Skipping invalid predicted key rate at index 134 for n_X = 10000
# Skipping invalid predicted key rate at index 135 for n_X = 10000
# Skipping invalid predicted key rate at index 136 for n_X = 10000
# Skipping invalid predicted key rate at index 137 for n_X = 10000
# Skipping invalid predicted key rate at index 138 for n_X = 10000
# Skipping invalid predicted key rate at index 139 for n_X = 10000
# Skipping invalid predicted key rate at index 140 for n_X = 10000
# Skipping invalid predicted key rate at index 141 for n_X = 10000
# Skipping invalid predicted key rate at index 142 for n_X = 10000
# Skipping invalid predicted key rate at index 143 for n_X = 10000
# Skipping invalid predicted key rate at index 144 for n_X = 10000
# Skipping invalid predicted key rate at index 145 for n_X = 10000
# Skipping invalid predicted key rate at index 146 for n_X = 10000
# Skipping invalid predicted key rate at index 147 for n_X = 10000
# Skipping invalid predicted key rate at index 148 for n_X = 10000
# Skipping invalid predicted key rate at index 149 for n_X = 10000
# Skipping invalid predicted key rate at index 150 for n_X = 10000
# Skipping invalid predicted key rate at index 151 for n_X = 10000
# Skipping invalid predicted key rate at index 152 for n_X = 10000
# Skipping invalid predicted key rate at index 153 for n_X = 10000
# Skipping invalid predicted key rate at index 154 for n_X = 10000
# Skipping invalid predicted key rate at index 155 for n_X = 10000
# Skipping invalid predicted key rate at index 156 for n_X = 10000
# Skipping invalid predicted key rate at index 157 for n_X = 10000
# Skipping invalid predicted key rate at index 158 for n_X = 10000
# Skipping invalid predicted key rate at index 159 for n_X = 10000
# Skipping invalid predicted key rate at index 160 for n_X = 10000
# Skipping invalid predicted key rate at index 161 for n_X = 10000
# Skipping invalid predicted key rate at index 162 for n_X = 10000
# Skipping invalid predicted key rate at index 163 for n_X = 10000
# Skipping invalid predicted key rate at index 164 for n_X = 10000
# Skipping invalid predicted key rate at index 165 for n_X = 10000
# Skipping invalid predicted key rate at index 166 for n_X = 10000
# Skipping invalid predicted key rate at index 167 for n_X = 10000
# Skipping invalid predicted key rate at index 168 for n_X = 10000
# Skipping invalid predicted key rate at index 169 for n_X = 10000
# Skipping invalid predicted key rate at index 170 for n_X = 10000
# Skipping invalid predicted key rate at index 171 for n_X = 10000
# Skipping invalid predicted key rate at index 172 for n_X = 10000
# Skipping invalid predicted key rate at index 173 for n_X = 10000
# Skipping invalid predicted key rate at index 174 for n_X = 10000
# Skipping invalid predicted key rate at index 175 for n_X = 10000
# Skipping invalid predicted key rate at index 176 for n_X = 10000
# Skipping invalid predicted key rate at index 177 for n_X = 10000
# Skipping invalid predicted key rate at index 178 for n_X = 10000
# Skipping invalid predicted key rate at index 179 for n_X = 10000
# Skipping invalid predicted key rate at index 180 for n_X = 10000
# Skipping invalid predicted key rate at index 181 for n_X = 10000
# Skipping invalid predicted key rate at index 182 for n_X = 10000
# Skipping invalid predicted key rate at index 183 for n_X = 10000
# Skipping invalid predicted key rate at index 184 for n_X = 10000
# Skipping invalid predicted key rate at index 185 for n_X = 10000
# Skipping invalid predicted key rate at index 186 for n_X = 10000
# Skipping invalid predicted key rate at index 187 for n_X = 10000
# Skipping invalid predicted key rate at index 188 for n_X = 10000
# Skipping invalid predicted key rate at index 189 for n_X = 10000
# Skipping invalid predicted key rate at index 190 for n_X = 10000
# Skipping invalid predicted key rate at index 191 for n_X = 10000
# Skipping invalid predicted key rate at index 192 for n_X = 10000
# Skipping invalid predicted key rate at index 193 for n_X = 10000
# Skipping invalid predicted key rate at index 194 for n_X = 10000
# Skipping invalid predicted key rate at index 195 for n_X = 10000
# Skipping invalid predicted key rate at index 196 for n_X = 10000
# Skipping invalid predicted key rate at index 197 for n_X = 10000
# Skipping invalid predicted key rate at index 198 for n_X = 10000
# Skipping invalid predicted key rate at index 199 for n_X = 10000
# Skipping invalid predicted key rate at index 200 for n_X = 10000
# Skipping invalid predicted key rate at index 201 for n_X = 10000
# Skipping invalid predicted key rate at index 202 for n_X = 10000
# Skipping invalid predicted key rate at index 203 for n_X = 10000
# Skipping invalid predicted key rate at index 204 for n_X = 10000
# Skipping invalid predicted key rate at index 205 for n_X = 10000
# Skipping invalid predicted key rate at index 206 for n_X = 10000
# Skipping invalid predicted key rate at index 207 for n_X = 10000
# Skipping invalid predicted key rate at index 208 for n_X = 10000
# Skipping invalid predicted key rate at index 209 for n_X = 10000
# Skipping invalid predicted key rate at index 210 for n_X = 10000
# Skipping invalid predicted key rate at index 211 for n_X = 10000
# Skipping invalid predicted key rate at index 212 for n_X = 10000
# Skipping invalid predicted key rate at index 213 for n_X = 10000
# Skipping invalid predicted key rate at index 214 for n_X = 10000
# Skipping invalid predicted key rate at index 215 for n_X = 10000
# Skipping invalid predicted key rate at index 216 for n_X = 10000
# Skipping invalid predicted key rate at index 217 for n_X = 10000
# Skipping invalid predicted key rate at index 218 for n_X = 10000
# Skipping invalid predicted key rate at index 219 for n_X = 10000
# Skipping invalid predicted key rate at index 220 for n_X = 10000
# Skipping invalid predicted key rate at index 221 for n_X = 10000
# Skipping invalid predicted key rate at index 222 for n_X = 10000
# Skipping invalid predicted key rate at index 223 for n_X = 10000
# Skipping invalid predicted key rate at index 224 for n_X = 10000
# Skipping invalid predicted key rate at index 225 for n_X = 10000
# Skipping invalid predicted key rate at index 226 for n_X = 10000
# Skipping invalid predicted key rate at index 227 for n_X = 10000
# Skipping invalid predicted key rate at index 228 for n_X = 10000
# Skipping invalid predicted key rate at index 229 for n_X = 10000
# Skipping invalid predicted key rate at index 230 for n_X = 10000
# Skipping invalid predicted key rate at index 231 for n_X = 10000
# Skipping invalid predicted key rate at index 232 for n_X = 10000
# Skipping invalid predicted key rate at index 233 for n_X = 10000
# Skipping invalid predicted key rate at index 234 for n_X = 10000
# Skipping invalid predicted key rate at index 235 for n_X = 10000
# Skipping invalid predicted key rate at index 236 for n_X = 10000
# Skipping invalid predicted key rate at index 237 for n_X = 10000
# Skipping invalid predicted key rate at index 238 for n_X = 10000
# Skipping invalid predicted key rate at index 239 for n_X = 10000
# Skipping invalid predicted key rate at index 240 for n_X = 10000
# Skipping invalid predicted key rate at index 241 for n_X = 10000
# Skipping invalid predicted key rate at index 242 for n_X = 10000
# Skipping invalid predicted key rate at index 243 for n_X = 10000
# Skipping invalid predicted key rate at index 244 for n_X = 10000
# Skipping invalid predicted key rate at index 245 for n_X = 10000
# Skipping invalid predicted key rate at index 246 for n_X = 10000
# Skipping invalid predicted key rate at index 247 for n_X = 10000
# Skipping invalid predicted key rate at index 248 for n_X = 10000
# Skipping invalid predicted key rate at index 249 for n_X = 10000
# Skipping invalid predicted key rate at index 250 for n_X = 10000
# Skipping invalid predicted key rate at index 251 for n_X = 10000
# Skipping invalid predicted key rate at index 252 for n_X = 10000
# Skipping invalid predicted key rate at index 253 for n_X = 10000
# Skipping invalid predicted key rate at index 254 for n_X = 10000
# Skipping invalid predicted key rate at index 255 for n_X = 10000
# Skipping invalid predicted key rate at index 256 for n_X = 10000
# Skipping invalid predicted key rate at index 257 for n_X = 10000
# Skipping invalid predicted key rate at index 258 for n_X = 10000
# Skipping invalid predicted key rate at index 259 for n_X = 10000
# Skipping invalid predicted key rate at index 260 for n_X = 10000
# Skipping invalid predicted key rate at index 261 for n_X = 10000
# Skipping invalid predicted key rate at index 262 for n_X = 10000
# Skipping invalid predicted key rate at index 263 for n_X = 10000
# Skipping invalid predicted key rate at index 264 for n_X = 10000
# Skipping invalid predicted key rate at index 265 for n_X = 10000
# Skipping invalid predicted key rate at index 266 for n_X = 10000
# Skipping invalid predicted key rate at index 267 for n_X = 10000
# Skipping invalid predicted key rate at index 268 for n_X = 10000
# Skipping invalid predicted key rate at index 269 for n_X = 10000
# Skipping invalid predicted key rate at index 270 for n_X = 10000
# Skipping invalid predicted key rate at index 271 for n_X = 10000
# Skipping invalid predicted key rate at index 272 for n_X = 10000
# Skipping invalid predicted key rate at index 273 for n_X = 10000
# Skipping invalid predicted key rate at index 274 for n_X = 10000
# Skipping invalid predicted key rate at index 275 for n_X = 10000
# Skipping invalid predicted key rate at index 276 for n_X = 10000
# Skipping invalid predicted key rate at index 277 for n_X = 10000
# Skipping invalid predicted key rate at index 278 for n_X = 10000
# Skipping invalid predicted key rate at index 279 for n_X = 10000
# Skipping invalid predicted key rate at index 280 for n_X = 10000
# Skipping invalid predicted key rate at index 281 for n_X = 10000
# Skipping invalid predicted key rate at index 282 for n_X = 10000
# Skipping invalid predicted key rate at index 283 for n_X = 10000
# Skipping invalid predicted key rate at index 284 for n_X = 10000
# Skipping invalid predicted key rate at index 285 for n_X = 10000
# Skipping invalid predicted key rate at index 286 for n_X = 10000
# Skipping invalid predicted key rate at index 287 for n_X = 10000
# Skipping invalid predicted key rate at index 288 for n_X = 10000
# Skipping invalid predicted key rate at index 289 for n_X = 10000
# Skipping invalid predicted key rate at index 290 for n_X = 10000
# Skipping invalid predicted key rate at index 291 for n_X = 10000
# Skipping invalid predicted key rate at index 292 for n_X = 10000
# Skipping invalid predicted key rate at index 293 for n_X = 10000
# Skipping invalid predicted key rate at index 294 for n_X = 10000
# Skipping invalid predicted key rate at index 295 for n_X = 10000
# Skipping invalid predicted key rate at index 296 for n_X = 10000
# Skipping invalid predicted key rate at index 297 for n_X = 10000
# Skipping invalid predicted key rate at index 298 for n_X = 10000
# Skipping invalid predicted key rate at index 299 for n_X = 10000
# Skipping invalid predicted key rate at index 300 for n_X = 10000
# Skipping invalid predicted key rate at index 301 for n_X = 10000
# Skipping invalid predicted key rate at index 302 for n_X = 10000
# Skipping invalid predicted key rate at index 303 for n_X = 10000
# Skipping invalid predicted key rate at index 304 for n_X = 10000
# Skipping invalid predicted key rate at index 305 for n_X = 10000
# Skipping invalid predicted key rate at index 306 for n_X = 10000
# Skipping invalid predicted key rate at index 307 for n_X = 10000
# Skipping invalid predicted key rate at index 308 for n_X = 10000
# Skipping invalid predicted key rate at index 309 for n_X = 10000
# Skipping invalid predicted key rate at index 310 for n_X = 10000
# Skipping invalid predicted key rate at index 311 for n_X = 10000
# Skipping invalid predicted key rate at index 312 for n_X = 10000
# Skipping invalid predicted key rate at index 313 for n_X = 10000
# Skipping invalid predicted key rate at index 314 for n_X = 10000
# Skipping invalid predicted key rate at index 315 for n_X = 10000
# Skipping invalid predicted key rate at index 316 for n_X = 10000
# Skipping invalid predicted key rate at index 317 for n_X = 10000
# Skipping invalid predicted key rate at index 318 for n_X = 10000
# Skipping invalid predicted key rate at index 319 for n_X = 10000
# Skipping invalid predicted key rate at index 320 for n_X = 10000
# Skipping invalid predicted key rate at index 321 for n_X = 10000
# Skipping invalid predicted key rate at index 322 for n_X = 10000
# Skipping invalid predicted key rate at index 323 for n_X = 10000
# Skipping invalid predicted key rate at index 324 for n_X = 10000
# Skipping invalid predicted key rate at index 325 for n_X = 10000
# Skipping invalid predicted key rate at index 326 for n_X = 10000
# Skipping invalid predicted key rate at index 327 for n_X = 10000
# Skipping invalid predicted key rate at index 328 for n_X = 10000
# Skipping invalid predicted key rate at index 329 for n_X = 10000
# Skipping invalid predicted key rate at index 330 for n_X = 10000
# Skipping invalid predicted key rate at index 331 for n_X = 10000
# Skipping invalid predicted key rate at index 332 for n_X = 10000
# Skipping invalid predicted key rate at index 333 for n_X = 10000
# Skipping invalid predicted key rate at index 334 for n_X = 10000
# Skipping invalid predicted key rate at index 335 for n_X = 10000
# Skipping invalid predicted key rate at index 336 for n_X = 10000
# Skipping invalid predicted key rate at index 337 for n_X = 10000
# Skipping invalid predicted key rate at index 338 for n_X = 10000
# Skipping invalid predicted key rate at index 339 for n_X = 10000
# Skipping invalid predicted key rate at index 340 for n_X = 10000
# Skipping invalid predicted key rate at index 341 for n_X = 10000
# Skipping invalid predicted key rate at index 342 for n_X = 10000
# Skipping invalid predicted key rate at index 343 for n_X = 10000
# Skipping invalid predicted key rate at index 344 for n_X = 10000
# Skipping invalid predicted key rate at index 345 for n_X = 10000
# Skipping invalid predicted key rate at index 346 for n_X = 10000
# Skipping invalid predicted key rate at index 347 for n_X = 10000
# Skipping invalid predicted key rate at index 348 for n_X = 10000
# Skipping invalid predicted key rate at index 349 for n_X = 10000
# Skipping invalid predicted key rate at index 350 for n_X = 10000
# Skipping invalid predicted key rate at index 351 for n_X = 10000
# Skipping invalid predicted key rate at index 352 for n_X = 10000
# Skipping invalid predicted key rate at index 353 for n_X = 10000
# Skipping invalid predicted key rate at index 354 for n_X = 10000
# Skipping invalid predicted key rate at index 355 for n_X = 10000
# Skipping invalid predicted key rate at index 356 for n_X = 10000
# Skipping invalid predicted key rate at index 357 for n_X = 10000
# Skipping invalid predicted key rate at index 358 for n_X = 10000
# Skipping invalid predicted key rate at index 359 for n_X = 10000
# Skipping invalid predicted key rate at index 360 for n_X = 10000
# Skipping invalid predicted key rate at index 361 for n_X = 10000
# Skipping invalid predicted key rate at index 362 for n_X = 10000
# Skipping invalid predicted key rate at index 363 for n_X = 10000
# Skipping invalid predicted key rate at index 364 for n_X = 10000
# Skipping invalid predicted key rate at index 365 for n_X = 10000
# Skipping invalid predicted key rate at index 366 for n_X = 10000
# Skipping invalid predicted key rate at index 367 for n_X = 10000
# Skipping invalid predicted key rate at index 368 for n_X = 10000
# Skipping invalid predicted key rate at index 369 for n_X = 10000
# Skipping invalid predicted key rate at index 370 for n_X = 10000
# Skipping invalid predicted key rate at index 371 for n_X = 10000
# Skipping invalid predicted key rate at index 372 for n_X = 10000
# Skipping invalid predicted key rate at index 373 for n_X = 10000
# Skipping invalid predicted key rate at index 374 for n_X = 10000
# Skipping invalid predicted key rate at index 375 for n_X = 10000
# Skipping invalid predicted key rate at index 376 for n_X = 10000
# Skipping invalid predicted key rate at index 377 for n_X = 10000
# Skipping invalid predicted key rate at index 378 for n_X = 10000
# Skipping invalid predicted key rate at index 379 for n_X = 10000
# Skipping invalid predicted key rate at index 380 for n_X = 10000
# Skipping invalid predicted key rate at index 381 for n_X = 10000
# Skipping invalid predicted key rate at index 382 for n_X = 10000
# Skipping invalid predicted key rate at index 383 for n_X = 10000
# Skipping invalid predicted key rate at index 384 for n_X = 10000
# Skipping invalid predicted key rate at index 385 for n_X = 10000
# Skipping invalid predicted key rate at index 386 for n_X = 10000
# Skipping invalid predicted key rate at index 387 for n_X = 10000
# Skipping invalid predicted key rate at index 388 for n_X = 10000
# Skipping invalid predicted key rate at index 389 for n_X = 10000
# Skipping invalid predicted key rate at index 390 for n_X = 10000
# Skipping invalid predicted key rate at index 391 for n_X = 10000
# Skipping invalid predicted key rate at index 392 for n_X = 10000
# Skipping invalid predicted key rate at index 393 for n_X = 10000
# Skipping invalid predicted key rate at index 394 for n_X = 10000
# Skipping invalid predicted key rate at index 395 for n_X = 10000
# Skipping invalid predicted key rate at index 396 for n_X = 10000
# Skipping invalid predicted key rate at index 397 for n_X = 10000
# Skipping invalid predicted key rate at index 398 for n_X = 10000
# Skipping invalid predicted key rate at index 399 for n_X = 10000
# Skipping invalid predicted key rate at index 400 for n_X = 10000
# Skipping invalid predicted key rate at index 401 for n_X = 10000
# Skipping invalid predicted key rate at index 402 for n_X = 10000
# Skipping invalid predicted key rate at index 403 for n_X = 10000
# Skipping invalid predicted key rate at index 404 for n_X = 10000
# Skipping invalid predicted key rate at index 405 for n_X = 10000
# Skipping invalid predicted key rate at index 406 for n_X = 10000
# Skipping invalid predicted key rate at index 407 for n_X = 10000
# Skipping invalid predicted key rate at index 408 for n_X = 10000
# Skipping invalid predicted key rate at index 409 for n_X = 10000
# Skipping invalid predicted key rate at index 410 for n_X = 10000
# Skipping invalid predicted key rate at index 411 for n_X = 10000
# Skipping invalid predicted key rate at index 412 for n_X = 10000
# Skipping invalid predicted key rate at index 413 for n_X = 10000
# Skipping invalid predicted key rate at index 414 for n_X = 10000
# Skipping invalid predicted key rate at index 415 for n_X = 10000
# Skipping invalid predicted key rate at index 416 for n_X = 10000
# Skipping invalid predicted key rate at index 417 for n_X = 10000
# Skipping invalid predicted key rate at index 418 for n_X = 10000
# Skipping invalid predicted key rate at index 419 for n_X = 10000
# Skipping invalid predicted key rate at index 420 for n_X = 10000
# Skipping invalid predicted key rate at index 421 for n_X = 10000
# Skipping invalid predicted key rate at index 422 for n_X = 10000
# Skipping invalid predicted key rate at index 423 for n_X = 10000
# Skipping invalid predicted key rate at index 424 for n_X = 10000
# Skipping invalid predicted key rate at index 425 for n_X = 10000
# Skipping invalid predicted key rate at index 426 for n_X = 10000
# Skipping invalid predicted key rate at index 427 for n_X = 10000
# Skipping invalid predicted key rate at index 428 for n_X = 10000
# Skipping invalid predicted key rate at index 429 for n_X = 10000
# Skipping invalid predicted key rate at index 430 for n_X = 10000
# Skipping invalid predicted key rate at index 431 for n_X = 10000
# Skipping invalid predicted key rate at index 432 for n_X = 10000
# Skipping invalid predicted key rate at index 433 for n_X = 10000
# Skipping invalid predicted key rate at index 434 for n_X = 10000
# Skipping invalid predicted key rate at index 435 for n_X = 10000
# Skipping invalid predicted key rate at index 436 for n_X = 10000
# Skipping invalid predicted key rate at index 437 for n_X = 10000
# Skipping invalid predicted key rate at index 438 for n_X = 10000
# Skipping invalid predicted key rate at index 439 for n_X = 10000
# Skipping invalid predicted key rate at index 440 for n_X = 10000
# Skipping invalid predicted key rate at index 441 for n_X = 10000
# Skipping invalid predicted key rate at index 442 for n_X = 10000
# Skipping invalid predicted key rate at index 443 for n_X = 10000
# Skipping invalid predicted key rate at index 444 for n_X = 10000
# Skipping invalid predicted key rate at index 445 for n_X = 10000
# Skipping invalid predicted key rate at index 446 for n_X = 10000
# Skipping invalid predicted key rate at index 447 for n_X = 10000
# Skipping invalid predicted key rate at index 448 for n_X = 10000
# Skipping invalid predicted key rate at index 449 for n_X = 10000
# Skipping invalid predicted key rate at index 450 for n_X = 10000
# Skipping invalid predicted key rate at index 451 for n_X = 10000
# Skipping invalid predicted key rate at index 452 for n_X = 10000
# Skipping invalid predicted key rate at index 453 for n_X = 10000
# Skipping invalid predicted key rate at index 454 for n_X = 10000
# Skipping invalid predicted key rate at index 455 for n_X = 10000
# Skipping invalid predicted key rate at index 456 for n_X = 10000
# Skipping invalid predicted key rate at index 457 for n_X = 10000
# Skipping invalid predicted key rate at index 458 for n_X = 10000
# Skipping invalid predicted key rate at index 459 for n_X = 10000
# Skipping invalid predicted key rate at index 460 for n_X = 10000
# Skipping invalid predicted key rate at index 461 for n_X = 10000
# Skipping invalid predicted key rate at index 462 for n_X = 10000
# Skipping invalid predicted key rate at index 463 for n_X = 10000
# Skipping invalid predicted key rate at index 464 for n_X = 10000
# Skipping invalid predicted key rate at index 465 for n_X = 10000
# Skipping invalid predicted key rate at index 466 for n_X = 10000
# Skipping invalid predicted key rate at index 467 for n_X = 10000
# Skipping invalid predicted key rate at index 468 for n_X = 10000
# Skipping invalid predicted key rate at index 469 for n_X = 10000
# Skipping invalid predicted key rate at index 470 for n_X = 10000
# Skipping invalid predicted key rate at index 471 for n_X = 10000
# Skipping invalid predicted key rate at index 472 for n_X = 10000
# Skipping invalid predicted key rate at index 473 for n_X = 10000
# Skipping invalid predicted key rate at index 474 for n_X = 10000
# Skipping invalid predicted key rate at index 475 for n_X = 10000
# Skipping invalid predicted key rate at index 476 for n_X = 10000
# Skipping invalid predicted key rate at index 477 for n_X = 10000
# Skipping invalid predicted key rate at index 478 for n_X = 10000
# Skipping invalid predicted key rate at index 479 for n_X = 10000
# Skipping invalid predicted key rate at index 480 for n_X = 10000
# Skipping invalid predicted key rate at index 481 for n_X = 10000
# Skipping invalid predicted key rate at index 482 for n_X = 10000
# Skipping invalid predicted key rate at index 483 for n_X = 10000
# Skipping invalid predicted key rate at index 484 for n_X = 10000
# Skipping invalid predicted key rate at index 485 for n_X = 10000
# Skipping invalid predicted key rate at index 486 for n_X = 10000
# Skipping invalid predicted key rate at index 487 for n_X = 10000
# Skipping invalid predicted key rate at index 488 for n_X = 10000
# Skipping invalid predicted key rate at index 489 for n_X = 10000
# Skipping invalid predicted key rate at index 490 for n_X = 10000
# Skipping invalid predicted key rate at index 491 for n_X = 10000
# Skipping invalid predicted key rate at index 492 for n_X = 10000
# Skipping invalid predicted key rate at index 493 for n_X = 10000
# Skipping invalid predicted key rate at index 494 for n_X = 10000
# Skipping invalid predicted key rate at index 495 for n_X = 10000
# Skipping invalid predicted key rate at index 496 for n_X = 10000
# Skipping invalid predicted key rate at index 497 for n_X = 10000
# Skipping invalid predicted key rate at index 498 for n_X = 10000
# Skipping invalid predicted key rate at index 499 for n_X = 10000
# Skipping invalid predicted key rate at index 500 for n_X = 10000
# Skipping invalid predicted key rate at index 501 for n_X = 10000
# Skipping invalid predicted key rate at index 502 for n_X = 10000
# Skipping invalid predicted key rate at index 503 for n_X = 10000
# Skipping invalid predicted key rate at index 504 for n_X = 10000
# Skipping invalid predicted key rate at index 505 for n_X = 10000
# Skipping invalid predicted key rate at index 506 for n_X = 10000
# Skipping invalid predicted key rate at index 507 for n_X = 10000
# Skipping invalid predicted key rate at index 508 for n_X = 10000
# Skipping invalid predicted key rate at index 509 for n_X = 10000
# Skipping invalid predicted key rate at index 510 for n_X = 10000
# Skipping invalid predicted key rate at index 511 for n_X = 10000
# Skipping invalid predicted key rate at index 512 for n_X = 10000
# Skipping invalid predicted key rate at index 513 for n_X = 10000
# Skipping invalid predicted key rate at index 514 for n_X = 10000
# Skipping invalid predicted key rate at index 515 for n_X = 10000
# Skipping invalid predicted key rate at index 516 for n_X = 10000
# Skipping invalid predicted key rate at index 517 for n_X = 10000
# Skipping invalid predicted key rate at index 518 for n_X = 10000
# Skipping invalid predicted key rate at index 519 for n_X = 10000
# Skipping invalid predicted key rate at index 520 for n_X = 10000
# Skipping invalid predicted key rate at index 521 for n_X = 10000
# Skipping invalid predicted key rate at index 522 for n_X = 10000
# Skipping invalid predicted key rate at index 523 for n_X = 10000
# Skipping invalid predicted key rate at index 524 for n_X = 10000
# Skipping invalid predicted key rate at index 525 for n_X = 10000
# Skipping invalid predicted key rate at index 526 for n_X = 10000
# Skipping invalid predicted key rate at index 527 for n_X = 10000
# Skipping invalid predicted key rate at index 528 for n_X = 10000
# Skipping invalid predicted key rate at index 529 for n_X = 10000
# Skipping invalid predicted key rate at index 530 for n_X = 10000
# Skipping invalid predicted key rate at index 531 for n_X = 10000
# Skipping invalid predicted key rate at index 532 for n_X = 10000
# Skipping invalid predicted key rate at index 533 for n_X = 10000
# Skipping invalid predicted key rate at index 534 for n_X = 10000
# Skipping invalid predicted key rate at index 535 for n_X = 10000
# Skipping invalid predicted key rate at index 536 for n_X = 10000
# Skipping invalid predicted key rate at index 537 for n_X = 10000
# Skipping invalid predicted key rate at index 538 for n_X = 10000
# Skipping invalid predicted key rate at index 539 for n_X = 10000
# Skipping invalid predicted key rate at index 540 for n_X = 10000
# Skipping invalid predicted key rate at index 541 for n_X = 10000
# Skipping invalid predicted key rate at index 542 for n_X = 10000
# Skipping invalid predicted key rate at index 543 for n_X = 10000
# Skipping invalid predicted key rate at index 544 for n_X = 10000
# Skipping invalid predicted key rate at index 545 for n_X = 10000
# Skipping invalid predicted key rate at index 546 for n_X = 10000
# Skipping invalid predicted key rate at index 547 for n_X = 10000
# Skipping invalid predicted key rate at index 548 for n_X = 10000
# Skipping invalid predicted key rate at index 549 for n_X = 10000
# Skipping invalid predicted key rate at index 550 for n_X = 10000
# Skipping invalid predicted key rate at index 551 for n_X = 10000
# Skipping invalid predicted key rate at index 552 for n_X = 10000
# Skipping invalid predicted key rate at index 553 for n_X = 10000
# Skipping invalid predicted key rate at index 554 for n_X = 10000
# Skipping invalid predicted key rate at index 555 for n_X = 10000
# Skipping invalid predicted key rate at index 556 for n_X = 10000
# Skipping invalid predicted key rate at index 557 for n_X = 10000
# Skipping invalid predicted key rate at index 558 for n_X = 10000
# Skipping invalid predicted key rate at index 559 for n_X = 10000
# Skipping invalid predicted key rate at index 560 for n_X = 10000
# Skipping invalid predicted key rate at index 561 for n_X = 10000
# Skipping invalid predicted key rate at index 562 for n_X = 10000
# Skipping invalid predicted key rate at index 563 for n_X = 10000
# Skipping invalid predicted key rate at index 564 for n_X = 10000
# Skipping invalid predicted key rate at index 565 for n_X = 10000
# Skipping invalid predicted key rate at index 566 for n_X = 10000
# Skipping invalid predicted key rate at index 567 for n_X = 10000
# Skipping invalid predicted key rate at index 568 for n_X = 10000
# Skipping invalid predicted key rate at index 569 for n_X = 10000
# Skipping invalid predicted key rate at index 570 for n_X = 10000
# Skipping invalid predicted key rate at index 571 for n_X = 10000
# Skipping invalid predicted key rate at index 572 for n_X = 10000
# Skipping invalid predicted key rate at index 573 for n_X = 10000
# Skipping invalid predicted key rate at index 574 for n_X = 10000
# Skipping invalid predicted key rate at index 575 for n_X = 10000
# Skipping invalid predicted key rate at index 576 for n_X = 10000
# Skipping invalid predicted key rate at index 577 for n_X = 10000
# Skipping invalid predicted key rate at index 578 for n_X = 10000
# Skipping invalid predicted key rate at index 579 for n_X = 10000
# Skipping invalid predicted key rate at index 580 for n_X = 10000
# Skipping invalid predicted key rate at index 581 for n_X = 10000
# Skipping invalid predicted key rate at index 582 for n_X = 10000
# Skipping invalid predicted key rate at index 583 for n_X = 10000
# Skipping invalid predicted key rate at index 584 for n_X = 10000
# Skipping invalid predicted key rate at index 585 for n_X = 10000
# Skipping invalid predicted key rate at index 586 for n_X = 10000
# Skipping invalid predicted key rate at index 587 for n_X = 10000
# Skipping invalid predicted key rate at index 588 for n_X = 10000
# Skipping invalid predicted key rate at index 589 for n_X = 10000
# Skipping invalid predicted key rate at index 590 for n_X = 10000
# Skipping invalid predicted key rate at index 591 for n_X = 10000
# Skipping invalid predicted key rate at index 592 for n_X = 10000
# Skipping invalid predicted key rate at index 593 for n_X = 10000
# Skipping invalid predicted key rate at index 594 for n_X = 10000
# Skipping invalid predicted key rate at index 595 for n_X = 10000
# Skipping invalid predicted key rate at index 596 for n_X = 10000
# Skipping invalid predicted key rate at index 597 for n_X = 10000
# Skipping invalid predicted key rate at index 598 for n_X = 10000
# Skipping invalid predicted key rate at index 599 for n_X = 10000
# Skipping invalid predicted key rate at index 600 for n_X = 10000
# Skipping invalid predicted key rate at index 601 for n_X = 10000
# Skipping invalid predicted key rate at index 602 for n_X = 10000
# Skipping invalid predicted key rate at index 603 for n_X = 10000
# Skipping invalid predicted key rate at index 604 for n_X = 10000
# Skipping invalid predicted key rate at index 605 for n_X = 10000
# Skipping invalid predicted key rate at index 606 for n_X = 10000
# Skipping invalid predicted key rate at index 607 for n_X = 10000
# Skipping invalid predicted key rate at index 608 for n_X = 10000
# Skipping invalid predicted key rate at index 609 for n_X = 10000
# Skipping invalid predicted key rate at index 610 for n_X = 10000
# Skipping invalid predicted key rate at index 611 for n_X = 10000
# Skipping invalid predicted key rate at index 612 for n_X = 10000
# Skipping invalid predicted key rate at index 613 for n_X = 10000
# Skipping invalid predicted key rate at index 614 for n_X = 10000
# Skipping invalid predicted key rate at index 615 for n_X = 10000
# Skipping invalid predicted key rate at index 616 for n_X = 10000
# Skipping invalid predicted key rate at index 617 for n_X = 10000
# Skipping invalid predicted key rate at index 618 for n_X = 10000
# Skipping invalid predicted key rate at index 619 for n_X = 10000
# Skipping invalid predicted key rate at index 620 for n_X = 10000
# Skipping invalid predicted key rate at index 621 for n_X = 10000
# Skipping invalid predicted key rate at index 622 for n_X = 10000
# Skipping invalid predicted key rate at index 623 for n_X = 10000
# Skipping invalid predicted key rate at index 624 for n_X = 10000
# Skipping invalid predicted key rate at index 625 for n_X = 10000
# Skipping invalid predicted key rate at index 626 for n_X = 10000
# Skipping invalid predicted key rate at index 627 for n_X = 10000
# Skipping invalid predicted key rate at index 628 for n_X = 10000
# Skipping invalid predicted key rate at index 629 for n_X = 10000
# Skipping invalid predicted key rate at index 630 for n_X = 10000
# Skipping invalid predicted key rate at index 631 for n_X = 10000
# Skipping invalid predicted key rate at index 632 for n_X = 10000
# Skipping invalid predicted key rate at index 633 for n_X = 10000
# Skipping invalid predicted key rate at index 634 for n_X = 10000
# Skipping invalid predicted key rate at index 635 for n_X = 10000
# Skipping invalid predicted key rate at index 636 for n_X = 10000
# Skipping invalid predicted key rate at index 637 for n_X = 10000
# Skipping invalid predicted key rate at index 638 for n_X = 10000
# Skipping invalid predicted key rate at index 639 for n_X = 10000
# Skipping invalid predicted key rate at index 640 for n_X = 10000
# Skipping invalid predicted key rate at index 641 for n_X = 10000
# Skipping invalid predicted key rate at index 642 for n_X = 10000
# Skipping invalid predicted key rate at index 643 for n_X = 10000
# Skipping invalid predicted key rate at index 644 for n_X = 10000
# Skipping invalid predicted key rate at index 645 for n_X = 10000
# Skipping invalid predicted key rate at index 646 for n_X = 10000
# Skipping invalid predicted key rate at index 647 for n_X = 10000
# Skipping invalid predicted key rate at index 648 for n_X = 10000
# Skipping invalid predicted key rate at index 649 for n_X = 10000
# Skipping invalid predicted key rate at index 650 for n_X = 10000
# Skipping invalid predicted key rate at index 651 for n_X = 10000
# Skipping invalid predicted key rate at index 652 for n_X = 10000
# Skipping invalid predicted key rate at index 653 for n_X = 10000
# Skipping invalid predicted key rate at index 654 for n_X = 10000
# Skipping invalid predicted key rate at index 655 for n_X = 10000
# Skipping invalid predicted key rate at index 656 for n_X = 10000
# Skipping invalid predicted key rate at index 657 for n_X = 10000
# Skipping invalid predicted key rate at index 658 for n_X = 10000
# Skipping invalid predicted key rate at index 659 for n_X = 10000
# Skipping invalid predicted key rate at index 660 for n_X = 10000
# Skipping invalid predicted key rate at index 661 for n_X = 10000
# Skipping invalid predicted key rate at index 662 for n_X = 10000
# Skipping invalid predicted key rate at index 663 for n_X = 10000
# Skipping invalid predicted key rate at index 664 for n_X = 10000
# Skipping invalid predicted key rate at index 665 for n_X = 10000
# Skipping invalid predicted key rate at index 666 for n_X = 10000
# Skipping invalid predicted key rate at index 667 for n_X = 10000
# Skipping invalid predicted key rate at index 668 for n_X = 10000
# Skipping invalid predicted key rate at index 669 for n_X = 10000
# Skipping invalid predicted key rate at index 670 for n_X = 10000
# Skipping invalid predicted key rate at index 671 for n_X = 10000
# Skipping invalid predicted key rate at index 672 for n_X = 10000
# Skipping invalid predicted key rate at index 673 for n_X = 10000
# Skipping invalid predicted key rate at index 674 for n_X = 10000
# Skipping invalid predicted key rate at index 675 for n_X = 10000
# Skipping invalid predicted key rate at index 676 for n_X = 10000
# Skipping invalid predicted key rate at index 677 for n_X = 10000
# Skipping invalid predicted key rate at index 678 for n_X = 10000
# Skipping invalid predicted key rate at index 679 for n_X = 10000
# Skipping invalid predicted key rate at index 680 for n_X = 10000
# Skipping invalid predicted key rate at index 681 for n_X = 10000
# Skipping invalid predicted key rate at index 682 for n_X = 10000
# Skipping invalid predicted key rate at index 683 for n_X = 10000
# Skipping invalid predicted key rate at index 684 for n_X = 10000
# Skipping invalid predicted key rate at index 685 for n_X = 10000
# Skipping invalid predicted key rate at index 686 for n_X = 10000
# Skipping invalid predicted key rate at index 687 for n_X = 10000
# Skipping invalid predicted key rate at index 688 for n_X = 10000
# Skipping invalid predicted key rate at index 689 for n_X = 10000
# Skipping invalid predicted key rate at index 690 for n_X = 10000
# Skipping invalid predicted key rate at index 691 for n_X = 10000
# Skipping invalid predicted key rate at index 692 for n_X = 10000
# Skipping invalid predicted key rate at index 693 for n_X = 10000
# Skipping invalid predicted key rate at index 694 for n_X = 10000
# Skipping invalid predicted key rate at index 695 for n_X = 10000
# Skipping invalid predicted key rate at index 696 for n_X = 10000
# Skipping invalid predicted key rate at index 697 for n_X = 10000
# Skipping invalid predicted key rate at index 698 for n_X = 10000
# Skipping invalid predicted key rate at index 699 for n_X = 10000
# Skipping invalid predicted key rate at index 700 for n_X = 10000
# Skipping invalid predicted key rate at index 701 for n_X = 10000
# Skipping invalid predicted key rate at index 702 for n_X = 10000
# Skipping invalid predicted key rate at index 703 for n_X = 10000
# Skipping invalid predicted key rate at index 704 for n_X = 10000
# Skipping invalid predicted key rate at index 705 for n_X = 10000
# Skipping invalid predicted key rate at index 706 for n_X = 10000
# Skipping invalid predicted key rate at index 707 for n_X = 10000
# Skipping invalid predicted key rate at index 708 for n_X = 10000
# Skipping invalid predicted key rate at index 709 for n_X = 10000
# Skipping invalid predicted key rate at index 710 for n_X = 10000
# Skipping invalid predicted key rate at index 711 for n_X = 10000
# Skipping invalid predicted key rate at index 712 for n_X = 10000
# Skipping invalid predicted key rate at index 713 for n_X = 10000
# Skipping invalid predicted key rate at index 714 for n_X = 10000
# Skipping invalid predicted key rate at index 715 for n_X = 10000
# Skipping invalid predicted key rate at index 716 for n_X = 10000
# Skipping invalid predicted key rate at index 717 for n_X = 10000
# Skipping invalid predicted key rate at index 718 for n_X = 10000
# Skipping invalid predicted key rate at index 719 for n_X = 10000
# Skipping invalid predicted key rate at index 720 for n_X = 10000
# Skipping invalid predicted key rate at index 721 for n_X = 10000
# Skipping invalid predicted key rate at index 722 for n_X = 10000
# Skipping invalid predicted key rate at index 723 for n_X = 10000
# Skipping invalid predicted key rate at index 724 for n_X = 10000
# Skipping invalid predicted key rate at index 725 for n_X = 10000
# Skipping invalid predicted key rate at index 726 for n_X = 10000
# Skipping invalid predicted key rate at index 727 for n_X = 10000
# Skipping invalid predicted key rate at index 728 for n_X = 10000
# Skipping invalid predicted key rate at index 729 for n_X = 10000
# Skipping invalid predicted key rate at index 730 for n_X = 10000
# Skipping invalid predicted key rate at index 731 for n_X = 10000
# Skipping invalid predicted key rate at index 732 for n_X = 10000
# Skipping invalid predicted key rate at index 733 for n_X = 10000
# Skipping invalid predicted key rate at index 734 for n_X = 10000
# Skipping invalid predicted key rate at index 735 for n_X = 10000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# ...
# Skipping invalid predicted key rate at index 617 for n_X = 1000000000
# Skipping invalid predicted key rate at index 621 for n_X = 1000000000
# Skipping invalid predicted key rate at index 622 for n_X = 1000000000
# Skipping invalid predicted key rate at index 624 for n_X = 1000000000
# Skipping invalid predicted key rate at index 626 for n_X = 1000000000
# Skipping invalid predicted key rate at index 628 for n_X = 1000000000
# Skipping invalid predicted key rate at index 629 for n_X = 1000000000
# Skipping invalid predicted key rate at index 630 for n_X = 1000000000
# Skipping invalid predicted key rate at index 631 for n_X = 1000000000
# Skipping invalid predicted key rate at index 632 for n_X = 1000000000
# Skipping invalid predicted key rate at index 633 for n_X = 1000000000
# Skipping invalid predicted key rate at index 634 for n_X = 1000000000
# Skipping invalid predicted key rate at index 635 for n_X = 1000000000
# Skipping invalid predicted key rate at index 636 for n_X = 1000000000
# Skipping invalid predicted key rate at index 637 for n_X = 1000000000
# Skipping invalid predicted key rate at index 639 for n_X = 1000000000
# Skipping invalid predicted key rate at index 640 for n_X = 1000000000
# Skipping invalid predicted key rate at index 641 for n_X = 1000000000
# Skipping invalid predicted key rate at index 643 for n_X = 1000000000
# Skipping invalid predicted key rate at index 644 for n_X = 1000000000
# Skipping invalid predicted key rate at index 646 for n_X = 1000000000
# Skipping invalid predicted key rate at index 647 for n_X = 1000000000
# Skipping invalid predicted key rate at index 648 for n_X = 1000000000
# Skipping invalid predicted key rate at index 649 for n_X = 1000000000
# Skipping invalid predicted key rate at index 652 for n_X = 1000000000
# Skipping invalid predicted key rate at index 653 for n_X = 1000000000
# Skipping invalid predicted key rate at index 654 for n_X = 1000000000
# Skipping invalid predicted key rate at index 656 for n_X = 1000000000
# Skipping invalid predicted key rate at index 658 for n_X = 1000000000
# Skipping invalid predicted key rate at index 659 for n_X = 1000000000
# Skipping invalid predicted key rate at index 661 for n_X = 1000000000
# Skipping invalid predicted key rate at index 662 for n_X = 1000000000
# Skipping invalid predicted key rate at index 663 for n_X = 1000000000
# Skipping invalid predicted key rate at index 664 for n_X = 1000000000
# Skipping invalid predicted key rate at index 665 for n_X = 1000000000
# Skipping invalid predicted key rate at index 666 for n_X = 1000000000
# Skipping invalid predicted key rate at index 667 for n_X = 1000000000
# Skipping invalid predicted key rate at index 668 for n_X = 1000000000
# Skipping invalid predicted key rate at index 669 for n_X = 1000000000
# Skipping invalid predicted key rate at index 670 for n_X = 1000000000
# Skipping invalid predicted key rate at index 671 for n_X = 1000000000
# Skipping invalid predicted key rate at index 672 for n_X = 1000000000
# Skipping invalid predicted key rate at index 673 for n_X = 1000000000
# Skipping invalid predicted key rate at index 674 for n_X = 1000000000
# Skipping invalid predicted key rate at index 675 for n_X = 1000000000
# Skipping invalid predicted key rate at index 676 for n_X = 1000000000
# Skipping invalid predicted key rate at index 678 for n_X = 1000000000
# Skipping invalid predicted key rate at index 680 for n_X = 1000000000
# Skipping invalid predicted key rate at index 681 for n_X = 1000000000
# Skipping invalid predicted key rate at index 683 for n_X = 1000000000
# Skipping invalid predicted key rate at index 684 for n_X = 1000000000
# Skipping invalid predicted key rate at index 685 for n_X = 1000000000
# Skipping invalid predicted key rate at index 687 for n_X = 1000000000
# Skipping invalid predicted key rate at index 689 for n_X = 1000000000
# Skipping invalid predicted key rate at index 690 for n_X = 1000000000
# Skipping invalid predicted key rate at index 691 for n_X = 1000000000
# Skipping invalid predicted key rate at index 692 for n_X = 1000000000
# Skipping invalid predicted key rate at index 693 for n_X = 1000000000
# Skipping invalid predicted key rate at index 694 for n_X = 1000000000
# Skipping invalid predicted key rate at index 696 for n_X = 1000000000
# Skipping invalid predicted key rate at index 697 for n_X = 1000000000
# Skipping invalid predicted key rate at index 699 for n_X = 1000000000
# Skipping invalid predicted key rate at index 700 for n_X = 1000000000
# Skipping invalid predicted key rate at index 701 for n_X = 1000000000
# Skipping invalid predicted key rate at index 702 for n_X = 1000000000
# Skipping invalid predicted key rate at index 704 for n_X = 1000000000
# Skipping invalid predicted key rate at index 705 for n_X = 1000000000
# Skipping invalid predicted key rate at index 706 for n_X = 1000000000
# Skipping invalid predicted key rate at index 707 for n_X = 1000000000
# Skipping invalid predicted key rate at index 709 for n_X = 1000000000
# Skipping invalid predicted key rate at index 711 for n_X = 1000000000
# Skipping invalid predicted key rate at index 712 for n_X = 1000000000
# Skipping invalid predicted key rate at index 714 for n_X = 1000000000
# Skipping invalid predicted key rate at index 715 for n_X = 1000000000
# Skipping invalid predicted key rate at index 716 for n_X = 1000000000
# Skipping invalid predicted key rate at index 717 for n_X = 1000000000
# Skipping invalid predicted key rate at index 718 for n_X = 1000000000
# Skipping invalid predicted key rate at index 719 for n_X = 1000000000
# Skipping invalid predicted key rate at index 720 for n_X = 1000000000
# Skipping invalid predicted key rate at index 722 for n_X = 1000000000
# Skipping invalid predicted key rate at index 723 for n_X = 1000000000
# Skipping invalid predicted key rate at index 726 for n_X = 1000000000
# Skipping invalid predicted key rate at index 727 for n_X = 1000000000
# Skipping invalid predicted key rate at index 728 for n_X = 1000000000
# Skipping invalid predicted key rate at index 729 for n_X = 1000000000
# Skipping invalid predicted key rate at index 730 for n_X = 1000000000
# Skipping invalid predicted key rate at index 731 for n_X = 1000000000
# Skipping invalid predicted key rate at index 733 for n_X = 1000000000
# Skipping invalid predicted key rate at index 736 for n_X = 1000000000
# Skipping invalid predicted key rate at index 737 for n_X = 1000000000
# Skipping invalid predicted key rate at index 740 for n_X = 1000000000
# Skipping invalid predicted key rate at index 742 for n_X = 1000000000
# Skipping invalid predicted key rate at index 744 for n_X = 1000000000
# Skipping invalid predicted key rate at index 745 for n_X = 1000000000
# Skipping invalid predicted key rate at index 746 for n_X = 1000000000
# Skipping invalid predicted key rate at index 747 for n_X = 1000000000
# Skipping invalid predicted key rate at index 748 for n_X = 1000000000
# Skipping invalid predicted key rate at index 749 for n_X = 1000000000
# Skipping invalid predicted key rate at index 750 for n_X = 1000000000
# Skipping invalid predicted key rate at index 751 for n_X = 1000000000
# Skipping invalid predicted key rate at index 752 for n_X = 1000000000
# Skipping invalid predicted key rate at index 753 for n_X = 1000000000
# Skipping invalid predicted key rate at index 754 for n_X = 1000000000
# Skipping invalid predicted key rate at index 756 for n_X = 1000000000
# Skipping invalid predicted key rate at index 759 for n_X = 1000000000
# Skipping invalid predicted key rate at index 761 for n_X = 1000000000
# Skipping invalid predicted key rate at index 763 for n_X = 1000000000
# Skipping invalid predicted key rate at index 766 for n_X = 1000000000
# Skipping invalid predicted key rate at index 769 for n_X = 1000000000
# Skipping invalid predicted key rate at index 772 for n_X = 1000000000
# Skipping invalid predicted key rate at index 773 for n_X = 1000000000
# Skipping invalid predicted key rate at index 779 for n_X = 1000000000
# Skipping invalid predicted key rate at index 781 for n_X = 1000000000
# Skipping invalid predicted key rate at index 787 for n_X = 1000000000
# Skipping invalid predicted key rate at index 788 for n_X = 1000000000
# Skipping invalid predicted key rate at index 792 for n_X = 1000000000
# Skipping invalid predicted key rate at index 795 for n_X = 1000000000
# Skipping invalid predicted key rate at index 798 for n_X = 1000000000
# Skipping invalid predicted key rate at index 799 for n_X = 1000000000
# Skipping invalid predicted key rate at index 801 for n_X = 1000000000
# Skipping invalid predicted key rate at index 803 for n_X = 1000000000
# Skipping invalid predicted key rate at index 807 for n_X = 1000000000
# Skipping invalid predicted key rate at index 808 for n_X = 1000000000
# Skipping invalid predicted key rate at index 810 for n_X = 1000000000
# Skipping invalid predicted key rate at index 812 for n_X = 1000000000
# Skipping invalid predicted key rate at index 814 for n_X = 1000000000
# Skipping invalid predicted key rate at index 816 for n_X = 1000000000
# Skipping invalid predicted key rate at index 817 for n_X = 1000000000
# Skipping invalid predicted key rate at index 818 for n_X = 1000000000
# Skipping invalid predicted key rate at index 819 for n_X = 1000000000
# Skipping invalid predicted key rate at index 820 for n_X = 1000000000
# Skipping invalid predicted key rate at index 822 for n_X = 1000000000
# Skipping invalid predicted key rate at index 824 for n_X = 1000000000
# Skipping invalid predicted key rate at index 826 for n_X = 1000000000
# Skipping invalid predicted key rate at index 827 for n_X = 1000000000
# Skipping invalid predicted key rate at index 828 for n_X = 1000000000
# Skipping invalid predicted key rate at index 829 for n_X = 1000000000
# Skipping invalid predicted key rate at index 830 for n_X = 1000000000
# Skipping invalid predicted key rate at index 832 for n_X = 1000000000
# Skipping invalid predicted key rate at index 834 for n_X = 1000000000
# Skipping invalid predicted key rate at index 835 for n_X = 1000000000
# Skipping invalid predicted key rate at index 837 for n_X = 1000000000
# Skipping invalid predicted key rate at index 838 for n_X = 1000000000
# Skipping invalid predicted key rate at index 839 for n_X = 1000000000
# Skipping invalid predicted key rate at index 840 for n_X = 1000000000
# Skipping invalid predicted key rate at index 842 for n_X = 1000000000
# Skipping invalid predicted key rate at index 845 for n_X = 1000000000
# Skipping invalid predicted key rate at index 847 for n_X = 1000000000
# Skipping invalid predicted key rate at index 848 for n_X = 1000000000
# Skipping invalid predicted key rate at index 849 for n_X = 1000000000
# Skipping invalid predicted key rate at index 851 for n_X = 1000000000
# Skipping invalid predicted key rate at index 853 for n_X = 1000000000
# Skipping invalid predicted key rate at index 854 for n_X = 1000000000
# Skipping invalid predicted key rate at index 855 for n_X = 1000000000
# Skipping invalid predicted key rate at index 856 for n_X = 1000000000
# Skipping invalid predicted key rate at index 859 for n_X = 1000000000
# Skipping invalid predicted key rate at index 861 for n_X = 1000000000
# Skipping invalid predicted key rate at index 864 for n_X = 1000000000
# Skipping invalid predicted key rate at index 867 for n_X = 1000000000
# Skipping invalid predicted key rate at index 868 for n_X = 1000000000
# Skipping invalid predicted key rate at index 869 for n_X = 1000000000
# Skipping invalid predicted key rate at index 872 for n_X = 1000000000
# Skipping invalid predicted key rate at index 873 for n_X = 1000000000
# Skipping invalid predicted key rate at index 874 for n_X = 1000000000
# Skipping invalid predicted key rate at index 875 for n_X = 1000000000
# Skipping invalid predicted key rate at index 876 for n_X = 1000000000
# Skipping invalid predicted key rate at index 877 for n_X = 1000000000
# Skipping invalid predicted key rate at index 878 for n_X = 1000000000
# Skipping invalid predicted key rate at index 879 for n_X = 1000000000
# Skipping invalid predicted key rate at index 880 for n_X = 1000000000
# Skipping invalid predicted key rate at index 881 for n_X = 1000000000
# Skipping invalid predicted key rate at index 882 for n_X = 1000000000
# Skipping invalid predicted key rate at index 883 for n_X = 1000000000
# Skipping invalid predicted key rate at index 887 for n_X = 1000000000
# Skipping invalid predicted key rate at index 888 for n_X = 1000000000
# Skipping invalid predicted key rate at index 890 for n_X = 1000000000
# Skipping invalid predicted key rate at index 891 for n_X = 1000000000
# Skipping invalid predicted key rate at index 892 for n_X = 1000000000
# Skipping invalid predicted key rate at index 893 for n_X = 1000000000
# Skipping invalid predicted key rate at index 895 for n_X = 1000000000
# Skipping invalid predicted key rate at index 898 for n_X = 1000000000
# Skipping invalid predicted key rate at index 899 for n_X = 1000000000
# Skipping invalid predicted key rate at index 900 for n_X = 1000000000
# Skipping invalid predicted key rate at index 901 for n_X = 1000000000
# Skipping invalid predicted key rate at index 902 for n_X = 1000000000
# Skipping invalid predicted key rate at index 903 for n_X = 1000000000
# Skipping invalid predicted key rate at index 906 for n_X = 1000000000
# Skipping invalid predicted key rate at index 908 for n_X = 1000000000
# Skipping invalid predicted key rate at index 911 for n_X = 1000000000
# Skipping invalid predicted key rate at index 912 for n_X = 1000000000
# Skipping invalid predicted key rate at index 914 for n_X = 1000000000
# Skipping invalid predicted key rate at index 915 for n_X = 1000000000
# Skipping invalid predicted key rate at index 916 for n_X = 1000000000
# Skipping invalid predicted key rate at index 918 for n_X = 1000000000
# Skipping invalid predicted key rate at index 919 for n_X = 1000000000
# Skipping invalid predicted key rate at index 920 for n_X = 1000000000
# Skipping invalid predicted key rate at index 921 for n_X = 1000000000
# Skipping invalid predicted key rate at index 922 for n_X = 1000000000
# Skipping invalid predicted key rate at index 923 for n_X = 1000000000
# Skipping invalid predicted key rate at index 925 for n_X = 1000000000
# Skipping invalid predicted key rate at index 926 for n_X = 1000000000
# Skipping invalid predicted key rate at index 928 for n_X = 1000000000
# Skipping invalid predicted key rate at index 929 for n_X = 1000000000
# Skipping invalid predicted key rate at index 930 for n_X = 1000000000
# Skipping invalid predicted key rate at index 931 for n_X = 1000000000
# Skipping invalid predicted key rate at index 933 for n_X = 1000000000
# Skipping invalid predicted key rate at index 934 for n_X = 1000000000
# Skipping invalid predicted key rate at index 935 for n_X = 1000000000
# Skipping invalid predicted key rate at index 936 for n_X = 1000000000
# Skipping invalid predicted key rate at index 938 for n_X = 1000000000
# Skipping invalid predicted key rate at index 939 for n_X = 1000000000
# Skipping invalid predicted key rate at index 940 for n_X = 1000000000
# Skipping invalid predicted key rate at index 941 for n_X = 1000000000
# Skipping invalid predicted key rate at index 942 for n_X = 1000000000
# Skipping invalid predicted key rate at index 943 for n_X = 1000000000
# Skipping invalid predicted key rate at index 944 for n_X = 1000000000
# Skipping invalid predicted key rate at index 945 for n_X = 1000000000
# Skipping invalid predicted key rate at index 946 for n_X = 1000000000
# Skipping invalid predicted key rate at index 947 for n_X = 1000000000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+09.png
# --- Plotting Time: 0.66 seconds ---
# ✓ Key rate subplots saved to keyrate_subplots_last_epoch.png
# ✓ Parameter subplots saved to parameters_subplots_last_epoch.png
# Model saved to bb84_nn_model.pth
# Epoch 5000/5000, Train Loss:a 0.0002, Val Loss: 0.0003, Learning Rate: 0.000001, Time: 7.01s (Eval: 5.01s, Plot: 1.77s)
# --- Total Training Time: 1178.82 seconds ---

# %%
# %%
# Plotting the losses with smoothing
def moving_average(data, window_size=5):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

epochs = range(1, len(train_losses) + 1)
window_size = 5
smoothed_train_losses = moving_average(train_losses, window_size)
smoothed_val_losses = moving_average(val_losses, window_size)
smoothed_epochs = range(window_size, len(train_losses) + 1)

# %%
plt.figure(figsize=(12, 6))
# plt.plot(smoothed_epochs, smoothed_train_losses, label='Smoothed Training Loss', linestyle='-')
# plt.plot(smoothed_epochs, smoothed_val_losses, label='Smoothed Validation Loss', linestyle='--')
plt.plot(epochs, train_losses, label='Training Loss', linestyle='-', alpha=0.3)
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--', alpha=0.5)
plt.xlabel('Epochs')
plt.ylim(0, 0.002)
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_plot.png', dpi=150)
plt.show()
# plt.close()

print("Training Complete")

# Plotting the learning rates
plt.figure(figsize=(12, 6))
plt.plot(epochs, learning_rates, label='Learning Rate', linestyle='-', color='tab:blue')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')
plt.grid(True)
plt.tight_layout()
plt.savefig('learning_rate_plot.png', dpi=150)
plt.show()
# plt.close()
# Out:
# Training Complete
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/2391135169.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/2391135169.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
def plot_keyrate_and_parameters(fiber_lengths, optimized_key_rates, optimized_params_array, 
                                predicted_key_rates, predicted_params_array, epoch, filename, 
                                learning_rates=None, nx=None):
    """
    Plots key rates and parameters for a specific n_X value.
    
    Parameters:
    - fiber_lengths: Array of fiber lengths.
    - optimized_key_rates: Array of optimized key rates.
    - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - learning_rates: List of learning rates over epochs (optional, not used).
    - nx: The n_X value for the plot title (optional).
    """

    # Start timing
    plot_start_time = time.time()

    # Create a figure with 2 subplots: key rate (left), all parameters (right)
    fig = plt.figure(figsize=(15, 6))  # Adjusted height for horizontal layout

    # Define the grid layout: 1 row, 2 columns
    gs = fig.add_gridspec(1, 2, width_ratios=[1, 1])

    # Key Rate Plot (Left)
    ax_keyrate = fig.add_subplot(gs[0, 0])

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    threshold = 1e-8
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Plot key rates with distinct linestyles and increased thickness for predicted
    ax_keyrate.plot(fiber_lengths, np.log10(predicted_key_rates), 'r--', label='Predicted Key Rate', linewidth=4.0, alpha=0.7)
    ax_keyrate.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linewidth=2.0, alpha=1.0)

    # Use scientific notation for nx in the title
    ax_keyrate.set_title(f"Key Rates for $n_X = 5 \\times 10^8$")  # Fixed title
    ax_keyrate.set_xlabel("Fiber Length (km)")
    ax_keyrate.set_ylabel("Secret Key Rate per Pulse")
    ax_keyrate.grid(True)
    ax_keyrate.legend(loc='upper right')

    # Parameter Plot (Right) - Combine probabilities and intensities
    ax_params = fig.add_subplot(gs[0, 1])

    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    colors = ['red', 'purple', 'orange', 'green', 'blue']
    param_indices = [0, 1, 2, 3, 4]  # Indices for mu_1, mu_2, P_mu_1, P_mu_2, P_X  

    # Plot all parameters
    for param_idx, (label, color) in zip(param_indices, zip(param_labels, colors)):
        ax_params.plot(fiber_lengths, predicted_params_array[:, param_idx], label=f'Predicted {label}', color=color, linestyle='--', linewidth=4.0, alpha=0.7)
        ax_params.plot(fiber_lengths, optimized_params_array[:, param_idx], label=f'Optimized {label}', color=color, linestyle='-', linewidth=2.0, alpha=1.0)
        
    # Use scientific notation for nx in the title
    ax_params.set_title(f"Parameters for $n_X = 5 \\times 10^8$")  # Fixed title
    ax_params.set_xlabel("Fiber Length (km)")
    ax_params.set_ylabel("Parameter Value")
    ax_params.set_ylim(0.0, 1.0)
    ax_params.grid(True)

    # Move legend outside the plot to avoid overlap
    ax_params.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Comparison plot saved to {filename}")

# %%
# for nx in all_evaluation_data.keys():
#     eval_data = all_evaluation_data[nx]
#     fiber_lengths = eval_data['fiber_lengths']
#     optimized_params_array = eval_data['optimized_params_array']
#     optimized_key_rates = eval_data['optimized_key_rates']
#     X_test_tensor = eval_data['X_test_tensor']
#     with torch.no_grad():
#         predicted_params_scaled = model(X_test_tensor).cpu().numpy()
#         predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
#         predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
        
#         # Apply constraints
#         predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6)  # mu_1
#         predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6)  # mu_2
#         predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)  # P_mu_1
#         predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)  # P_mu_2
#         predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)  # P_X
        
#         # Enforce sum constraint
#         prob_sum = predicted_params_array[:, 2] + predicted_params_array[:, 3]
#         mask_sum_gt_1 = prob_sum > 1.0
#         if np.any(mask_sum_gt_1):

# # for nx in all_evaluation_data.keys():
# #     eval_data = all_evaluation_data[nx]
# #     fiber_lengths = eval_data['fiber_lengths']
# #     optimized_params_array = eval_data['optimized_params_array']
# #     optimized_key_rates = eval_data['optimized_key_rates']
# #     X_test_tensor = eval_data['X_test_tensor']

# #     with torch.no_grad():
# #         predicted_params_scaled = model(X_test_tensor).cpu().numpy()
# #         predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
# #         predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
# #         predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6)
# #         predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6)
# #         predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)
# #         predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)
# #         predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)

#         # Compute and filter predicted key rates
#         # Compute and filter predicted key rates
#         predicted_key_rates = []
#         valid_indices = []
#         for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
#             key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
#                                       epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
#                                       e_mis=5e-3, P_ap=0, n_event=1)
#             if key_rate is None:
#                 print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
#                 continue
#             predicted_key_rates.append(key_rate)
#             valid_indices.append(idx)
#         predicted_key_rates = np.array(predicted_key_rates)
#         # After computing valid_indices for predictions
#         if len(valid_indices) > 0:
#             plot_relative_errors(
#                 fiber_lengths[valid_indices],  # Only plot where we have predictions
#                 optimized_key_rates[valid_indices],  # Matching optimized data
#                 optimized_params_array[valid_indices],  # Matching optimized params
#                 predicted_key_rates,  # Already filtered
#                 valid_predicted_params, epoch,
#                 f'parameter_relative_error_nx_{nx:.0e}.png', nx=nx
#             )
#     else:
#         print(f"⚠️  No valid predictions for n_X = {nx}, skipping relative error plot")
#     #     predicted_key_rates = []
#     #     valid_indices = []
#     #     for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
#     #         key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
#     #                                   epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
#     #                                   e_mis=5e-3, P_ap=0, n_event=1)
#     #         if key_rate is None:
#     #             print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
#     #             continue
#     #         predicted_key_rates.append(key_rate)
#     #         valid_indices.append(idx)
#     #     predicted_key_rates = np.array(predicted_key_rates)

#     #     # Filter data based on valid predicted key rates
#     #     fiber_lengths = fiber_lengths[valid_indices]
#     #     # optimized_key_rates = optimized_key_rates[valid_indices]
#     #     optimized_params_array = optimized_params_array[valid_indices]
#     #     predicted_params_array = predicted_params_array[valid_indices]

#     # # Plot relative errors for this n_X
#     # plot_start_time = time.time()
#     # plot_relative_errors(
#     #     fiber_lengths, optimized_key_rates, optimized_params_array,
#     #     predicted_key_rates, predicted_params_array, epoch='final_test',
#     #     filename=f'relative_error_nx_{nx:.0e}.png', nx=nx
#     # )
#     # print(f"--- Final Test Plotting Time (relative_error_nx_{nx:.0e}): {time.time() - plot_start_time:.2f} seconds ---")


for nx in all_evaluation_data.keys():
    eval_data = all_evaluation_data[nx]
    fiber_lengths = eval_data['fiber_lengths']
    optimized_params_array = eval_data['optimized_params_array']
    optimized_key_rates = eval_data['optimized_key_rates']
    X_test_tensor = eval_data['X_test_tensor']
    
    with torch.no_grad():
        predicted_params_scaled = model(X_test_tensor).cpu().numpy()
        predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
        predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
        
        # Apply constraints
        predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6)  # mu_1
        predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6)  # mu_2
        predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)  # P_mu_1
        predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)  # P_mu_2
        predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)  # P_X
        
        # Enforce sum constraint
        prob_sum = predicted_params_array[:, 2] + predicted_params_array[:, 3]
        mask_sum_gt_1 = prob_sum > 1.0
        if np.any(mask_sum_gt_1):
            predicted_params_array[mask_sum_gt_1, 2] /= prob_sum[mask_sum_gt_1]
            predicted_params_array[mask_sum_gt_1, 3] /= prob_sum[mask_sum_gt_1]

        # Compute and filter predicted key rates
        predicted_key_rates = []
        valid_indices = []
        for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
            key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                      epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                      e_mis=5e-3, P_ap=0, n_event=1)
            if key_rate is None:
                # print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
                continue
            predicted_key_rates.append(key_rate)
            valid_indices.append(idx)
        predicted_key_rates = np.array(predicted_key_rates)
        
        # After computing valid_indices for predictions
        if len(valid_indices) > 0:
            plot_relative_errors(
                fiber_lengths[valid_indices], 
                optimized_key_rates[valid_indices], 
                optimized_params_array[valid_indices], 
                predicted_key_rates, 
                predicted_params_array[valid_indices], 
                epoch='final_test', 
                filename=f'parameter_relative_error_nx_{nx:.0e}.png', # <--- FIXED THIS LINE
                nx=nx
            )
        else:
            print(f"⚠️  No valid predictions for n_X = {nx}, skipping relative error plot")
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+04.png
# --- Plotting Time: 0.63 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+05.png
# --- Plotting Time: 0.68 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+06.png
# --- Plotting Time: 0.78 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+07.png
# --- Plotting Time: 0.63 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+08.png
# --- Plotting Time: 0.65 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_69446/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+09.png
# --- Plotting Time: 0.64 seconds ---

# %%
def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
                        predicted_key_rates, predicted_params_array, epoch, filename, 
                        nx=None, threshold=1e-8):
    """
    Plots relative errors of predicted vs. optimized parameters and key rate for a specific n_X.
    
    Parameters:
    - fiber_lengths: Array of fiber lengths (km).
    - optimized_key_rates: Array of optimized key rates.
    - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - nx: The n_X value for the plot title (optional).
    - threshold: Key rate threshold for physical cutoff (default: 1e-8).
    """
    # Start timing
    plot_start_time = time.time()

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Compute relative errors
    # Parameters: mu_1, mu_2, P_mu_1, P_mu_2, P_X
    relative_errors = []
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    for i in range(5):
        optimized = optimized_params_array[:, i]
        predicted = predicted_params_array[:, i]
        # Avoid division by zero with a small threshold
        denominator = np.maximum(optimized, 1e-10)
        rel_error = (predicted - optimized) / denominator
        relative_errors.append(rel_error)
    
    # Key rate relative error
    denominator = np.maximum(optimized_key_rates, 1e-10)
    key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Plot relative errors
    for i in range(5):
        row = i // 3
        col = i % 3
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Relative Error')
        ax.set_title(f'Relative Error for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Key rate subplot
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Relative Error')
    ax_key.set_title('Relative Error for Key Rate')
    ax_key.grid(True)
    ax_key.legend(loc='best')

    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
        # Example title update (adjust based on actual function structure)
    fig.suptitle(f"Relative Errors of Parameters for $n_X = 5 \\times 10^8$", fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Relative error plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")
