# %%
# %% [markdown]
# Import necessary libraries
import torch
import torch.nn as nn
from torch.utils.data import DataLoader, TensorDataset, Subset
import torch.optim as optim
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split, KFold
from sklearn.preprocessing import StandardScaler, MinMaxScaler
from sklearn.metrics import mean_absolute_error
import json
from tqdm import tqdm
import torch.nn.functional as F
import joblib
import os
import sys
from torch.utils.data import DataLoader, random_split
import time  # For timing

# Set matplotlib to use a non-interactive backend
plt.switch_backend('Agg')

# Get the notebook's directory
notebook_dir = os.getcwd()
# Add parent directory to path
project_root = os.path.dirname(notebook_dir)
sys.path.append(project_root)

# %% [markdown]
# Checking if the MPS (Metal Performance Shaders) backend is available

# %%
# Check if MPS is available
if not torch.backends.mps.is_available():
    raise RuntimeError("MPS device not available. Check if PyTorch and macOS set up correctly.")

# Set the device to MPS
device = torch.device("mps")  # Use GPU on M2 Pro

# %%
# %%
# Import the objective function
from QKD_Functions.QKD_Functions import (
    calculate_factorial, calculate_tau_n, calculate_eta_ch, calculate_eta_sys,
    calculate_D_mu_k, calculate_n_X_total, calculate_N, calculate_n_Z_total,
    calculate_e_mu_k, calculate_e_obs, calculate_h, calculate_lambda_EC,
    calculate_sqrt_term, calculate_n_pm, calculate_S_0, calculate_S_1,
    calculate_m_mu_k, calculate_m_pm, calculate_v_1, calculate_gamma,
    calculate_Phi, calculate_LastTwoTerm, calculate_l, calculate_R,
    experimental_parameters, other_parameters, calculate_key_rates_and_metrics,
    penalty, objective,
)
# Out:
# /Users/daai6ga1hou2/anaconda3/envs/qkd-training_set/lib/python3.9/site-packages/tqdm_joblib/__init__.py:4: TqdmExperimentalWarning: Using `tqdm.autonotebook.tqdm` in notebook mode. Use `tqdm.tqdm` instead to force console mode (e.g. in jupyter console)
#   from tqdm.autonotebook import tqdm

# %%
# Define a safe wrapper for the objective function
# def safe_objective(params, L, nx, **kwargs):
#     try:
#         key_rate = objective(params, L, nx, **kwargs)[0]
#         if np.isnan(key_rate) or np.isinf(key_rate) or key_rate <= 0:
#             print(f"Invalid key rate (NaN, Inf, or <= 0) for params {params}, L={L}, nx={nx}: {key_rate}")
#             return None  # Return None to indicate invalid result
#         return key_rate
#     except Exception as e:
#         print(f"Error in objective for params {params}, L={L}, nx={nx}: {e}")
#         return None  # Return None on error

def safe_objective(params, L, nx, **kwargs):
    try:
        # Ensure params are in a numpy array for checking
        params_np = np.array(params)
        # Check for NaN/Inf in input params themselves (can happen from NN)
        if np.any(np.isnan(params_np)) or np.any(np.isinf(params_np)):
             print(f"Invalid input params (NaN/Inf): {params_np}, L={L}, nx={nx}")
             return None

        key_rate = objective(params, L, nx, **kwargs)[0]

        if np.isnan(key_rate):
            print(f"Objective returned NaN for params {params}, L={L}, nx={nx}")
            return None
        if np.isinf(key_rate):
            print(f"Objective returned Inf for params {params}, L={L}, nx={nx}")
            return None
        if key_rate <= 0:
            # Be slightly more tolerant? Maybe allow exactly 0?
            # Or keep <= 0 but report it
            print(f"Objective returned non-positive key rate ({key_rate}) for params {params}, L={L}, nx={nx}")
            # Decide if you want to return None or the non-positive value
            return None # Keep filtering non-positive for now
        return key_rate
    except Exception as e:
        print(f"Exception in objective for params {params}, L={L}, nx={nx}: {e}")
        # Add traceback for more detail if needed:
        # import traceback
        # print(traceback.format_exc())
        return None
    
# %%
# Load dataset
with open('../Training_Data/n_X/good/cleaned_combined_datasets.json', 'r') as f:
    data_by_nx = json.load(f)

print(f"The overall dataset contains {len(data_by_nx)} entries (number of unique n_X values).")

# Print the number of entries for each n_X before filtering
for n_x in data_by_nx.keys():
    print(f"Number of entries for n_X = {n_x}: {len(data_by_nx[n_x])}")
# Out:
# The overall dataset contains 6 entries (number of unique n_X values).
# Number of entries for n_X = 10000.0: 736
# Number of entries for n_X = 100000.0: 855
# Number of entries for n_X = 1000000.0: 902
# Number of entries for n_X = 10000000.0: 927
# Number of entries for n_X = 100000000.0: 942
# Number of entries for n_X = 1000000000.0: 948

# %%
# Flatten the data structure and filter
cleaned_data = []
for n_x, entries in data_by_nx.items():
    filtered_entries = [item for item in entries if item["key_rate"] > 0 and item["e_1"] * 100 <= 200]
    print(f"After filtering, n_X = {n_x} has {len(filtered_entries)} entries.")
    cleaned_data.extend(filtered_entries)

# Verify the cleaned dataset
if not cleaned_data:
    print("No valid data after filtering.")
else:
    print(f"Filtered dataset contains {len(cleaned_data)} entries.")
    print("\nSample entry from the cleaned dataset:")
    print(json.dumps(cleaned_data[0], indent=2))
    print("\nNumber of unique n_X values:", len(data_by_nx))

# %%
X = np.array([[item['e_1'], item['e_2'], item['e_3'], item['e_4']] for item in cleaned_data])
Y = np.array([[item['optimized_params']['mu_1'], item['optimized_params']['mu_2'], item['optimized_params']['P_mu_1'], item['optimized_params']['P_mu_2'], item['optimized_params']['P_X_value']] for item in cleaned_data])
# Out:
# After filtering, n_X = 10000.0 has 736 entries.
# After filtering, n_X = 100000.0 has 855 entries.
# After filtering, n_X = 1000000.0 has 902 entries.
# After filtering, n_X = 10000000.0 has 927 entries.
# After filtering, n_X = 100000000.0 has 942 entries.
# After filtering, n_X = 1000000000.0 has 948 entries.
# Filtered dataset contains 5310 entries.
#
# Sample entry from the cleaned dataset:
# {
#   "fiber_length": 0.0,
#   "e_1": 0.0,
#   "e_2": 6.221848749616356,
#   "e_3": 0.5,
#   "e_4": 4.0,
#   "key_rate": 0.00037995895580899045,
#   "optimized_params": {
#     "mu_1": 0.6126301275287198,
#     "mu_2": 0.13818683663411718,
#     "P_mu_1": 0.04604299826386499,
#     "P_mu_2": 0.6110117432731096,
#     "P_X_value": 0.414731486913827
#   }
# }
#
# Number of unique n_X values: 6

# %%
from sklearn.utils import shuffle

X, Y = shuffle(X, Y, random_state=42)

scaler = StandardScaler()
X = scaler.fit_transform(X)  # Fit and transform on training data

y_scaler = MinMaxScaler()  # Scale targets to [0, 1]
Y = y_scaler.fit_transform(Y)

# Save the scalers
joblib.dump(scaler, '../models/scaler.pkl')  # Save StandardScaler
joblib.dump(y_scaler, '../models/y_scaler.pkl')  # Save MinMaxScaler

print(f"X shape: {X.shape}, Y shape: {Y.shape}")
dataset = TensorDataset(torch.tensor(X, dtype=torch.float32), torch.tensor(Y, dtype=torch.float32))

# %%
# Split dataset into train and validation sets
train_size = int(0.8 * len(dataset))  # 80% for training
val_size = len(dataset) - train_size  # 20% for validation

train_dataset, val_dataset = random_split(dataset, [train_size, val_size])

# Data loaders with increased batch size
train_loader = DataLoader(train_dataset, batch_size=64, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=64, shuffle=False)
# Out:
# X shape: (5310, 4), Y shape: (5310, 5)

# %%
# %%
# Load evaluation data for n_X = 5e8
with open("../n_X/good/5e8_100_reordered_qkd_grouped_dataset_20250226_191349.json", 'r') as f:
    evaluation_dataset = json.load(f)

# Select target n_X for evaluation
target_nx = 5 * 100000000  # 5e8
nx_key = str(float(target_nx))
if nx_key not in evaluation_dataset:
    raise ValueError(f"No data found for n_X = {target_nx}")
evaluation_data = evaluation_dataset[nx_key]

# Verify the size of the evaluation dataset
print(f"Number of data points for n_X = {target_nx}: {len(evaluation_data)}")
# Out:
# Number of data points for n_X = 500000000: 100

# %%
# Extract evaluation fiber lengths and optimized parameters
fiber_lengths_un_seen = np.array([entry["fiber_length"] for entry in evaluation_data])
optimized_params_array_un_seen = np.array([list(entry["optimized_params"].values()) for entry in evaluation_data])

# Evaluate optimized key rates for evaluation
optimized_key_rates_un_seen = []
valid_indices_un_seen = []
for idx, (params, L) in enumerate(zip(optimized_params_array_un_seen, fiber_lengths_un_seen)):
    key_rate = safe_objective(params, L, target_nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                              epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
    if key_rate is None:
        print(f"Skipping invalid key rate at index {idx}")
    else:
        optimized_key_rates_un_seen.append(key_rate)
        valid_indices_un_seen.append(idx)
optimized_key_rates_un_seen = np.array(optimized_key_rates_un_seen)

# Filter the evaluation data to exclude invalid key rates
fiber_lengths_un_seen = fiber_lengths_un_seen[valid_indices_un_seen]
optimized_params_array_un_seen = optimized_params_array_un_seen[valid_indices_un_seen]
# Out:
# Objective returned non-positive key rate (-2.5459075744215506e-31) for params [5.21125578e-01 3.37384994e-01 1.92634353e-01 6.63224253e-01
#  1.00000000e-12], L=189.89898989898992, nx=500000000
# Skipping invalid key rate at index 94
# Objective returned non-positive key rate (-1.0847670075212521e-30) for params [9.00000000e-01 4.09777073e-01 1.21908112e-01 6.52515070e-01
#  1.00000000e-12], L=191.91919191919195, nx=500000000
# Skipping invalid key rate at index 95
# Objective returned non-positive key rate (-1.0756742243147874e-30) for params [8.13544868e-01 2.57789157e-01 3.75126595e-01 1.07065241e-01
#  1.00000000e-12], L=193.93939393939394, nx=500000000
# Skipping invalid key rate at index 96
# Objective returned non-positive key rate (-5.9934352286340745e-31) for params [5.53278979e-01 2.55719551e-01 4.01755354e-01 4.61925236e-01
#  1.00000000e-12], L=195.95959595959596, nx=500000000
# Skipping invalid key rate at index 97
# Objective returned non-positive key rate (-8.89190788063512e-31) for params [7.59296721e-01 3.16646804e-02 3.70889007e-01 2.18637344e-01
#  1.00000000e-12], L=197.97979797979798, nx=500000000
# Skipping invalid key rate at index 98
# Objective returned non-positive key rate (-1.1490135538073274e-30) for params [6.73503745e-01 3.99482743e-01 3.28961560e-01 3.94124936e-01
#  1.00000000e-12], L=200.0, nx=500000000
# Skipping invalid key rate at index 99

# %%
# Prepare test inputs for evaluation (n_X = 5e8)
X_test_un_seen = []
for L in fiber_lengths_un_seen:
    e_1 = L / 100
    e_2 = -np.log10(6e-7)
    e_3 = 5e-3 * 100
    e_4 = np.log10(target_nx)
    X_test_un_seen.append([e_1, e_2, e_3, e_4])

X_test_un_seen = np.array(X_test_un_seen)
X_test_scaled_un_seen = scaler.transform(X_test_un_seen)
X_test_tensor_un_seen = torch.tensor(X_test_scaled_un_seen, dtype=torch.float32).to(device)
print(f"After filtering NaN in optimized_key_rates_un_seen, {len(optimized_key_rates_un_seen)} data points remain for n_X = 5e8.")
# Out:
# After filtering NaN in optimized_key_rates_un_seen, 94 data points remain for n_X = 5e8.

# %%
# %% [markdown]
# ### Prepare Evaluation Data for All n_X Values (10^4 to 10^9) Before Training

# Load the combined dataset
combined_file_path = '../Training_Data/n_X/good/cleaned_combined_datasets.json'
try:
    with open(combined_file_path, 'r') as f:
        combined_data = json.load(f)
    print(f"Loaded combined dataset with {len(combined_data)} n_X entries.")
except FileNotFoundError:
    raise FileNotFoundError(f"Combined dataset not found at {combined_file_path}.")
# Out:
# Loaded combined dataset with 6 n_X entries.

# %%
# Define the range of n_X values to evaluate
nx_values = [10**s for s in range(4, 10)]  # 10^4 to 10^9

# Dictionary to store evaluation data for each n_X
all_evaluation_data = {}

# %%
# Extract and prepare evaluation data for each n_X
for nx in nx_values:
    nx_key = str(float(nx))
    if nx_key not in combined_data:
        print(f"No data found for n_X = {nx} in the combined dataset. Skipping...")
        continue
    evaluation_data = combined_data[nx_key]
    print(f"Extracted {len(evaluation_data)} entries for n_X = {nx}.")

    # Extract fiber lengths and optimized parameters
    fiber_lengths = np.array([entry["fiber_length"] for entry in evaluation_data])
    optimized_params_array = np.array([list(entry["optimized_params"].values()) for entry in evaluation_data])

    # Compute optimized key rates
    optimized_key_rates = []
    valid_indices = []
    for idx, (params, L) in enumerate(zip(optimized_params_array, fiber_lengths)):
        key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                  epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                  e_mis=5e-3, P_ap=0, n_event=1)
        if key_rate is None:
            print(f"Skipping invalid optimized key rate at index {idx} for n_X = {nx}")
            continue
        optimized_key_rates.append(key_rate)
        valid_indices.append(idx)
    optimized_key_rates = np.array(optimized_key_rates)

    # Filter the evaluation data to exclude invalid key rates
    fiber_lengths = fiber_lengths[valid_indices]
    optimized_params_array = optimized_params_array[valid_indices]

    # Prepare test inputs for evaluation
    X_test = []
    for L in fiber_lengths:
        e_1 = L / 100
        e_2 = -np.log10(6e-7)
        e_3 = 5e-3 * 100
        e_4 = np.log10(nx)
        X_test.append([e_1, e_2, e_3, e_4])
    X_test = np.array(X_test)
    X_test_scaled = scaler.transform(X_test)
    X_test_tensor = torch.tensor(X_test_scaled, dtype=torch.float32).to(device)

    # Store all evaluation data in a dictionary
    all_evaluation_data[nx] = {
        'fiber_lengths': fiber_lengths,
        'optimized_params_array': optimized_params_array,
        'optimized_key_rates': optimized_key_rates,
        'X_test_tensor': X_test_tensor
    }
    print(f"After filtering invalid key rates, {len(optimized_key_rates)} data points remain for n_X = {nx}.")
# Out:
# Extracted 736 entries for n_X = 10000.
# After filtering invalid key rates, 736 data points remain for n_X = 10000.
# Extracted 855 entries for n_X = 100000.
# After filtering invalid key rates, 855 data points remain for n_X = 100000.
# Extracted 902 entries for n_X = 1000000.
# After filtering invalid key rates, 902 data points remain for n_X = 1000000.
# Extracted 927 entries for n_X = 10000000.
# After filtering invalid key rates, 927 data points remain for n_X = 10000000.
# Extracted 942 entries for n_X = 100000000.
# After filtering invalid key rates, 942 data points remain for n_X = 100000000.
# Extracted 948 entries for n_X = 1000000000.
# After filtering invalid key rates, 948 data points remain for n_X = 1000000000.

# %%
# %%
# Define the neural network model
class BB84NN(nn.Module):
    def __init__(self):
        super(BB84NN, self).__init__()
        self.fc1 = nn.Linear(4, 16)
        self.fc2 = nn.Linear(16, 32)
        self.fc3 = nn.Linear(32, 16)
        self.fc4 = nn.Linear(16, 5)

    def forward(self, x):
        x = F.relu(self.fc1(x))
        x = F.relu(self.fc2(x))
        x = F.relu(self.fc3(x))
        x = self.fc4(x)
        return x

# %%
# Initialize model, loss, optimizer, and scheduler
model = BB84NN().to(device)
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(), lr=1e-3)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, mode='min', factor=0.1, patience=5, min_lr=1e-6)

# Lists to store metrics
train_losses = []
val_losses = []
learning_rates = []

# %%
def plot_keyrate_subplots(all_data, epoch, filename):
    """
    Plots key rates vs fiber length for multiple n_X values on separate subplots. all_data: dict with keys as n_X values and values containing fiber_lengths, optimized_key_rates, predicted_key_rates.
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True, sharey=True)
    fig.suptitle(f"Key Rates vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())  # Ensure n_X values are sorted

    for i, nx in enumerate(nx_values):
        if i >= 6:  # Limit to 6 subplots
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        predicted_key_rates = all_data[nx].get('predicted_key_rates', None)

        # Filter out NaN values
        valid_mask = ~(np.isnan(optimized_key_rates))
        if predicted_key_rates is not None:
            valid_mask &= ~np.isnan(predicted_key_rates)
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_key_rates = optimized_key_rates[valid_mask]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[valid_mask]

        # Find cutoff where optimized key rate becomes very small
        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_key_rates = optimized_key_rates[:cutoff_idx]
        if predicted_key_rates is not None:
            predicted_key_rates = predicted_key_rates[:cutoff_idx]

        # Plot key rates with adjusted linestyles and transparency
        ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linestyle='-', linewidth=2.0, alpha=1.0)  # Thicker line, semi-transparent
        if predicted_key_rates is not None and len(predicted_key_rates) > 0:
            ax.plot(fiber_lengths, np.log10(predicted_key_rates), 'r', label='Predicted Key Rate', 
                    linestyle=':',
                    # linestyle=(0, (1, 10)),  # Short dash (1 point) to look like a dot, 10-point gap
                    linewidth=4.0, alpha=0.7) # Thicker line, fully opaque
        
                
        # Compute the exponent for nx (e.g., nx = 10000 -> exponent = 4)
        exponent = int(np.log10(nx))
        # Set the title with LaTeX formatting for 10^exponent
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Secret Key Rate per Pulse")

        ax.legend(loc='upper right')

    # Remove empty subplots
    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)

    print(f"Key rate subplots saved to {filename}")

# %%
def plot_parameters_subplots(all_data, epoch, filename):
    """
    Plots optimized and predicted parameters vs fiber length for multiple n_X values on separate subplots.
    all_data: dict with keys as n_X values and values containing fiber_lengths, optimized_params_array, predicted_params_array.
    """
    fig, axes = plt.subplots(2, 3, figsize=(15, 10), sharex=True, sharey=True)
    fig.suptitle(f"Optimized and Predicted Parameters vs Fiber Length at Epoch {epoch+1} ($n_X = 10^s, s=4,5,...,9$)", fontsize=16)

    axes = axes.flatten()
    nx_values = sorted(all_data.keys())

    param_labels = ['$P_X$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$\mu_1$', '$\mu_2$']
    colors = ['blue', 'orange', 'green', 'red', 'purple']

    # Store handles and labels for the shared legend
    handles, labels = [], []

    for i, nx in enumerate(nx_values):
        if i >= 6:
            break

        ax = axes[i]
        fiber_lengths = all_data[nx]['fiber_lengths']
        optimized_params_array = all_data[nx]['optimized_params_array']
        predicted_params_array = all_data[nx].get('predicted_params_array', None)

        # Filter out NaN values in key rates to align with key rate plots
        optimized_key_rates = all_data[nx]['optimized_key_rates']
        valid_mask = ~(np.isnan(optimized_key_rates))
        fiber_lengths = fiber_lengths[valid_mask]
        optimized_params_array = optimized_params_array[valid_mask]
        if predicted_params_array is not None:
            predicted_params_array = predicted_params_array[valid_mask]

        # Truncate based on key rate cutoff
        threshold = 1e-8
        cutoff_idx = np.where(optimized_key_rates[valid_mask] <= threshold)[0]
        if len(cutoff_idx) > 0:
            cutoff_idx = cutoff_idx[0]
        else:
            cutoff_idx = len(fiber_lengths)

        fiber_lengths = fiber_lengths[:cutoff_idx]
        optimized_params_array = optimized_params_array[:cutoff_idx]
        if predicted_params_array is not None:
            predicted_params_array = predicted_params_array[:cutoff_idx]

        # Plot parameters with slight transparency for predicted lines
        for param_idx, (label, color) in enumerate(zip(param_labels, colors)):
            # Plot optimized line
            line_opt = ax.plot(fiber_lengths, optimized_params_array[:, param_idx], 
                               label=f'Optimized {label}', color=color, linestyle='-', linewidth=2.0, alpha=1.0)
            # Plot predicted line
            if predicted_params_array is not None:
                line_pred = ax.plot(fiber_lengths, predicted_params_array[:, param_idx], 
                                    label=f'Predicted {label}', color=color, linestyle=':', 
                                    linewidth=4.0, alpha=0.7)
            
            # Collect handles and labels only from the first subplot (i=0)
            if i == 0:
                handles.append(line_opt[0])
                labels.append(f'Optimized {label}')
                if predicted_params_array is not None:
                    handles.append(line_pred[0])
                    labels.append(f'Predicted {label}')

        # Compute the exponent for nx (e.g., nx = 10000 -> exponent = 4)
        exponent = int(np.log10(nx))
        # Set the title with LaTeX formatting for 10^exponent
        ax.set_title(f"$n_X = 10^{{{exponent}}}$")
        
        ax.set_ylim(0.0, 1.0)
        ax.grid(True)

        if i >= 3:
            ax.set_xlabel("Fiber Length (km)")
        if i % 3 == 0:
            ax.set_ylabel("Parameter Value")

    # Remove empty subplots
    for i in range(len(nx_values), 6):
        fig.delaxes(axes[i])

    # Add a single shared legend outside the entire grid
    fig.legend(handles, labels, loc='center left', bbox_to_anchor=(0.92, 0.5))

    # Adjust layout to make space for the legend on the right
    plt.tight_layout(rect=[0, 0, 0.9, 0.95])  # Leave 10% space on the right for the shared legend
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    print(f"Parameter subplots saved to {filename}")

# %%
def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
                         predicted_key_rates, predicted_params_array, epoch, filename, 
                         nx=None, threshold=1e-7):  # Increase threshold to 1e-7
    # Start timing
    plot_start_time = time.time()

    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Compute relative errors
    # Parameters: mu_1, mu_2, P_mu_1, P_mu_2, P_X
    relative_errors = []
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    for i in range(5):
        optimized = optimized_params_array[:, i]
        predicted = predicted_params_array[:, i]
        denominator = np.maximum(optimized, 1e-10)
        rel_error = (predicted - optimized) / denominator
        relative_errors.append(rel_error)
    
    # Key rate relative error with a higher threshold
    denominator = np.maximum(optimized_key_rates, 1e-7)  # Increase threshold to 1e-7
    key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Plot relative errors
    for i in range(5):
        row = i // 3
        col = i % 3
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Relative Error')
        ax.set_title(f'Relative Error for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Key rate subplot
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Relative Error')
    ax_key.set_title('Relative Error for Key Rate')
    ax_key.grid(True)
    ax_key.legend(loc='best')

    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
    fig.suptitle(f'Relative Errors of Parameters for $n_X = 10^{{{exponent}}}$', fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Relative error plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
# Training loop
import time

# Training loop
total_start_time = time.time()
num_epochs = 5000
for epoch in range(num_epochs):
    start_time = time.time()

    # Training phase
    model.train()
    running_loss = 0.0
    for inputs, targets in train_loader:
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()
        outputs = model(inputs)
        loss = criterion(outputs, targets)
        loss.backward()
        optimizer.step()
        running_loss += loss.item() * inputs.size(0)
    epoch_loss = running_loss / len(train_loader.dataset)
    train_losses.append(epoch_loss)

    # Validation phase
    model.eval()
    val_running_loss = 0.0
    with torch.no_grad():
        for inputs, targets in val_loader:
            inputs, targets = inputs.to(device), targets.to(device)
            outputs = model(inputs)
            loss = criterion(outputs, targets)
            val_running_loss += loss.item() * inputs.size(0)
    val_loss = val_running_loss / len(val_loader.dataset)
    val_losses.append(val_loss)

    # Update learning rate
    scheduler.step(val_loss)
    current_lr = optimizer.param_groups[0]['lr']
    learning_rates.append(current_lr)

    # Evaluate and plot at the first and last epochs
    eval_time = 0
    plot_time = 0
    if epoch == 0 or epoch == num_epochs - 1:
        model.eval()
        with torch.no_grad():
            # Prepare data for all n_X values
            plot_data = {}
            eval_start = time.time()
            for nx, eval_data in all_evaluation_data.items():
                fiber_lengths = eval_data['fiber_lengths']
                optimized_params_array = eval_data['optimized_params_array']
                optimized_key_rates = eval_data['optimized_key_rates']
                X_test_tensor = eval_data['X_test_tensor']

                # Compute predicted parameters and key rates
                predicted_params_scaled = model(X_test_tensor).cpu().numpy()
                predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
                predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
                predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6) # mu_1
                predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6) # mu_2
                predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)    # P_mu_1
                predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)    # P_mu_2
                predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)    # P_X
                
                # --- NEW: Enforce Sum Constraint ---
                prob_sum = predicted_params_array[:, 2] + predicted_params_array[:, 3]
                # Option A: Normalize if sum > 1
                mask_sum_gt_1 = prob_sum > 1.0
                if np.any(mask_sum_gt_1):
                    predicted_params_array[mask_sum_gt_1, 2] /= prob_sum[mask_sum_gt_1] # Scale P_mu_1
                    predicted_params_array[mask_sum_gt_1, 3] /= prob_sum[mask_sum_gt_1] # Scale P_mu_2
                # Option B: Clip individual probabilities again (less physically motivated, but simpler)
                # predicted_params_array[:, 2] = np.minimum(predicted_params_array[:, 2], 1.0 - predicted_params_array[:, 3]) # Ensure P_mu_1 <= 1 - P_mu_2
                
                # Compute and filter predicted key rates
                predicted_key_rates = []
                valid_indices = []
                for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
                    key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                              epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                              e_mis=5e-3, P_ap=0, n_event=1)
                    if key_rate is None:
                        print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
                        continue
                    predicted_key_rates.append(key_rate)
                    valid_indices.append(idx)
                predicted_key_rates = np.array(predicted_key_rates)

                # Filter data based on valid predicted key rates
                fiber_lengths = fiber_lengths[valid_indices]
                optimized_key_rates = optimized_key_rates[valid_indices]
                optimized_params_array = optimized_params_array[valid_indices]
                predicted_params_array = predicted_params_array[valid_indices]

                # Store data for plotting
                plot_data[nx] = {
                    'fiber_lengths': fiber_lengths,
                    'optimized_key_rates': optimized_key_rates,
                    'predicted_key_rates': predicted_key_rates,
                    'optimized_params_array': optimized_params_array,
                    'predicted_params_array': predicted_params_array
                }

                # Plot relative errors for this n_X
                plot_relative_errors(
                    fiber_lengths, optimized_key_rates, optimized_params_array,
                    predicted_key_rates, predicted_params_array, epoch,
                    f'parameter_relative_error_nx_{nx:.0e}.png', nx=nx
                )

            eval_time += time.time() - eval_start

            # Plot subplots at the first and last epochs
            plot_start = time.time()
            if epoch == 0:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_first_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_first_epoch.png')
            if epoch == num_epochs - 1:
                plot_keyrate_subplots(plot_data, epoch, f'keyrate_subplots_last_epoch.png')
                plot_parameters_subplots(plot_data, epoch, f'parameters_subplots_last_epoch.png')
            plot_time += time.time() - plot_start

            torch.save(model.state_dict(), 'bb84_nn_model.pth')
            print("Model saved to bb84_nn_model.pth")

    # Print epoch results with timing and learning rate
    epoch_time = time.time() - start_time
    print(f"Epoch {epoch+1}/{num_epochs}, Train Loss: {epoch_loss:.4f}, Val Loss: {val_loss:.4f}, "
          f"Learning Rate: {current_lr:.6f}, Time: {epoch_time:.2f}s (Eval: {eval_time:.2f}s, Plot: {plot_time:.2f}s)")

# Print total training time
total_training_time = time.time() - total_start_time
print(f"--- Total Training Time: {total_training_time:.2f} seconds ---")
# Out:
# Objective returned NaN for params [0.5794454  0.2931385  0.18912245 0.77275324 0.7395108 ], L=0.0, nx=10000
# Skipping invalid predicted key rate at index 0 for n_X = 10000
# Objective returned NaN for params [0.5793322  0.2930146  0.18885249 0.77275324 0.739054  ], L=0.2002002002002002, nx=10000
# Skipping invalid predicted key rate at index 1 for n_X = 10000
# Objective returned NaN for params [0.57921886 0.29289067 0.18858255 0.77275324 0.7385973 ], L=0.4004004004004004, nx=10000
# Skipping invalid predicted key rate at index 2 for n_X = 10000
# Objective returned NaN for params [0.5791056  0.29276675 0.18831271 0.77275324 0.73814064], L=0.6006006006006006, nx=10000
# Skipping invalid predicted key rate at index 3 for n_X = 10000
# Objective returned NaN for params [0.5789923  0.29264283 0.1880428  0.77275324 0.737684  ], L=0.8008008008008008, nx=10000
# Skipping invalid predicted key rate at index 4 for n_X = 10000
# Objective returned NaN for params [0.57887906 0.2925189  0.18777284 0.77275324 0.7372273 ], L=1.001001001001001, nx=10000
# Skipping invalid predicted key rate at index 5 for n_X = 10000
# Objective returned NaN for params [0.57876575 0.29239497 0.18750295 0.77275324 0.7367705 ], L=1.2012012012012012, nx=10000
# Skipping invalid predicted key rate at index 6 for n_X = 10000
# Objective returned NaN for params [0.57865244 0.29227108 0.187233   0.77275324 0.7363138 ], L=1.4014014014014016, nx=10000
# Skipping invalid predicted key rate at index 7 for n_X = 10000
# Objective returned NaN for params [0.5785392  0.29214716 0.1869631  0.77275324 0.7358572 ], L=1.6016016016016017, nx=10000
# Skipping invalid predicted key rate at index 8 for n_X = 10000
# Objective returned NaN for params [0.5784259  0.29202324 0.1866932  0.77275324 0.73540056], L=1.8018018018018018, nx=10000
# Skipping invalid predicted key rate at index 9 for n_X = 10000
# Objective returned NaN for params [0.57831264 0.29189932 0.18642324 0.77275324 0.73494387], L=2.002002002002002, nx=10000
# Skipping invalid predicted key rate at index 10 for n_X = 10000
# Objective returned NaN for params [0.5781994  0.2917754  0.18615338 0.77275324 0.7344871 ], L=2.2022022022022023, nx=10000
# Skipping invalid predicted key rate at index 11 for n_X = 10000
# Objective returned NaN for params [0.578086   0.29165152 0.18588343 0.77275324 0.73403037], L=2.4024024024024024, nx=10000
# Skipping invalid predicted key rate at index 12 for n_X = 10000
# Objective returned NaN for params [0.57797277 0.2915276  0.18561353 0.77275324 0.73357373], L=2.6026026026026026, nx=10000
# Skipping invalid predicted key rate at index 13 for n_X = 10000
# Objective returned NaN for params [0.57785946 0.29140365 0.1853436  0.77275324 0.7331171 ], L=2.802802802802803, nx=10000
# Skipping invalid predicted key rate at index 14 for n_X = 10000
# Objective returned NaN for params [0.5777462  0.29127976 0.18507372 0.77275324 0.73266023], L=3.0030030030030033, nx=10000
# Skipping invalid predicted key rate at index 15 for n_X = 10000
# Objective returned NaN for params [0.57763296 0.29115584 0.18480381 0.77275324 0.73220366], L=3.2032032032032034, nx=10000
# Skipping invalid predicted key rate at index 16 for n_X = 10000
# Objective returned NaN for params [0.57751966 0.29103196 0.18453388 0.77275324 0.7317469 ], L=3.4034034034034035, nx=10000
# Skipping invalid predicted key rate at index 17 for n_X = 10000
# Objective returned NaN for params [0.5774064  0.290908   0.18426403 0.77275324 0.7312903 ], L=3.6036036036036037, nx=10000
# Skipping invalid predicted key rate at index 18 for n_X = 10000
# Objective returned NaN for params [0.5772931  0.2907841  0.18399407 0.77275324 0.73083365], L=3.8038038038038042, nx=10000
# Skipping invalid predicted key rate at index 19 for n_X = 10000
# Objective returned NaN for params [0.5771798  0.29066017 0.18372415 0.77275324 0.73037696], L=4.004004004004004, nx=10000
# Skipping invalid predicted key rate at index 20 for n_X = 10000
# Objective returned NaN for params [0.57706654 0.29053625 0.18345429 0.77275324 0.7299202 ], L=4.2042042042042045, nx=10000
# Skipping invalid predicted key rate at index 21 for n_X = 10000
# Objective returned NaN for params [0.57695323 0.29041234 0.18318436 0.77275324 0.7294636 ], L=4.404404404404405, nx=10000
# Skipping invalid predicted key rate at index 22 for n_X = 10000
# Objective returned NaN for params [0.57684    0.29028842 0.18291444 0.77275324 0.7290068 ], L=4.604604604604605, nx=10000
# Skipping invalid predicted key rate at index 23 for n_X = 10000
# Objective returned NaN for params [0.5767267  0.29016447 0.18264453 0.77275324 0.7285501 ], L=4.804804804804805, nx=10000
# Skipping invalid predicted key rate at index 24 for n_X = 10000
# Objective returned NaN for params [0.5766134  0.2900406  0.18237458 0.77275324 0.72809345], L=5.005005005005005, nx=10000
# Skipping invalid predicted key rate at index 25 for n_X = 10000
# Objective returned NaN for params [0.5765001  0.28991666 0.1821047  0.77275324 0.72763675], L=5.205205205205205, nx=10000
# Skipping invalid predicted key rate at index 26 for n_X = 10000
# Objective returned NaN for params [0.5763868  0.28979278 0.18183479 0.77275324 0.72718   ], L=5.405405405405406, nx=10000
# Skipping invalid predicted key rate at index 27 for n_X = 10000
# Objective returned NaN for params [0.57627356 0.28966886 0.18156487 0.77275324 0.7267234 ], L=5.605605605605606, nx=10000
# Skipping invalid predicted key rate at index 28 for n_X = 10000
# Objective returned NaN for params [0.57616025 0.28954494 0.18129496 0.77275324 0.72626674], L=5.805805805805806, nx=10000
# Skipping invalid predicted key rate at index 29 for n_X = 10000
# Objective returned NaN for params [0.576047   0.28942102 0.18102501 0.77275324 0.72581   ], L=6.0060060060060065, nx=10000
# Skipping invalid predicted key rate at index 30 for n_X = 10000
# Objective returned NaN for params [0.5759337  0.2892971  0.18075514 0.77275324 0.7253533 ], L=6.206206206206207, nx=10000
# Skipping invalid predicted key rate at index 31 for n_X = 10000
# Objective returned NaN for params [0.57582045 0.2891732  0.18048525 0.77275324 0.72489667], L=6.406406406406407, nx=10000
# Skipping invalid predicted key rate at index 32 for n_X = 10000
# Objective returned NaN for params [0.5757072  0.2890493  0.1802153  0.77275324 0.7244399 ], L=6.606606606606607, nx=10000
# Skipping invalid predicted key rate at index 33 for n_X = 10000
# Objective returned NaN for params [0.5755939  0.28892535 0.17994533 0.77275324 0.72398317], L=6.806806806806807, nx=10000
# Skipping invalid predicted key rate at index 34 for n_X = 10000
# Objective returned NaN for params [0.5754806  0.28880143 0.17967546 0.77275324 0.72352654], L=7.007007007007007, nx=10000
# Skipping invalid predicted key rate at index 35 for n_X = 10000
# Objective returned NaN for params [0.5753673  0.28867754 0.17940561 0.77275324 0.72306985], L=7.207207207207207, nx=10000
# Skipping invalid predicted key rate at index 36 for n_X = 10000
# Objective returned NaN for params [0.575254   0.28855363 0.17913562 0.77275324 0.7226131 ], L=7.407407407407407, nx=10000
# Skipping invalid predicted key rate at index 37 for n_X = 10000
# Objective returned NaN for params [0.5751408  0.2884297  0.17886572 0.77275324 0.72215647], L=7.6076076076076085, nx=10000
# Skipping invalid predicted key rate at index 38 for n_X = 10000
# Objective returned NaN for params [0.57502747 0.28830582 0.17859583 0.77275324 0.7216997 ], L=7.807807807807809, nx=10000
# Skipping invalid predicted key rate at index 39 for n_X = 10000
# Objective returned NaN for params [0.5749142  0.2881819  0.17832594 0.77275324 0.7212431 ], L=8.008008008008009, nx=10000
# Skipping invalid predicted key rate at index 40 for n_X = 10000
# Objective returned NaN for params [0.5748009  0.28805795 0.17805597 0.77275324 0.72078633], L=8.208208208208209, nx=10000
# Skipping invalid predicted key rate at index 41 for n_X = 10000
# Objective returned NaN for params [0.57468766 0.28793404 0.17778605 0.77275324 0.72032964], L=8.408408408408409, nx=10000
# Skipping invalid predicted key rate at index 42 for n_X = 10000
# Objective returned NaN for params [0.57457435 0.28781015 0.17751615 0.77275324 0.719873  ], L=8.608608608608609, nx=10000
# Skipping invalid predicted key rate at index 43 for n_X = 10000
# Objective returned NaN for params [0.57446104 0.2876862  0.17724626 0.77275324 0.71941626], L=8.80880880880881, nx=10000
# Skipping invalid predicted key rate at index 44 for n_X = 10000
# Objective returned NaN for params [0.5743478  0.28756228 0.17697632 0.77275324 0.7189596 ], L=9.00900900900901, nx=10000
# Skipping invalid predicted key rate at index 45 for n_X = 10000
# Objective returned NaN for params [0.5742345  0.28743836 0.1767064  0.77275324 0.71850294], L=9.20920920920921, nx=10000
# Skipping invalid predicted key rate at index 46 for n_X = 10000
# Objective returned NaN for params [0.57412124 0.2873145  0.17643654 0.77275324 0.71804625], L=9.40940940940941, nx=10000
# Skipping invalid predicted key rate at index 47 for n_X = 10000
# Objective returned NaN for params [0.5740079  0.28719056 0.17616655 0.77275324 0.71758956], L=9.60960960960961, nx=10000
# Skipping invalid predicted key rate at index 48 for n_X = 10000
# Objective returned NaN for params [0.5738947  0.28706664 0.17589669 0.77275324 0.7171328 ], L=9.80980980980981, nx=10000
# Skipping invalid predicted key rate at index 49 for n_X = 10000
# Objective returned NaN for params [0.5737814  0.28694275 0.1756268  0.77275324 0.7166762 ], L=10.01001001001001, nx=10000
# Skipping invalid predicted key rate at index 50 for n_X = 10000
# Objective returned NaN for params [0.57366806 0.2868188  0.17535684 0.77275324 0.71621954], L=10.21021021021021, nx=10000
# Skipping invalid predicted key rate at index 51 for n_X = 10000
# Objective returned NaN for params [0.5735548  0.2866949  0.17508695 0.77275324 0.71576285], L=10.41041041041041, nx=10000
# Skipping invalid predicted key rate at index 52 for n_X = 10000
# Objective returned NaN for params [0.5734415  0.286571   0.17481704 0.77275324 0.7153061 ], L=10.61061061061061, nx=10000
# Skipping invalid predicted key rate at index 53 for n_X = 10000
# Objective returned NaN for params [0.57332826 0.28644708 0.17454715 0.77275324 0.7148495 ], L=10.810810810810812, nx=10000
# Skipping invalid predicted key rate at index 54 for n_X = 10000
# Objective returned NaN for params [0.573215   0.28632316 0.17427723 0.77275324 0.7143927 ], L=11.011011011011012, nx=10000
# Skipping invalid predicted key rate at index 55 for n_X = 10000
# Objective returned NaN for params [0.5731017  0.28619924 0.17400724 0.77275324 0.713936  ], L=11.211211211211213, nx=10000
# Skipping invalid predicted key rate at index 56 for n_X = 10000
# Objective returned NaN for params [0.5729884  0.28607532 0.17373738 0.77275324 0.71347934], L=11.411411411411413, nx=10000
# Skipping invalid predicted key rate at index 57 for n_X = 10000
# Objective returned NaN for params [0.5728751  0.28595138 0.17346747 0.77275324 0.71302265], L=11.611611611611613, nx=10000
# Skipping invalid predicted key rate at index 58 for n_X = 10000
# Objective returned NaN for params [0.57276183 0.28582746 0.1731976  0.77275324 0.712566  ], L=11.811811811811813, nx=10000
# Skipping invalid predicted key rate at index 59 for n_X = 10000
# Objective returned NaN for params [0.5726486  0.2857036  0.17292763 0.77275324 0.71210927], L=12.012012012012013, nx=10000
# Skipping invalid predicted key rate at index 60 for n_X = 10000
# Objective returned NaN for params [0.5725353  0.28557965 0.17265777 0.77275324 0.71165264], L=12.212212212212213, nx=10000
# Skipping invalid predicted key rate at index 61 for n_X = 10000
# Objective returned NaN for params [0.572422   0.28545573 0.17238784 0.77275324 0.7111959 ], L=12.412412412412413, nx=10000
# Skipping invalid predicted key rate at index 62 for n_X = 10000
# Objective returned NaN for params [0.5723087  0.28533185 0.1721179  0.77275324 0.7107393 ], L=12.612612612612613, nx=10000
# Skipping invalid predicted key rate at index 63 for n_X = 10000
# Objective returned NaN for params [0.5721954  0.2852079  0.17184803 0.77275324 0.71028256], L=12.812812812812814, nx=10000
# Skipping invalid predicted key rate at index 64 for n_X = 10000
# Objective returned NaN for params [0.57208216 0.285084   0.17157806 0.77275324 0.70982593], L=13.013013013013014, nx=10000
# Skipping invalid predicted key rate at index 65 for n_X = 10000
# Objective returned NaN for params [0.57196885 0.2849601  0.17130813 0.77275324 0.7093692 ], L=13.213213213213214, nx=10000
# Skipping invalid predicted key rate at index 66 for n_X = 10000
# Objective returned NaN for params [0.5718556  0.28483614 0.1710383  0.77275324 0.70891243], L=13.413413413413414, nx=10000
# Skipping invalid predicted key rate at index 67 for n_X = 10000
# Objective returned NaN for params [0.5717423  0.28471226 0.17076838 0.77275324 0.70845574], L=13.613613613613614, nx=10000
# Skipping invalid predicted key rate at index 68 for n_X = 10000
# Objective returned NaN for params [0.57162905 0.28458834 0.17049845 0.77275324 0.7079991 ], L=13.813813813813814, nx=10000
# Skipping invalid predicted key rate at index 69 for n_X = 10000
# Objective returned NaN for params [0.5715222  0.28446525 0.17024758 0.77275324 0.70755386], L=14.014014014014014, nx=10000
# Skipping invalid predicted key rate at index 70 for n_X = 10000
# Objective returned NaN for params [0.57142496 0.28434342 0.17002551 0.77275324 0.7071258 ], L=14.214214214214214, nx=10000
# Skipping invalid predicted key rate at index 71 for n_X = 10000
# Objective returned NaN for params [0.57132775 0.2842216  0.16980341 0.77275324 0.70669764], L=14.414414414414415, nx=10000
# Skipping invalid predicted key rate at index 72 for n_X = 10000
# Objective returned NaN for params [0.5712305  0.28409976 0.16958132 0.77275324 0.70626974], L=14.614614614614615, nx=10000
# Skipping invalid predicted key rate at index 73 for n_X = 10000
# Objective returned NaN for params [0.5711333  0.28397793 0.16935919 0.77275324 0.7058416 ], L=14.814814814814815, nx=10000
# Skipping invalid predicted key rate at index 74 for n_X = 10000
# Objective returned NaN for params [0.57103604 0.28385606 0.16913705 0.77275324 0.7054135 ], L=15.015015015015017, nx=10000
# Skipping invalid predicted key rate at index 75 for n_X = 10000
# Objective returned NaN for params [0.5709388  0.28373423 0.16891499 0.77275324 0.7049856 ], L=15.215215215215217, nx=10000
# Skipping invalid predicted key rate at index 76 for n_X = 10000
# Objective returned NaN for params [0.5708416  0.28361237 0.16869284 0.77275324 0.7045575 ], L=15.415415415415417, nx=10000
# Skipping invalid predicted key rate at index 77 for n_X = 10000
# Objective returned NaN for params [0.5707444  0.28349057 0.16847074 0.77275324 0.7041294 ], L=15.615615615615617, nx=10000
# Skipping invalid predicted key rate at index 78 for n_X = 10000
# Objective returned NaN for params [0.5706471  0.28336874 0.16824865 0.77275324 0.7037014 ], L=15.815815815815817, nx=10000
# Skipping invalid predicted key rate at index 79 for n_X = 10000
# Objective returned NaN for params [0.57054996 0.28324687 0.16802652 0.77275324 0.70327336], L=16.016016016016017, nx=10000
# Skipping invalid predicted key rate at index 80 for n_X = 10000
# Objective returned NaN for params [0.5704527  0.28312504 0.1678044  0.77275324 0.7028453 ], L=16.216216216216218, nx=10000
# Skipping invalid predicted key rate at index 81 for n_X = 10000
# Objective returned NaN for params [0.5703555  0.2830032  0.1675823  0.77275324 0.70241725], L=16.416416416416418, nx=10000
# Skipping invalid predicted key rate at index 82 for n_X = 10000
# Objective returned NaN for params [0.57025826 0.28288138 0.16736025 0.77275324 0.7019892 ], L=16.616616616616618, nx=10000
# Skipping invalid predicted key rate at index 83 for n_X = 10000
# Objective returned NaN for params [0.57016104 0.28275955 0.16713808 0.77275324 0.70156115], L=16.816816816816818, nx=10000
# Skipping invalid predicted key rate at index 84 for n_X = 10000
# Objective returned NaN for params [0.57006377 0.2826377  0.16691598 0.77275324 0.70113313], L=17.017017017017018, nx=10000
# Skipping invalid predicted key rate at index 85 for n_X = 10000
# Objective returned NaN for params [0.5699666  0.28251585 0.16669391 0.77275324 0.70070505], L=17.217217217217218, nx=10000
# Skipping invalid predicted key rate at index 86 for n_X = 10000
# Objective returned NaN for params [0.56986934 0.28239405 0.16647178 0.77275324 0.70027703], L=17.41741741741742, nx=10000
# Skipping invalid predicted key rate at index 87 for n_X = 10000
# Objective returned NaN for params [0.5697721  0.2822722  0.16624965 0.77275324 0.699849  ], L=17.61761761761762, nx=10000
# Skipping invalid predicted key rate at index 88 for n_X = 10000
# Objective returned NaN for params [0.56967497 0.28215036 0.16602758 0.77275324 0.6994209 ], L=17.81781781781782, nx=10000
# Skipping invalid predicted key rate at index 89 for n_X = 10000
# Objective returned NaN for params [0.5695777  0.28202853 0.16580544 0.77275324 0.6989929 ], L=18.01801801801802, nx=10000
# Skipping invalid predicted key rate at index 90 for n_X = 10000
# Objective returned NaN for params [0.5694805  0.2819067  0.16558331 0.77275324 0.6985648 ], L=18.21821821821822, nx=10000
# Skipping invalid predicted key rate at index 91 for n_X = 10000
# Objective returned NaN for params [0.5693832  0.28178483 0.16536126 0.77275324 0.6981367 ], L=18.41841841841842, nx=10000
# Skipping invalid predicted key rate at index 92 for n_X = 10000
# Objective returned NaN for params [0.569286   0.281663   0.16513908 0.77275324 0.69770867], L=18.61861861861862, nx=10000
# Skipping invalid predicted key rate at index 93 for n_X = 10000
# Objective returned NaN for params [0.56918883 0.28154117 0.164917   0.77275324 0.6972807 ], L=18.81881881881882, nx=10000
# Skipping invalid predicted key rate at index 94 for n_X = 10000
# Objective returned NaN for params [0.56909156 0.28141934 0.1646949  0.77275324 0.6968527 ], L=19.01901901901902, nx=10000
# Skipping invalid predicted key rate at index 95 for n_X = 10000
# Objective returned NaN for params [0.5689943  0.2812975  0.16447277 0.77275324 0.69642454], L=19.21921921921922, nx=10000
# Skipping invalid predicted key rate at index 96 for n_X = 10000
# Objective returned NaN for params [0.5688971  0.28117567 0.1642507  0.77275324 0.6959966 ], L=19.41941941941942, nx=10000
# Skipping invalid predicted key rate at index 97 for n_X = 10000
# Objective returned NaN for params [0.5687999  0.2810538  0.16402857 0.77275324 0.69556844], L=19.61961961961962, nx=10000
# Skipping invalid predicted key rate at index 98 for n_X = 10000
# Objective returned NaN for params [0.56870264 0.280932   0.16380647 0.77275324 0.6951404 ], L=19.81981981981982, nx=10000
# Skipping invalid predicted key rate at index 99 for n_X = 10000
# Objective returned NaN for params [0.5686054  0.28081018 0.1635843  0.77275324 0.6947123 ], L=20.02002002002002, nx=10000
# Skipping invalid predicted key rate at index 100 for n_X = 10000
# Objective returned NaN for params [0.5685082  0.28068832 0.1633622  0.77275324 0.6942843 ], L=20.22022022022022, nx=10000
# Skipping invalid predicted key rate at index 101 for n_X = 10000
# Objective returned NaN for params [0.568411   0.28056648 0.1631401  0.77275324 0.6938563 ], L=20.42042042042042, nx=10000
# Skipping invalid predicted key rate at index 102 for n_X = 10000
# Objective returned NaN for params [0.5683138  0.28044462 0.162918   0.77275324 0.6934282 ], L=20.62062062062062, nx=10000
# Skipping invalid predicted key rate at index 103 for n_X = 10000
# Objective returned NaN for params [0.5682165  0.2803228  0.16269587 0.77275324 0.6930002 ], L=20.82082082082082, nx=10000
# Skipping invalid predicted key rate at index 104 for n_X = 10000
# Objective returned NaN for params [0.56811935 0.280201   0.16247377 0.77275324 0.6925722 ], L=21.02102102102102, nx=10000
# Skipping invalid predicted key rate at index 105 for n_X = 10000
# Objective returned NaN for params [0.56802213 0.28007916 0.16225171 0.77275324 0.6921441 ], L=21.22122122122122, nx=10000
# Skipping invalid predicted key rate at index 106 for n_X = 10000
# Objective returned NaN for params [0.56792486 0.2799573  0.16202961 0.77275324 0.6917161 ], L=21.421421421421424, nx=10000
# Skipping invalid predicted key rate at index 107 for n_X = 10000
# Objective returned NaN for params [0.56782764 0.27983546 0.16180746 0.77275324 0.691288  ], L=21.621621621621625, nx=10000
# Skipping invalid predicted key rate at index 108 for n_X = 10000
# Objective returned NaN for params [0.5677304  0.2797136  0.16158536 0.77275324 0.69086   ], L=21.821821821821825, nx=10000
# Skipping invalid predicted key rate at index 109 for n_X = 10000
# Objective returned NaN for params [0.5676332  0.27959183 0.16136324 0.77275324 0.69043195], L=22.022022022022025, nx=10000
# Skipping invalid predicted key rate at index 110 for n_X = 10000
# Objective returned NaN for params [0.567536   0.27946994 0.16114114 0.77275324 0.6900038 ], L=22.222222222222225, nx=10000
# Skipping invalid predicted key rate at index 111 for n_X = 10000
# Objective returned NaN for params [0.5674388  0.27934813 0.16091904 0.77275324 0.68957585], L=22.422422422422425, nx=10000
# Skipping invalid predicted key rate at index 112 for n_X = 10000
# Objective returned NaN for params [0.5673415  0.2792263  0.1606969  0.77275324 0.68914783], L=22.622622622622625, nx=10000
# Skipping invalid predicted key rate at index 113 for n_X = 10000
# Objective returned NaN for params [0.5672443  0.2791044  0.1604748  0.77275324 0.6887197 ], L=22.822822822822825, nx=10000
# Skipping invalid predicted key rate at index 114 for n_X = 10000
# Objective returned NaN for params [0.5671471  0.2789826  0.1602527  0.77275324 0.6882916 ], L=23.023023023023026, nx=10000
# Skipping invalid predicted key rate at index 115 for n_X = 10000
# Objective returned NaN for params [0.56704986 0.27886075 0.16003063 0.77275324 0.6878636 ], L=23.223223223223226, nx=10000
# Skipping invalid predicted key rate at index 116 for n_X = 10000
# Objective returned NaN for params [0.56695265 0.27873898 0.15980847 0.77275324 0.68743557], L=23.423423423423426, nx=10000
# Skipping invalid predicted key rate at index 117 for n_X = 10000
# Objective returned NaN for params [0.56685543 0.2786171  0.15958637 0.77275324 0.6870075 ], L=23.623623623623626, nx=10000
# Skipping invalid predicted key rate at index 118 for n_X = 10000
# Objective returned NaN for params [0.56675816 0.27849528 0.15936427 0.77275324 0.68657947], L=23.823823823823826, nx=10000
# Skipping invalid predicted key rate at index 119 for n_X = 10000
# Objective returned NaN for params [0.56666094 0.27837342 0.1591422  0.77275324 0.6861514 ], L=24.024024024024026, nx=10000
# Skipping invalid predicted key rate at index 120 for n_X = 10000
# Objective returned NaN for params [0.5665637  0.2782516  0.1589201  0.77275324 0.68572336], L=24.224224224224226, nx=10000
# Skipping invalid predicted key rate at index 121 for n_X = 10000
# Objective returned NaN for params [0.5664665  0.27812976 0.15869796 0.77275324 0.68529534], L=24.424424424424426, nx=10000
# Skipping invalid predicted key rate at index 122 for n_X = 10000
# Objective returned NaN for params [0.56636935 0.2780079  0.15847579 0.77275324 0.68486726], L=24.624624624624627, nx=10000
# Skipping invalid predicted key rate at index 123 for n_X = 10000
# Objective returned NaN for params [0.566272   0.2778861  0.15825373 0.77275324 0.68443924], L=24.824824824824827, nx=10000
# Skipping invalid predicted key rate at index 124 for n_X = 10000
# Objective returned NaN for params [0.56617486 0.27776423 0.1580316  0.77275324 0.6840112 ], L=25.025025025025027, nx=10000
# Skipping invalid predicted key rate at index 125 for n_X = 10000
# Objective returned NaN for params [0.56607765 0.2776424  0.15780957 0.77275324 0.68358314], L=25.225225225225227, nx=10000
# Skipping invalid predicted key rate at index 126 for n_X = 10000
# Objective returned NaN for params [0.5659804  0.27752057 0.15758742 0.77275324 0.6831551 ], L=25.425425425425427, nx=10000
# Skipping invalid predicted key rate at index 127 for n_X = 10000
# Objective returned NaN for params [0.5658812  0.27739826 0.15737174 0.77275324 0.68272835], L=25.625625625625627, nx=10000
# Skipping invalid predicted key rate at index 128 for n_X = 10000
# Objective returned NaN for params [0.5657786  0.27727517 0.15716746 0.77275324 0.68230385], L=25.825825825825827, nx=10000
# Skipping invalid predicted key rate at index 129 for n_X = 10000
# Objective returned NaN for params [0.565676   0.27715206 0.15696318 0.77275324 0.6818792 ], L=26.026026026026027, nx=10000
# Skipping invalid predicted key rate at index 130 for n_X = 10000
# Objective returned NaN for params [0.56557345 0.27702892 0.15675882 0.77275324 0.68145484], L=26.226226226226228, nx=10000
# Skipping invalid predicted key rate at index 131 for n_X = 10000
# Objective returned NaN for params [0.56547076 0.2769058  0.15655455 0.77275324 0.6810302 ], L=26.426426426426428, nx=10000
# Skipping invalid predicted key rate at index 132 for n_X = 10000
# Objective returned NaN for params [0.5653682  0.2767827  0.15635024 0.77275324 0.6806057 ], L=26.626626626626628, nx=10000
# Skipping invalid predicted key rate at index 133 for n_X = 10000
# Objective returned NaN for params [0.56526554 0.27665958 0.15614593 0.77275324 0.68018115], L=26.826826826826828, nx=10000
# Skipping invalid predicted key rate at index 134 for n_X = 10000
# Objective returned NaN for params [0.56516296 0.27653646 0.15594167 0.77275324 0.6797567 ], L=27.027027027027028, nx=10000
# Skipping invalid predicted key rate at index 135 for n_X = 10000
# Objective returned NaN for params [0.5650603  0.27641335 0.15573736 0.77275324 0.67933214], L=27.227227227227228, nx=10000
# Skipping invalid predicted key rate at index 136 for n_X = 10000
# Objective returned NaN for params [0.5649577  0.27629024 0.15553305 0.77275324 0.6789077 ], L=27.42742742742743, nx=10000
# Skipping invalid predicted key rate at index 137 for n_X = 10000
# Objective returned NaN for params [0.5648551  0.27616712 0.15532877 0.77275324 0.6784831 ], L=27.62762762762763, nx=10000
# Skipping invalid predicted key rate at index 138 for n_X = 10000
# Objective returned NaN for params [0.56475246 0.276044   0.15512447 0.77275324 0.6780586 ], L=27.82782782782783, nx=10000
# Skipping invalid predicted key rate at index 139 for n_X = 10000
# Objective returned NaN for params [0.5646499  0.2759209  0.15492016 0.77275324 0.6776341 ], L=28.02802802802803, nx=10000
# Skipping invalid predicted key rate at index 140 for n_X = 10000
# Objective returned NaN for params [0.5645473  0.27579778 0.15471585 0.77275324 0.6772096 ], L=28.22822822822823, nx=10000
# Skipping invalid predicted key rate at index 141 for n_X = 10000
# Objective returned NaN for params [0.5644446  0.27567467 0.15451159 0.77275324 0.6767851 ], L=28.42842842842843, nx=10000
# Skipping invalid predicted key rate at index 142 for n_X = 10000
# Objective returned NaN for params [0.564342   0.27555153 0.1543073  0.77275324 0.6763605 ], L=28.62862862862863, nx=10000
# Skipping invalid predicted key rate at index 143 for n_X = 10000
# Objective returned NaN for params [0.56423944 0.2754284  0.15410301 0.77275324 0.675936  ], L=28.82882882882883, nx=10000
# Skipping invalid predicted key rate at index 144 for n_X = 10000
# Objective returned NaN for params [0.5641368  0.27530533 0.15389866 0.77275324 0.6755115 ], L=29.02902902902903, nx=10000
# Skipping invalid predicted key rate at index 145 for n_X = 10000
# Objective returned NaN for params [0.56403416 0.27518222 0.15369435 0.77275324 0.675087  ], L=29.22922922922923, nx=10000
# Skipping invalid predicted key rate at index 146 for n_X = 10000
# Objective returned NaN for params [0.5639316  0.2750591  0.15349008 0.77275324 0.6746625 ], L=29.42942942942943, nx=10000
# Skipping invalid predicted key rate at index 147 for n_X = 10000
# Objective returned NaN for params [0.56382895 0.274936   0.15328577 0.77275324 0.67423797], L=29.62962962962963, nx=10000
# Skipping invalid predicted key rate at index 148 for n_X = 10000
# Objective returned NaN for params [0.56372637 0.27481285 0.15308149 0.77275324 0.67381346], L=29.82982982982983, nx=10000
# Skipping invalid predicted key rate at index 149 for n_X = 10000
# Objective returned NaN for params [0.5636238  0.27468973 0.15287726 0.77275324 0.67338896], L=30.030030030030034, nx=10000
# Skipping invalid predicted key rate at index 150 for n_X = 10000
# Objective returned NaN for params [0.5635211  0.27456662 0.15267289 0.77275324 0.67296433], L=30.230230230230234, nx=10000
# Skipping invalid predicted key rate at index 151 for n_X = 10000
# Objective returned NaN for params [0.56341845 0.27444354 0.15246862 0.77275324 0.67253983], L=30.430430430430434, nx=10000
# Skipping invalid predicted key rate at index 152 for n_X = 10000
# Objective returned NaN for params [0.56331587 0.27432042 0.15226427 0.77275324 0.6721153 ], L=30.630630630630634, nx=10000
# Skipping invalid predicted key rate at index 153 for n_X = 10000
# Objective returned NaN for params [0.5632133  0.27419728 0.15206005 0.77275324 0.6716908 ], L=30.830830830830834, nx=10000
# Skipping invalid predicted key rate at index 154 for n_X = 10000
# Objective returned NaN for params [0.56311065 0.27407417 0.15185572 0.77275324 0.6712663 ], L=31.031031031031034, nx=10000
# Skipping invalid predicted key rate at index 155 for n_X = 10000
# Objective returned NaN for params [0.56300807 0.27395105 0.15165141 0.77275324 0.6708418 ], L=31.231231231231234, nx=10000
# Skipping invalid predicted key rate at index 156 for n_X = 10000
# Objective returned NaN for params [0.56290543 0.27382794 0.15144715 0.77275324 0.6704173 ], L=31.431431431431434, nx=10000
# Skipping invalid predicted key rate at index 157 for n_X = 10000
# Objective returned NaN for params [0.56280285 0.2737048  0.15124278 0.77275324 0.66999274], L=31.631631631631635, nx=10000
# Skipping invalid predicted key rate at index 158 for n_X = 10000
# Objective returned NaN for params [0.5627002  0.2735817  0.1510385  0.77275324 0.66956824], L=31.831831831831835, nx=10000
# Skipping invalid predicted key rate at index 159 for n_X = 10000
# Objective returned NaN for params [0.5625976  0.2734586  0.15083423 0.77275324 0.66914374], L=32.032032032032035, nx=10000
# Skipping invalid predicted key rate at index 160 for n_X = 10000
# Objective returned NaN for params [0.562495   0.2733355  0.15062992 0.77275324 0.66871923], L=32.232232232232235, nx=10000
# Skipping invalid predicted key rate at index 161 for n_X = 10000
# Objective returned NaN for params [0.56239235 0.27321237 0.15042561 0.77275324 0.6682947 ], L=32.432432432432435, nx=10000
# Skipping invalid predicted key rate at index 162 for n_X = 10000
# Objective returned NaN for params [0.5622898  0.27308926 0.15022135 0.77275324 0.6678701 ], L=32.632632632632635, nx=10000
# Skipping invalid predicted key rate at index 163 for n_X = 10000
# Objective returned NaN for params [0.56218714 0.27296615 0.15001707 0.77275324 0.6674457 ], L=32.832832832832835, nx=10000
# Skipping invalid predicted key rate at index 164 for n_X = 10000
# Objective returned NaN for params [0.5620845  0.27284303 0.14981274 0.77275324 0.6670212 ], L=33.033033033033036, nx=10000
# Skipping invalid predicted key rate at index 165 for n_X = 10000
# Objective returned NaN for params [0.5619819  0.2727199  0.14960843 0.77275324 0.6665966 ], L=33.233233233233236, nx=10000
# Skipping invalid predicted key rate at index 166 for n_X = 10000
# Objective returned NaN for params [0.56187934 0.27259678 0.14940412 0.77275324 0.6661721 ], L=33.433433433433436, nx=10000
# Skipping invalid predicted key rate at index 167 for n_X = 10000
# Objective returned NaN for params [0.5617767  0.2724737  0.14919984 0.77275324 0.6657476 ], L=33.633633633633636, nx=10000
# Skipping invalid predicted key rate at index 168 for n_X = 10000
# Objective returned NaN for params [0.56167406 0.27235058 0.14899552 0.77275324 0.6653231 ], L=33.833833833833836, nx=10000
# Skipping invalid predicted key rate at index 169 for n_X = 10000
# Objective returned NaN for params [0.5615715  0.27222744 0.14879122 0.77258474 0.6648985 ], L=34.034034034034036, nx=10000
# Skipping invalid predicted key rate at index 170 for n_X = 10000
# Objective returned NaN for params [0.56146884 0.27210432 0.14858696 0.7719898  0.66447407], L=34.234234234234236, nx=10000
# Skipping invalid predicted key rate at index 171 for n_X = 10000
# Objective returned NaN for params [0.56136626 0.2719812  0.14838265 0.77139497 0.6640495 ], L=34.434434434434436, nx=10000
# Skipping invalid predicted key rate at index 172 for n_X = 10000
# Objective returned NaN for params [0.5612636  0.27185813 0.14817844 0.7708     0.663625  ], L=34.63463463463464, nx=10000
# Skipping invalid predicted key rate at index 173 for n_X = 10000
# Objective returned NaN for params [0.561161   0.271735   0.14797403 0.77020514 0.6632005 ], L=34.83483483483484, nx=10000
# Skipping invalid predicted key rate at index 174 for n_X = 10000
# Objective returned NaN for params [0.56105834 0.27161187 0.14776978 0.76961017 0.6627759 ], L=35.03503503503504, nx=10000
# Skipping invalid predicted key rate at index 175 for n_X = 10000
# Objective returned NaN for params [0.5609558  0.27148876 0.14756545 0.7690153  0.6623515 ], L=35.23523523523524, nx=10000
# Skipping invalid predicted key rate at index 176 for n_X = 10000
# Objective returned NaN for params [0.5608532  0.27136564 0.14736119 0.76842046 0.661927  ], L=35.43543543543544, nx=10000
# Skipping invalid predicted key rate at index 177 for n_X = 10000
# Objective returned NaN for params [0.56075054 0.27124253 0.14715685 0.7678256  0.66150236], L=35.63563563563564, nx=10000
# Skipping invalid predicted key rate at index 178 for n_X = 10000
# Objective returned NaN for params [0.5606479  0.27111945 0.14695255 0.76723063 0.66107786], L=35.83583583583584, nx=10000
# Skipping invalid predicted key rate at index 179 for n_X = 10000
# Objective returned NaN for params [0.5605453  0.2709963  0.14674827 0.7666358  0.66065335], L=36.03603603603604, nx=10000
# Skipping invalid predicted key rate at index 180 for n_X = 10000
# Objective returned NaN for params [0.56044275 0.2708732  0.14654396 0.7660408  0.6602287 ], L=36.23623623623624, nx=10000
# Skipping invalid predicted key rate at index 181 for n_X = 10000
# Objective returned NaN for params [0.5603401  0.27075008 0.1463397  0.765446   0.65980434], L=36.43643643643644, nx=10000
# Skipping invalid predicted key rate at index 182 for n_X = 10000
# Objective returned NaN for params [0.56023747 0.27062696 0.14613539 0.76485115 0.6593797 ], L=36.63663663663664, nx=10000
# Skipping invalid predicted key rate at index 183 for n_X = 10000
# Objective returned NaN for params [0.5601348  0.27050385 0.14593108 0.7642562  0.65895534], L=36.83683683683684, nx=10000
# Skipping invalid predicted key rate at index 184 for n_X = 10000
# Objective returned NaN for params [0.56003225 0.2703807  0.1457268  0.76366127 0.6585307 ], L=37.03703703703704, nx=10000
# Skipping invalid predicted key rate at index 185 for n_X = 10000
# Objective returned NaN for params [0.55992967 0.27025762 0.14552249 0.7630664  0.6581063 ], L=37.23723723723724, nx=10000
# Skipping invalid predicted key rate at index 186 for n_X = 10000
# Objective returned NaN for params [0.559827   0.2701345  0.14531817 0.7624716  0.6576817 ], L=37.43743743743744, nx=10000
# Skipping invalid predicted key rate at index 187 for n_X = 10000
# Objective returned NaN for params [0.5597244  0.2700114  0.14511389 0.7618766  0.6572572 ], L=37.63763763763764, nx=10000
# Skipping invalid predicted key rate at index 188 for n_X = 10000
# Objective returned NaN for params [0.5596218  0.26988828 0.14490964 0.76128167 0.65683264], L=37.83783783783784, nx=10000
# Skipping invalid predicted key rate at index 189 for n_X = 10000
# Objective returned NaN for params [0.5595192  0.26976514 0.14470533 0.7606868  0.6564082 ], L=38.03803803803804, nx=10000
# Skipping invalid predicted key rate at index 190 for n_X = 10000
# Objective returned NaN for params [0.5594166  0.26964203 0.14450103 0.76009196 0.6559836 ], L=38.23823823823824, nx=10000
# Skipping invalid predicted key rate at index 191 for n_X = 10000
# Objective returned NaN for params [0.55931395 0.26951894 0.14429669 0.759497   0.6555591 ], L=38.43843843843844, nx=10000
# Skipping invalid predicted key rate at index 192 for n_X = 10000
# Objective returned NaN for params [0.5592113  0.2693958  0.14409241 0.75890213 0.6551346 ], L=38.63863863863864, nx=10000
# Skipping invalid predicted key rate at index 193 for n_X = 10000
# Objective returned NaN for params [0.55910873 0.2692727  0.14388816 0.7583073  0.6547101 ], L=38.83883883883884, nx=10000
# Skipping invalid predicted key rate at index 194 for n_X = 10000
# Objective returned NaN for params [0.55900615 0.2691496  0.14368387 0.7577124  0.6542856 ], L=39.03903903903904, nx=10000
# Skipping invalid predicted key rate at index 195 for n_X = 10000
# Objective returned NaN for params [0.5589035  0.26902646 0.1434795  0.75711745 0.653861  ], L=39.23923923923924, nx=10000
# Skipping invalid predicted key rate at index 196 for n_X = 10000
# Objective returned NaN for params [0.5588009  0.26890334 0.14327525 0.7565225  0.6534365 ], L=39.43943943943944, nx=10000
# Skipping invalid predicted key rate at index 197 for n_X = 10000
# Objective returned NaN for params [0.55869824 0.26878023 0.14307092 0.7559277  0.6530121 ], L=39.63963963963964, nx=10000
# Skipping invalid predicted key rate at index 198 for n_X = 10000
# Objective returned NaN for params [0.5585957  0.26865712 0.14286661 0.75533277 0.6525875 ], L=39.83983983983984, nx=10000
# Skipping invalid predicted key rate at index 199 for n_X = 10000
# Objective returned NaN for params [0.5584931  0.26853397 0.14266232 0.7547379  0.65216297], L=40.04004004004004, nx=10000
# Skipping invalid predicted key rate at index 200 for n_X = 10000
# Objective returned NaN for params [0.55839044 0.2684109  0.14245802 0.75414294 0.65173846], L=40.24024024024024, nx=10000
# Skipping invalid predicted key rate at index 201 for n_X = 10000
# Objective returned NaN for params [0.5582878  0.26828778 0.14225373 0.75354815 0.65131396], L=40.44044044044044, nx=10000
# Skipping invalid predicted key rate at index 202 for n_X = 10000
# Objective returned NaN for params [0.5581852  0.26816463 0.14204948 0.7529531  0.6508894 ], L=40.64064064064064, nx=10000
# Skipping invalid predicted key rate at index 203 for n_X = 10000
# Objective returned NaN for params [0.55808264 0.26804155 0.14184512 0.7523583  0.65046495], L=40.84084084084084, nx=10000
# Skipping invalid predicted key rate at index 204 for n_X = 10000
# Objective returned NaN for params [0.55797994 0.26791844 0.14164084 0.75176346 0.6500404 ], L=41.04104104104104, nx=10000
# Skipping invalid predicted key rate at index 205 for n_X = 10000
# Objective returned NaN for params [0.55787736 0.26779532 0.14143653 0.7511685  0.6496159 ], L=41.24124124124124, nx=10000
# Skipping invalid predicted key rate at index 206 for n_X = 10000
# Objective returned NaN for params [0.5577747  0.2676722  0.1412323  0.75057364 0.6491914 ], L=41.44144144144144, nx=10000
# Skipping invalid predicted key rate at index 207 for n_X = 10000
# Objective returned NaN for params [0.55767214 0.2675491  0.14102794 0.74997866 0.64876676], L=41.64164164164164, nx=10000
# Skipping invalid predicted key rate at index 208 for n_X = 10000
# Objective returned NaN for params [0.5575695  0.26742595 0.1408237  0.7493838  0.6483424 ], L=41.84184184184184, nx=10000
# Skipping invalid predicted key rate at index 209 for n_X = 10000
# Objective returned NaN for params [0.5574669  0.26730287 0.14061937 0.74878883 0.64791775], L=42.04204204204204, nx=10000
# Skipping invalid predicted key rate at index 210 for n_X = 10000
# Objective returned NaN for params [0.5573643  0.26717976 0.1404151  0.7481941  0.64749324], L=42.24224224224224, nx=10000
# Skipping invalid predicted key rate at index 211 for n_X = 10000
# Objective returned NaN for params [0.5572617  0.2670566  0.14021076 0.7475991  0.64706886], L=42.44244244244244, nx=10000
# Skipping invalid predicted key rate at index 212 for n_X = 10000
# Objective returned NaN for params [0.5571591  0.2669335  0.1400065  0.7470043  0.64664423], L=42.64264264264264, nx=10000
# Skipping invalid predicted key rate at index 213 for n_X = 10000
# Objective returned NaN for params [0.5570565  0.26681042 0.13980219 0.7464094  0.64621973], L=42.84284284284285, nx=10000
# Skipping invalid predicted key rate at index 214 for n_X = 10000
# Objective returned NaN for params [0.55695385 0.26668727 0.13959788 0.74581444 0.6457952 ], L=43.04304304304305, nx=10000
# Skipping invalid predicted key rate at index 215 for n_X = 10000
# Objective returned NaN for params [0.5568512  0.26656416 0.13939357 0.7452196  0.6453707 ], L=43.24324324324325, nx=10000
# Skipping invalid predicted key rate at index 216 for n_X = 10000
# Objective returned NaN for params [0.5567486  0.26644105 0.13918927 0.7446247  0.6449461 ], L=43.44344344344345, nx=10000
# Skipping invalid predicted key rate at index 217 for n_X = 10000
# Objective returned NaN for params [0.55664605 0.26631793 0.13898502 0.7440298  0.6445216 ], L=43.64364364364365, nx=10000
# Skipping invalid predicted key rate at index 218 for n_X = 10000
# Objective returned NaN for params [0.5565434  0.26619482 0.13878068 0.74343485 0.6440971 ], L=43.84384384384385, nx=10000
# Skipping invalid predicted key rate at index 219 for n_X = 10000
# Objective returned NaN for params [0.5564408  0.26607174 0.13857637 0.74283993 0.6436726 ], L=44.04404404404405, nx=10000
# Skipping invalid predicted key rate at index 220 for n_X = 10000
# Objective returned NaN for params [0.5563382  0.26594856 0.1383721  0.7422451  0.6432481 ], L=44.24424424424425, nx=10000
# Skipping invalid predicted key rate at index 221 for n_X = 10000
# Objective returned NaN for params [0.55623555 0.26582548 0.13816778 0.74165016 0.6428236 ], L=44.44444444444445, nx=10000
# Skipping invalid predicted key rate at index 222 for n_X = 10000
# Objective returned NaN for params [0.5561329  0.26570237 0.1379635  0.7410553  0.6423991 ], L=44.64464464464465, nx=10000
# Skipping invalid predicted key rate at index 223 for n_X = 10000
# Objective returned NaN for params [0.55603033 0.26557925 0.13775918 0.74046046 0.6419745 ], L=44.84484484484485, nx=10000
# Skipping invalid predicted key rate at index 224 for n_X = 10000
# Objective returned NaN for params [0.5559277  0.26545614 0.13755491 0.7398655  0.64155   ], L=45.04504504504505, nx=10000
# Skipping invalid predicted key rate at index 225 for n_X = 10000
# Objective returned NaN for params [0.5558251  0.26533303 0.13735063 0.7392706  0.6411255 ], L=45.24524524524525, nx=10000
# Skipping invalid predicted key rate at index 226 for n_X = 10000
# Objective returned NaN for params [0.5557225  0.2652099  0.13714631 0.73867565 0.640701  ], L=45.44544544544545, nx=10000
# Skipping invalid predicted key rate at index 227 for n_X = 10000
# Objective returned NaN for params [0.55561984 0.2650868  0.13694203 0.7380808  0.6402765 ], L=45.64564564564565, nx=10000
# Skipping invalid predicted key rate at index 228 for n_X = 10000
# Objective returned NaN for params [0.55551726 0.26496366 0.13673766 0.73748595 0.639852  ], L=45.84584584584585, nx=10000
# Skipping invalid predicted key rate at index 229 for n_X = 10000
# Objective returned NaN for params [0.5554146  0.26484054 0.1365334  0.7368911  0.6394275 ], L=46.04604604604605, nx=10000
# Skipping invalid predicted key rate at index 230 for n_X = 10000
# Objective returned NaN for params [0.55531204 0.26471746 0.13632913 0.736296   0.63900286], L=46.24624624624625, nx=10000
# Skipping invalid predicted key rate at index 231 for n_X = 10000
# Objective returned NaN for params [0.5552094  0.26459435 0.13612483 0.73570126 0.63857836], L=46.44644644644645, nx=10000
# Skipping invalid predicted key rate at index 232 for n_X = 10000
# Objective returned NaN for params [0.55510676 0.2644712  0.13592052 0.7351063  0.63815385], L=46.64664664664665, nx=10000
# Skipping invalid predicted key rate at index 233 for n_X = 10000
# Objective returned NaN for params [0.5550042  0.26434812 0.1357162  0.7345115  0.63772935], L=46.84684684684685, nx=10000
# Skipping invalid predicted key rate at index 234 for n_X = 10000
# Objective returned NaN for params [0.5549016  0.264225   0.13551195 0.7339166  0.63730484], L=47.04704704704705, nx=10000
# Skipping invalid predicted key rate at index 235 for n_X = 10000
# Objective returned NaN for params [0.55479896 0.26410186 0.13530761 0.73332167 0.63688034], L=47.24724724724725, nx=10000
# Skipping invalid predicted key rate at index 236 for n_X = 10000
# Objective returned NaN for params [0.5546963  0.26397875 0.13510339 0.73272675 0.6364558 ], L=47.44744744744745, nx=10000
# Skipping invalid predicted key rate at index 237 for n_X = 10000
# Objective returned NaN for params [0.55459374 0.26385564 0.13489902 0.73213184 0.6360313 ], L=47.64764764764765, nx=10000
# Skipping invalid predicted key rate at index 238 for n_X = 10000
# Objective returned NaN for params [0.5544911  0.26373252 0.13469476 0.731537   0.63560677], L=47.84784784784785, nx=10000
# Skipping invalid predicted key rate at index 239 for n_X = 10000
# Objective returned NaN for params [0.5543885  0.2636094  0.13449045 0.730942   0.63518226], L=48.04804804804805, nx=10000
# Skipping invalid predicted key rate at index 240 for n_X = 10000
# Objective returned NaN for params [0.5542859  0.2634863  0.13428615 0.73034716 0.63475764], L=48.24824824824825, nx=10000
# Skipping invalid predicted key rate at index 241 for n_X = 10000
# Objective returned NaN for params [0.55418324 0.26336315 0.13408187 0.72975224 0.63433325], L=48.44844844844845, nx=10000
# Skipping invalid predicted key rate at index 242 for n_X = 10000
# Objective returned NaN for params [0.55408067 0.26324007 0.13387758 0.72915745 0.63390875], L=48.64864864864865, nx=10000
# Skipping invalid predicted key rate at index 243 for n_X = 10000
# Objective returned NaN for params [0.5539781  0.26311696 0.13367324 0.7285625  0.63348424], L=48.84884884884885, nx=10000
# Skipping invalid predicted key rate at index 244 for n_X = 10000
# Objective returned NaN for params [0.55387545 0.26299384 0.13346897 0.7279676  0.6330596 ], L=49.04904904904905, nx=10000
# Skipping invalid predicted key rate at index 245 for n_X = 10000
# Objective returned NaN for params [0.5537728  0.26287073 0.13326468 0.72737277 0.6326351 ], L=49.24924924924925, nx=10000
# Skipping invalid predicted key rate at index 246 for n_X = 10000
# Objective returned NaN for params [0.55367017 0.2627476  0.1330604  0.7267778  0.6322105 ], L=49.44944944944945, nx=10000
# Skipping invalid predicted key rate at index 247 for n_X = 10000
# Objective returned NaN for params [0.5535676  0.26262447 0.13285609 0.72618294 0.631786  ], L=49.64964964964965, nx=10000
# Skipping invalid predicted key rate at index 248 for n_X = 10000
# Objective returned NaN for params [0.553465   0.26250136 0.13265179 0.725588   0.6313616 ], L=49.84984984984985, nx=10000
# Skipping invalid predicted key rate at index 249 for n_X = 10000
# Objective returned NaN for params [0.55336237 0.26237828 0.13244747 0.72499317 0.6309371 ], L=50.050050050050054, nx=10000
# Skipping invalid predicted key rate at index 250 for n_X = 10000
# Objective returned NaN for params [0.55325973 0.26225516 0.13224317 0.72439826 0.6305125 ], L=50.250250250250254, nx=10000
# Skipping invalid predicted key rate at index 251 for n_X = 10000
# Objective returned NaN for params [0.5531571  0.26213202 0.13203883 0.72380334 0.630088  ], L=50.450450450450454, nx=10000
# Skipping invalid predicted key rate at index 252 for n_X = 10000
# Objective returned NaN for params [0.5530546  0.2620089  0.13183457 0.7232084  0.62966347], L=50.650650650650654, nx=10000
# Skipping invalid predicted key rate at index 253 for n_X = 10000
# Objective returned NaN for params [0.55295193 0.2618858  0.13163029 0.7226135  0.6292389 ], L=50.850850850850854, nx=10000
# Skipping invalid predicted key rate at index 254 for n_X = 10000
# Objective returned NaN for params [0.5528493  0.26176268 0.13142595 0.72201866 0.62881446], L=51.051051051051054, nx=10000
# Skipping invalid predicted key rate at index 255 for n_X = 10000
# Objective returned NaN for params [0.55274665 0.2616396  0.13122171 0.72142375 0.6283899 ], L=51.251251251251254, nx=10000
# ...
# Skipping invalid predicted key rate at index 868 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42432806 0.24821302 0.6302523  0.25632682 0.71331716], L=174.1741741741742, nx=1000000000
# Skipping invalid predicted key rate at index 870 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42404422 0.24710058 0.6325507  0.25366393 0.7125001 ], L=174.37437437437438, nx=1000000000
# Skipping invalid predicted key rate at index 871 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42347655 0.24487567 0.63714755 0.24833785 0.71086586], L=174.77477477477478, nx=1000000000
# Skipping invalid predicted key rate at index 873 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42309603 0.24235353 0.6423304  0.24321088 0.7074684 ], L=175.17517517517518, nx=1000000000
# Skipping invalid predicted key rate at index 875 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42316192 0.24068566 0.6457241  0.24091968 0.7033567 ], L=175.3753753753754, nx=1000000000
# Skipping invalid predicted key rate at index 876 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42329347 0.23734981 0.65251184 0.2363374  0.6951331 ], L=175.7757757757758, nx=1000000000
# Skipping invalid predicted key rate at index 878 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42335925 0.23568186 0.6559055  0.23404619 0.69102114], L=175.97597597597598, nx=1000000000
# Skipping invalid predicted key rate at index 879 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4234251  0.23401392 0.6592993  0.231755   0.6869094 ], L=176.1761761761762, nx=1000000000
# Skipping invalid predicted key rate at index 880 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42349088 0.23234612 0.6626929  0.22946383 0.68279773], L=176.37637637637638, nx=1000000000
# Skipping invalid predicted key rate at index 881 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4235567  0.23067813 0.66608673 0.22717269 0.67868584], L=176.5765765765766, nx=1000000000
# Skipping invalid predicted key rate at index 882 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42368832 0.2273423  0.67287403 0.22259031 0.67046213], L=176.976976976977, nx=1000000000
# Skipping invalid predicted key rate at index 884 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42375413 0.22567433 0.676268   0.22029911 0.66635036], L=177.17717717717719, nx=1000000000
# Skipping invalid predicted key rate at index 885 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42381996 0.22400643 0.6796617  0.21800788 0.66223854], L=177.3773773773774, nx=1000000000
# Skipping invalid predicted key rate at index 886 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42388576 0.22233857 0.6830554  0.21571681 0.65812695], L=177.57757757757759, nx=1000000000
# Skipping invalid predicted key rate at index 887 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4239516  0.22067071 0.6864491  0.21342559 0.6540151 ], L=177.7777777777778, nx=1000000000
# Skipping invalid predicted key rate at index 888 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42414898 0.21566689 0.69663036 0.20655204 0.64167964], L=178.3783783783784, nx=1000000000
# Skipping invalid predicted key rate at index 891 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42421478 0.213999   0.7000243  0.20426093 0.63756794], L=178.5785785785786, nx=1000000000
# Skipping invalid predicted key rate at index 892 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42434642 0.21066317 0.7068117  0.19967853 0.6293442 ], L=178.978978978979, nx=1000000000
# Skipping invalid predicted key rate at index 894 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42441222 0.20899524 0.7102055  0.19738737 0.62523246], L=179.1791791791792, nx=1000000000
# Skipping invalid predicted key rate at index 895 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42454386 0.20565939 0.71699303 0.19280502 0.61700886], L=179.5795795795796, nx=1000000000
# Skipping invalid predicted key rate at index 897 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42460966 0.2039915  0.7203867  0.19051386 0.61289704], L=179.7797797797798, nx=1000000000
# Skipping invalid predicted key rate at index 898 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4246755  0.20232357 0.7237806  0.18822266 0.6087853 ], L=179.97997997998, nx=1000000000
# Skipping invalid predicted key rate at index 899 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247413  0.20065565 0.7271742  0.18593149 0.6046734 ], L=180.1801801801802, nx=1000000000
# Skipping invalid predicted key rate at index 900 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42487288 0.19731985 0.73396176 0.18134913 0.59644985], L=180.5805805805806, nx=1000000000
# Skipping invalid predicted key rate at index 902 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4250045  0.19398405 0.7407492  0.17676683 0.5882263 ], L=180.980980980981, nx=1000000000
# Skipping invalid predicted key rate at index 904 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42506057 0.19221185 0.74425006 0.17435208 0.5838304 ], L=181.1811811811812, nx=1000000000
# Skipping invalid predicted key rate at index 905 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42505226 0.18975416 0.7484549  0.17112513 0.57756686], L=181.3813813813814, nx=1000000000
# Skipping invalid predicted key rate at index 906 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42504394 0.18729657 0.75265986 0.16789816 0.5713034 ], L=181.5815815815816, nx=1000000000
# Skipping invalid predicted key rate at index 907 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4250357  0.18483885 0.75686485 0.16467114 0.5650399 ], L=181.7817817817818, nx=1000000000
# Skipping invalid predicted key rate at index 908 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42501074 0.17746593 0.76947933 0.15499035 0.54624945], L=182.3823823823824, nx=1000000000
# Skipping invalid predicted key rate at index 911 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42500243 0.1750083  0.7736843  0.1517634  0.5399859 ], L=182.5825825825826, nx=1000000000
# Skipping invalid predicted key rate at index 912 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249941  0.17255056 0.7778893  0.14853637 0.5337222 ], L=182.7827827827828, nx=1000000000
# Skipping invalid predicted key rate at index 913 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42498586 0.17009293 0.7820943  0.14530943 0.52745885], L=182.982982982983, nx=1000000000
# Skipping invalid predicted key rate at index 914 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249775  0.16763523 0.7862991  0.14208242 0.5211951 ], L=183.1831831831832, nx=1000000000
# Skipping invalid predicted key rate at index 915 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42496923 0.16517763 0.790504   0.13885556 0.5149318 ], L=183.3833833833834, nx=1000000000
# Skipping invalid predicted key rate at index 916 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249609  0.16271996 0.7947089  0.13562857 0.50866824], L=183.5835835835836, nx=1000000000
# Skipping invalid predicted key rate at index 917 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42495263 0.16026233 0.7989138  0.1324016  0.5024048 ], L=183.7837837837838, nx=1000000000
# Skipping invalid predicted key rate at index 918 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42494434 0.15780464 0.8031189  0.1291746  0.4961412 ], L=183.983983983984, nx=1000000000
# Skipping invalid predicted key rate at index 919 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249361  0.1553471  0.8073235  0.12594767 0.4898779 ], L=184.1841841841842, nx=1000000000
# Skipping invalid predicted key rate at index 920 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42492774 0.15288928 0.8115286  0.12272064 0.48361412], L=184.3843843843844, nx=1000000000
# Skipping invalid predicted key rate at index 921 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42491943 0.15043166 0.8157335  0.11949372 0.47735065], L=184.5845845845846, nx=1000000000
# Skipping invalid predicted key rate at index 922 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249111  0.1479741  0.81993806 0.1162669  0.4710874 ], L=184.7847847847848, nx=1000000000
# Skipping invalid predicted key rate at index 923 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42490286 0.14551644 0.8241432  0.11303992 0.46482387], L=184.984984984985, nx=1000000000
# Skipping invalid predicted key rate at index 924 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42489454 0.1430587  0.82834804 0.10981283 0.4585601 ], L=185.1851851851852, nx=1000000000
# Skipping invalid predicted key rate at index 925 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42488623 0.14060108 0.832553   0.10658603 0.45229682], L=185.3853853853854, nx=1000000000
# Skipping invalid predicted key rate at index 926 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42486134 0.13322811 0.8451678  0.096905   0.4335061 ], L=185.985985985986, nx=1000000000
# Skipping invalid predicted key rate at index 929 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42485303 0.13077042 0.84937274 0.09367801 0.42724255], L=186.1861861861862, nx=1000000000
# Skipping invalid predicted key rate at index 930 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248447 0.1283128 0.8535776 0.0904512 0.4209792], L=186.3863863863864, nx=1000000000
# Skipping invalid predicted key rate at index 931 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42483646 0.12585516 0.85778254 0.08722422 0.41471565], L=186.5865865865866, nx=1000000000
# Skipping invalid predicted key rate at index 932 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42482814 0.12339745 0.8619875  0.08399716 0.40845206], L=186.7867867867868, nx=1000000000
# Skipping invalid predicted key rate at index 933 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42481983 0.12093987 0.86619234 0.08077025 0.40218863], L=186.986986986987, nx=1000000000
# Skipping invalid predicted key rate at index 934 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248115  0.11848215 0.8703974  0.07754324 0.395925  ], L=187.1871871871872, nx=1000000000
# Skipping invalid predicted key rate at index 935 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248032  0.11602443 0.87460226 0.07431623 0.38966134], L=187.3873873873874, nx=1000000000
# Skipping invalid predicted key rate at index 936 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42479494 0.11356685 0.8788072  0.0710893  0.38339794], L=187.5875875875876, nx=1000000000
# Skipping invalid predicted key rate at index 937 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42478657 0.11110919 0.8794155  0.0678624  0.37713453], L=187.7877877877878, nx=1000000000
# Skipping invalid predicted key rate at index 938 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42477828 0.10865156 0.8794155  0.06583714 0.37087104], L=187.987987987988, nx=1000000000
# Skipping invalid predicted key rate at index 939 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42477    0.10619384 0.8794155  0.06583714 0.36460736], L=188.1881881881882, nx=1000000000
# Skipping invalid predicted key rate at index 940 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42476165 0.10373626 0.8794155  0.06583714 0.3583441 ], L=188.3883883883884, nx=1000000000
# Skipping invalid predicted key rate at index 941 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247534  0.10127854 0.8794155  0.06583714 0.3520804 ], L=188.5885885885886, nx=1000000000
# Skipping invalid predicted key rate at index 942 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247451  0.09882088 0.8794155  0.06583714 0.34581697], L=188.7887887887888, nx=1000000000
# Skipping invalid predicted key rate at index 943 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42473683 0.09636326 0.8794155  0.06583714 0.33955342], L=188.988988988989, nx=1000000000
# Skipping invalid predicted key rate at index 944 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247285  0.09390559 0.8794155  0.06583714 0.33328998], L=189.1891891891892, nx=1000000000
# Skipping invalid predicted key rate at index 945 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42462733 0.09168331 0.8794155  0.06583714 0.32696563], L=189.3893893893894, nx=1000000000
# Skipping invalid predicted key rate at index 946 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4243841  0.08986846 0.8794155  0.06583714 0.320587  ], L=189.5895895895896, nx=1000000000
# Skipping invalid predicted key rate at index 947 for n_X = 1000000000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to parameter_relative_error_nx_1e+09.png
# --- Plotting Time: 1.21 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/326472314.py:43: UserWarning: linestyle is redundantly defined by the 'linestyle' keyword argument and the fmt string "b-" (-> linestyle='-'). The keyword argument will take precedence.
#   ax.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linestyle='-', linewidth=2.0, alpha=1.0)  # Thicker line, semi-transparent
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/326472314.py:70: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# Key rate subplots saved to keyrate_subplots_last_epoch.png
# Parameter subplots saved to parameters_subplots_last_epoch.png
# Model saved to bb84_nn_model.pth
# Epoch 5000/5000, Train Loss: 0.0002, Val Loss: 0.0002, Learning Rate: 0.000001, Time: 10.77s (Eval: 7.98s, Plot: 2.52s)
# --- Total Training Time: 1220.91 seconds ---
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/4242544360.py:90: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# %%
# Plotting the losses with smoothing
def moving_average(data, window_size=5):
    return np.convolve(data, np.ones(window_size)/window_size, mode='valid')

epochs = range(1, len(train_losses) + 1)
window_size = 5
smoothed_train_losses = moving_average(train_losses, window_size)
smoothed_val_losses = moving_average(val_losses, window_size)
smoothed_epochs = range(window_size, len(train_losses) + 1)

# %%
plt.figure(figsize=(12, 6))
# plt.plot(smoothed_epochs, smoothed_train_losses, label='Smoothed Training Loss', linestyle='-')
# plt.plot(smoothed_epochs, smoothed_val_losses, label='Smoothed Validation Loss', linestyle='--')
plt.plot(epochs, train_losses, label='Training Loss', linestyle='-', alpha=0.3)
plt.plot(epochs, val_losses, label='Validation Loss', linestyle='--', alpha=0.5)
plt.xlabel('Epochs')
plt.ylim(0, 0.002)
plt.ylabel('Loss')
plt.legend()
plt.title('Training and Validation Loss')
plt.grid(True)
plt.tight_layout()
plt.savefig('loss_plot.png', dpi=150)
plt.show()
# plt.close()

print("Training Complete")

# Plotting the learning rates
plt.figure(figsize=(12, 6))
plt.plot(epochs, learning_rates, label='Learning Rate', linestyle='-', color='tab:blue')
plt.xlabel('Epochs')
plt.ylabel('Learning Rate')
plt.legend()
plt.title('Learning Rate over Epochs')
plt.grid(True)
plt.tight_layout()
plt.savefig('learning_rate_plot.png', dpi=150)
plt.show()
# plt.close()
# Out:
# Training Complete
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/2391135169.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/2391135169.py:29: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
# %% [markdown]
# ### Test the Trained Model on n_X = 5e8 Dataset

# Load the saved model
model = BB84NN().to(device)
model.load_state_dict(torch.load('bb84_nn_model.pth'))
model.eval()
print("Loaded saved model for testing.")

# Evaluate the model on the n_X = 5e8 dataset
with torch.no_grad():
    predicted_params_scaled_un_seen = model(X_test_tensor_un_seen).cpu().numpy()
    predicted_params_scaled_un_seen = np.clip(predicted_params_scaled_un_seen, 0, 1)
    predicted_params_un_seen = y_scaler.inverse_transform(predicted_params_scaled_un_seen)
    print("Predicted parameters (mu_1, mu_2, P_mu_1, P_mu_2, P_X):")
    print(predicted_params_un_seen[:5])
    predicted_params_un_seen[:, 0] = np.maximum(predicted_params_un_seen[:, 0], 1e-6)
    predicted_params_un_seen[:, 1] = np.maximum(predicted_params_un_seen[:, 1], 1e-6)
    predicted_params_un_seen[:, 2] = np.clip(predicted_params_un_seen[:, 2], 0, 1)
    predicted_params_un_seen[:, 3] = np.clip(predicted_params_un_seen[:, 3], 0, 1)
    predicted_params_un_seen[:, 4] = np.clip(predicted_params_un_seen[:, 4], 0, 1)

    # Evaluate predicted key rates
    predicted_key_rates_un_seen = []
    valid_indices_pred = []
    for idx, (params, L) in enumerate(zip(predicted_params_un_seen, fiber_lengths_un_seen)):
        key_rate = safe_objective(params, L, target_nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                  epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, e_mis=5e-3, P_ap=0, n_event=1)
        if key_rate is None:
            print(f"Skipping invalid predicted key rate at index {idx} for n_X = {target_nx}")
            continue
        predicted_key_rates_un_seen.append(key_rate)
        valid_indices_pred.append(idx)
    predicted_key_rates_un_seen = np.array(predicted_key_rates_un_seen)

    # Further filter based on valid predicted key rates
    fiber_lengths_un_seen = fiber_lengths_un_seen[valid_indices_pred]
    optimized_key_rates_un_seen = optimized_key_rates_un_seen[valid_indices_pred]
    optimized_params_array_un_seen = optimized_params_array_un_seen[valid_indices_pred]
    predicted_params_un_seen = predicted_params_un_seen[valid_indices_pred]
    print(f"After filtering invalid key rates in predicted_key_rates_un_seen, {len(predicted_key_rates_un_seen)} data points remain for n_X = 5e8.")

# Debug: Check for NaN in optimized_key_rates_un_seen and predicted_key_rates_un_seen
print("Checking for NaN in optimized_key_rates_un_seen:")
print(f"Number of NaN values: {np.isnan(optimized_key_rates_un_seen).sum()}")
print("Checking for NaN in predicted_key_rates_un_seen:")
print(f"Number of NaN values: {np.isnan(predicted_key_rates_un_seen).sum()}")
# Out:
# Loaded saved model for testing.
# Predicted parameters (mu_1, mu_2, P_mu_1, P_mu_2, P_X):
# [[0.49388713 0.35793784 0.18170445 0.77275324 0.8624248 ]
#  [0.4926497  0.3574458  0.18171202 0.77275324 0.8628936 ]
#  [0.49141762 0.35697138 0.1817677  0.77275324 0.86311513]
#  [0.49019083 0.35651496 0.18187256 0.77275324 0.86308485]
#  [0.48896402 0.35605857 0.18197748 0.77275324 0.8630543 ]]
# Objective returned non-positive key rate (-1e+250) for params [0.49388713 0.35793784 0.18170445 0.77275324 0.8624248 ], L=0.0, nx=500000000
# Skipping invalid predicted key rate at index 0 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4926497  0.3574458  0.18171202 0.77275324 0.8628936 ], L=2.0202020202020203, nx=500000000
# Skipping invalid predicted key rate at index 1 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.49019083 0.35651496 0.18187256 0.77275324 0.86308485], L=6.0606060606060606, nx=500000000
# Skipping invalid predicted key rate at index 3 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48896402 0.35605857 0.18197748 0.77275324 0.8630543 ], L=8.080808080808081, nx=500000000
# Skipping invalid predicted key rate at index 4 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48405692 0.354233   0.18239693 0.7713463  0.8629324 ], L=16.161616161616163, nx=500000000
# Skipping invalid predicted key rate at index 8 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4816034  0.35332024 0.18260671 0.7690409  0.86287147], L=20.202020202020204, nx=500000000
# Skipping invalid predicted key rate at index 10 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48037663 0.35286382 0.18271156 0.7678883  0.8628409 ], L=22.222222222222225, nx=500000000
# Skipping invalid predicted key rate at index 11 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47925535 0.35223708 0.18282016 0.76679754 0.86271197], L=24.242424242424242, nx=500000000
# Skipping invalid predicted key rate at index 12 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47726876 0.35081744 0.18298963 0.76525253 0.86236143], L=28.282828282828284, nx=500000000
# Skipping invalid predicted key rate at index 14 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47641814 0.35004112 0.183042   0.7648858  0.86214954], L=30.303030303030305, nx=500000000
# Skipping invalid predicted key rate at index 15 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47627157 0.34972236 0.1831651  0.764822   0.8619703 ], L=32.323232323232325, nx=500000000
# Skipping invalid predicted key rate at index 16 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47643322 0.34960395 0.1833192  0.7648906  0.8618054 ], L=34.343434343434346, nx=500000000
# Skipping invalid predicted key rate at index 17 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47659492 0.34948558 0.18347324 0.7649593  0.8616402 ], L=36.36363636363637, nx=500000000
# Skipping invalid predicted key rate at index 18 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47675657 0.3493672  0.18362734 0.76502794 0.86147517], L=38.38383838383839, nx=500000000
# Skipping invalid predicted key rate at index 19 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47691828 0.3492488  0.18378146 0.76509666 0.8613102 ], L=40.40404040404041, nx=500000000
# Skipping invalid predicted key rate at index 20 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47707993 0.34913045 0.1839355  0.7651652  0.86114514], L=42.42424242424243, nx=500000000
# Skipping invalid predicted key rate at index 21 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47740322 0.34889367 0.1842437  0.7653026  0.8608151 ], L=46.46464646464647, nx=500000000
# Skipping invalid predicted key rate at index 23 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47756493 0.34877533 0.18439768 0.7653712  0.86065   ], L=48.484848484848484, nx=500000000
# Skipping invalid predicted key rate at index 24 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4778883  0.34853858 0.18470587 0.76550853 0.8603201 ], L=52.525252525252526, nx=500000000
# Skipping invalid predicted key rate at index 26 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47821164 0.34830177 0.18501396 0.76564586 0.8599899 ], L=56.56565656565657, nx=500000000
# Skipping invalid predicted key rate at index 28 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4783733 0.3481834 0.1851681 0.7657145 0.8598249], L=58.58585858585859, nx=500000000
# Skipping invalid predicted key rate at index 29 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.478535   0.348065   0.1853222  0.7657832  0.85965985], L=60.60606060606061, nx=500000000
# Skipping invalid predicted key rate at index 30 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47869664 0.34794664 0.18547626 0.76585186 0.8594948 ], L=62.62626262626263, nx=500000000
# Skipping invalid predicted key rate at index 31 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4788583  0.34782827 0.1856303  0.76592046 0.8593297 ], L=64.64646464646465, nx=500000000
# Skipping invalid predicted key rate at index 32 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47928056 0.34746164 0.18606432 0.76595217 0.8589441 ], L=68.68686868686869, nx=500000000
# Skipping invalid predicted key rate at index 34 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.47960782 0.3471259  0.18642923 0.765844   0.85868615], L=70.70707070707071, nx=500000000
# Skipping invalid predicted key rate at index 35 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48058966 0.34611863 0.18752393 0.76551944 0.8579125 ], L=76.76767676767678, nx=500000000
# Skipping invalid predicted key rate at index 38 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48091695 0.34578288 0.18788888 0.7654113  0.8576545 ], L=78.7878787878788, nx=500000000
# Skipping invalid predicted key rate at index 39 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48117986 0.34542847 0.18821129 0.76526904 0.85770553], L=80.80808080808082, nx=500000000
# Skipping invalid predicted key rate at index 40 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.481531   0.34481332 0.18955782 0.763728   0.8583595 ], L=84.84848484848486, nx=500000000
# Skipping invalid predicted key rate at index 42 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48169956 0.34450963 0.1902596  0.7629064  0.8587082 ], L=86.86868686868688, nx=500000000
# Skipping invalid predicted key rate at index 43 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48186812 0.34420595 0.1909615  0.7620847  0.85905737], L=88.8888888888889, nx=500000000
# Skipping invalid predicted key rate at index 44 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48203668 0.34390226 0.1916633  0.7612631  0.8594063 ], L=90.90909090909092, nx=500000000
# Skipping invalid predicted key rate at index 45 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48237377 0.34329486 0.19306697 0.7596198  0.8601042 ], L=94.94949494949496, nx=500000000
# Skipping invalid predicted key rate at index 47 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.483296   0.34251517 0.19462173 0.75675786 0.86032856], L=101.01010101010101, nx=500000000
# Skipping invalid predicted key rate at index 50 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48448035 0.34217513 0.19490513 0.7543071  0.8593534 ], L=105.05050505050505, nx=500000000
# Skipping invalid predicted key rate at index 52 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48507252 0.34200513 0.19504687 0.75308174 0.8588659 ], L=107.07070707070707, nx=500000000
# Skipping invalid predicted key rate at index 53 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48566467 0.3418351  0.19518854 0.7518564  0.85837847], L=109.0909090909091, nx=500000000
# Skipping invalid predicted key rate at index 54 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4862568  0.34166503 0.19533028 0.75063103 0.85789096], L=111.11111111111111, nx=500000000
# Skipping invalid predicted key rate at index 55 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.486849   0.34149498 0.19547199 0.7494056  0.8574034 ], L=113.13131313131314, nx=500000000
# Skipping invalid predicted key rate at index 56 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4874024  0.34141976 0.19645247 0.74779814 0.85731053], L=115.15151515151516, nx=500000000
# Skipping invalid predicted key rate at index 57 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4879312 0.3414046 0.1979657 0.745948  0.857468 ], L=117.17171717171718, nx=500000000
# Skipping invalid predicted key rate at index 58 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48846    0.3413895  0.19947894 0.74409777 0.8576256 ], L=119.1919191919192, nx=500000000
# Skipping invalid predicted key rate at index 59 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.49004638 0.34134418 0.20401867 0.7385473  0.8580984 ], L=125.25252525252526, nx=500000000
# Skipping invalid predicted key rate at index 62 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.49021122 0.34136507 0.2058125  0.7361344  0.8575513 ], L=127.27272727272728, nx=500000000
# Skipping invalid predicted key rate at index 63 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48973742 0.34144923 0.20809862 0.73273414 0.85576814], L=129.2929292929293, nx=500000000
# Skipping invalid predicted key rate at index 64 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48926368 0.34153348 0.21038483 0.729334   0.85398495], L=131.31313131313132, nx=500000000
# Skipping invalid predicted key rate at index 65 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48878986 0.3416177  0.212671   0.7259338  0.852202  ], L=133.33333333333334, nx=500000000
# Skipping invalid predicted key rate at index 66 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48784232 0.341786   0.21724342 0.7191333  0.84863573], L=137.37373737373738, nx=500000000
# Skipping invalid predicted key rate at index 68 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4874085  0.34184703 0.21955284 0.7158021  0.8469291 ], L=139.3939393939394, nx=500000000
# Skipping invalid predicted key rate at index 69 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48704457 0.34186748 0.22190295 0.71259147 0.8453561 ], L=141.41414141414143, nx=500000000
# Skipping invalid predicted key rate at index 70 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4866806  0.3418879  0.22425307 0.7093808  0.84378314], L=143.43434343434345, nx=500000000
# Skipping invalid predicted key rate at index 71 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48631665 0.34190828 0.22660318 0.7061702  0.84220994], L=145.45454545454547, nx=500000000
# Skipping invalid predicted key rate at index 72 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.48595273 0.34192875 0.22895335 0.7029596  0.84063697], L=147.4747474747475, nx=500000000
# Skipping invalid predicted key rate at index 73 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4851591  0.34209192 0.23170976 0.6977841  0.8391324 ], L=149.4949494949495, nx=500000000
# Skipping invalid predicted key rate at index 74 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4847249  0.34287867 0.23705384 0.689267   0.8369996 ], L=151.51515151515153, nx=500000000
# Skipping invalid predicted key rate at index 75 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.46059898 0.333075   0.30388162 0.58960795 0.791505  ], L=155.55555555555557, nx=500000000
# Skipping invalid predicted key rate at index 77 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.43823257 0.31955004 0.3837477  0.49093285 0.7525126 ], L=159.5959595959596, nx=500000000
# Skipping invalid predicted key rate at index 79 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.43431926 0.3131231  0.42398039 0.45367503 0.7387467 ], L=161.61616161616163, nx=500000000
# Skipping invalid predicted key rate at index 80 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.43040597 0.30669624 0.46421316 0.41641712 0.7249809 ], L=163.63636363636365, nx=500000000
# Skipping invalid predicted key rate at index 81 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.42861596 0.28585047 0.5213515  0.36049363 0.71198314], L=167.6767676767677, nx=500000000
# Skipping invalid predicted key rate at index 83 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4229185  0.25345156 0.59880334 0.27838644 0.690457  ], L=173.73737373737376, nx=500000000
# Skipping invalid predicted key rate at index 86 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4214828  0.22418101 0.65863645 0.22920707 0.63351816], L=177.7777777777778, nx=500000000
# Skipping invalid predicted key rate at index 88 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4221469  0.20735031 0.6928825  0.20608708 0.5920265 ], L=179.79797979797982, nx=500000000
# Skipping invalid predicted key rate at index 89 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.42227867 0.18484718 0.7329547  0.17624576 0.5350799 ], L=181.81818181818184, nx=500000000
# Skipping invalid predicted key rate at index 90 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4221949  0.1600471  0.77538615 0.14368267 0.47187528], L=183.83838383838386, nx=500000000
# Skipping invalid predicted key rate at index 91 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.4221111  0.13524719 0.8178173  0.11111985 0.4086709 ], L=185.85858585858588, nx=500000000
# Skipping invalid predicted key rate at index 92 for n_X = 500000000
# Objective returned non-positive key rate (-1e+250) for params [0.42202732 0.11044718 0.8602488  0.07855677 0.34546626], L=187.8787878787879, nx=500000000
# Skipping invalid predicted key rate at index 93 for n_X = 500000000
# After filtering invalid key rates in predicted_key_rates_un_seen, 26 data points remain for n_X = 5e8.
# Checking for NaN in optimized_key_rates_un_seen:
# Number of NaN values: 0
# Checking for NaN in predicted_key_rates_un_seen:
# Number of NaN values: 0

# %%
def plot_keyrate_and_parameters(fiber_lengths, optimized_key_rates, optimized_params_array, 
                                predicted_key_rates, predicted_params_array, epoch, filename, 
                                learning_rates=None, nx=None):
    """
    Plots key rates and parameters for a specific n_X value.
    
    Parameters:
    - fiber_lengths: Array of fiber lengths.
    - optimized_key_rates: Array of optimized key rates.
    - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - learning_rates: List of learning rates over epochs (optional, not used).
    - nx: The n_X value for the plot title (optional).
    """

    # Start timing
    plot_start_time = time.time()

    # Create a figure with 2 subplots: key rate (left), all parameters (right)
    fig = plt.figure(figsize=(15, 6))  # Adjusted height for horizontal layout

    # Define the grid layout: 1 row, 2 columns
    gs = fig.add_gridspec(1, 2, width_ratios=[1, 1])

    # Key Rate Plot (Left)
    ax_keyrate = fig.add_subplot(gs[0, 0])

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    threshold = 1e-8
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Plot key rates with distinct linestyles and increased thickness for predicted
    ax_keyrate.plot(fiber_lengths, np.log10(predicted_key_rates), 'r--', label='Predicted Key Rate', linewidth=4.0, alpha=0.7)
    ax_keyrate.plot(fiber_lengths, np.log10(optimized_key_rates), 'b-', label='Optimized Key Rate', linewidth=2.0, alpha=1.0)

    # Use scientific notation for nx in the title
    ax_keyrate.set_title(f"Key Rates for $n_X = 5 \\times 10^8$")  # Fixed title
    ax_keyrate.set_xlabel("Fiber Length (km)")
    ax_keyrate.set_ylabel("Secret Key Rate per Pulse")
    ax_keyrate.grid(True)
    ax_keyrate.legend(loc='upper right')

    # Parameter Plot (Right) - Combine probabilities and intensities
    ax_params = fig.add_subplot(gs[0, 1])

    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    colors = ['red', 'purple', 'orange', 'green', 'blue']
    param_indices = [0, 1, 2, 3, 4]  # Indices for mu_1, mu_2, P_mu_1, P_mu_2, P_X  

    # Plot all parameters
    for param_idx, (label, color) in zip(param_indices, zip(param_labels, colors)):
        ax_params.plot(fiber_lengths, predicted_params_array[:, param_idx], label=f'Predicted {label}', color=color, linestyle='--', linewidth=4.0, alpha=0.7)
        ax_params.plot(fiber_lengths, optimized_params_array[:, param_idx], label=f'Optimized {label}', color=color, linestyle='-', linewidth=2.0, alpha=1.0)
        
    # Use scientific notation for nx in the title
    ax_params.set_title(f"Parameters for $n_X = 5 \\times 10^8$")  # Fixed title
    ax_params.set_xlabel("Fiber Length (km)")
    ax_params.set_ylabel("Parameter Value")
    ax_params.set_ylim(0.0, 1.0)
    ax_params.grid(True)

    # Move legend outside the plot to avoid overlap
    ax_params.legend(loc='center left', bbox_to_anchor=(1, 0.5))

    # Adjust layout to prevent overlap
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches="tight")
    plt.show()
    plt.close(fig)
    print(f"Comparison plot saved to {filename}")

# %%
for nx in all_evaluation_data.keys():
    eval_data = all_evaluation_data[nx]
    fiber_lengths = eval_data['fiber_lengths']
    optimized_params_array = eval_data['optimized_params_array']
    optimized_key_rates = eval_data['optimized_key_rates']
    X_test_tensor = eval_data['X_test_tensor']

    with torch.no_grad():
        predicted_params_scaled = model(X_test_tensor).cpu().numpy()
        predicted_params_scaled = np.clip(predicted_params_scaled, 0, 1)
        predicted_params_array = y_scaler.inverse_transform(predicted_params_scaled)
        predicted_params_array[:, 0] = np.maximum(predicted_params_array[:, 0], 1e-6)
        predicted_params_array[:, 1] = np.maximum(predicted_params_array[:, 1], 1e-6)
        predicted_params_array[:, 2] = np.clip(predicted_params_array[:, 2], 0, 1)
        predicted_params_array[:, 3] = np.clip(predicted_params_array[:, 3], 0, 1)
        predicted_params_array[:, 4] = np.clip(predicted_params_array[:, 4], 0, 1)

        # Compute and filter predicted key rates
        predicted_key_rates = []
        valid_indices = []
        for idx, (params, L) in enumerate(zip(predicted_params_array, fiber_lengths)):
            key_rate = safe_objective(params, L, nx, alpha=0.2, eta_Bob=0.1, P_dc_value=6e-7, 
                                      epsilon_sec=1e-10, epsilon_cor=1e-15, f_EC=1.16, 
                                      e_mis=5e-3, P_ap=0, n_event=1)
            if key_rate is None:
                print(f"Skipping invalid predicted key rate at index {idx} for n_X = {nx}")
                continue
            predicted_key_rates.append(key_rate)
            valid_indices.append(idx)
        predicted_key_rates = np.array(predicted_key_rates)

        # Filter data based on valid predicted key rates
        fiber_lengths = fiber_lengths[valid_indices]
        optimized_key_rates = optimized_key_rates[valid_indices]
        optimized_params_array = optimized_params_array[valid_indices]
        predicted_params_array = predicted_params_array[valid_indices]

    # Plot relative errors for this n_X
    plot_start_time = time.time()
    plot_relative_errors(
        fiber_lengths, optimized_key_rates, optimized_params_array,
        predicted_key_rates, predicted_params_array, epoch='final_test',
        filename=f'relative_error_nx_{nx:.0e}.png', nx=nx
    )
    print(f"--- Final Test Plotting Time (relative_error_nx_{nx:.0e}): {time.time() - plot_start_time:.2f} seconds ---")
# Out:
# Objective returned non-positive key rate (-1e+250) for params [0.60711163 0.13833332 0.04560989 0.61332816 0.41392168], L=0.0, nx=10000
# Skipping invalid predicted key rate at index 0 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6070091  0.13828968 0.04560989 0.6132862  0.41391465], L=0.2002002002002002, nx=10000
# Skipping invalid predicted key rate at index 1 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60690296 0.1382514  0.04560989 0.61325735 0.4139326 ], L=0.4004004004004004, nx=10000
# Skipping invalid predicted key rate at index 2 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6067965  0.13821334 0.04560989 0.613229   0.4139515 ], L=0.6006006006006006, nx=10000
# Skipping invalid predicted key rate at index 3 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60669017 0.1381753  0.04560989 0.6132006  0.41397035], L=0.8008008008008008, nx=10000
# Skipping invalid predicted key rate at index 4 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60658383 0.13813722 0.04560989 0.6131722  0.4139892 ], L=1.001001001001001, nx=10000
# Skipping invalid predicted key rate at index 5 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60647744 0.13809913 0.04560989 0.6131438  0.41400802], L=1.2012012012012012, nx=10000
# Skipping invalid predicted key rate at index 6 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6063711  0.13806105 0.04560989 0.6131153  0.4140268 ], L=1.4014014014014016, nx=10000
# Skipping invalid predicted key rate at index 7 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6062647  0.13802299 0.04560989 0.6130869  0.4140455 ], L=1.6016016016016017, nx=10000
# Skipping invalid predicted key rate at index 8 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6061584  0.13798492 0.04560989 0.61305857 0.41406444], L=1.8018018018018018, nx=10000
# Skipping invalid predicted key rate at index 9 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60605204 0.13794686 0.04560989 0.6130301  0.4140833 ], L=2.002002002002002, nx=10000
# Skipping invalid predicted key rate at index 10 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60594565 0.13790879 0.04560989 0.6130017  0.41410208], L=2.2022022022022023, nx=10000
# Skipping invalid predicted key rate at index 11 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6058393  0.13787073 0.04560989 0.6129733  0.41412097], L=2.4024024024024024, nx=10000
# Skipping invalid predicted key rate at index 12 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.605733   0.13783266 0.04560989 0.61294484 0.41413975], L=2.6026026026026026, nx=10000
# Skipping invalid predicted key rate at index 13 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6056266  0.13779455 0.04560989 0.61291647 0.41415858], L=2.802802802802803, nx=10000
# Skipping invalid predicted key rate at index 14 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60552025 0.1377565  0.04560989 0.6128881  0.4141774 ], L=3.0030030030030033, nx=10000
# Skipping invalid predicted key rate at index 15 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6054139  0.13771842 0.04560989 0.6128596  0.41419616], L=3.2032032032032034, nx=10000
# Skipping invalid predicted key rate at index 16 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6053075  0.13768037 0.04560989 0.61283123 0.41421506], L=3.4034034034034035, nx=10000
# Skipping invalid predicted key rate at index 17 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6052012  0.1376423  0.04560989 0.6128028  0.41423386], L=3.6036036036036037, nx=10000
# Skipping invalid predicted key rate at index 18 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6050948  0.13760422 0.04560989 0.61277443 0.4142527 ], L=3.8038038038038042, nx=10000
# Skipping invalid predicted key rate at index 19 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60498846 0.13756613 0.04560989 0.612746   0.41427144], L=4.004004004004004, nx=10000
# Skipping invalid predicted key rate at index 20 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6048821  0.13752806 0.04560989 0.6127176  0.4142903 ], L=4.2042042042042045, nx=10000
# Skipping invalid predicted key rate at index 21 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60477567 0.13749002 0.04560989 0.61268914 0.41430914], L=4.404404404404405, nx=10000
# Skipping invalid predicted key rate at index 22 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60466933 0.13745196 0.04560989 0.61266077 0.414328  ], L=4.604604604604605, nx=10000
# Skipping invalid predicted key rate at index 23 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.604563   0.13741387 0.04560989 0.6126324  0.41434693], L=4.804804804804805, nx=10000
# Skipping invalid predicted key rate at index 24 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6044566  0.13737583 0.04560989 0.61260396 0.4143657 ], L=5.005005005005005, nx=10000
# Skipping invalid predicted key rate at index 25 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60435027 0.13733776 0.04560989 0.6125755  0.41438454], L=5.205205205205205, nx=10000
# Skipping invalid predicted key rate at index 26 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60424393 0.13729969 0.04560989 0.61254716 0.41440335], L=5.405405405405406, nx=10000
# Skipping invalid predicted key rate at index 27 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60413754 0.13726158 0.04560989 0.61251867 0.41442215], L=5.605605605605606, nx=10000
# Skipping invalid predicted key rate at index 28 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6040312  0.13722353 0.04560989 0.61249036 0.41444102], L=5.805805805805806, nx=10000
# Skipping invalid predicted key rate at index 29 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6039249  0.13718547 0.04560989 0.61246186 0.4144598 ], L=6.0060060060060065, nx=10000
# Skipping invalid predicted key rate at index 30 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6038185  0.13714737 0.04560989 0.61243343 0.41447866], L=6.206206206206207, nx=10000
# Skipping invalid predicted key rate at index 31 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6037121  0.13710931 0.04560989 0.61240506 0.41449744], L=6.406406406406407, nx=10000
# Skipping invalid predicted key rate at index 32 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60360575 0.13707124 0.04560989 0.6123767  0.41451633], L=6.606606606606607, nx=10000
# Skipping invalid predicted key rate at index 33 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6034994  0.13703316 0.04560989 0.61234826 0.41453505], L=6.806806806806807, nx=10000
# Skipping invalid predicted key rate at index 34 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6033931  0.13699509 0.04560989 0.6123199  0.41455394], L=7.007007007007007, nx=10000
# Skipping invalid predicted key rate at index 35 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6032867  0.13695703 0.04560989 0.6122915  0.41457286], L=7.207207207207207, nx=10000
# Skipping invalid predicted key rate at index 36 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60318035 0.13691893 0.04560989 0.61226296 0.41459152], L=7.407407407407407, nx=10000
# Skipping invalid predicted key rate at index 37 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60307395 0.13688087 0.04560989 0.61223465 0.41461042], L=7.6076076076076085, nx=10000
# Skipping invalid predicted key rate at index 38 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6029676  0.13684283 0.04560989 0.6122062  0.41462922], L=7.807807807807809, nx=10000
# Skipping invalid predicted key rate at index 39 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6028612  0.13680474 0.04560989 0.6121777  0.414648  ], L=8.008008008008009, nx=10000
# Skipping invalid predicted key rate at index 40 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6027549  0.13676669 0.04560989 0.61214936 0.41466683], L=8.208208208208209, nx=10000
# Skipping invalid predicted key rate at index 41 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6026485  0.1367286  0.04560989 0.612121   0.41468567], L=8.408408408408409, nx=10000
# Skipping invalid predicted key rate at index 42 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60254216 0.13669053 0.04560989 0.61209255 0.4147045 ], L=8.608608608608609, nx=10000
# Skipping invalid predicted key rate at index 43 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6024358  0.13665248 0.04560989 0.6120642  0.41472343], L=8.80880880880881, nx=10000
# Skipping invalid predicted key rate at index 44 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60232943 0.13661438 0.04560989 0.6120357  0.41474214], L=9.00900900900901, nx=10000
# Skipping invalid predicted key rate at index 45 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6022231  0.13657632 0.04560989 0.6120073  0.414761  ], L=9.20920920920921, nx=10000
# Skipping invalid predicted key rate at index 46 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6021167  0.13653827 0.04560989 0.6119789  0.41477984], L=9.40940940940941, nx=10000
# Skipping invalid predicted key rate at index 47 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60201037 0.1365002  0.04560989 0.6119505  0.41479862], L=9.60960960960961, nx=10000
# Skipping invalid predicted key rate at index 48 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60190403 0.1364621  0.04560989 0.6119221  0.41481745], L=9.80980980980981, nx=10000
# Skipping invalid predicted key rate at index 49 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60179764 0.13642405 0.04560989 0.6118937  0.41483632], L=10.01001001001001, nx=10000
# Skipping invalid predicted key rate at index 50 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6016913  0.13638596 0.04560989 0.6118653  0.4148551 ], L=10.21021021021021, nx=10000
# Skipping invalid predicted key rate at index 51 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.601585   0.1363479  0.04560989 0.61183685 0.41487402], L=10.41041041041041, nx=10000
# Skipping invalid predicted key rate at index 52 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6014785  0.13630982 0.04560989 0.6118085  0.4148928 ], L=10.61061061061061, nx=10000
# Skipping invalid predicted key rate at index 53 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60137224 0.13627174 0.04560989 0.61178005 0.41491157], L=10.810810810810812, nx=10000
# Skipping invalid predicted key rate at index 54 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60126585 0.13623369 0.04560989 0.6117517  0.41493046], L=11.011011011011012, nx=10000
# Skipping invalid predicted key rate at index 55 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60115945 0.13619563 0.04560989 0.6117232  0.41494924], L=11.211211211211213, nx=10000
# Skipping invalid predicted key rate at index 56 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6010531  0.13615759 0.04560989 0.6116949  0.4149682 ], L=11.411411411411413, nx=10000
# Skipping invalid predicted key rate at index 57 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6009472  0.13612089 0.04560989 0.61166435 0.4149672 ], L=11.611611611611613, nx=10000
# Skipping invalid predicted key rate at index 58 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60084176 0.13608585 0.04560989 0.6116315  0.41494367], L=11.811811811811813, nx=10000
# Skipping invalid predicted key rate at index 59 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60073626 0.1360508  0.04560989 0.6115987  0.41491994], L=12.012012012012013, nx=10000
# Skipping invalid predicted key rate at index 60 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60063076 0.13601579 0.04560989 0.6115658  0.41489625], L=12.212212212212213, nx=10000
# Skipping invalid predicted key rate at index 61 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6005254  0.13598074 0.04560989 0.611533   0.41487256], L=12.412412412412413, nx=10000
# Skipping invalid predicted key rate at index 62 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6004199  0.13594571 0.04560989 0.6115001  0.41484895], L=12.612612612612613, nx=10000
# Skipping invalid predicted key rate at index 63 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.60031444 0.13591069 0.04560989 0.61146724 0.41482535], L=12.812812812812814, nx=10000
# Skipping invalid predicted key rate at index 64 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.600209   0.13587561 0.04560989 0.6114344  0.41480166], L=13.013013013013014, nx=10000
# Skipping invalid predicted key rate at index 65 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.6001035  0.1358406  0.04560989 0.6114016  0.41477796], L=13.213213213213214, nx=10000
# Skipping invalid predicted key rate at index 66 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59999806 0.13580555 0.04560989 0.6113687  0.41475427], L=13.413413413413414, nx=10000
# Skipping invalid predicted key rate at index 67 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5998926  0.13577051 0.04560989 0.61133593 0.41473073], L=13.613613613613614, nx=10000
# Skipping invalid predicted key rate at index 68 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5997872  0.13573547 0.04560989 0.6113031  0.4147071 ], L=13.813813813813814, nx=10000
# Skipping invalid predicted key rate at index 69 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59968174 0.13570046 0.04560989 0.61127025 0.4146834 ], L=14.014014014014014, nx=10000
# Skipping invalid predicted key rate at index 70 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59957623 0.13566543 0.04560989 0.61123735 0.4146598 ], L=14.214214214214214, nx=10000
# Skipping invalid predicted key rate at index 71 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5994708  0.13563035 0.04560989 0.6112045  0.41463608], L=14.414414414414415, nx=10000
# Skipping invalid predicted key rate at index 72 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59936535 0.13559534 0.04560989 0.61117166 0.4146124 ], L=14.614614614614615, nx=10000
# Skipping invalid predicted key rate at index 73 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59925985 0.13556029 0.04560989 0.6111388  0.41458872], L=14.814814814814815, nx=10000
# Skipping invalid predicted key rate at index 74 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5991544  0.13552526 0.04560989 0.61110604 0.41456518], L=15.015015015015017, nx=10000
# Skipping invalid predicted key rate at index 75 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.599049   0.13549025 0.04560989 0.61107314 0.41454154], L=15.215215215215217, nx=10000
# Skipping invalid predicted key rate at index 76 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5989435  0.13545519 0.04560989 0.61104035 0.4145179 ], L=15.415415415415417, nx=10000
# Skipping invalid predicted key rate at index 77 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59883803 0.13542014 0.04560989 0.61100745 0.41449425], L=15.615615615615617, nx=10000
# Skipping invalid predicted key rate at index 78 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59873265 0.13538514 0.04560989 0.61097467 0.4144706 ], L=15.815815815815817, nx=10000
# Skipping invalid predicted key rate at index 79 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5986271  0.13535011 0.04560989 0.61094177 0.41444695], L=16.016016016016017, nx=10000
# Skipping invalid predicted key rate at index 80 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5985217  0.13531506 0.04560989 0.610909   0.41442332], L=16.216216216216218, nx=10000
# Skipping invalid predicted key rate at index 81 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59841627 0.13528001 0.04560989 0.61087614 0.41439956], L=16.416416416416418, nx=10000
# Skipping invalid predicted key rate at index 82 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5983107  0.13524497 0.04560989 0.61084324 0.414376  ], L=16.616616616616618, nx=10000
# Skipping invalid predicted key rate at index 83 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59820527 0.13520996 0.04560989 0.6108104  0.41435233], L=16.816816816816818, nx=10000
# Skipping invalid predicted key rate at index 84 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5980999  0.13517493 0.04560989 0.61077756 0.4143287 ], L=17.017017017017018, nx=10000
# Skipping invalid predicted key rate at index 85 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5979944  0.13513984 0.04560989 0.6107448  0.41430494], L=17.217217217217218, nx=10000
# Skipping invalid predicted key rate at index 86 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59788895 0.1351048  0.04560989 0.6107119  0.41428125], L=17.41741741741742, nx=10000
# Skipping invalid predicted key rate at index 87 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5977835  0.13506977 0.04560989 0.6106791  0.4142577 ], L=17.61761761761762, nx=10000
# Skipping invalid predicted key rate at index 88 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.597678   0.13503475 0.04560989 0.6106462  0.41423407], L=17.81781781781782, nx=10000
# Skipping invalid predicted key rate at index 89 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59757257 0.13499975 0.04560989 0.6106133  0.41421044], L=18.01801801801802, nx=10000
# Skipping invalid predicted key rate at index 90 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5974671  0.13496467 0.04560989 0.61058044 0.4141867 ], L=18.21821821821822, nx=10000
# Skipping invalid predicted key rate at index 91 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5973616  0.13492967 0.04560989 0.61054766 0.4141632 ], L=18.41841841841842, nx=10000
# Skipping invalid predicted key rate at index 92 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59725624 0.13489461 0.04560989 0.6105149  0.4141395 ], L=18.61861861861862, nx=10000
# Skipping invalid predicted key rate at index 93 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59715074 0.13485958 0.04560989 0.610482   0.41411582], L=18.81881881881882, nx=10000
# Skipping invalid predicted key rate at index 94 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59704524 0.13482454 0.04560989 0.61044914 0.41409212], L=19.01901901901902, nx=10000
# Skipping invalid predicted key rate at index 95 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59693986 0.1347895  0.04560989 0.6104163  0.41406846], L=19.21921921921922, nx=10000
# Skipping invalid predicted key rate at index 96 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59683436 0.1347545  0.04560989 0.6103835  0.41404492], L=19.41941941941942, nx=10000
# Skipping invalid predicted key rate at index 97 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5967289  0.13471943 0.04560989 0.6103506  0.4140212 ], L=19.61961961961962, nx=10000
# Skipping invalid predicted key rate at index 98 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5966235  0.1346844  0.04560989 0.61031777 0.4139976 ], L=19.81981981981982, nx=10000
# Skipping invalid predicted key rate at index 99 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.596518   0.13464935 0.04560989 0.61028486 0.41397384], L=20.02002002002002, nx=10000
# Skipping invalid predicted key rate at index 100 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59641254 0.1346143  0.04560989 0.6102521  0.41395026], L=20.22022022022022, nx=10000
# Skipping invalid predicted key rate at index 101 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5963071  0.13457929 0.04560989 0.61021924 0.41392657], L=20.42042042042042, nx=10000
# Skipping invalid predicted key rate at index 102 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5962016  0.13454427 0.04560989 0.6101864  0.41390303], L=20.62062062062062, nx=10000
# Skipping invalid predicted key rate at index 103 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59609616 0.13450922 0.04560989 0.61015356 0.41387933], L=20.82082082082082, nx=10000
# Skipping invalid predicted key rate at index 104 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5959907  0.13447416 0.04560989 0.61012065 0.41385558], L=21.02102102102102, nx=10000
# Skipping invalid predicted key rate at index 105 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5958852  0.13443917 0.04560989 0.6100879  0.41383207], L=21.22122122122122, nx=10000
# Skipping invalid predicted key rate at index 106 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5957798  0.13440411 0.04560989 0.61005497 0.41380835], L=21.421421421421424, nx=10000
# Skipping invalid predicted key rate at index 107 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59567434 0.13436906 0.04560989 0.6100222  0.41378468], L=21.621621621621625, nx=10000
# Skipping invalid predicted key rate at index 108 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59556884 0.13433403 0.04560989 0.6099893  0.413761  ], L=21.821821821821825, nx=10000
# Skipping invalid predicted key rate at index 109 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5954634  0.13429902 0.04560989 0.6099565  0.4137375 ], L=22.022022022022025, nx=10000
# Skipping invalid predicted key rate at index 110 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59535795 0.13426396 0.04560989 0.60992366 0.4137138 ], L=22.222222222222225, nx=10000
# Skipping invalid predicted key rate at index 111 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5952525  0.13422891 0.04560989 0.6098908  0.41369012], L=22.422422422422425, nx=10000
# Skipping invalid predicted key rate at index 112 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5951471  0.13419387 0.04560989 0.60985804 0.4136665 ], L=22.622622622622625, nx=10000
# Skipping invalid predicted key rate at index 113 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5950416  0.13415886 0.04560989 0.6098251  0.41364273], L=22.822822822822825, nx=10000
# Skipping invalid predicted key rate at index 114 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59493613 0.13412382 0.04560989 0.6097923  0.41361913], L=23.023023023023026, nx=10000
# Skipping invalid predicted key rate at index 115 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59483063 0.13408878 0.04560989 0.6097594  0.4135955 ], L=23.223223223223226, nx=10000
# Skipping invalid predicted key rate at index 116 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5947252  0.13405375 0.04560989 0.60972655 0.4135718 ], L=23.423423423423426, nx=10000
# Skipping invalid predicted key rate at index 117 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59461975 0.13401872 0.04560989 0.60969377 0.4135482 ], L=23.623623623623626, nx=10000
# Skipping invalid predicted key rate at index 118 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5945143  0.13398367 0.04560989 0.60966086 0.41352457], L=23.823823823823826, nx=10000
# Skipping invalid predicted key rate at index 119 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5944088  0.13394865 0.04560989 0.609628   0.41350088], L=24.024024024024026, nx=10000
# Skipping invalid predicted key rate at index 120 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59430337 0.13391359 0.04560989 0.60959524 0.41347724], L=24.224224224224226, nx=10000
# Skipping invalid predicted key rate at index 121 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5941979  0.13387856 0.04560989 0.60956234 0.4134537 ], L=24.424424424424426, nx=10000
# Skipping invalid predicted key rate at index 122 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5940924  0.13384353 0.04560989 0.6095295  0.41343004], L=24.624624624624627, nx=10000
# Skipping invalid predicted key rate at index 123 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.593987   0.13380852 0.04560989 0.60949665 0.41340634], L=24.824824824824827, nx=10000
# Skipping invalid predicted key rate at index 124 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59388155 0.13377345 0.04560989 0.6094638  0.4133827 ], L=25.025025025025027, nx=10000
# Skipping invalid predicted key rate at index 125 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5937761  0.13373843 0.04560989 0.609431   0.41335902], L=25.225225225225227, nx=10000
# Skipping invalid predicted key rate at index 126 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59367067 0.13370337 0.04560989 0.6093982  0.41333532], L=25.425425425425427, nx=10000
# Skipping invalid predicted key rate at index 127 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59356517 0.13366833 0.04560989 0.60936534 0.4133117 ], L=25.625625625625627, nx=10000
# Skipping invalid predicted key rate at index 128 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5934597  0.1336333  0.04560989 0.60933244 0.41328803], L=25.825825825825827, nx=10000
# Skipping invalid predicted key rate at index 129 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5933543  0.13359827 0.04560989 0.6092996  0.41326445], L=26.026026026026027, nx=10000
# Skipping invalid predicted key rate at index 130 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5932488  0.13356325 0.04560989 0.60926676 0.4132408 ], L=26.226226226226228, nx=10000
# Skipping invalid predicted key rate at index 131 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59314334 0.1335282  0.04560989 0.6092339  0.4132171 ], L=26.426426426426428, nx=10000
# Skipping invalid predicted key rate at index 132 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5930379  0.13349317 0.04560989 0.6092011  0.41319346], L=26.626626626626628, nx=10000
# Skipping invalid predicted key rate at index 133 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5929324  0.13345814 0.04560989 0.6091682  0.41316977], L=26.826826826826828, nx=10000
# Skipping invalid predicted key rate at index 134 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59282696 0.13342309 0.04560989 0.6091353  0.4131461 ], L=27.027027027027028, nx=10000
# Skipping invalid predicted key rate at index 135 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5927215  0.13338804 0.04560989 0.60910255 0.41312248], L=27.227227227227228, nx=10000
# Skipping invalid predicted key rate at index 136 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.592616   0.13335302 0.04560989 0.60906976 0.41309887], L=27.42742742742743, nx=10000
# Skipping invalid predicted key rate at index 137 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5925106  0.133318   0.04560989 0.60903686 0.4130753 ], L=27.62762762762763, nx=10000
# Skipping invalid predicted key rate at index 138 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59240514 0.13328296 0.04560989 0.609004   0.4130516 ], L=27.82782782782783, nx=10000
# Skipping invalid predicted key rate at index 139 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5922997  0.13324788 0.04560989 0.6089712  0.41302785], L=28.02802802802803, nx=10000
# Skipping invalid predicted key rate at index 140 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59219426 0.13321286 0.04560989 0.60893834 0.41300425], L=28.22822822822823, nx=10000
# Skipping invalid predicted key rate at index 141 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5920888  0.13317782 0.04560989 0.60890543 0.41298056], L=28.42842842842843, nx=10000
# Skipping invalid predicted key rate at index 142 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59198326 0.13314281 0.04560989 0.6088726  0.41295692], L=28.62862862862863, nx=10000
# Skipping invalid predicted key rate at index 143 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5918779  0.13310775 0.04560989 0.60883975 0.41293323], L=28.82882882882883, nx=10000
# Skipping invalid predicted key rate at index 144 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59177244 0.13307273 0.04560989 0.60880697 0.4129097 ], L=29.02902902902903, nx=10000
# Skipping invalid predicted key rate at index 145 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59166694 0.13303767 0.04560989 0.6087741  0.412886  ], L=29.22922922922923, nx=10000
# Skipping invalid predicted key rate at index 146 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5915615  0.13300264 0.04560989 0.6087413  0.41286236], L=29.42942942942943, nx=10000
# Skipping invalid predicted key rate at index 147 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59145606 0.13296762 0.04560989 0.60870844 0.4128387 ], L=29.62962962962963, nx=10000
# Skipping invalid predicted key rate at index 148 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59135056 0.13293257 0.04560989 0.60867554 0.412815  ], L=29.82982982982983, nx=10000
# Skipping invalid predicted key rate at index 149 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5912451  0.13289754 0.04560989 0.6086427  0.4127913 ], L=30.030030030030034, nx=10000
# Skipping invalid predicted key rate at index 150 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5911396  0.13286251 0.04560989 0.60860986 0.41276777], L=30.230230230230234, nx=10000
# Skipping invalid predicted key rate at index 151 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59103423 0.13282746 0.04560989 0.6085771  0.4127442 ], L=30.430430430430434, nx=10000
# Skipping invalid predicted key rate at index 152 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5909288  0.13279244 0.04560989 0.6085442  0.4127205 ], L=30.630630630630634, nx=10000
# Skipping invalid predicted key rate at index 153 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59082323 0.13275738 0.04560989 0.6085113  0.41269675], L=30.830830830830834, nx=10000
# Skipping invalid predicted key rate at index 154 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5907178  0.13272236 0.04560989 0.60847855 0.41267315], L=31.031031031031034, nx=10000
# Skipping invalid predicted key rate at index 155 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5906124  0.13268733 0.04560989 0.6084457  0.41264957], L=31.231231231231234, nx=10000
# Skipping invalid predicted key rate at index 156 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5905069  0.13265227 0.04560989 0.6084128  0.41262582], L=31.431431431431434, nx=10000
# Skipping invalid predicted key rate at index 157 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5904015  0.13261724 0.04560989 0.60837996 0.4126022 ], L=31.631631631631635, nx=10000
# Skipping invalid predicted key rate at index 158 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59029603 0.13258222 0.04560989 0.6083472  0.41257858], L=31.831831831831835, nx=10000
# Skipping invalid predicted key rate at index 159 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.59019053 0.13254716 0.04560989 0.6083143  0.4125549 ], L=32.032032032032035, nx=10000
# Skipping invalid predicted key rate at index 160 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5900851  0.13251215 0.04560989 0.6082815  0.41253123], L=32.232232232232235, nx=10000
# Skipping invalid predicted key rate at index 161 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58997965 0.13247709 0.04560989 0.6082486  0.41250753], L=32.432432432432435, nx=10000
# Skipping invalid predicted key rate at index 162 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58987415 0.13244209 0.04560989 0.6082158  0.412484  ], L=32.632632632632635, nx=10000
# Skipping invalid predicted key rate at index 163 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5897687  0.13240705 0.04560989 0.6081829  0.41246036], L=32.832832832832835, nx=10000
# Skipping invalid predicted key rate at index 164 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58966327 0.13237199 0.04560989 0.6081501  0.4124366 ], L=33.033033033033036, nx=10000
# Skipping invalid predicted key rate at index 165 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58955777 0.13233697 0.04560989 0.6081173  0.41241303], L=33.233233233233236, nx=10000
# Skipping invalid predicted key rate at index 166 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5894523  0.13230191 0.04560989 0.60808444 0.41238943], L=33.433433433433436, nx=10000
# Skipping invalid predicted key rate at index 167 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5893469  0.13226688 0.04560989 0.60805154 0.41236573], L=33.633633633633636, nx=10000
# Skipping invalid predicted key rate at index 168 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5892414  0.13223186 0.04560989 0.6080187  0.412342  ], L=33.833833833833836, nx=10000
# Skipping invalid predicted key rate at index 169 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.589136   0.13219681 0.04560989 0.6079859  0.41231844], L=34.034034034034036, nx=10000
# Skipping invalid predicted key rate at index 170 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5890305  0.1321618  0.04560989 0.607953   0.41229478], L=34.234234234234236, nx=10000
# Skipping invalid predicted key rate at index 171 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58892506 0.13212675 0.04560989 0.6079202  0.41227105], L=34.434434434434436, nx=10000
# Skipping invalid predicted key rate at index 172 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5888196  0.1320917  0.04560989 0.6078874  0.41224745], L=34.63463463463464, nx=10000
# Skipping invalid predicted key rate at index 173 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5887141  0.13205667 0.04560989 0.6078544  0.4122237 ], L=34.83483483483484, nx=10000
# Skipping invalid predicted key rate at index 174 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5886087  0.13202162 0.04560989 0.60782164 0.41220006], L=35.03503503503504, nx=10000
# Skipping invalid predicted key rate at index 175 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58850324 0.13198659 0.04560989 0.60778886 0.41217664], L=35.23523523523524, nx=10000
# Skipping invalid predicted key rate at index 176 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58839774 0.13195157 0.04560989 0.60775596 0.41215283], L=35.43543543543544, nx=10000
# Skipping invalid predicted key rate at index 177 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5882923  0.13191654 0.04560989 0.6077231  0.4121292 ], L=35.63563563563564, nx=10000
# Skipping invalid predicted key rate at index 178 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58818686 0.13188149 0.04560989 0.6076903  0.41210547], L=35.83583583583584, nx=10000
# Skipping invalid predicted key rate at index 179 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58808136 0.13184643 0.04560989 0.6076575  0.41208184], L=36.03603603603604, nx=10000
# Skipping invalid predicted key rate at index 180 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5879759  0.1318114  0.04560989 0.6076246  0.41205814], L=36.23623623623624, nx=10000
# Skipping invalid predicted key rate at index 181 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5878705  0.13177638 0.04562391 0.6075917  0.41203457], L=36.43643643643644, nx=10000
# Skipping invalid predicted key rate at index 182 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58776504 0.13174134 0.04564078 0.60755885 0.41201097], L=36.63663663663664, nx=10000
# Skipping invalid predicted key rate at index 183 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5876596  0.13170628 0.04565758 0.6075261  0.41198727], L=36.83683683683684, nx=10000
# Skipping invalid predicted key rate at index 184 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58759075 0.13169509 0.04567811 0.607509   0.4119654 ], L=37.03703703703704, nx=10000
# Skipping invalid predicted key rate at index 185 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58757526 0.13171855 0.04570399 0.6075148  0.41194588], L=37.23723723723724, nx=10000
# Skipping invalid predicted key rate at index 186 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5875598  0.13174199 0.0457299  0.6075207  0.41192633], L=37.43743743743744, nx=10000
# Skipping invalid predicted key rate at index 187 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58754426 0.13176541 0.0457558  0.6075265  0.41190675], L=37.63763763763764, nx=10000
# Skipping invalid predicted key rate at index 188 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58752877 0.13178886 0.04578167 0.6075323  0.4118873 ], L=37.83783783783784, nx=10000
# Skipping invalid predicted key rate at index 189 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58751327 0.13181232 0.04580757 0.6075382  0.41186777], L=38.03803803803804, nx=10000
# Skipping invalid predicted key rate at index 190 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5874978  0.13183576 0.04583349 0.60754395 0.4118483 ], L=38.23823823823824, nx=10000
# Skipping invalid predicted key rate at index 191 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58748233 0.13185921 0.04585942 0.60754985 0.41182873], L=38.43843843843844, nx=10000
# Skipping invalid predicted key rate at index 192 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5874668  0.13188262 0.04588525 0.6075556  0.41180924], L=38.63863863863864, nx=10000
# Skipping invalid predicted key rate at index 193 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5874513  0.1319061  0.04591115 0.6075616  0.41178986], L=38.83883883883884, nx=10000
# Skipping invalid predicted key rate at index 194 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58743584 0.13192953 0.04593704 0.6075674  0.41177025], L=39.03903903903904, nx=10000
# Skipping invalid predicted key rate at index 195 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58742034 0.13195299 0.04596293 0.6075733  0.4117508 ], L=39.23923923923924, nx=10000
# Skipping invalid predicted key rate at index 196 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5874048  0.13197641 0.04598881 0.60757905 0.4117313 ], L=39.43943943943944, nx=10000
# Skipping invalid predicted key rate at index 197 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58738935 0.13199985 0.04601469 0.60758495 0.4117118 ], L=39.63963963963964, nx=10000
# Skipping invalid predicted key rate at index 198 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5873738  0.1320233  0.04604057 0.60759073 0.4116923 ], L=39.83983983983984, nx=10000
# Skipping invalid predicted key rate at index 199 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5873583  0.13204674 0.04606647 0.6075966  0.41167277], L=40.04004004004004, nx=10000
# Skipping invalid predicted key rate at index 200 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5873428  0.1320702  0.04609237 0.6076024  0.41165325], L=40.24024024024024, nx=10000
# Skipping invalid predicted key rate at index 201 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5873273  0.1320936  0.0461182  0.60760826 0.41163373], L=40.44044044044044, nx=10000
# Skipping invalid predicted key rate at index 202 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58728087 0.13216394 0.04619589 0.60762584 0.4115753 ], L=41.04104104104104, nx=10000
# Skipping invalid predicted key rate at index 205 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5872498  0.13221084 0.04624776 0.6076374  0.41153616], L=41.44144144144144, nx=10000
# Skipping invalid predicted key rate at index 207 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5872344  0.13223428 0.04627359 0.60764325 0.41151667], L=41.64164164164164, nx=10000
# Skipping invalid predicted key rate at index 208 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5872188  0.13225771 0.04629949 0.60764915 0.41149724], L=41.84184184184184, nx=10000
# Skipping invalid predicted key rate at index 209 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5872033  0.13228115 0.04632534 0.60765505 0.4114777 ], L=42.04204204204204, nx=10000
# Skipping invalid predicted key rate at index 210 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5871879  0.1323046  0.04635127 0.60766083 0.4114582 ], L=42.24224224224224, nx=10000
# Skipping invalid predicted key rate at index 211 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5871723  0.13232805 0.04637717 0.6076666  0.4114387 ], L=42.44244244244244, nx=10000
# Skipping invalid predicted key rate at index 212 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5871569  0.1323515  0.04640305 0.6076725  0.41141924], L=42.64264264264264, nx=10000
# Skipping invalid predicted key rate at index 213 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5871414  0.13237491 0.04642887 0.60767835 0.4113997 ], L=42.84284284284285, nx=10000
# Skipping invalid predicted key rate at index 214 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58712584 0.1323984  0.04645487 0.60768414 0.41138014], L=43.04304304304305, nx=10000
# Skipping invalid predicted key rate at index 215 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5871104  0.13242182 0.0464807  0.60769004 0.4113607 ], L=43.24324324324325, nx=10000
# Skipping invalid predicted key rate at index 216 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5870949  0.13244526 0.04650661 0.6076959  0.41134116], L=43.44344344344345, nx=10000
# Skipping invalid predicted key rate at index 217 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5870794  0.1324687  0.04653249 0.6077017  0.4113217 ], L=43.64364364364365, nx=10000
# Skipping invalid predicted key rate at index 218 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5870639  0.13249215 0.0465584  0.60770756 0.41130218], L=43.84384384384385, nx=10000
# Skipping invalid predicted key rate at index 219 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58704835 0.13251558 0.04658425 0.60771334 0.4112827 ], L=44.04404404404405, nx=10000
# Skipping invalid predicted key rate at index 220 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5870329  0.132539   0.04661015 0.60771924 0.41126308], L=44.24424424424425, nx=10000
# Skipping invalid predicted key rate at index 221 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.58700186 0.13258593 0.04666195 0.60773087 0.4112242 ], L=44.64464464464465, nx=10000
# Skipping invalid predicted key rate at index 223 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5869864  0.13260935 0.04668781 0.6077367  0.4112046 ], L=44.84484484484485, nx=10000
# Skipping invalid predicted key rate at index 224 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5869709  0.13263279 0.04671372 0.60774255 0.41118512], L=45.04504504504505, nx=10000
# Skipping invalid predicted key rate at index 225 for n_X = 10000
# Objective returned non-positive key rate (-1e+250) for params [0.5869554  0.13265623 0.04673962 0.60774845 0.4111656 ], L=45.24524524524525, nx=10000
# Skipping invalid predicted key rate at index 226 for n_X = 10000
# ...
# Skipping invalid predicted key rate at index 861 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42603096 0.25488776 0.6164618  0.2723048  0.71821994], L=172.972972972973, nx=1000000000
# Skipping invalid predicted key rate at index 864 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42574713 0.25377524 0.6187603  0.26964185 0.71740276], L=173.17317317317318, nx=1000000000
# Skipping invalid predicted key rate at index 865 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4254633  0.25266284 0.62105864 0.2669789  0.7165857 ], L=173.3733733733734, nx=1000000000
# Skipping invalid predicted key rate at index 866 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4251795  0.25155044 0.62335694 0.264316   0.71576864], L=173.57357357357358, nx=1000000000
# Skipping invalid predicted key rate at index 867 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42489567 0.25043795 0.62565535 0.26165286 0.7149514 ], L=173.7737737737738, nx=1000000000
# Skipping invalid predicted key rate at index 868 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42432806 0.24821302 0.6302523  0.25632682 0.71331716], L=174.1741741741742, nx=1000000000
# Skipping invalid predicted key rate at index 870 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42404422 0.24710058 0.6325507  0.25366393 0.7125001 ], L=174.37437437437438, nx=1000000000
# Skipping invalid predicted key rate at index 871 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42347655 0.24487567 0.63714755 0.24833785 0.71086586], L=174.77477477477478, nx=1000000000
# Skipping invalid predicted key rate at index 873 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42309603 0.24235353 0.6423304  0.24321088 0.7074684 ], L=175.17517517517518, nx=1000000000
# Skipping invalid predicted key rate at index 875 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42316192 0.24068566 0.6457241  0.24091968 0.7033567 ], L=175.3753753753754, nx=1000000000
# Skipping invalid predicted key rate at index 876 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42329347 0.23734981 0.65251184 0.2363374  0.6951331 ], L=175.7757757757758, nx=1000000000
# Skipping invalid predicted key rate at index 878 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42335925 0.23568186 0.6559055  0.23404619 0.69102114], L=175.97597597597598, nx=1000000000
# Skipping invalid predicted key rate at index 879 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4234251  0.23401392 0.6592993  0.231755   0.6869094 ], L=176.1761761761762, nx=1000000000
# Skipping invalid predicted key rate at index 880 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42349088 0.23234612 0.6626929  0.22946383 0.68279773], L=176.37637637637638, nx=1000000000
# Skipping invalid predicted key rate at index 881 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4235567  0.23067813 0.66608673 0.22717269 0.67868584], L=176.5765765765766, nx=1000000000
# Skipping invalid predicted key rate at index 882 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42368832 0.2273423  0.67287403 0.22259031 0.67046213], L=176.976976976977, nx=1000000000
# Skipping invalid predicted key rate at index 884 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42375413 0.22567433 0.676268   0.22029911 0.66635036], L=177.17717717717719, nx=1000000000
# Skipping invalid predicted key rate at index 885 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42381996 0.22400643 0.6796617  0.21800788 0.66223854], L=177.3773773773774, nx=1000000000
# Skipping invalid predicted key rate at index 886 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42388576 0.22233857 0.6830554  0.21571681 0.65812695], L=177.57757757757759, nx=1000000000
# Skipping invalid predicted key rate at index 887 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4239516  0.22067071 0.6864491  0.21342559 0.6540151 ], L=177.7777777777778, nx=1000000000
# Skipping invalid predicted key rate at index 888 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42414898 0.21566689 0.69663036 0.20655204 0.64167964], L=178.3783783783784, nx=1000000000
# Skipping invalid predicted key rate at index 891 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42421478 0.213999   0.7000243  0.20426093 0.63756794], L=178.5785785785786, nx=1000000000
# Skipping invalid predicted key rate at index 892 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42434642 0.21066317 0.7068117  0.19967853 0.6293442 ], L=178.978978978979, nx=1000000000
# Skipping invalid predicted key rate at index 894 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42441222 0.20899524 0.7102055  0.19738737 0.62523246], L=179.1791791791792, nx=1000000000
# Skipping invalid predicted key rate at index 895 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42454386 0.20565939 0.71699303 0.19280502 0.61700886], L=179.5795795795796, nx=1000000000
# Skipping invalid predicted key rate at index 897 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42460966 0.2039915  0.7203867  0.19051386 0.61289704], L=179.7797797797798, nx=1000000000
# Skipping invalid predicted key rate at index 898 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4246755  0.20232357 0.7237806  0.18822266 0.6087853 ], L=179.97997997998, nx=1000000000
# Skipping invalid predicted key rate at index 899 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247413  0.20065565 0.7271742  0.18593149 0.6046734 ], L=180.1801801801802, nx=1000000000
# Skipping invalid predicted key rate at index 900 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42487288 0.19731985 0.73396176 0.18134913 0.59644985], L=180.5805805805806, nx=1000000000
# Skipping invalid predicted key rate at index 902 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4250045  0.19398405 0.7407492  0.17676683 0.5882263 ], L=180.980980980981, nx=1000000000
# Skipping invalid predicted key rate at index 904 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42506057 0.19221185 0.74425006 0.17435208 0.5838304 ], L=181.1811811811812, nx=1000000000
# Skipping invalid predicted key rate at index 905 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42505226 0.18975416 0.7484549  0.17112513 0.57756686], L=181.3813813813814, nx=1000000000
# Skipping invalid predicted key rate at index 906 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42504394 0.18729657 0.75265986 0.16789816 0.5713034 ], L=181.5815815815816, nx=1000000000
# Skipping invalid predicted key rate at index 907 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4250357  0.18483885 0.75686485 0.16467114 0.5650399 ], L=181.7817817817818, nx=1000000000
# Skipping invalid predicted key rate at index 908 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42501074 0.17746593 0.76947933 0.15499035 0.54624945], L=182.3823823823824, nx=1000000000
# Skipping invalid predicted key rate at index 911 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42500243 0.1750083  0.7736843  0.1517634  0.5399859 ], L=182.5825825825826, nx=1000000000
# Skipping invalid predicted key rate at index 912 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249941  0.17255056 0.7778893  0.14853637 0.5337222 ], L=182.7827827827828, nx=1000000000
# Skipping invalid predicted key rate at index 913 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42498586 0.17009293 0.7820943  0.14530943 0.52745885], L=182.982982982983, nx=1000000000
# Skipping invalid predicted key rate at index 914 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249775  0.16763523 0.7862991  0.14208242 0.5211951 ], L=183.1831831831832, nx=1000000000
# Skipping invalid predicted key rate at index 915 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42496923 0.16517763 0.790504   0.13885556 0.5149318 ], L=183.3833833833834, nx=1000000000
# Skipping invalid predicted key rate at index 916 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249609  0.16271996 0.7947089  0.13562857 0.50866824], L=183.5835835835836, nx=1000000000
# Skipping invalid predicted key rate at index 917 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42495263 0.16026233 0.7989138  0.1324016  0.5024048 ], L=183.7837837837838, nx=1000000000
# Skipping invalid predicted key rate at index 918 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42494434 0.15780464 0.8031189  0.1291746  0.4961412 ], L=183.983983983984, nx=1000000000
# Skipping invalid predicted key rate at index 919 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249361  0.1553471  0.8073235  0.12594767 0.4898779 ], L=184.1841841841842, nx=1000000000
# Skipping invalid predicted key rate at index 920 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42492774 0.15288928 0.8115286  0.12272064 0.48361412], L=184.3843843843844, nx=1000000000
# Skipping invalid predicted key rate at index 921 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42491943 0.15043166 0.8157335  0.11949372 0.47735065], L=184.5845845845846, nx=1000000000
# Skipping invalid predicted key rate at index 922 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4249111  0.1479741  0.81993806 0.1162669  0.4710874 ], L=184.7847847847848, nx=1000000000
# Skipping invalid predicted key rate at index 923 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42490286 0.14551644 0.8241432  0.11303992 0.46482387], L=184.984984984985, nx=1000000000
# Skipping invalid predicted key rate at index 924 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42489454 0.1430587  0.82834804 0.10981283 0.4585601 ], L=185.1851851851852, nx=1000000000
# Skipping invalid predicted key rate at index 925 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42488623 0.14060108 0.832553   0.10658603 0.45229682], L=185.3853853853854, nx=1000000000
# Skipping invalid predicted key rate at index 926 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42486134 0.13322811 0.8451678  0.096905   0.4335061 ], L=185.985985985986, nx=1000000000
# Skipping invalid predicted key rate at index 929 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42485303 0.13077042 0.84937274 0.09367801 0.42724255], L=186.1861861861862, nx=1000000000
# Skipping invalid predicted key rate at index 930 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248447 0.1283128 0.8535776 0.0904512 0.4209792], L=186.3863863863864, nx=1000000000
# Skipping invalid predicted key rate at index 931 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42483646 0.12585516 0.85778254 0.08722422 0.41471565], L=186.5865865865866, nx=1000000000
# Skipping invalid predicted key rate at index 932 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42482814 0.12339745 0.8619875  0.08399716 0.40845206], L=186.7867867867868, nx=1000000000
# Skipping invalid predicted key rate at index 933 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42481983 0.12093987 0.86619234 0.08077025 0.40218863], L=186.986986986987, nx=1000000000
# Skipping invalid predicted key rate at index 934 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248115  0.11848215 0.8703974  0.07754324 0.395925  ], L=187.1871871871872, nx=1000000000
# Skipping invalid predicted key rate at index 935 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4248032  0.11602443 0.87460226 0.07431623 0.38966134], L=187.3873873873874, nx=1000000000
# Skipping invalid predicted key rate at index 936 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42479494 0.11356685 0.8788072  0.0710893  0.38339794], L=187.5875875875876, nx=1000000000
# Skipping invalid predicted key rate at index 937 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42478657 0.11110919 0.8794155  0.0678624  0.37713453], L=187.7877877877878, nx=1000000000
# Skipping invalid predicted key rate at index 938 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42477828 0.10865156 0.8794155  0.06583714 0.37087104], L=187.987987987988, nx=1000000000
# Skipping invalid predicted key rate at index 939 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42477    0.10619384 0.8794155  0.06583714 0.36460736], L=188.1881881881882, nx=1000000000
# Skipping invalid predicted key rate at index 940 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42476165 0.10373626 0.8794155  0.06583714 0.3583441 ], L=188.3883883883884, nx=1000000000
# Skipping invalid predicted key rate at index 941 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247534  0.10127854 0.8794155  0.06583714 0.3520804 ], L=188.5885885885886, nx=1000000000
# Skipping invalid predicted key rate at index 942 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247451  0.09882088 0.8794155  0.06583714 0.34581697], L=188.7887887887888, nx=1000000000
# Skipping invalid predicted key rate at index 943 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42473683 0.09636326 0.8794155  0.06583714 0.33955342], L=188.988988988989, nx=1000000000
# Skipping invalid predicted key rate at index 944 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4247285  0.09390559 0.8794155  0.06583714 0.33328998], L=189.1891891891892, nx=1000000000
# Skipping invalid predicted key rate at index 945 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.42462733 0.09168331 0.8794155  0.06583714 0.32696563], L=189.3893893893894, nx=1000000000
# Skipping invalid predicted key rate at index 946 for n_X = 1000000000
# Objective returned non-positive key rate (-1e+250) for params [0.4243841  0.08986846 0.8794155  0.06583714 0.320587  ], L=189.5895895895896, nx=1000000000
# Skipping invalid predicted key rate at index 947 for n_X = 1000000000
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/4027905518.py:72: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Relative error plot saved to relative_error_nx_1e+09.png
# --- Plotting Time: 1.08 seconds ---
# --- Final Test Plotting Time (relative_error_nx_1e+09): 1.08 seconds ---

# %%
# Compute Mean Absolute Error (MAE) for parameters and key rates
mae_params = mean_absolute_error(optimized_params_array_un_seen, predicted_params_un_seen, multioutput='raw_values')
param_labels = ['$mu_1$', '$mu_2$', '$P_{mu_1}$', '$P_{mu_2}$', '$P_X$']
for label, mae in zip(param_labels, mae_params):
    print(f"MAE for {label}: {mae:.6f}")

# Compute MAE for key rates, handling NaN values
valid_mask = ~(np.isnan(optimized_key_rates_un_seen) | np.isnan(predicted_key_rates_un_seen))
if not np.any(valid_mask):
    print("Warning: All key rates are NaN. Cannot compute MAE for key rates.")
    mae_key_rates = float('nan')
else:
    mae_key_rates = mean_absolute_error(
        optimized_key_rates_un_seen[valid_mask],
        predicted_key_rates_un_seen[valid_mask]
    )
    print(f"Computed MAE for Key Rates using {np.sum(valid_mask)} valid data points.")
print(f"MAE for Key Rates: {mae_key_rates:.6f}")
# Out:
# MAE for $mu_1$: 0.001394
# MAE for $mu_2$: 0.001606
# MAE for $P_{mu_1}$: 0.006342
# MAE for $P_{mu_2}$: 0.007561
# MAE for $P_X$: 0.003187
# Computed MAE for Key Rates using 26 valid data points.
# MAE for Key Rates: 0.000001

# %%
def plot_relative_errors(fiber_lengths, optimized_key_rates, optimized_params_array, 
                        predicted_key_rates, predicted_params_array, epoch, filename, 
                        nx=None, threshold=1e-8):
    """
    Plots relative errors of predicted vs. optimized parameters and key rate for a specific n_X.
    
    Parameters:
    - fiber_lengths: Array of fiber lengths (km).
    - optimized_key_rates: Array of optimized key rates.
    - optimized_params_array: Array of optimized parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - predicted_key_rates: Array of predicted key rates.
    - predicted_params_array: Array of predicted parameters [mu_1, mu_2, P_mu_1, P_mu_2, P_X].
    - epoch: Epoch number or string (e.g., 'final_test').
    - filename: Output filename for the plot.
    - nx: The n_X value for the plot title (optional).
    - threshold: Key rate threshold for physical cutoff (default: 1e-8).
    """
    # Start timing
    plot_start_time = time.time()

    # Filter out NaN values
    valid_mask = ~(np.isnan(optimized_key_rates) | np.isnan(predicted_key_rates))
    fiber_lengths = fiber_lengths[valid_mask]
    optimized_key_rates = optimized_key_rates[valid_mask]
    predicted_key_rates = predicted_key_rates[valid_mask]
    optimized_params_array = optimized_params_array[valid_mask]
    predicted_params_array = predicted_params_array[valid_mask]

    # Find cutoff where optimized key rate becomes very small
    cutoff_idx = np.where(optimized_key_rates <= threshold)[0]
    if len(cutoff_idx) > 0:
        cutoff_idx = cutoff_idx[0]
    else:
        cutoff_idx = len(fiber_lengths)

    fiber_lengths = fiber_lengths[:cutoff_idx]
    optimized_key_rates = optimized_key_rates[:cutoff_idx]
    predicted_key_rates = predicted_key_rates[:cutoff_idx]
    optimized_params_array = optimized_params_array[:cutoff_idx]
    predicted_params_array = predicted_params_array[:cutoff_idx]

    # Compute relative errors
    # Parameters: mu_1, mu_2, P_mu_1, P_mu_2, P_X
    relative_errors = []
    param_labels = ['$\mu_1$', '$\mu_2$', '$P_{\mu_1}$', '$P_{\mu_2}$', '$P_X$']
    for i in range(5):
        optimized = optimized_params_array[:, i]
        predicted = predicted_params_array[:, i]
        # Avoid division by zero with a small threshold
        denominator = np.maximum(optimized, 1e-10)
        rel_error = (predicted - optimized) / denominator
        relative_errors.append(rel_error)
    
    # Key rate relative error
    denominator = np.maximum(optimized_key_rates, 1e-10)
    key_rate_rel_error = (predicted_key_rates - optimized_key_rates) / denominator

    # Create figure with 6 subplots (2 rows, 3 columns)
    fig = plt.figure(figsize=(18, 10))
    gs = fig.add_gridspec(2, 3, hspace=0.3, wspace=0.3)

    # Plot relative errors
    for i in range(5):
        row = i // 3
        col = i % 3
        ax = fig.add_subplot(gs[row, col])
        ax.plot(fiber_lengths, relative_errors[i], 'b-', label=f'Relative Error {param_labels[i]}')
        ax.set_xlabel('Fiber Length (km)')
        ax.set_ylabel('Relative Error')
        ax.set_title(f'Relative Error for {param_labels[i]}')
        ax.grid(True)
        ax.legend(loc='best')

    # Key rate subplot
    ax_key = fig.add_subplot(gs[1, 2])
    ax_key.plot(fiber_lengths, key_rate_rel_error, 'r-', label='Relative Error Key Rate')
    ax_key.set_xlabel('Fiber Length (km)')
    ax_key.set_ylabel('Relative Error')
    ax_key.set_title('Relative Error for Key Rate')
    ax_key.grid(True)
    ax_key.legend(loc='best')

    # Overall title
    exponent = int(np.log10(nx)) if nx is not None else ''
        # Example title update (adjust based on actual function structure)
    fig.suptitle(f"Relative Errors of Parameters for $n_X = 5 \\times 10^8$", fontsize=16)

    # Save and close
    plt.tight_layout(rect=[0, 0, 1, 0.95])
    plt.savefig(filename, dpi=300, bbox_inches='tight')
    plt.close(fig)
    print(f"Relative error plot saved to {filename}")

    # Print plotting time
    plot_time = time.time() - plot_start_time
    print(f"--- Plotting Time: {plot_time:.2f} seconds ---")

# %%
# Plot the comparison for n_X = 5e8
plot_start_time = time.time()
plot_keyrate_and_parameters(
    fiber_lengths_un_seen, optimized_key_rates_un_seen, optimized_params_array_un_seen,
    predicted_key_rates_un_seen, predicted_params_un_seen, epoch='final_test',
    filename='keyrate_parameters_5e8.png', learning_rates=learning_rates, nx=target_nx
)

print(f"--- Final Test Plotting Time (keyrate_and_parameters): {time.time() - plot_start_time:.2f} seconds ---")

# Plot relative errors for n_X = 5e8
plot_relative_errors(
    fiber_lengths_un_seen, optimized_key_rates_un_seen, optimized_params_array_un_seen,
    predicted_key_rates_un_seen, predicted_params_un_seen, epoch='final_test',
    filename=f'relative_error_nx_{target_nx:.0e}.png', nx=target_nx
)
# Out:
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/3333918397.py:89: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /var/folders/8m/0wg1hssn6n79tjc8mh6p_spr0000gn/T/ipykernel_29760/788938366.py:89: UserWarning: This figure includes Axes that are not compatible with tight_layout, so results might be incorrect.
#   plt.tight_layout(rect=[0, 0, 1, 0.95])
# Comparison plot saved to keyrate_parameters_5e8.png
# --- Final Test Plotting Time (keyrate_and_parameters): 0.82 seconds ---
# Relative error plot saved to relative_error_nx_5e+08.png
# --- Plotting Time: 1.14 seconds ---
