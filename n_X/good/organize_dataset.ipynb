# %%
import json

# Define the filenames
dataset1_file = "new/good/1_4_1000_reordered_qkd_grouped_dataset_20250226_165841.json"  # Replace with your actual filename
dataset2_file = "new/good/1_5_1000_reordered_qkd_grouped_dataset_20250226_140147.json"  # Replace with your actual filename
dataset3_file = "new/good/1_6_1000_reordered_qkd_grouped_dataset_20250226_135310.json"
dataset4_file = "new/good/1_7_1000_reordered_qkd_grouped_dataset_20250226_005552.json"
dataset5_file = "new/good/1_8_1000_reordered_qkd_grouped_dataset_20250225_183509.json"
dataset6_file = "new/good/1_9_1000_reordered_qkd_grouped_dataset_20250225_223422.json"

# Read and parse the JSON files
with open(dataset1_file, 'r') as f1:
    dataset1 = json.load(f1)  # Loads the JSON content into a Python dict

with open(dataset2_file, 'r') as f2:
    dataset2 = json.load(f2)  # Loads the JSON content into a Python dict

with open(dataset3_file, 'r') as f3:
    dataset3 = json.load(f3)  # Loads the JSON content into a Python dict

with open(dataset4_file, 'r') as f4:
    dataset4 = json.load(f4)  # Loads the JSON content into a Python dict

with open(dataset5_file, 'r') as f5:
    dataset5 = json.load(f5)  # Loads the JSON content into a Python dict

with open(dataset6_file, 'r') as f6:
    dataset6 = json.load(f6)  # Loads the JSON content into a Python dict

# Initialize combined dictionary
combined_data = {}

# Add datasets dynamically
combined_data.update(dataset1)  # Add "100000.0" key and its list
combined_data.update(dataset2)  # Add "1000000.0" key and its list
combined_data.update(dataset3)  # Add "1000000.0" key and its list
combined_data.update(dataset4)  # Add "1000000.0" key and its list
combined_data.update(dataset5)  # Add "1000000.0" key and its list
combined_data.update(dataset6)  # Add "1000000.0" key and its list

# To add more datasets later:
# with open("dataset3.json", 'r') as f3:
#     dataset3 = json.load(f3)
#     combined_data.update(dataset3)

# Save the combined result to a new file (optional)
with open("combined_datasets.json", 'w') as outfile:
    json.dump(combined_data, outfile, indent=2)

# Or print it
combined_json = json.dumps(combined_data, indent=2)
print(combined_json)
# Out:
# {
#   "10000.0": [
#     {
#       "fiber_length": 0.0,
#       "e_1": 0.0,
#       "e_2": 6.221848749616356,
#       "e_3": 0.5,
#       "e_4": 4.0,
#       "key_rate": 0.00037995895580899045,
#       "optimized_params": {
#         "mu_1": 0.6126301275287198,
#         "mu_2": 0.13818683663411718,
#         "P_mu_1": 0.04604299826386499,
#         "P_mu_2": 0.6110117432731096,
#         "P_X_value": 0.414731486913827
#       }
#     },
#     {
#       "fiber_length": 0.2002002002002002,
#       "e_1": 0.002002002002002002,
#       "e_2": 6.221848749616356,
#       "e_3": 0.5,
#       "e_4": 4.0,
#       "key_rate": 0.00037630144621220586,
#       "optimized_params": {
#         "mu_1": 0.6123490836545931,
#         "mu_2": 0.13812714947830815,
#         "P_mu_1": 0.04603533966339164,
#         "P_mu_2": 0.611003627460577,
#         "P_X_value": 0.4147254673698554
#       }
#     },
#     {
#       "fiber_length": 0.4004004004004004,
#       "e_1": 0.004004004004004004,
# ...
